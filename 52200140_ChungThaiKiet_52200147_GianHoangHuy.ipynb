# %% [markdown]
# # Kiểm tra readme trước

# %% [markdown]
# # Thuật toán 1: SKYFUP

# %%
import sys, os
import time
import tracemalloc

# %% [markdown]
# ## Cài đặt cấu trúc dữ liệu

# %% [markdown]
# ### Cài đặt UP-Lists

# %%
class Up:
    """
    Đối tượng lưu trữ các thông tin của i ứng với giao dịch (TID, xác xuất, tiện ích, tiện ích còn lại, tiện ích giao dịch)
    """
    def __init__(self, TID, prob, util, r_utility, trans_util):
        """
        Khởi tạo UP

        Args:
            TID (int): mã giao dịch
            prob (float): xác xuất
            util (int): giá trị tiện ích
            r_utility (int): tiện ích còn lại
            trans_util (int): tiện ích giao dịch
        """
        self.TID = TID
        self.prob = round(prob, 2)
        self.util = util
        self.r_utility = r_utility
        self.trans_util = trans_util

    def combine_with(self, other_up):
        """
        Kết hợp 2 Up với nhau

        Args:
            other_up (Up): Up cần kết hợp

        Returns:
            Up: một Up mới
        """
        combined_prob = round(self.prob * other_up.prob, 2)
        combined_util = self.util + other_up.util
        return Up(self.TID, combined_prob, combined_util, other_up.r_utility, other_up.trans_util)

    def __repr__(self):
        return f"Up(TID={self.TID}, prob={self.prob}, util={self.util}, r_utility={self.r_utility}, trans_util={self.trans_util})\n"

# %% [markdown]
# ### Cài đặt IMCUP-Lists

# %%
class IMCUP:
    """
    Đối tượng lưu trữ các thông tin của một item bao gồm: tên, độ hỗ trợ mong đợi, danh sách Up,
        giá trị xác xuất lớn nhất trong Up, TWU, giá trị tiện ích, phần tử cuối của item
    """
    def __init__(self, name, up_list=None):
        """
        Khởi tạo IMCUP

        Args:
            name (str): tên của IMCUP hay tên của item
            up_list (List[Up], None): danh sách Up của item
        """
        self.name = name
        self.exp_sup = round(sum(up.prob for up in up_list), 2) if up_list else 0
        self.up_list = up_list if up_list else []
        self.max_prob = round(max(up.prob for up in up_list), 2) if up_list else 0
        self.trans_wei_util = sum(up.trans_util for up in up_list) if up_list else 0
        self.utility = sum(up.util for up in up_list) if up_list else 0
        self.r_utility = sum(up.r_utility for up in up_list) if up_list else 0
        self.last = []

    def update(self, probability: float, TID, trans_util, r_utility, util_value) -> None:
        """
        Cập nhật lại các giá trị trong IMCUP

        Args:
            probability (float): xác xuất tồn tại
            TID (_type_): mã giao dịch
            trans_util (_type_): tiện ích giao dịch
            r_utility (_type_): tiện ích còn lại
            util_value (_type_): giá trị tiện ích
        """
        probability = round(probability, 2)  
        up = Up(TID, probability, util_value, r_utility, trans_util)
        self.exp_sup = round(self.exp_sup + probability, 2) 
        self.utility += util_value
        self.r_utility += r_utility
        self.up_list.append(up)
        self.max_prob = max(self.max_prob, probability)
        self.trans_wei_util += trans_util

    def combine_up(self, up_list_x, tep_list_y):
        """
        Kết hợp hai danh sách Up

        Args:
            up_list_x (List[Up]): danh sách Up của item X
            tep_list_y (List[Up]): danh sách Up của item Y

        Returns:
            List[Up]: danh sách Up của item XY
        """
        up_list_xy = []
        i, j = 0, 0
        while i < len(up_list_x) and j < len(tep_list_y):
            tX = up_list_x[i]
            tY = tep_list_y[j]
            if tX.TID < tY.TID:
                i += 1
            elif tX.TID > tY.TID:
                j += 1
            else:
                combined_prob = round(tX.prob * tY.prob, 2)
                combined_util = tX.util + tY.util
                up_list_xy.append(Up(tX.TID, combined_prob, combined_util, tY.r_utility, tX.trans_util))
                i += 1
                j += 1
        return up_list_xy

    def combine_with(self, other_up):
        """
        Kết hợp hai IMCUP lại với nhau

        Args:
            other_up (IMCUP): IMCUP tham gia kết hợp

        Returns:
            IMCUP: một IMCUP mới
        """
        if len(other_up.last) == 0:
            combined_name = self.name + ', ' + other_up.name
            combined_tep_list = self.combine_up(self.up_list, other_up.up_list)
            last = [other_up]
        else:
            combined_name = self.name + ', ' + other_up.last[0].name
            combined_tep_list = self.combine_up(self.up_list, other_up.last[0].up_list)
            last = other_up.last

        combined_cup = IMCUP(combined_name, combined_tep_list)
        combined_cup.last = last
        return combined_cup

    def __repr__(self) -> str:
        return f"IMCUP(name={self.name}, exp_sup={self.exp_sup}, r_utility={self.r_utility}, utility={self.utility})"

# %% [markdown]
# ## Cài đặt thuật toán

# %%
class AlgorithmTUHUFP:
    """
    Triển khai thuật toán khai thác top-k mẫu phổ biến tiện ích cao không chắc chắn
    """
    def __init__(self):
        self.start_timestamp = 0
        self.end_timestamp = 0
        self.database_size = 0
        self.database_util = 0
        self.candidates = 0
        self.top_UHUFP = []
        self.single_imcup = {}
        self.threshold = float('-inf')
        self.min_util = float('-inf')
        self.peak_memory_usage = 0

    def read_data(self, file_path, percentage, k) -> None:
        """
        Đọc cơ sỡ dữ liệu từ file và xử lý dữ liệu

        Args:
            file_path (str): đường dẫn chứa file cơ sở dữ liệu
            percentage (float): ngưỡng tiện ích (%)
            k (int): số lượng mẫu cần tìm
        """

        file_paths = file_path.split(", ")
 
        try:
            with open(file_paths[0], 'r') as file1, open(file_paths[1], 'r') as file2:
                print("Reading data . . .")
                tlines = file1.readlines()
                ulines = file2.readlines()
                i_name = tlines[0].strip().split(" ")

                TID = 1
                # xử lý từng giao dịch
                for prob_line, util_line in zip(tlines[1:], ulines):
                    self.process_data(i_name, prob_line.strip(), util_line.strip(), TID)
                    TID += 1
                    self.database_size += 1

                self.min_util = int(self.database_util * percentage)
                print(f"Minimum utility set to: {self.min_util}")
        except FileNotFoundError as e:
            print(f"File not found: {e}")
            print("STOP ALGORITHM !!!")
            sys.exit(0)
        except Exception as e:
            print(f"An error occurred: {e}")
            sys.exit(0)

            
    def process_data(self, i_name, prob_line, util_line, TID) -> None:
        """
        Xử lý từng giao dịch và tạo IMCUP

        Args:
            i_name (List[str]): danh sách các item
            prob_line (float): danh sách các xác xuất của item
            util_line (int): danh sách tiện ích của item
            TID (int): mã giao dịch
        """

        prob_list = prob_line.split(" ")
        trans = util_line.split(":")
        item_util = trans[0].split(" ") # Danh sách các mục (items)
        trans_util = int(trans[1]) # Tổng lợi ích của giao dịch (transaction utility)
        util_list = trans[2].split(" ") # Danh sách lợi ích từng mục trong giao dịch

        i_util_list = {i: int(util) for i, util in zip(item_util, util_list)}

        self.database_util += trans_util

        for i, prob in enumerate(prob_list):
            prob = prob.strip()
    
            # Chỉ xử lý nếu giá trị xác suất tồn tại và lớn hơn 0
            if prob and float(prob) > 0:
                try:
                    # Lấy tên mục (item name) từ chỉ mục (index)
                    i = i_name[i]
                    probability = round(float(prob), 2)  # Round to 2 decimal places
                   
                   # Lấy giá trị lợi ích của mục hiện tại
                    util_value = i_util_list[i]
                    imcup_name = i
                    
                    # Xác định vị trí của mục trong danh sách các keys
                    keys = list(i_util_list.keys()) 
                    index = keys.index(imcup_name) 

                    # Tính tổng lợi ích của các mục sau mục hiện tại
                    r = sum(i_util_list[k] for k in keys[index + 1:])

                    #kiểm tra imcup đã được tạo hay chưa
                    if imcup_name in self.single_imcup:
                        self.single_imcup[imcup_name].update(probability, TID, trans_util, r, util_value)
                    else:
                        new_up = Up(TID, probability, util_value, r, trans_util)
                        self.single_imcup[imcup_name] = IMCUP(imcup_name, [new_up])
                except ValueError as ve:
                    print(f"Error processing probability '{prob}': {ve}")
                    continue



    def combine_cup(self, upX, upY):
        """
        Kết hơp hai Up X và Y

        Args:
            upX (Up): Up tham gia kết hợp
            upY (Up): Up tham gia kết hợp

        Returns:
           Up: UpXY
        """
        combined_cup = upX.combine_with(upY)
        combined_cup.exp_sup = round(combined_cup.exp_sup, 2) 
        return combined_cup
    
    

    def check(self, combined, k):
        """
        Kiểm tra mẫu có phải là mẫu tiện ích cao

        Args:
            combined (Up): mẫu cần kiểm tra
           TUHUFP k (int): số lượng mẫu cần tìm
        """

        # kiểm tra và thêm vào top k nếu thỏa điều kiện utility > min_util
        if combined.utility >= self.min_util:
            self.top_UHUFP.append({'name': combined.name, 'exp_sup': combined.exp_sup, 'utility': combined.utility})
            self.top_UHUFP.sort(key=lambda x: x['exp_sup'], reverse=True)
            if len(self.top_UHUFP) > k:
                self.top_UHUFP.pop()
                self.threshold = self.top_UHUFP[-1]['exp_sup']
            # cập nhật lại threshold khi top_UHUFP đã đủ k mẫu
            if len(self.top_UHUFP) == k:
                self.threshold = self.top_UHUFP[-1]['exp_sup']


    def Search(self, currentUp, k):
        """
        Khai thác mẫu từ danh sách ứng viên

        Args:
            currentUp (List[Up]): danh sách ứng viên tham gia
            k (int): số lượng mẫu cần tìm
        """
        if len(currentUp) <= 1:
            # dừng thuật toán khi không còn ứng viên tham gia
            return
        # duyệt từng ứng viên
        for i in range(len(currentUp) - 1):
            # kiểm tra điều kiện tiện ích
            if currentUp[i].utility + currentUp[i].r_utility > self.min_util:
                newCupList = []
                for j in range(i + 1, len(currentUp)):
                    overestimate = currentUp[i].exp_sup * currentUp[j].max_prob
                    if currentUp[j].exp_sup < self.threshold or overestimate < self.threshold:
                        break
                    combined = self.combine_cup(currentUp[i], currentUp[j])
                    # kiểm tra và thêm vào top k nếu thỏa điều kiện
                    if combined.exp_sup > self.threshold and combined.trans_wei_util > self.min_util:
                        self.check(combined, k)
                        # thêm các ứng viên mới
                        if combined.trans_wei_util >= self.min_util:
                            newCupList.append(combined)
                            self.candidates += 1
                # tìm kiếm với danh sách ứng viên mới
                self.Search(newCupList, k)

    def create_candidate(self, min_util, k):
        """
        Tìm top k đầu tiên và các ứng viên

        Args:
            min_util (int): ngưỡng tiện ích
            k (int): số lượng mẫu cần tìm

        Returns:
            List[Up]: danh sách các ứng viên
        """
        candidate_list = []
        imcup = sorted(self.single_imcup.values(), key=lambda x: x.exp_sup, reverse=True)
        # lấy k Up đầu tiên có giá trị expSup lớn nhất
        for up in imcup[:k]:
            if up.trans_wei_util >= min_util:
                candidate_list.append(up)
            if up.utility >= min_util:
                self.top_UHUFP.append({'name': up.name, 'exp_sup': up.exp_sup, 'utility': up.utility})
        return candidate_list


    def run(self, file_path, percentage, k):
        """
        Khởi chạy thuật toán

        Args:
            file_path (str): đường dẫn tới file cơ sở dữ liệu
            percentage (_type_): ngưỡng tiện ích (%)
            k (int): số lượng mẫu cần tìm
        """

        self.start_timestamp = time.time()
        self.candidates = 0
        self.database_size = 0

        # đọc dữ liệu từ file
        self.read_data(file_path, percentage, k)
        print({'database util: ': self.database_util})

        # danh sách ứng viên
        candidate_list = self.create_candidate(self.min_util, k)
        if not self.single_imcup:
            print("No Up List was created. STOP ALGORITHM !!!")
            sys.exit(0)
        self.candidates = len(candidate_list)

        # đặt threhold
        if len(self.top_UHUFP) == k:
            self.threshold = self.top_UHUFP[-1]['exp_sup']

        # Bắt đầu theo dõi bộ nhớ
        tracemalloc.start()
        # bắt đầu tìm kiếm
        self.Search(candidate_list, k)
        print(f"Top {k} CUPs:")
        i = 1
        for Up in self.top_UHUFP[:]:
            print(f" {i}: {Up}")
            i +=1
        # Kết thúc theo dõi bộ nhớ và lấy thông tin
        _, self.peak_memory_usage = tracemalloc.get_traced_memory()
        tracemalloc.stop()
        self.peak_memory_usage /= 10**6  # Chuyển đổi sang MB

        self.end_timestamp = time.time()

    def print_stats(self, path):
        """
        Thống kê thông tin kết quả chạy thuật toán

        Args:
            path (str): đường dẫn lưu thông tin
        """        

        total_utility = 0
        directory = os.path.dirname(path)
        if directory and not os.path.exists(directory):
            os.makedirs(directory)

        with open(path, 'w') as output_file:
            output_file.write(f"minUtil: {self.min_util}\n")
            self.top_UHUFP.sort(key=lambda x: x['utility'], reverse=True)
            for t in self.top_UHUFP:
                total_utility += t['utility']
                output_file.write(f"{t['name']}: {t['exp_sup']}: {t['utility']}\n")
            output_file.write("=============  TOP-K UFPs v1.20 - STATS =============\n")
            output_file.write(f" Transactions count from database : {self.database_size}\n")
            output_file.write(f" Candidates count : {self.candidates}\n")
            output_file.write(f" Sum utility : {total_utility}\n")
            output_file.write(f" Algorithm run time : {self.end_timestamp - self.start_timestamp:.0f} seconds\n")
            output_file.write(f" Peak memory usage : {self.peak_memory_usage:.2f} MB\n")  # Ghi lại peak memory usage

# %%
# a b c d e
# 0.6 0 0.8 0.5 0
# 0 0.7 0.4 0 0
# 0.6 0.6 0.9 0.8 0
# 0 0.5 0 0.8 0
# 0.9 0.7 0.9 0.6 0.8
# 0 0 0.9 0 0.8
# 0 0 0.4 0.9 0
# 0.6 0.8 0 0.8 0.5
# 0.6 0 0.5 0.3 0
# 0 0 0.6 0 0.7


# a d c:65:14 7 44
# b c:37:4 33
# a b d c:38:21 4 2 11
# b d:11:8 3
# e a b d c:49:9 7 6 5 22 
# e c:58:36 22
# d c:23:1 22
# e a b d:61:36 21 2 2
# a d c:59:14 1 44
# e c:42:9 33

# %%
# chạy với retail
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/example.txt, ./data/example_utility.txt", 0.3, 6)
algorithm.print_stats("./out/TUHUFP/output_example.txt")
# Out:
# Reading data . . .
# Minimum utility set to: 30
# {'database util: ': 102}
# Top 6 CUPs:
#  1: {'name': 'd', 'exp_sup': 3.3, 'utility': 30}
#  2: {'name': 'c, d', 'exp_sup': 1.95, 'utility': 38}
#  3: {'name': 'd, a', 'exp_sup': 1.2, 'utility': 35}
#  4: {'name': 'c, d, a', 'exp_sup': 0.98, 'utility': 42}
#  5: {'name': 'c, d, b', 'exp_sup': 0.88, 'utility': 40}
#  6: {'name': 'd, a, b', 'exp_sup': 0.55, 'utility': 33}

# %% [markdown]
# ## Hiện thức foodmart

# %%
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_foodmart.txt, ./data/foodmart_utility.txt", 0.0004, 100)
algorithm.print_stats("./out/TUHUFP/foodmart/output_foodmart_top_100.txt")
# Out:
# Reading data . . .
# Minimum utility set to: 4804
# {'database util: ': 12011023}
# Top 100 CUPs:
#  1: {'name': '304', 'exp_sup': 14.23, 'utility': 13607}
#  2: {'name': '1373', 'exp_sup': 13.55, 'utility': 25560}
#  3: {'name': '272', 'exp_sup': 13.54, 'utility': 22678}
#  4: {'name': '1293', 'exp_sup': 12.66, 'utility': 8352}
#  5: {'name': '1292', 'exp_sup': 12.6, 'utility': 24642}
#  6: {'name': '545', 'exp_sup': 12.1, 'utility': 9419}
#  7: {'name': '357', 'exp_sup': 11.97, 'utility': 11520}
#  8: {'name': '634', 'exp_sup': 11.88, 'utility': 11881}
#  9: {'name': '617', 'exp_sup': 11.75, 'utility': 7527}
#  10: {'name': '1423', 'exp_sup': 11.75, 'utility': 16116}
#  11: {'name': '916', 'exp_sup': 11.68, 'utility': 15163}
#  12: {'name': '1012', 'exp_sup': 11.65, 'utility': 19861}
#  13: {'name': '903', 'exp_sup': 11.62, 'utility': 14616}
#  14: {'name': '831', 'exp_sup': 11.39, 'utility': 8848}
#  15: {'name': '888', 'exp_sup': 11.38, 'utility': 5280}
#  16: {'name': '918', 'exp_sup': 11.38, 'utility': 18414}
#  17: {'name': '1390', 'exp_sup': 11.26, 'utility': 12415}
#  18: {'name': '404', 'exp_sup': 11.02, 'utility': 7000}
#  19: {'name': '308', 'exp_sup': 10.94, 'utility': 11554}
#  20: {'name': '1351', 'exp_sup': 10.9, 'utility': 9352}
#  21: {'name': '1451', 'exp_sup': 10.9, 'utility': 7614}
#  22: {'name': '1315', 'exp_sup': 10.88, 'utility': 9612}
#  23: {'name': '599', 'exp_sup': 10.79, 'utility': 12519}
#  24: {'name': '932', 'exp_sup': 10.78, 'utility': 8262}
#  25: {'name': '1161', 'exp_sup': 10.54, 'utility': 21540}
#  26: {'name': '276', 'exp_sup': 10.37, 'utility': 18528}
#  27: {'name': '718', 'exp_sup': 10.36, 'utility': 9741}
#  28: {'name': '520', 'exp_sup': 10.36, 'utility': 14840}
#  29: {'name': '386', 'exp_sup': 10.29, 'utility': 10927}
#  30: {'name': '1362', 'exp_sup': 10.29, 'utility': 8046}
#  31: {'name': '1439', 'exp_sup': 10.25, 'utility': 8400}
#  32: {'name': '447', 'exp_sup': 10.23, 'utility': 17856}
#  33: {'name': '1220', 'exp_sup': 10.18, 'utility': 11700}
#  34: {'name': '1508', 'exp_sup': 10.16, 'utility': 19116}
#  35: {'name': '1399', 'exp_sup': 10.11, 'utility': 10324}
#  36: {'name': '1110', 'exp_sup': 10.1, 'utility': 17920}
#  37: {'name': '378', 'exp_sup': 10.08, 'utility': 5994}
#  38: {'name': '69', 'exp_sup': 10.07, 'utility': 16430}
#  39: {'name': '1282', 'exp_sup': 10.05, 'utility': 18232}
#  40: {'name': '749', 'exp_sup': 10.03, 'utility': 11748}
#  41: {'name': '602', 'exp_sup': 10.0, 'utility': 13696}
#  42: {'name': '1442', 'exp_sup': 9.99, 'utility': 10332}
#  43: {'name': '1426', 'exp_sup': 9.96, 'utility': 21692}
#  44: {'name': '391', 'exp_sup': 9.95, 'utility': 8777}
#  45: {'name': '501', 'exp_sup': 9.87, 'utility': 6227}
#  46: {'name': '307', 'exp_sup': 9.83, 'utility': 7400}
#  47: {'name': '1456', 'exp_sup': 9.82, 'utility': 8784}
#  48: {'name': '200', 'exp_sup': 9.8, 'utility': 12190}
#  49: {'name': '326', 'exp_sup': 9.77, 'utility': 13091}
#  50: {'name': '1347', 'exp_sup': 9.71, 'utility': 9912}
#  51: {'name': '1224', 'exp_sup': 9.67, 'utility': 6944}
#  52: {'name': '1291', 'exp_sup': 9.65, 'utility': 12642}
#  53: {'name': '73', 'exp_sup': 9.65, 'utility': 11184}
#  54: {'name': '1487', 'exp_sup': 9.64, 'utility': 5320}
#  55: {'name': '246', 'exp_sup': 9.63, 'utility': 17655}
#  56: {'name': '1257', 'exp_sup': 9.62, 'utility': 9505}
#  57: {'name': '311', 'exp_sup': 9.57, 'utility': 8600}
#  58: {'name': '247', 'exp_sup': 9.52, 'utility': 9256}
#  59: {'name': '54', 'exp_sup': 9.51, 'utility': 12889}
#  60: {'name': '1118', 'exp_sup': 9.5, 'utility': 13178}
#  61: {'name': '1045', 'exp_sup': 9.48, 'utility': 21090}
#  62: {'name': '27', 'exp_sup': 9.44, 'utility': 16165}
#  63: {'name': '1464', 'exp_sup': 9.44, 'utility': 14800}
#  64: {'name': '1048', 'exp_sup': 9.43, 'utility': 11713}
#  65: {'name': '812', 'exp_sup': 9.41, 'utility': 14696}
#  66: {'name': '1473', 'exp_sup': 9.4, 'utility': 13452}
#  67: {'name': '640', 'exp_sup': 9.36, 'utility': 13209}
#  68: {'name': '1264', 'exp_sup': 9.35, 'utility': 11985}
#  69: {'name': '222', 'exp_sup': 9.33, 'utility': 22910}
#  70: {'name': '969', 'exp_sup': 9.33, 'utility': 7920}
#  71: {'name': '278', 'exp_sup': 9.33, 'utility': 18480}
#  72: {'name': '434', 'exp_sup': 9.33, 'utility': 7384}
#  73: {'name': '988', 'exp_sup': 9.3, 'utility': 24187}
#  74: {'name': '266', 'exp_sup': 9.29, 'utility': 10692}
#  75: {'name': '419', 'exp_sup': 9.29, 'utility': 14994}
#  76: {'name': '219', 'exp_sup': 9.27, 'utility': 11844}
#  77: {'name': '382', 'exp_sup': 9.27, 'utility': 9072}
#  78: {'name': '435', 'exp_sup': 9.24, 'utility': 14433}
#  79: {'name': '1516', 'exp_sup': 9.22, 'utility': 15792}
#  80: {'name': '1217', 'exp_sup': 9.21, 'utility': 7239}
#  81: {'name': '890', 'exp_sup': 9.18, 'utility': 12789}
#  82: {'name': '1308', 'exp_sup': 9.18, 'utility': 12642}
#  83: {'name': '728', 'exp_sup': 9.17, 'utility': 11528}
#  84: {'name': '175', 'exp_sup': 9.14, 'utility': 19635}
#  85: {'name': '449', 'exp_sup': 9.12, 'utility': 15867}
#  86: {'name': '1357', 'exp_sup': 9.1, 'utility': 11653}
#  87: {'name': '1399, 1426', 'exp_sup': 0.86, 'utility': 5680}

# %%
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_foodmart.txt, ./data/foodmart_utility.txt", 0.0004, 300)
algorithm.print_stats("./out/TUHUFP/foodmart/output_foodmart_top_300.txt")
# Out:
# Reading data . . .
# Minimum utility set to: 4804
# {'database util: ': 12011023}
# Top 300 CUPs:
#  1: {'name': '304', 'exp_sup': 14.23, 'utility': 13607}
#  2: {'name': '1373', 'exp_sup': 13.55, 'utility': 25560}
#  3: {'name': '272', 'exp_sup': 13.54, 'utility': 22678}
#  4: {'name': '1293', 'exp_sup': 12.66, 'utility': 8352}
#  5: {'name': '1292', 'exp_sup': 12.6, 'utility': 24642}
#  6: {'name': '545', 'exp_sup': 12.1, 'utility': 9419}
#  7: {'name': '357', 'exp_sup': 11.97, 'utility': 11520}
#  8: {'name': '634', 'exp_sup': 11.88, 'utility': 11881}
#  9: {'name': '617', 'exp_sup': 11.75, 'utility': 7527}
#  10: {'name': '1423', 'exp_sup': 11.75, 'utility': 16116}
#  11: {'name': '916', 'exp_sup': 11.68, 'utility': 15163}
#  12: {'name': '1012', 'exp_sup': 11.65, 'utility': 19861}
#  13: {'name': '903', 'exp_sup': 11.62, 'utility': 14616}
#  14: {'name': '831', 'exp_sup': 11.39, 'utility': 8848}
#  15: {'name': '888', 'exp_sup': 11.38, 'utility': 5280}
#  16: {'name': '918', 'exp_sup': 11.38, 'utility': 18414}
#  17: {'name': '1390', 'exp_sup': 11.26, 'utility': 12415}
#  18: {'name': '404', 'exp_sup': 11.02, 'utility': 7000}
#  19: {'name': '308', 'exp_sup': 10.94, 'utility': 11554}
#  20: {'name': '1351', 'exp_sup': 10.9, 'utility': 9352}
#  21: {'name': '1451', 'exp_sup': 10.9, 'utility': 7614}
#  22: {'name': '1315', 'exp_sup': 10.88, 'utility': 9612}
#  23: {'name': '599', 'exp_sup': 10.79, 'utility': 12519}
#  24: {'name': '932', 'exp_sup': 10.78, 'utility': 8262}
#  25: {'name': '1161', 'exp_sup': 10.54, 'utility': 21540}
#  26: {'name': '276', 'exp_sup': 10.37, 'utility': 18528}
#  27: {'name': '718', 'exp_sup': 10.36, 'utility': 9741}
#  28: {'name': '520', 'exp_sup': 10.36, 'utility': 14840}
#  29: {'name': '386', 'exp_sup': 10.29, 'utility': 10927}
#  30: {'name': '1362', 'exp_sup': 10.29, 'utility': 8046}
#  31: {'name': '1439', 'exp_sup': 10.25, 'utility': 8400}
#  32: {'name': '447', 'exp_sup': 10.23, 'utility': 17856}
#  33: {'name': '1220', 'exp_sup': 10.18, 'utility': 11700}
#  34: {'name': '1508', 'exp_sup': 10.16, 'utility': 19116}
#  35: {'name': '1399', 'exp_sup': 10.11, 'utility': 10324}
#  36: {'name': '1110', 'exp_sup': 10.1, 'utility': 17920}
#  37: {'name': '378', 'exp_sup': 10.08, 'utility': 5994}
#  38: {'name': '69', 'exp_sup': 10.07, 'utility': 16430}
#  39: {'name': '1282', 'exp_sup': 10.05, 'utility': 18232}
#  40: {'name': '749', 'exp_sup': 10.03, 'utility': 11748}
#  41: {'name': '602', 'exp_sup': 10.0, 'utility': 13696}
#  42: {'name': '1442', 'exp_sup': 9.99, 'utility': 10332}
#  43: {'name': '1426', 'exp_sup': 9.96, 'utility': 21692}
#  44: {'name': '391', 'exp_sup': 9.95, 'utility': 8777}
#  45: {'name': '501', 'exp_sup': 9.87, 'utility': 6227}
#  46: {'name': '307', 'exp_sup': 9.83, 'utility': 7400}
#  47: {'name': '1456', 'exp_sup': 9.82, 'utility': 8784}
#  48: {'name': '200', 'exp_sup': 9.8, 'utility': 12190}
#  49: {'name': '326', 'exp_sup': 9.77, 'utility': 13091}
#  50: {'name': '1347', 'exp_sup': 9.71, 'utility': 9912}
#  51: {'name': '1224', 'exp_sup': 9.67, 'utility': 6944}
#  52: {'name': '1291', 'exp_sup': 9.65, 'utility': 12642}
#  53: {'name': '73', 'exp_sup': 9.65, 'utility': 11184}
#  54: {'name': '1487', 'exp_sup': 9.64, 'utility': 5320}
#  55: {'name': '246', 'exp_sup': 9.63, 'utility': 17655}
#  56: {'name': '1257', 'exp_sup': 9.62, 'utility': 9505}
#  57: {'name': '311', 'exp_sup': 9.57, 'utility': 8600}
#  58: {'name': '247', 'exp_sup': 9.52, 'utility': 9256}
#  59: {'name': '54', 'exp_sup': 9.51, 'utility': 12889}
#  60: {'name': '1118', 'exp_sup': 9.5, 'utility': 13178}
#  61: {'name': '1045', 'exp_sup': 9.48, 'utility': 21090}
#  62: {'name': '27', 'exp_sup': 9.44, 'utility': 16165}
#  63: {'name': '1464', 'exp_sup': 9.44, 'utility': 14800}
#  64: {'name': '1048', 'exp_sup': 9.43, 'utility': 11713}
#  65: {'name': '812', 'exp_sup': 9.41, 'utility': 14696}
#  66: {'name': '1473', 'exp_sup': 9.4, 'utility': 13452}
#  67: {'name': '640', 'exp_sup': 9.36, 'utility': 13209}
#  68: {'name': '1264', 'exp_sup': 9.35, 'utility': 11985}
#  69: {'name': '222', 'exp_sup': 9.33, 'utility': 22910}
#  70: {'name': '969', 'exp_sup': 9.33, 'utility': 7920}
#  71: {'name': '278', 'exp_sup': 9.33, 'utility': 18480}
#  72: {'name': '434', 'exp_sup': 9.33, 'utility': 7384}
#  73: {'name': '988', 'exp_sup': 9.3, 'utility': 24187}
#  74: {'name': '266', 'exp_sup': 9.29, 'utility': 10692}
#  75: {'name': '419', 'exp_sup': 9.29, 'utility': 14994}
#  76: {'name': '219', 'exp_sup': 9.27, 'utility': 11844}
#  77: {'name': '382', 'exp_sup': 9.27, 'utility': 9072}
#  78: {'name': '435', 'exp_sup': 9.24, 'utility': 14433}
#  79: {'name': '1516', 'exp_sup': 9.22, 'utility': 15792}
#  80: {'name': '1217', 'exp_sup': 9.21, 'utility': 7239}
#  81: {'name': '890', 'exp_sup': 9.18, 'utility': 12789}
#  82: {'name': '1308', 'exp_sup': 9.18, 'utility': 12642}
#  83: {'name': '728', 'exp_sup': 9.17, 'utility': 11528}
#  84: {'name': '175', 'exp_sup': 9.14, 'utility': 19635}
#  85: {'name': '449', 'exp_sup': 9.12, 'utility': 15867}
#  86: {'name': '1357', 'exp_sup': 9.1, 'utility': 11653}
#  87: {'name': '1281', 'exp_sup': 9.1, 'utility': 13573}
#  88: {'name': '813', 'exp_sup': 9.09, 'utility': 7967}
#  89: {'name': '566', 'exp_sup': 9.05, 'utility': 7120}
#  90: {'name': '604', 'exp_sup': 9.04, 'utility': 6250}
#  91: {'name': '1394', 'exp_sup': 9.01, 'utility': 10870}
#  92: {'name': '1547', 'exp_sup': 9.0, 'utility': 12614}
#  93: {'name': '1338', 'exp_sup': 8.99, 'utility': 10656}
#  94: {'name': '281', 'exp_sup': 8.97, 'utility': 14465}
#  95: {'name': '470', 'exp_sup': 8.96, 'utility': 18259}
#  96: {'name': '941', 'exp_sup': 8.96, 'utility': 18565}
#  97: {'name': '1104', 'exp_sup': 8.96, 'utility': 13965}
#  98: {'name': '383', 'exp_sup': 8.89, 'utility': 14300}
#  99: {'name': '685', 'exp_sup': 8.87, 'utility': 9333}
#  100: {'name': '1119', 'exp_sup': 8.86, 'utility': 13314}
#  101: {'name': '1472', 'exp_sup': 8.86, 'utility': 12760}
#  102: {'name': '111', 'exp_sup': 8.85, 'utility': 17052}
#  103: {'name': '380', 'exp_sup': 8.84, 'utility': 4880}
#  104: {'name': '1348', 'exp_sup': 8.83, 'utility': 14326}
#  105: {'name': '1306', 'exp_sup': 8.83, 'utility': 10127}
#  106: {'name': '584', 'exp_sup': 8.8, 'utility': 12173}
#  107: {'name': '1432', 'exp_sup': 8.77, 'utility': 9180}
#  108: {'name': '1444', 'exp_sup': 8.77, 'utility': 10384}
#  109: {'name': '1397', 'exp_sup': 8.76, 'utility': 5577}
#  110: {'name': '231', 'exp_sup': 8.75, 'utility': 14575}
#  111: {'name': '863', 'exp_sup': 8.74, 'utility': 14006}
#  112: {'name': '1526', 'exp_sup': 8.73, 'utility': 8085}
#  113: {'name': '422', 'exp_sup': 8.73, 'utility': 17616}
#  114: {'name': '236', 'exp_sup': 8.72, 'utility': 9412}
#  115: {'name': '55', 'exp_sup': 8.72, 'utility': 15750}
#  116: {'name': '497', 'exp_sup': 8.66, 'utility': 10472}
#  117: {'name': '606', 'exp_sup': 8.66, 'utility': 12720}
#  118: {'name': '1268', 'exp_sup': 8.66, 'utility': 7150}
#  119: {'name': '1043', 'exp_sup': 8.65, 'utility': 6908}
#  120: {'name': '1470', 'exp_sup': 8.64, 'utility': 11327}
#  121: {'name': '1210', 'exp_sup': 8.63, 'utility': 9681}
#  122: {'name': '883', 'exp_sup': 8.63, 'utility': 13041}
#  123: {'name': '1522', 'exp_sup': 8.62, 'utility': 6147}
#  124: {'name': '1384', 'exp_sup': 8.61, 'utility': 12593}
#  125: {'name': '1296', 'exp_sup': 8.6, 'utility': 14548}
#  126: {'name': '626', 'exp_sup': 8.6, 'utility': 4902}
#  127: {'name': '389', 'exp_sup': 8.59, 'utility': 8771}
#  128: {'name': '1098', 'exp_sup': 8.58, 'utility': 6255}
#  129: {'name': '946', 'exp_sup': 8.55, 'utility': 13965}
#  130: {'name': '943', 'exp_sup': 8.54, 'utility': 10621}
#  131: {'name': '1499', 'exp_sup': 8.53, 'utility': 6255}
#  132: {'name': '1310', 'exp_sup': 8.53, 'utility': 19102}
#  133: {'name': '108', 'exp_sup': 8.52, 'utility': 9417}
#  134: {'name': '260', 'exp_sup': 8.51, 'utility': 11592}
#  135: {'name': '772', 'exp_sup': 8.5, 'utility': 9894}
#  136: {'name': '414', 'exp_sup': 8.49, 'utility': 12188}
#  137: {'name': '844', 'exp_sup': 8.48, 'utility': 14564}
#  138: {'name': '580', 'exp_sup': 8.45, 'utility': 12532}
#  139: {'name': '170', 'exp_sup': 8.45, 'utility': 14080}
#  140: {'name': '1089', 'exp_sup': 8.41, 'utility': 10621}
#  141: {'name': '502', 'exp_sup': 8.39, 'utility': 16801}
#  142: {'name': '1543', 'exp_sup': 8.36, 'utility': 10912}
#  143: {'name': '44', 'exp_sup': 8.34, 'utility': 12298}
#  144: {'name': '379', 'exp_sup': 8.34, 'utility': 15785}
#  145: {'name': '469', 'exp_sup': 8.32, 'utility': 6837}
#  146: {'name': '493', 'exp_sup': 8.31, 'utility': 12408}
#  147: {'name': '625', 'exp_sup': 8.31, 'utility': 9821}
#  148: {'name': '825', 'exp_sup': 8.29, 'utility': 12452}
#  149: {'name': '154', 'exp_sup': 8.29, 'utility': 9016}
#  150: {'name': '321', 'exp_sup': 8.28, 'utility': 12291}
#  151: {'name': '1247', 'exp_sup': 8.26, 'utility': 8064}
#  152: {'name': '1340', 'exp_sup': 8.25, 'utility': 13107}
#  153: {'name': '324', 'exp_sup': 8.24, 'utility': 7289}
#  154: {'name': '508', 'exp_sup': 8.23, 'utility': 17055}
#  155: {'name': '577', 'exp_sup': 8.22, 'utility': 11004}
#  156: {'name': '448', 'exp_sup': 8.21, 'utility': 9086}
#  157: {'name': '673', 'exp_sup': 8.2, 'utility': 11782}
#  158: {'name': '20', 'exp_sup': 8.2, 'utility': 14178}
#  159: {'name': '968', 'exp_sup': 8.19, 'utility': 5760}
#  160: {'name': '1160', 'exp_sup': 8.19, 'utility': 13517}
#  161: {'name': '795', 'exp_sup': 8.18, 'utility': 4992}
#  162: {'name': '1389', 'exp_sup': 8.17, 'utility': 15254}
#  163: {'name': '1251', 'exp_sup': 8.15, 'utility': 14320}
#  164: {'name': '1483', 'exp_sup': 8.14, 'utility': 8520}
#  165: {'name': '1075', 'exp_sup': 8.12, 'utility': 6314}
#  166: {'name': '227', 'exp_sup': 8.09, 'utility': 7722}
#  167: {'name': '1174', 'exp_sup': 8.09, 'utility': 8853}
#  168: {'name': '1468', 'exp_sup': 8.08, 'utility': 5670}
#  169: {'name': '443', 'exp_sup': 8.08, 'utility': 6783}
#  170: {'name': '1294', 'exp_sup': 8.07, 'utility': 7052}
#  171: {'name': '1061', 'exp_sup': 8.07, 'utility': 8466}
#  172: {'name': '1050', 'exp_sup': 8.06, 'utility': 5632}
#  173: {'name': '1180', 'exp_sup': 8.06, 'utility': 19890}
#  174: {'name': '173', 'exp_sup': 8.06, 'utility': 6864}
#  175: {'name': '819', 'exp_sup': 8.06, 'utility': 11634}
#  176: {'name': '823', 'exp_sup': 8.05, 'utility': 15435}
#  177: {'name': '1077', 'exp_sup': 8.05, 'utility': 15455}
#  178: {'name': '951', 'exp_sup': 8.05, 'utility': 9457}
#  179: {'name': '225', 'exp_sup': 8.04, 'utility': 22951}
#  180: {'name': '1478', 'exp_sup': 8.03, 'utility': 9044}
#  181: {'name': '1056', 'exp_sup': 8.03, 'utility': 10835}
#  182: {'name': '284', 'exp_sup': 8.02, 'utility': 4950}
#  183: {'name': '521', 'exp_sup': 8.02, 'utility': 14155}
#  184: {'name': '1165', 'exp_sup': 8.01, 'utility': 12690}
#  185: {'name': '907', 'exp_sup': 8.01, 'utility': 17100}
#  186: {'name': '1154', 'exp_sup': 8.01, 'utility': 7304}
#  187: {'name': '464', 'exp_sup': 8.01, 'utility': 14952}
#  188: {'name': '1380', 'exp_sup': 7.99, 'utility': 19548}
#  189: {'name': '703', 'exp_sup': 7.98, 'utility': 13959}
#  190: {'name': '980', 'exp_sup': 7.98, 'utility': 7740}
#  191: {'name': '117', 'exp_sup': 7.97, 'utility': 10175}
#  192: {'name': '919', 'exp_sup': 7.96, 'utility': 6930}
#  193: {'name': '1079', 'exp_sup': 7.96, 'utility': 7072}
#  194: {'name': '528', 'exp_sup': 7.96, 'utility': 5952}
#  195: {'name': '541', 'exp_sup': 7.95, 'utility': 8272}
#  196: {'name': '313', 'exp_sup': 7.94, 'utility': 16245}
#  197: {'name': '1518', 'exp_sup': 7.94, 'utility': 20416}
#  198: {'name': '376', 'exp_sup': 7.93, 'utility': 9988}
#  199: {'name': '479', 'exp_sup': 7.93, 'utility': 8385}
#  200: {'name': '563', 'exp_sup': 7.92, 'utility': 6216}
#  201: {'name': '774', 'exp_sup': 7.9, 'utility': 12005}
#  202: {'name': '650', 'exp_sup': 7.88, 'utility': 8370}
#  203: {'name': '415', 'exp_sup': 7.88, 'utility': 11640}
#  204: {'name': '618', 'exp_sup': 7.88, 'utility': 5600}
#  205: {'name': '721', 'exp_sup': 7.86, 'utility': 9485}
#  206: {'name': '374', 'exp_sup': 7.83, 'utility': 6407}
#  207: {'name': '153', 'exp_sup': 7.83, 'utility': 14144}
#  208: {'name': '1410', 'exp_sup': 7.82, 'utility': 6536}
#  209: {'name': '742', 'exp_sup': 7.8, 'utility': 12350}
#  210: {'name': '1346', 'exp_sup': 7.77, 'utility': 10105}
#  211: {'name': '851', 'exp_sup': 7.76, 'utility': 9030}
#  212: {'name': '836', 'exp_sup': 7.75, 'utility': 5428}
#  213: {'name': '877', 'exp_sup': 7.74, 'utility': 8374}
#  214: {'name': '529', 'exp_sup': 7.74, 'utility': 10074}
#  215: {'name': '878', 'exp_sup': 7.74, 'utility': 9724}
#  216: {'name': '913', 'exp_sup': 7.74, 'utility': 7476}
#  217: {'name': '1029', 'exp_sup': 7.74, 'utility': 8736}
#  218: {'name': '1254', 'exp_sup': 7.73, 'utility': 14680}
#  219: {'name': '1116', 'exp_sup': 7.73, 'utility': 11377}
#  220: {'name': '375', 'exp_sup': 7.72, 'utility': 8931}
#  221: {'name': '1250', 'exp_sup': 7.71, 'utility': 10368}
#  222: {'name': '1086', 'exp_sup': 7.69, 'utility': 10365}
#  223: {'name': '816', 'exp_sup': 7.69, 'utility': 10992}
#  224: {'name': '924', 'exp_sup': 7.69, 'utility': 14040}
#  225: {'name': '1372', 'exp_sup': 7.69, 'utility': 10458}
#  226: {'name': '1237', 'exp_sup': 7.68, 'utility': 13750}
#  227: {'name': '834', 'exp_sup': 7.67, 'utility': 10656}
#  228: {'name': '915', 'exp_sup': 7.67, 'utility': 12341}
#  229: {'name': '49', 'exp_sup': 7.66, 'utility': 17238}
#  230: {'name': '824', 'exp_sup': 7.64, 'utility': 10550}
#  231: {'name': '992', 'exp_sup': 7.64, 'utility': 9486}
#  232: {'name': '787', 'exp_sup': 7.64, 'utility': 5662}
#  233: {'name': '1241', 'exp_sup': 7.62, 'utility': 12516}
#  234: {'name': '1463', 'exp_sup': 7.62, 'utility': 8118}
#  235: {'name': '600', 'exp_sup': 7.62, 'utility': 9471}
#  236: {'name': '1416', 'exp_sup': 7.62, 'utility': 12788}
#  237: {'name': '24', 'exp_sup': 7.6, 'utility': 10726}
#  238: {'name': '619', 'exp_sup': 7.59, 'utility': 10575}
#  239: {'name': '555', 'exp_sup': 7.59, 'utility': 12960}
#  240: {'name': '1540', 'exp_sup': 7.59, 'utility': 14432}
#  241: {'name': '418', 'exp_sup': 7.58, 'utility': 14536}
#  242: {'name': '1368', 'exp_sup': 7.57, 'utility': 19525}
#  243: {'name': '1019', 'exp_sup': 7.56, 'utility': 11968}
#  244: {'name': '385', 'exp_sup': 7.55, 'utility': 5148}
#  245: {'name': '1493', 'exp_sup': 7.55, 'utility': 16632}
#  246: {'name': '191', 'exp_sup': 7.54, 'utility': 12054}
#  247: {'name': '882', 'exp_sup': 7.54, 'utility': 12201}
#  248: {'name': '1142', 'exp_sup': 7.54, 'utility': 11800}
#  249: {'name': '922', 'exp_sup': 7.53, 'utility': 12950}
#  250: {'name': '853', 'exp_sup': 7.52, 'utility': 12804}
#  251: {'name': '261', 'exp_sup': 7.52, 'utility': 12844}
#  252: {'name': '789', 'exp_sup': 7.51, 'utility': 12670}
#  253: {'name': '125', 'exp_sup': 7.51, 'utility': 9737}
#  254: {'name': '756', 'exp_sup': 7.5, 'utility': 13393}
#  255: {'name': '1499, 1056', 'exp_sup': 1.52, 'utility': 4891}
#  256: {'name': '890, 191', 'exp_sup': 1.37, 'utility': 5715}
#  257: {'name': '890, 1410, 1493', 'exp_sup': 0.91, 'utility': 4876}
#  258: {'name': '1399, 1426', 'exp_sup': 0.86, 'utility': 5680}
#  259: {'name': '916, 379, 922', 'exp_sup': 0.78, 'utility': 5532}
#  260: {'name': '890, 1410, 191', 'exp_sup': 0.61, 'utility': 5301}
#  261: {'name': '1077, 721', 'exp_sup': 0.56, 'utility': 4892}
#  262: {'name': '890, 1410, 1493, 191', 'exp_sup': 0.54, 'utility': 6885}
#  263: {'name': '1472, 1389, 819', 'exp_sup': 0.43, 'utility': 4851}
#  264: {'name': '1399, 1426, 1043, 217', 'exp_sup': 0.4, 'utility': 5128}
#  265: {'name': '988, 1281', 'exp_sup': 0.36, 'utility': 5826}
#  266: {'name': '1472, 170', 'exp_sup': 0.35, 'utility': 4860}
#  267: {'name': '502, 968, 415', 'exp_sup': 0.28, 'utility': 5152}
#  268: {'name': '1210, 844, 1493', 'exp_sup': 0.27, 'utility': 5114}
#  269: {'name': '1118, 502, 968', 'exp_sup': 0.26, 'utility': 4873}
#  270: {'name': '1118, 502, 415', 'exp_sup': 0.23, 'utility': 6014}
#  271: {'name': '988, 772', 'exp_sup': 0.23, 'utility': 7188}
#  272: {'name': '1118, 502, 968, 415', 'exp_sup': 0.16, 'utility': 6910}
#  273: {'name': '988, 1281, 772', 'exp_sup': 0.15, 'utility': 7378}
#  274: {'name': '1362, 946, 742', 'exp_sup': 0.09, 'utility': 4827}
#  275: {'name': '604, 321, 49, 1314', 'exp_sup': 0.03, 'utility': 4922}
#  276: {'name': '545, 219, 422, 1098, 479, 1254', 'exp_sup': 0.01, 'utility': 5030}
#  277: {'name': '728, 1310, 528, 1254, 1493', 'exp_sup': 0.01, 'utility': 5039}

# %%
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_foodmart.txt, ./data/foodmart_utility.txt", 0.0004, 500)
algorithm.print_stats("./out/TUHUFP/foodmart/output_foodmart_top_500.txt")
# Out:
# Reading data . . .
# Minimum utility set to: 4804
# {'database util: ': 12011023}
# Top 500 CUPs:
#  1: {'name': '304', 'exp_sup': 14.23, 'utility': 13607}
#  2: {'name': '1373', 'exp_sup': 13.55, 'utility': 25560}
#  3: {'name': '272', 'exp_sup': 13.54, 'utility': 22678}
#  4: {'name': '1293', 'exp_sup': 12.66, 'utility': 8352}
#  5: {'name': '1292', 'exp_sup': 12.6, 'utility': 24642}
#  6: {'name': '545', 'exp_sup': 12.1, 'utility': 9419}
#  7: {'name': '357', 'exp_sup': 11.97, 'utility': 11520}
#  8: {'name': '634', 'exp_sup': 11.88, 'utility': 11881}
#  9: {'name': '617', 'exp_sup': 11.75, 'utility': 7527}
#  10: {'name': '1423', 'exp_sup': 11.75, 'utility': 16116}
#  11: {'name': '916', 'exp_sup': 11.68, 'utility': 15163}
#  12: {'name': '1012', 'exp_sup': 11.65, 'utility': 19861}
#  13: {'name': '903', 'exp_sup': 11.62, 'utility': 14616}
#  14: {'name': '831', 'exp_sup': 11.39, 'utility': 8848}
#  15: {'name': '888', 'exp_sup': 11.38, 'utility': 5280}
#  16: {'name': '918', 'exp_sup': 11.38, 'utility': 18414}
#  17: {'name': '1390', 'exp_sup': 11.26, 'utility': 12415}
#  18: {'name': '404', 'exp_sup': 11.02, 'utility': 7000}
#  19: {'name': '308', 'exp_sup': 10.94, 'utility': 11554}
#  20: {'name': '1351', 'exp_sup': 10.9, 'utility': 9352}
#  21: {'name': '1451', 'exp_sup': 10.9, 'utility': 7614}
#  22: {'name': '1315', 'exp_sup': 10.88, 'utility': 9612}
#  23: {'name': '599', 'exp_sup': 10.79, 'utility': 12519}
#  24: {'name': '932', 'exp_sup': 10.78, 'utility': 8262}
#  25: {'name': '1161', 'exp_sup': 10.54, 'utility': 21540}
#  26: {'name': '276', 'exp_sup': 10.37, 'utility': 18528}
#  27: {'name': '718', 'exp_sup': 10.36, 'utility': 9741}
#  28: {'name': '520', 'exp_sup': 10.36, 'utility': 14840}
#  29: {'name': '386', 'exp_sup': 10.29, 'utility': 10927}
#  30: {'name': '1362', 'exp_sup': 10.29, 'utility': 8046}
#  31: {'name': '1439', 'exp_sup': 10.25, 'utility': 8400}
#  32: {'name': '447', 'exp_sup': 10.23, 'utility': 17856}
#  33: {'name': '1220', 'exp_sup': 10.18, 'utility': 11700}
#  34: {'name': '1508', 'exp_sup': 10.16, 'utility': 19116}
#  35: {'name': '1399', 'exp_sup': 10.11, 'utility': 10324}
#  36: {'name': '1110', 'exp_sup': 10.1, 'utility': 17920}
#  37: {'name': '378', 'exp_sup': 10.08, 'utility': 5994}
#  38: {'name': '69', 'exp_sup': 10.07, 'utility': 16430}
#  39: {'name': '1282', 'exp_sup': 10.05, 'utility': 18232}
#  40: {'name': '749', 'exp_sup': 10.03, 'utility': 11748}
#  41: {'name': '602', 'exp_sup': 10.0, 'utility': 13696}
#  42: {'name': '1442', 'exp_sup': 9.99, 'utility': 10332}
#  43: {'name': '1426', 'exp_sup': 9.96, 'utility': 21692}
#  44: {'name': '391', 'exp_sup': 9.95, 'utility': 8777}
#  45: {'name': '501', 'exp_sup': 9.87, 'utility': 6227}
#  46: {'name': '307', 'exp_sup': 9.83, 'utility': 7400}
#  47: {'name': '1456', 'exp_sup': 9.82, 'utility': 8784}
#  48: {'name': '200', 'exp_sup': 9.8, 'utility': 12190}
#  49: {'name': '326', 'exp_sup': 9.77, 'utility': 13091}
#  50: {'name': '1347', 'exp_sup': 9.71, 'utility': 9912}
#  51: {'name': '1224', 'exp_sup': 9.67, 'utility': 6944}
#  52: {'name': '1291', 'exp_sup': 9.65, 'utility': 12642}
#  53: {'name': '73', 'exp_sup': 9.65, 'utility': 11184}
#  54: {'name': '1487', 'exp_sup': 9.64, 'utility': 5320}
#  55: {'name': '246', 'exp_sup': 9.63, 'utility': 17655}
#  56: {'name': '1257', 'exp_sup': 9.62, 'utility': 9505}
#  57: {'name': '311', 'exp_sup': 9.57, 'utility': 8600}
#  58: {'name': '247', 'exp_sup': 9.52, 'utility': 9256}
#  59: {'name': '54', 'exp_sup': 9.51, 'utility': 12889}
#  60: {'name': '1118', 'exp_sup': 9.5, 'utility': 13178}
#  61: {'name': '1045', 'exp_sup': 9.48, 'utility': 21090}
#  62: {'name': '27', 'exp_sup': 9.44, 'utility': 16165}
#  63: {'name': '1464', 'exp_sup': 9.44, 'utility': 14800}
#  64: {'name': '1048', 'exp_sup': 9.43, 'utility': 11713}
#  65: {'name': '812', 'exp_sup': 9.41, 'utility': 14696}
#  66: {'name': '1473', 'exp_sup': 9.4, 'utility': 13452}
#  67: {'name': '640', 'exp_sup': 9.36, 'utility': 13209}
#  68: {'name': '1264', 'exp_sup': 9.35, 'utility': 11985}
#  69: {'name': '222', 'exp_sup': 9.33, 'utility': 22910}
#  70: {'name': '969', 'exp_sup': 9.33, 'utility': 7920}
#  71: {'name': '278', 'exp_sup': 9.33, 'utility': 18480}
#  72: {'name': '434', 'exp_sup': 9.33, 'utility': 7384}
#  73: {'name': '988', 'exp_sup': 9.3, 'utility': 24187}
#  74: {'name': '266', 'exp_sup': 9.29, 'utility': 10692}
#  75: {'name': '419', 'exp_sup': 9.29, 'utility': 14994}
#  76: {'name': '219', 'exp_sup': 9.27, 'utility': 11844}
#  77: {'name': '382', 'exp_sup': 9.27, 'utility': 9072}
#  78: {'name': '435', 'exp_sup': 9.24, 'utility': 14433}
#  79: {'name': '1516', 'exp_sup': 9.22, 'utility': 15792}
#  80: {'name': '1217', 'exp_sup': 9.21, 'utility': 7239}
#  81: {'name': '890', 'exp_sup': 9.18, 'utility': 12789}
#  82: {'name': '1308', 'exp_sup': 9.18, 'utility': 12642}
#  83: {'name': '728', 'exp_sup': 9.17, 'utility': 11528}
#  84: {'name': '175', 'exp_sup': 9.14, 'utility': 19635}
#  85: {'name': '449', 'exp_sup': 9.12, 'utility': 15867}
#  86: {'name': '1357', 'exp_sup': 9.1, 'utility': 11653}
#  87: {'name': '1281', 'exp_sup': 9.1, 'utility': 13573}
#  88: {'name': '813', 'exp_sup': 9.09, 'utility': 7967}
#  89: {'name': '566', 'exp_sup': 9.05, 'utility': 7120}
#  90: {'name': '604', 'exp_sup': 9.04, 'utility': 6250}
#  91: {'name': '1394', 'exp_sup': 9.01, 'utility': 10870}
#  92: {'name': '1547', 'exp_sup': 9.0, 'utility': 12614}
#  93: {'name': '1338', 'exp_sup': 8.99, 'utility': 10656}
#  94: {'name': '281', 'exp_sup': 8.97, 'utility': 14465}
#  95: {'name': '470', 'exp_sup': 8.96, 'utility': 18259}
#  96: {'name': '941', 'exp_sup': 8.96, 'utility': 18565}
#  97: {'name': '1104', 'exp_sup': 8.96, 'utility': 13965}
#  98: {'name': '383', 'exp_sup': 8.89, 'utility': 14300}
#  99: {'name': '685', 'exp_sup': 8.87, 'utility': 9333}
#  100: {'name': '1119', 'exp_sup': 8.86, 'utility': 13314}
#  101: {'name': '1472', 'exp_sup': 8.86, 'utility': 12760}
#  102: {'name': '111', 'exp_sup': 8.85, 'utility': 17052}
#  103: {'name': '380', 'exp_sup': 8.84, 'utility': 4880}
#  104: {'name': '1348', 'exp_sup': 8.83, 'utility': 14326}
#  105: {'name': '1306', 'exp_sup': 8.83, 'utility': 10127}
#  106: {'name': '584', 'exp_sup': 8.8, 'utility': 12173}
#  107: {'name': '1432', 'exp_sup': 8.77, 'utility': 9180}
#  108: {'name': '1444', 'exp_sup': 8.77, 'utility': 10384}
#  109: {'name': '1397', 'exp_sup': 8.76, 'utility': 5577}
#  110: {'name': '231', 'exp_sup': 8.75, 'utility': 14575}
#  111: {'name': '863', 'exp_sup': 8.74, 'utility': 14006}
#  112: {'name': '1526', 'exp_sup': 8.73, 'utility': 8085}
#  113: {'name': '422', 'exp_sup': 8.73, 'utility': 17616}
#  114: {'name': '236', 'exp_sup': 8.72, 'utility': 9412}
#  115: {'name': '55', 'exp_sup': 8.72, 'utility': 15750}
#  116: {'name': '497', 'exp_sup': 8.66, 'utility': 10472}
#  117: {'name': '606', 'exp_sup': 8.66, 'utility': 12720}
#  118: {'name': '1268', 'exp_sup': 8.66, 'utility': 7150}
#  119: {'name': '1043', 'exp_sup': 8.65, 'utility': 6908}
#  120: {'name': '1470', 'exp_sup': 8.64, 'utility': 11327}
#  121: {'name': '1210', 'exp_sup': 8.63, 'utility': 9681}
#  122: {'name': '883', 'exp_sup': 8.63, 'utility': 13041}
#  123: {'name': '1522', 'exp_sup': 8.62, 'utility': 6147}
#  124: {'name': '1384', 'exp_sup': 8.61, 'utility': 12593}
#  125: {'name': '1296', 'exp_sup': 8.6, 'utility': 14548}
#  126: {'name': '626', 'exp_sup': 8.6, 'utility': 4902}
#  127: {'name': '389', 'exp_sup': 8.59, 'utility': 8771}
#  128: {'name': '1098', 'exp_sup': 8.58, 'utility': 6255}
#  129: {'name': '946', 'exp_sup': 8.55, 'utility': 13965}
#  130: {'name': '943', 'exp_sup': 8.54, 'utility': 10621}
#  131: {'name': '1499', 'exp_sup': 8.53, 'utility': 6255}
#  132: {'name': '1310', 'exp_sup': 8.53, 'utility': 19102}
#  133: {'name': '108', 'exp_sup': 8.52, 'utility': 9417}
#  134: {'name': '260', 'exp_sup': 8.51, 'utility': 11592}
#  135: {'name': '772', 'exp_sup': 8.5, 'utility': 9894}
#  136: {'name': '414', 'exp_sup': 8.49, 'utility': 12188}
#  137: {'name': '844', 'exp_sup': 8.48, 'utility': 14564}
#  138: {'name': '580', 'exp_sup': 8.45, 'utility': 12532}
#  139: {'name': '170', 'exp_sup': 8.45, 'utility': 14080}
#  140: {'name': '1089', 'exp_sup': 8.41, 'utility': 10621}
#  141: {'name': '502', 'exp_sup': 8.39, 'utility': 16801}
#  142: {'name': '1543', 'exp_sup': 8.36, 'utility': 10912}
#  143: {'name': '44', 'exp_sup': 8.34, 'utility': 12298}
#  144: {'name': '379', 'exp_sup': 8.34, 'utility': 15785}
#  145: {'name': '469', 'exp_sup': 8.32, 'utility': 6837}
#  146: {'name': '493', 'exp_sup': 8.31, 'utility': 12408}
#  147: {'name': '625', 'exp_sup': 8.31, 'utility': 9821}
#  148: {'name': '825', 'exp_sup': 8.29, 'utility': 12452}
#  149: {'name': '154', 'exp_sup': 8.29, 'utility': 9016}
#  150: {'name': '321', 'exp_sup': 8.28, 'utility': 12291}
#  151: {'name': '1247', 'exp_sup': 8.26, 'utility': 8064}
#  152: {'name': '1340', 'exp_sup': 8.25, 'utility': 13107}
#  153: {'name': '324', 'exp_sup': 8.24, 'utility': 7289}
#  154: {'name': '508', 'exp_sup': 8.23, 'utility': 17055}
#  155: {'name': '577', 'exp_sup': 8.22, 'utility': 11004}
#  156: {'name': '448', 'exp_sup': 8.21, 'utility': 9086}
#  157: {'name': '673', 'exp_sup': 8.2, 'utility': 11782}
#  158: {'name': '20', 'exp_sup': 8.2, 'utility': 14178}
#  159: {'name': '968', 'exp_sup': 8.19, 'utility': 5760}
#  160: {'name': '1160', 'exp_sup': 8.19, 'utility': 13517}
#  161: {'name': '795', 'exp_sup': 8.18, 'utility': 4992}
#  162: {'name': '1389', 'exp_sup': 8.17, 'utility': 15254}
#  163: {'name': '1251', 'exp_sup': 8.15, 'utility': 14320}
#  164: {'name': '1483', 'exp_sup': 8.14, 'utility': 8520}
#  165: {'name': '1075', 'exp_sup': 8.12, 'utility': 6314}
#  166: {'name': '227', 'exp_sup': 8.09, 'utility': 7722}
#  167: {'name': '1174', 'exp_sup': 8.09, 'utility': 8853}
#  168: {'name': '1468', 'exp_sup': 8.08, 'utility': 5670}
#  169: {'name': '443', 'exp_sup': 8.08, 'utility': 6783}
#  170: {'name': '1294', 'exp_sup': 8.07, 'utility': 7052}
#  171: {'name': '1061', 'exp_sup': 8.07, 'utility': 8466}
#  172: {'name': '1050', 'exp_sup': 8.06, 'utility': 5632}
#  173: {'name': '1180', 'exp_sup': 8.06, 'utility': 19890}
#  174: {'name': '173', 'exp_sup': 8.06, 'utility': 6864}
#  175: {'name': '819', 'exp_sup': 8.06, 'utility': 11634}
#  176: {'name': '823', 'exp_sup': 8.05, 'utility': 15435}
#  177: {'name': '1077', 'exp_sup': 8.05, 'utility': 15455}
#  178: {'name': '951', 'exp_sup': 8.05, 'utility': 9457}
#  179: {'name': '225', 'exp_sup': 8.04, 'utility': 22951}
#  180: {'name': '1478', 'exp_sup': 8.03, 'utility': 9044}
#  181: {'name': '1056', 'exp_sup': 8.03, 'utility': 10835}
#  182: {'name': '284', 'exp_sup': 8.02, 'utility': 4950}
#  183: {'name': '521', 'exp_sup': 8.02, 'utility': 14155}
#  184: {'name': '1165', 'exp_sup': 8.01, 'utility': 12690}
#  185: {'name': '907', 'exp_sup': 8.01, 'utility': 17100}
#  186: {'name': '1154', 'exp_sup': 8.01, 'utility': 7304}
#  187: {'name': '464', 'exp_sup': 8.01, 'utility': 14952}
#  188: {'name': '1380', 'exp_sup': 7.99, 'utility': 19548}
#  189: {'name': '703', 'exp_sup': 7.98, 'utility': 13959}
#  190: {'name': '980', 'exp_sup': 7.98, 'utility': 7740}
#  191: {'name': '117', 'exp_sup': 7.97, 'utility': 10175}
#  192: {'name': '919', 'exp_sup': 7.96, 'utility': 6930}
#  193: {'name': '1079', 'exp_sup': 7.96, 'utility': 7072}
#  194: {'name': '528', 'exp_sup': 7.96, 'utility': 5952}
#  195: {'name': '541', 'exp_sup': 7.95, 'utility': 8272}
#  196: {'name': '313', 'exp_sup': 7.94, 'utility': 16245}
#  197: {'name': '1518', 'exp_sup': 7.94, 'utility': 20416}
#  198: {'name': '376', 'exp_sup': 7.93, 'utility': 9988}
#  199: {'name': '479', 'exp_sup': 7.93, 'utility': 8385}
#  200: {'name': '563', 'exp_sup': 7.92, 'utility': 6216}
#  201: {'name': '774', 'exp_sup': 7.9, 'utility': 12005}
#  202: {'name': '650', 'exp_sup': 7.88, 'utility': 8370}
#  203: {'name': '415', 'exp_sup': 7.88, 'utility': 11640}
#  204: {'name': '618', 'exp_sup': 7.88, 'utility': 5600}
#  205: {'name': '721', 'exp_sup': 7.86, 'utility': 9485}
#  206: {'name': '374', 'exp_sup': 7.83, 'utility': 6407}
#  207: {'name': '153', 'exp_sup': 7.83, 'utility': 14144}
#  208: {'name': '1410', 'exp_sup': 7.82, 'utility': 6536}
#  209: {'name': '742', 'exp_sup': 7.8, 'utility': 12350}
#  210: {'name': '1346', 'exp_sup': 7.77, 'utility': 10105}
#  211: {'name': '851', 'exp_sup': 7.76, 'utility': 9030}
#  212: {'name': '836', 'exp_sup': 7.75, 'utility': 5428}
#  213: {'name': '877', 'exp_sup': 7.74, 'utility': 8374}
#  214: {'name': '529', 'exp_sup': 7.74, 'utility': 10074}
#  215: {'name': '878', 'exp_sup': 7.74, 'utility': 9724}
#  216: {'name': '913', 'exp_sup': 7.74, 'utility': 7476}
#  217: {'name': '1029', 'exp_sup': 7.74, 'utility': 8736}
#  218: {'name': '1254', 'exp_sup': 7.73, 'utility': 14680}
#  219: {'name': '1116', 'exp_sup': 7.73, 'utility': 11377}
#  220: {'name': '375', 'exp_sup': 7.72, 'utility': 8931}
#  221: {'name': '1250', 'exp_sup': 7.71, 'utility': 10368}
#  222: {'name': '1086', 'exp_sup': 7.69, 'utility': 10365}
#  223: {'name': '816', 'exp_sup': 7.69, 'utility': 10992}
#  224: {'name': '924', 'exp_sup': 7.69, 'utility': 14040}
#  225: {'name': '1372', 'exp_sup': 7.69, 'utility': 10458}
#  226: {'name': '1237', 'exp_sup': 7.68, 'utility': 13750}
#  227: {'name': '834', 'exp_sup': 7.67, 'utility': 10656}
#  228: {'name': '915', 'exp_sup': 7.67, 'utility': 12341}
#  229: {'name': '49', 'exp_sup': 7.66, 'utility': 17238}
#  230: {'name': '824', 'exp_sup': 7.64, 'utility': 10550}
#  231: {'name': '992', 'exp_sup': 7.64, 'utility': 9486}
#  232: {'name': '787', 'exp_sup': 7.64, 'utility': 5662}
#  233: {'name': '1241', 'exp_sup': 7.62, 'utility': 12516}
#  234: {'name': '1463', 'exp_sup': 7.62, 'utility': 8118}
#  235: {'name': '600', 'exp_sup': 7.62, 'utility': 9471}
#  236: {'name': '1416', 'exp_sup': 7.62, 'utility': 12788}
#  237: {'name': '24', 'exp_sup': 7.6, 'utility': 10726}
#  238: {'name': '619', 'exp_sup': 7.59, 'utility': 10575}
#  239: {'name': '555', 'exp_sup': 7.59, 'utility': 12960}
#  240: {'name': '1540', 'exp_sup': 7.59, 'utility': 14432}
#  241: {'name': '418', 'exp_sup': 7.58, 'utility': 14536}
#  242: {'name': '1368', 'exp_sup': 7.57, 'utility': 19525}
#  243: {'name': '1019', 'exp_sup': 7.56, 'utility': 11968}
#  244: {'name': '385', 'exp_sup': 7.55, 'utility': 5148}
#  245: {'name': '1493', 'exp_sup': 7.55, 'utility': 16632}
#  246: {'name': '191', 'exp_sup': 7.54, 'utility': 12054}
#  247: {'name': '882', 'exp_sup': 7.54, 'utility': 12201}
#  248: {'name': '1142', 'exp_sup': 7.54, 'utility': 11800}
#  249: {'name': '922', 'exp_sup': 7.53, 'utility': 12950}
#  250: {'name': '853', 'exp_sup': 7.52, 'utility': 12804}
#  251: {'name': '261', 'exp_sup': 7.52, 'utility': 12844}
#  252: {'name': '789', 'exp_sup': 7.51, 'utility': 12670}
#  253: {'name': '125', 'exp_sup': 7.51, 'utility': 9737}
#  254: {'name': '756', 'exp_sup': 7.5, 'utility': 13393}
#  255: {'name': '179', 'exp_sup': 7.5, 'utility': 17875}
#  256: {'name': '410', 'exp_sup': 7.49, 'utility': 6174}
#  257: {'name': '488', 'exp_sup': 7.49, 'utility': 10101}
#  258: {'name': '522', 'exp_sup': 7.49, 'utility': 8140}
#  259: {'name': '1408', 'exp_sup': 7.49, 'utility': 9805}
#  260: {'name': '1222', 'exp_sup': 7.48, 'utility': 9555}
#  261: {'name': '1252', 'exp_sup': 7.48, 'utility': 11391}
#  262: {'name': '811', 'exp_sup': 7.48, 'utility': 14256}
#  263: {'name': '1366', 'exp_sup': 7.46, 'utility': 11311}
#  264: {'name': '534', 'exp_sup': 7.46, 'utility': 11491}
#  265: {'name': '854', 'exp_sup': 7.45, 'utility': 7040}
#  266: {'name': '365', 'exp_sup': 7.45, 'utility': 17424}
#  267: {'name': '832', 'exp_sup': 7.45, 'utility': 15552}
#  268: {'name': '82', 'exp_sup': 7.45, 'utility': 12150}
#  269: {'name': '575', 'exp_sup': 7.44, 'utility': 13769}
#  270: {'name': '1063', 'exp_sup': 7.43, 'utility': 14303}
#  271: {'name': '739', 'exp_sup': 7.43, 'utility': 8568}
#  272: {'name': '547', 'exp_sup': 7.41, 'utility': 9702}
#  273: {'name': '730', 'exp_sup': 7.39, 'utility': 8084}
#  274: {'name': '800', 'exp_sup': 7.39, 'utility': 11729}
#  275: {'name': '792', 'exp_sup': 7.39, 'utility': 7668}
#  276: {'name': '370', 'exp_sup': 7.38, 'utility': 4968}
#  277: {'name': '1007', 'exp_sup': 7.37, 'utility': 13166}
#  278: {'name': '1418', 'exp_sup': 7.36, 'utility': 6279}
#  279: {'name': '662', 'exp_sup': 7.35, 'utility': 7585}
#  280: {'name': '288', 'exp_sup': 7.35, 'utility': 10582}
#  281: {'name': '1088', 'exp_sup': 7.34, 'utility': 15604}
#  282: {'name': '805', 'exp_sup': 7.33, 'utility': 9216}
#  283: {'name': '1070', 'exp_sup': 7.32, 'utility': 13689}
#  284: {'name': '1361', 'exp_sup': 7.32, 'utility': 7240}
#  285: {'name': '556', 'exp_sup': 7.3, 'utility': 13975}
#  286: {'name': '767', 'exp_sup': 7.3, 'utility': 6662}
#  287: {'name': '963', 'exp_sup': 7.3, 'utility': 12000}
#  288: {'name': '303', 'exp_sup': 7.29, 'utility': 9030}
#  289: {'name': '189', 'exp_sup': 7.29, 'utility': 14835}
#  290: {'name': '546', 'exp_sup': 7.28, 'utility': 10842}
#  291: {'name': '129', 'exp_sup': 7.28, 'utility': 5115}
#  292: {'name': '914', 'exp_sup': 7.27, 'utility': 9594}
#  293: {'name': '285', 'exp_sup': 7.27, 'utility': 7626}
#  294: {'name': '942', 'exp_sup': 7.26, 'utility': 7722}
#  295: {'name': '468', 'exp_sup': 7.26, 'utility': 7830}
#  296: {'name': '691', 'exp_sup': 7.26, 'utility': 11685}
#  297: {'name': '1538', 'exp_sup': 7.26, 'utility': 11893}
#  298: {'name': '158', 'exp_sup': 7.26, 'utility': 6004}
#  299: {'name': '1094', 'exp_sup': 7.26, 'utility': 17342}
#  300: {'name': '1324', 'exp_sup': 7.25, 'utility': 12578}
#  301: {'name': '346', 'exp_sup': 7.24, 'utility': 9752}
#  302: {'name': '937', 'exp_sup': 7.24, 'utility': 19133}
#  303: {'name': '1358', 'exp_sup': 7.22, 'utility': 6720}
#  304: {'name': '234', 'exp_sup': 7.22, 'utility': 12690}
#  305: {'name': '11', 'exp_sup': 7.21, 'utility': 16497}
#  306: {'name': '100', 'exp_sup': 7.2, 'utility': 8580}
#  307: {'name': '1497', 'exp_sup': 7.19, 'utility': 19406}
#  308: {'name': '1279', 'exp_sup': 7.18, 'utility': 11840}
#  309: {'name': '1055', 'exp_sup': 7.18, 'utility': 5184}
#  310: {'name': '1096', 'exp_sup': 7.17, 'utility': 9984}
#  311: {'name': '491', 'exp_sup': 7.17, 'utility': 14742}
#  312: {'name': '957', 'exp_sup': 7.17, 'utility': 10395}
#  313: {'name': '17', 'exp_sup': 7.16, 'utility': 11063}
#  314: {'name': '923', 'exp_sup': 7.16, 'utility': 7056}
#  315: {'name': '887', 'exp_sup': 7.14, 'utility': 7200}
#  316: {'name': '408', 'exp_sup': 7.14, 'utility': 11000}
#  317: {'name': '322', 'exp_sup': 7.14, 'utility': 13112}
#  318: {'name': '495', 'exp_sup': 7.14, 'utility': 5265}
#  319: {'name': '1267', 'exp_sup': 7.13, 'utility': 7520}
#  320: {'name': '149', 'exp_sup': 7.13, 'utility': 11952}
#  321: {'name': '1114', 'exp_sup': 7.13, 'utility': 11286}
#  322: {'name': '377', 'exp_sup': 7.13, 'utility': 10290}
#  323: {'name': '300', 'exp_sup': 7.12, 'utility': 14700}
#  324: {'name': '387', 'exp_sup': 7.12, 'utility': 13014}
#  325: {'name': '715', 'exp_sup': 7.11, 'utility': 6665}
#  326: {'name': '753', 'exp_sup': 7.11, 'utility': 8315}
#  327: {'name': '1001', 'exp_sup': 7.11, 'utility': 12852}
#  328: {'name': '1277', 'exp_sup': 7.1, 'utility': 8890}
#  329: {'name': '283', 'exp_sup': 7.09, 'utility': 14469}
#  330: {'name': '503', 'exp_sup': 7.07, 'utility': 8742}
#  331: {'name': '10', 'exp_sup': 7.07, 'utility': 5538}
#  332: {'name': '46', 'exp_sup': 7.06, 'utility': 11008}
#  333: {'name': '1190', 'exp_sup': 7.06, 'utility': 6110}
#  334: {'name': '178', 'exp_sup': 7.06, 'utility': 5320}
#  335: {'name': '865', 'exp_sup': 7.05, 'utility': 9758}
#  336: {'name': '1179', 'exp_sup': 7.04, 'utility': 11046}
#  337: {'name': '874', 'exp_sup': 7.04, 'utility': 7146}
#  338: {'name': '1134', 'exp_sup': 7.03, 'utility': 7098}
#  339: {'name': '1376', 'exp_sup': 7.03, 'utility': 6720}
#  340: {'name': '958', 'exp_sup': 7.03, 'utility': 6392}
#  341: {'name': '1417', 'exp_sup': 7.03, 'utility': 13357}
#  342: {'name': '1412', 'exp_sup': 7.03, 'utility': 7137}
#  343: {'name': '639', 'exp_sup': 7.03, 'utility': 15415}
#  344: {'name': '1081', 'exp_sup': 7.03, 'utility': 15423}
#  345: {'name': '1272', 'exp_sup': 7.02, 'utility': 12152}
#  346: {'name': '860', 'exp_sup': 7.02, 'utility': 10296}
#  347: {'name': '934', 'exp_sup': 7.01, 'utility': 5610}
#  348: {'name': '1209', 'exp_sup': 7.01, 'utility': 10530}
#  349: {'name': '991', 'exp_sup': 7.01, 'utility': 13650}
#  350: {'name': '1506', 'exp_sup': 7.0, 'utility': 9604}
#  351: {'name': '891', 'exp_sup': 6.99, 'utility': 12844}
#  352: {'name': '223', 'exp_sup': 6.97, 'utility': 14036}
#  353: {'name': '1353', 'exp_sup': 6.97, 'utility': 8064}
#  354: {'name': '1184', 'exp_sup': 6.96, 'utility': 11928}
#  355: {'name': '1328', 'exp_sup': 6.96, 'utility': 10165}
#  356: {'name': '953', 'exp_sup': 6.96, 'utility': 8768}
#  357: {'name': '727', 'exp_sup': 6.95, 'utility': 7640}
#  358: {'name': '725', 'exp_sup': 6.95, 'utility': 6407}
#  359: {'name': '667', 'exp_sup': 6.94, 'utility': 10906}
#  360: {'name': '1117', 'exp_sup': 6.93, 'utility': 14560}
#  361: {'name': '339', 'exp_sup': 6.93, 'utility': 6300}
#  362: {'name': '446', 'exp_sup': 6.93, 'utility': 20625}
#  363: {'name': '516', 'exp_sup': 6.93, 'utility': 7770}
#  364: {'name': '80', 'exp_sup': 6.92, 'utility': 17060}
#  365: {'name': '1062', 'exp_sup': 6.91, 'utility': 8330}
#  366: {'name': '1049', 'exp_sup': 6.91, 'utility': 15327}
#  367: {'name': '489', 'exp_sup': 6.9, 'utility': 12291}
#  368: {'name': '104', 'exp_sup': 6.89, 'utility': 15171}
#  369: {'name': '48', 'exp_sup': 6.89, 'utility': 6204}
#  370: {'name': '269', 'exp_sup': 6.89, 'utility': 8520}
#  371: {'name': '896', 'exp_sup': 6.88, 'utility': 13127}
#  372: {'name': '1106', 'exp_sup': 6.88, 'utility': 6073}
#  373: {'name': '760', 'exp_sup': 6.86, 'utility': 6919}
#  374: {'name': '1398', 'exp_sup': 6.86, 'utility': 17002}
#  375: {'name': '1386', 'exp_sup': 6.86, 'utility': 7544}
#  376: {'name': '1544', 'exp_sup': 6.85, 'utility': 5256}
#  377: {'name': '1145', 'exp_sup': 6.85, 'utility': 6594}
#  378: {'name': '1554', 'exp_sup': 6.84, 'utility': 8636}
#  379: {'name': '312', 'exp_sup': 6.84, 'utility': 8520}
#  380: {'name': '1028', 'exp_sup': 6.83, 'utility': 8960}
#  381: {'name': '1455', 'exp_sup': 6.82, 'utility': 10364}
#  382: {'name': '67', 'exp_sup': 6.82, 'utility': 10416}
#  383: {'name': '23', 'exp_sup': 6.81, 'utility': 5600}
#  384: {'name': '202', 'exp_sup': 6.8, 'utility': 5364}
#  385: {'name': '1438', 'exp_sup': 6.79, 'utility': 5754}
#  386: {'name': '1530', 'exp_sup': 6.78, 'utility': 6096}
#  387: {'name': '1485', 'exp_sup': 6.77, 'utility': 6750}
#  388: {'name': '22', 'exp_sup': 6.77, 'utility': 10763}
#  389: {'name': '394', 'exp_sup': 6.77, 'utility': 12520}
#  390: {'name': '747', 'exp_sup': 6.76, 'utility': 7137}
#  391: {'name': '751', 'exp_sup': 6.76, 'utility': 11607}
#  392: {'name': '560', 'exp_sup': 6.76, 'utility': 5160}
#  393: {'name': '58', 'exp_sup': 6.75, 'utility': 8778}
#  394: {'name': '63', 'exp_sup': 6.74, 'utility': 12390}
#  395: {'name': '898', 'exp_sup': 6.72, 'utility': 7308}
#  396: {'name': '911', 'exp_sup': 6.71, 'utility': 5910}
#  397: {'name': '1383', 'exp_sup': 6.71, 'utility': 9583}
#  398: {'name': '1136', 'exp_sup': 6.71, 'utility': 15162}
#  399: {'name': '587', 'exp_sup': 6.69, 'utility': 10464}
#  400: {'name': '1465', 'exp_sup': 6.69, 'utility': 11430}
#  401: {'name': '999', 'exp_sup': 6.69, 'utility': 10027}
#  402: {'name': '1363', 'exp_sup': 6.68, 'utility': 9044}
#  403: {'name': '1242', 'exp_sup': 6.68, 'utility': 7326}
#  404: {'name': '83', 'exp_sup': 6.68, 'utility': 20563}
#  405: {'name': '16', 'exp_sup': 6.67, 'utility': 13788}
#  406: {'name': '138', 'exp_sup': 6.67, 'utility': 9180}
#  407: {'name': '554', 'exp_sup': 6.66, 'utility': 14130}
#  408: {'name': '136', 'exp_sup': 6.66, 'utility': 13932}
#  409: {'name': '105', 'exp_sup': 6.66, 'utility': 13020}
#  410: {'name': '174', 'exp_sup': 6.66, 'utility': 5472}
#  411: {'name': '1491', 'exp_sup': 6.65, 'utility': 9030}
#  412: {'name': '931', 'exp_sup': 6.65, 'utility': 6270}
#  413: {'name': '785', 'exp_sup': 6.64, 'utility': 7517}
#  414: {'name': '341', 'exp_sup': 6.64, 'utility': 9418}
#  415: {'name': '9', 'exp_sup': 6.63, 'utility': 9922}
#  416: {'name': '1082', 'exp_sup': 6.63, 'utility': 8404}
#  417: {'name': '33', 'exp_sup': 6.62, 'utility': 6936}
#  418: {'name': '1499, 1056', 'exp_sup': 1.52, 'utility': 4891}
#  419: {'name': '890, 191', 'exp_sup': 1.37, 'utility': 5715}
#  420: {'name': '819, 1279', 'exp_sup': 1.27, 'utility': 6303}
#  421: {'name': '789, 556', 'exp_sup': 1.1, 'utility': 5496}
#  422: {'name': '890, 1410, 1493', 'exp_sup': 0.91, 'utility': 4876}
#  423: {'name': '1399, 1426', 'exp_sup': 0.86, 'utility': 5680}
#  424: {'name': '285, 1094', 'exp_sup': 0.86, 'utility': 4881}
#  425: {'name': '111, 937', 'exp_sup': 0.81, 'utility': 4963}
#  426: {'name': '916, 379, 922', 'exp_sup': 0.78, 'utility': 5532}
#  427: {'name': '222, 1497', 'exp_sup': 0.78, 'utility': 5726}
#  428: {'name': '1399, 1426, 1365', 'exp_sup': 0.7, 'utility': 6104}
#  429: {'name': '1426, 727', 'exp_sup': 0.67, 'utility': 6589}
#  430: {'name': '1338, 1049', 'exp_sup': 0.67, 'utility': 5928}
#  431: {'name': '890, 1410, 191', 'exp_sup': 0.61, 'utility': 5301}
#  432: {'name': '1389, 1279', 'exp_sup': 0.61, 'utility': 5360}
#  433: {'name': '1077, 721', 'exp_sup': 0.56, 'utility': 4892}
#  434: {'name': '890, 1410, 1493, 191', 'exp_sup': 0.54, 'utility': 6885}
#  435: {'name': '1399, 1426, 1043, 1365', 'exp_sup': 0.47, 'utility': 5106}
#  436: {'name': '1472, 1389, 819', 'exp_sup': 0.43, 'utility': 4851}
#  437: {'name': '1399, 1426, 1043, 217', 'exp_sup': 0.4, 'utility': 5128}
#  438: {'name': '988, 1281', 'exp_sup': 0.36, 'utility': 5826}
#  439: {'name': '1472, 170', 'exp_sup': 0.35, 'utility': 4860}
#  440: {'name': '1399, 1426, 1043, 217, 1365', 'exp_sup': 0.34, 'utility': 5446}
#  441: {'name': '1436, 111, 937', 'exp_sup': 0.34, 'utility': 5607}
#  442: {'name': '1389, 819, 1279', 'exp_sup': 0.34, 'utility': 5899}
#  443: {'name': '1472, 819, 1279', 'exp_sup': 0.32, 'utility': 5904}
#  444: {'name': '1426, 727, 1365', 'exp_sup': 0.3, 'utility': 5318}
#  445: {'name': '640, 324, 234', 'exp_sup': 0.28, 'utility': 4947}
#  446: {'name': '502, 968, 415', 'exp_sup': 0.28, 'utility': 5152}
#  447: {'name': '1210, 844, 1493', 'exp_sup': 0.27, 'utility': 5114}
#  448: {'name': '1118, 502, 968', 'exp_sup': 0.26, 'utility': 4873}
#  449: {'name': '1399, 1426, 1043, 1542', 'exp_sup': 0.25, 'utility': 5263}
#  450: {'name': '1472, 1389, 1279', 'exp_sup': 0.25, 'utility': 5003}
#  451: {'name': '1118, 502, 415', 'exp_sup': 0.23, 'utility': 6014}
#  452: {'name': '988, 772', 'exp_sup': 0.23, 'utility': 7188}
#  453: {'name': '1291, 941, 914', 'exp_sup': 0.22, 'utility': 5226}
#  454: {'name': '988, 1281, 339', 'exp_sup': 0.19, 'utility': 6806}
#  455: {'name': '1399, 1426, 1043, 1542, 1365', 'exp_sup': 0.18, 'utility': 5581}
#  456: {'name': '1399, 1426, 727', 'exp_sup': 0.17, 'utility': 7208}
#  457: {'name': '1426, 217, 727', 'exp_sup': 0.17, 'utility': 5697}
#  458: {'name': '1472, 1389, 819, 1279', 'exp_sup': 0.17, 'utility': 7219}
#  459: {'name': '1399, 1426, 1043, 217, 1542', 'exp_sup': 0.16, 'utility': 5603}
#  460: {'name': '1118, 502, 968, 415', 'exp_sup': 0.16, 'utility': 6910}
#  461: {'name': '988, 1281, 772', 'exp_sup': 0.15, 'utility': 7378}
#  462: {'name': '1399, 1426, 1043, 217, 1542, 1365', 'exp_sup': 0.13, 'utility': 5921}
#  463: {'name': '1045, 812, 313, 1049', 'exp_sup': 0.12, 'utility': 5243}
#  464: {'name': '1399, 1426, 727, 1365', 'exp_sup': 0.11, 'utility': 7632}
#  465: {'name': '1291, 941, 914, 958', 'exp_sup': 0.11, 'utility': 5906}
#  466: {'name': '988, 772, 339', 'exp_sup': 0.11, 'utility': 6142}
#  467: {'name': '1362, 946, 742', 'exp_sup': 0.09, 'utility': 4827}
#  468: {'name': '988, 1281, 772, 339', 'exp_sup': 0.08, 'utility': 8358}
#  469: {'name': '1399, 1426, 1043, 727', 'exp_sup': 0.07, 'utility': 5934}
#  470: {'name': '1399, 1426, 1043, 1542, 727', 'exp_sup': 0.06, 'utility': 6409}
#  471: {'name': '175, 418, 651', 'exp_sup': 0.05, 'utility': 5162}
#  472: {'name': '1399, 1426, 217, 727', 'exp_sup': 0.04, 'utility': 5332}
#  473: {'name': '1426, 1043, 217, 727, 1365', 'exp_sup': 0.04, 'utility': 4990}
#  474: {'name': '988, 1281, 772, 1142, 339', 'exp_sup': 0.04, 'utility': 5134}
#  475: {'name': '1019, 17, 104, 67', 'exp_sup': 0.04, 'utility': 5462}
#  476: {'name': '1398, 83', 'exp_sup': 0.04, 'utility': 5695}
#  477: {'name': '1508, 626, 825, 1019, 963', 'exp_sup': 0.03, 'utility': 4992}
#  478: {'name': '1399, 1426, 1043, 217, 727', 'exp_sup': 0.03, 'utility': 6274}
#  479: {'name': '1399, 1426, 1043, 727, 1365', 'exp_sup': 0.03, 'utility': 6252}
#  480: {'name': '1426, 756, 727', 'exp_sup': 0.03, 'utility': 5370}
#  481: {'name': '604, 321, 49, 1314', 'exp_sup': 0.03, 'utility': 4922}
#  482: {'name': '1399, 1426, 1043, 217, 1542, 727', 'exp_sup': 0.02, 'utility': 6749}
#  483: {'name': '1399, 1426, 1043, 217, 727, 1365', 'exp_sup': 0.02, 'utility': 6592}
#  484: {'name': '1399, 1426, 1043, 1542, 727, 1365', 'exp_sup': 0.02, 'utility': 6727}
#  485: {'name': '1399, 1426, 217, 727, 1365', 'exp_sup': 0.02, 'utility': 5650}
#  486: {'name': '1426, 217, 756, 727', 'exp_sup': 0.02, 'utility': 5778}
#  487: {'name': '1045, 812, 1049, 1554', 'exp_sup': 0.02, 'utility': 5150}
#  488: {'name': '545, 219, 422, 1098, 479, 1254', 'exp_sup': 0.01, 'utility': 5030}
#  489: {'name': '1399, 1426, 1043, 217, 1542, 727, 1365', 'exp_sup': 0.01, 'utility': 7067}
#  490: {'name': '1045, 812, 313, 1049, 1554', 'exp_sup': 0.01, 'utility': 6005}
#  491: {'name': '728, 1310, 528, 1254, 1493', 'exp_sup': 0.01, 'utility': 5039}
#  492: {'name': '175, 418, 874', 'exp_sup': 0.01, 'utility': 5794}
#  493: {'name': '1373, 617, 321, 1077, 620, 773, 1096', 'exp_sup': 0.0, 'utility': 4923}
#  494: {'name': '175, 418, 874, 651', 'exp_sup': 0.0, 'utility': 6434}

# %%
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_foodmart.txt, ./data/foodmart_utility.txt", 0.0004, 700)
algorithm.print_stats("./out/TUHUFP/foodmart/output_foodmart_top_700.txt")
# Out:
# Reading data . . .
# Minimum utility set to: 4804
# {'database util: ': 12011023}
# Top 700 CUPs:
#  1: {'name': '304', 'exp_sup': 14.23, 'utility': 13607}
#  2: {'name': '1373', 'exp_sup': 13.55, 'utility': 25560}
#  3: {'name': '272', 'exp_sup': 13.54, 'utility': 22678}
#  4: {'name': '1293', 'exp_sup': 12.66, 'utility': 8352}
#  5: {'name': '1292', 'exp_sup': 12.6, 'utility': 24642}
#  6: {'name': '545', 'exp_sup': 12.1, 'utility': 9419}
#  7: {'name': '357', 'exp_sup': 11.97, 'utility': 11520}
#  8: {'name': '634', 'exp_sup': 11.88, 'utility': 11881}
#  9: {'name': '617', 'exp_sup': 11.75, 'utility': 7527}
#  10: {'name': '1423', 'exp_sup': 11.75, 'utility': 16116}
#  11: {'name': '916', 'exp_sup': 11.68, 'utility': 15163}
#  12: {'name': '1012', 'exp_sup': 11.65, 'utility': 19861}
#  13: {'name': '903', 'exp_sup': 11.62, 'utility': 14616}
#  14: {'name': '831', 'exp_sup': 11.39, 'utility': 8848}
#  15: {'name': '888', 'exp_sup': 11.38, 'utility': 5280}
#  16: {'name': '918', 'exp_sup': 11.38, 'utility': 18414}
#  17: {'name': '1390', 'exp_sup': 11.26, 'utility': 12415}
#  18: {'name': '404', 'exp_sup': 11.02, 'utility': 7000}
#  19: {'name': '308', 'exp_sup': 10.94, 'utility': 11554}
#  20: {'name': '1351', 'exp_sup': 10.9, 'utility': 9352}
#  21: {'name': '1451', 'exp_sup': 10.9, 'utility': 7614}
#  22: {'name': '1315', 'exp_sup': 10.88, 'utility': 9612}
#  23: {'name': '599', 'exp_sup': 10.79, 'utility': 12519}
#  24: {'name': '932', 'exp_sup': 10.78, 'utility': 8262}
#  25: {'name': '1161', 'exp_sup': 10.54, 'utility': 21540}
#  26: {'name': '276', 'exp_sup': 10.37, 'utility': 18528}
#  27: {'name': '718', 'exp_sup': 10.36, 'utility': 9741}
#  28: {'name': '520', 'exp_sup': 10.36, 'utility': 14840}
#  29: {'name': '386', 'exp_sup': 10.29, 'utility': 10927}
#  30: {'name': '1362', 'exp_sup': 10.29, 'utility': 8046}
#  31: {'name': '1439', 'exp_sup': 10.25, 'utility': 8400}
#  32: {'name': '447', 'exp_sup': 10.23, 'utility': 17856}
#  33: {'name': '1220', 'exp_sup': 10.18, 'utility': 11700}
#  34: {'name': '1508', 'exp_sup': 10.16, 'utility': 19116}
#  35: {'name': '1399', 'exp_sup': 10.11, 'utility': 10324}
#  36: {'name': '1110', 'exp_sup': 10.1, 'utility': 17920}
#  37: {'name': '378', 'exp_sup': 10.08, 'utility': 5994}
#  38: {'name': '69', 'exp_sup': 10.07, 'utility': 16430}
#  39: {'name': '1282', 'exp_sup': 10.05, 'utility': 18232}
#  40: {'name': '749', 'exp_sup': 10.03, 'utility': 11748}
#  41: {'name': '602', 'exp_sup': 10.0, 'utility': 13696}
#  42: {'name': '1442', 'exp_sup': 9.99, 'utility': 10332}
#  43: {'name': '1426', 'exp_sup': 9.96, 'utility': 21692}
#  44: {'name': '391', 'exp_sup': 9.95, 'utility': 8777}
#  45: {'name': '501', 'exp_sup': 9.87, 'utility': 6227}
#  46: {'name': '307', 'exp_sup': 9.83, 'utility': 7400}
#  47: {'name': '1456', 'exp_sup': 9.82, 'utility': 8784}
#  48: {'name': '200', 'exp_sup': 9.8, 'utility': 12190}
#  49: {'name': '326', 'exp_sup': 9.77, 'utility': 13091}
#  50: {'name': '1347', 'exp_sup': 9.71, 'utility': 9912}
#  51: {'name': '1224', 'exp_sup': 9.67, 'utility': 6944}
#  52: {'name': '1291', 'exp_sup': 9.65, 'utility': 12642}
#  53: {'name': '73', 'exp_sup': 9.65, 'utility': 11184}
#  54: {'name': '1487', 'exp_sup': 9.64, 'utility': 5320}
#  55: {'name': '246', 'exp_sup': 9.63, 'utility': 17655}
#  56: {'name': '1257', 'exp_sup': 9.62, 'utility': 9505}
#  57: {'name': '311', 'exp_sup': 9.57, 'utility': 8600}
#  58: {'name': '247', 'exp_sup': 9.52, 'utility': 9256}
#  59: {'name': '54', 'exp_sup': 9.51, 'utility': 12889}
#  60: {'name': '1118', 'exp_sup': 9.5, 'utility': 13178}
#  61: {'name': '1045', 'exp_sup': 9.48, 'utility': 21090}
#  62: {'name': '27', 'exp_sup': 9.44, 'utility': 16165}
#  63: {'name': '1464', 'exp_sup': 9.44, 'utility': 14800}
#  64: {'name': '1048', 'exp_sup': 9.43, 'utility': 11713}
#  65: {'name': '812', 'exp_sup': 9.41, 'utility': 14696}
#  66: {'name': '1473', 'exp_sup': 9.4, 'utility': 13452}
#  67: {'name': '640', 'exp_sup': 9.36, 'utility': 13209}
#  68: {'name': '1264', 'exp_sup': 9.35, 'utility': 11985}
#  69: {'name': '222', 'exp_sup': 9.33, 'utility': 22910}
#  70: {'name': '969', 'exp_sup': 9.33, 'utility': 7920}
#  71: {'name': '278', 'exp_sup': 9.33, 'utility': 18480}
#  72: {'name': '434', 'exp_sup': 9.33, 'utility': 7384}
#  73: {'name': '988', 'exp_sup': 9.3, 'utility': 24187}
#  74: {'name': '266', 'exp_sup': 9.29, 'utility': 10692}
#  75: {'name': '419', 'exp_sup': 9.29, 'utility': 14994}
#  76: {'name': '219', 'exp_sup': 9.27, 'utility': 11844}
#  77: {'name': '382', 'exp_sup': 9.27, 'utility': 9072}
#  78: {'name': '435', 'exp_sup': 9.24, 'utility': 14433}
#  79: {'name': '1516', 'exp_sup': 9.22, 'utility': 15792}
#  80: {'name': '1217', 'exp_sup': 9.21, 'utility': 7239}
#  81: {'name': '890', 'exp_sup': 9.18, 'utility': 12789}
#  82: {'name': '1308', 'exp_sup': 9.18, 'utility': 12642}
#  83: {'name': '728', 'exp_sup': 9.17, 'utility': 11528}
#  84: {'name': '175', 'exp_sup': 9.14, 'utility': 19635}
#  85: {'name': '449', 'exp_sup': 9.12, 'utility': 15867}
#  86: {'name': '1357', 'exp_sup': 9.1, 'utility': 11653}
#  87: {'name': '1281', 'exp_sup': 9.1, 'utility': 13573}
#  88: {'name': '813', 'exp_sup': 9.09, 'utility': 7967}
#  89: {'name': '566', 'exp_sup': 9.05, 'utility': 7120}
#  90: {'name': '604', 'exp_sup': 9.04, 'utility': 6250}
#  91: {'name': '1394', 'exp_sup': 9.01, 'utility': 10870}
#  92: {'name': '1547', 'exp_sup': 9.0, 'utility': 12614}
#  93: {'name': '1338', 'exp_sup': 8.99, 'utility': 10656}
#  94: {'name': '281', 'exp_sup': 8.97, 'utility': 14465}
#  95: {'name': '470', 'exp_sup': 8.96, 'utility': 18259}
#  96: {'name': '941', 'exp_sup': 8.96, 'utility': 18565}
#  97: {'name': '1104', 'exp_sup': 8.96, 'utility': 13965}
#  98: {'name': '383', 'exp_sup': 8.89, 'utility': 14300}
#  99: {'name': '685', 'exp_sup': 8.87, 'utility': 9333}
#  100: {'name': '1119', 'exp_sup': 8.86, 'utility': 13314}
#  101: {'name': '1472', 'exp_sup': 8.86, 'utility': 12760}
#  102: {'name': '111', 'exp_sup': 8.85, 'utility': 17052}
#  103: {'name': '380', 'exp_sup': 8.84, 'utility': 4880}
#  104: {'name': '1348', 'exp_sup': 8.83, 'utility': 14326}
#  105: {'name': '1306', 'exp_sup': 8.83, 'utility': 10127}
#  106: {'name': '584', 'exp_sup': 8.8, 'utility': 12173}
#  107: {'name': '1432', 'exp_sup': 8.77, 'utility': 9180}
#  108: {'name': '1444', 'exp_sup': 8.77, 'utility': 10384}
#  109: {'name': '1397', 'exp_sup': 8.76, 'utility': 5577}
#  110: {'name': '231', 'exp_sup': 8.75, 'utility': 14575}
#  111: {'name': '863', 'exp_sup': 8.74, 'utility': 14006}
#  112: {'name': '1526', 'exp_sup': 8.73, 'utility': 8085}
#  113: {'name': '422', 'exp_sup': 8.73, 'utility': 17616}
#  114: {'name': '236', 'exp_sup': 8.72, 'utility': 9412}
#  115: {'name': '55', 'exp_sup': 8.72, 'utility': 15750}
#  116: {'name': '497', 'exp_sup': 8.66, 'utility': 10472}
#  117: {'name': '606', 'exp_sup': 8.66, 'utility': 12720}
#  118: {'name': '1268', 'exp_sup': 8.66, 'utility': 7150}
#  119: {'name': '1043', 'exp_sup': 8.65, 'utility': 6908}
#  120: {'name': '1470', 'exp_sup': 8.64, 'utility': 11327}
#  121: {'name': '1210', 'exp_sup': 8.63, 'utility': 9681}
#  122: {'name': '883', 'exp_sup': 8.63, 'utility': 13041}
#  123: {'name': '1522', 'exp_sup': 8.62, 'utility': 6147}
#  124: {'name': '1384', 'exp_sup': 8.61, 'utility': 12593}
#  125: {'name': '1296', 'exp_sup': 8.6, 'utility': 14548}
#  126: {'name': '626', 'exp_sup': 8.6, 'utility': 4902}
#  127: {'name': '389', 'exp_sup': 8.59, 'utility': 8771}
#  128: {'name': '1098', 'exp_sup': 8.58, 'utility': 6255}
#  129: {'name': '946', 'exp_sup': 8.55, 'utility': 13965}
#  130: {'name': '943', 'exp_sup': 8.54, 'utility': 10621}
#  131: {'name': '1499', 'exp_sup': 8.53, 'utility': 6255}
#  132: {'name': '1310', 'exp_sup': 8.53, 'utility': 19102}
#  133: {'name': '108', 'exp_sup': 8.52, 'utility': 9417}
#  134: {'name': '260', 'exp_sup': 8.51, 'utility': 11592}
#  135: {'name': '772', 'exp_sup': 8.5, 'utility': 9894}
#  136: {'name': '414', 'exp_sup': 8.49, 'utility': 12188}
#  137: {'name': '844', 'exp_sup': 8.48, 'utility': 14564}
#  138: {'name': '580', 'exp_sup': 8.45, 'utility': 12532}
#  139: {'name': '170', 'exp_sup': 8.45, 'utility': 14080}
#  140: {'name': '1089', 'exp_sup': 8.41, 'utility': 10621}
#  141: {'name': '502', 'exp_sup': 8.39, 'utility': 16801}
#  142: {'name': '1543', 'exp_sup': 8.36, 'utility': 10912}
#  143: {'name': '44', 'exp_sup': 8.34, 'utility': 12298}
#  144: {'name': '379', 'exp_sup': 8.34, 'utility': 15785}
#  145: {'name': '469', 'exp_sup': 8.32, 'utility': 6837}
#  146: {'name': '493', 'exp_sup': 8.31, 'utility': 12408}
#  147: {'name': '625', 'exp_sup': 8.31, 'utility': 9821}
#  148: {'name': '825', 'exp_sup': 8.29, 'utility': 12452}
#  149: {'name': '154', 'exp_sup': 8.29, 'utility': 9016}
#  150: {'name': '321', 'exp_sup': 8.28, 'utility': 12291}
#  151: {'name': '1247', 'exp_sup': 8.26, 'utility': 8064}
#  152: {'name': '1340', 'exp_sup': 8.25, 'utility': 13107}
#  153: {'name': '324', 'exp_sup': 8.24, 'utility': 7289}
#  154: {'name': '508', 'exp_sup': 8.23, 'utility': 17055}
#  155: {'name': '577', 'exp_sup': 8.22, 'utility': 11004}
#  156: {'name': '448', 'exp_sup': 8.21, 'utility': 9086}
#  157: {'name': '673', 'exp_sup': 8.2, 'utility': 11782}
#  158: {'name': '20', 'exp_sup': 8.2, 'utility': 14178}
#  159: {'name': '968', 'exp_sup': 8.19, 'utility': 5760}
#  160: {'name': '1160', 'exp_sup': 8.19, 'utility': 13517}
#  161: {'name': '795', 'exp_sup': 8.18, 'utility': 4992}
#  162: {'name': '1389', 'exp_sup': 8.17, 'utility': 15254}
#  163: {'name': '1251', 'exp_sup': 8.15, 'utility': 14320}
#  164: {'name': '1483', 'exp_sup': 8.14, 'utility': 8520}
#  165: {'name': '1075', 'exp_sup': 8.12, 'utility': 6314}
#  166: {'name': '227', 'exp_sup': 8.09, 'utility': 7722}
#  167: {'name': '1174', 'exp_sup': 8.09, 'utility': 8853}
#  168: {'name': '1468', 'exp_sup': 8.08, 'utility': 5670}
#  169: {'name': '443', 'exp_sup': 8.08, 'utility': 6783}
#  170: {'name': '1294', 'exp_sup': 8.07, 'utility': 7052}
#  171: {'name': '1061', 'exp_sup': 8.07, 'utility': 8466}
#  172: {'name': '1050', 'exp_sup': 8.06, 'utility': 5632}
#  173: {'name': '1180', 'exp_sup': 8.06, 'utility': 19890}
#  174: {'name': '173', 'exp_sup': 8.06, 'utility': 6864}
#  175: {'name': '819', 'exp_sup': 8.06, 'utility': 11634}
#  176: {'name': '823', 'exp_sup': 8.05, 'utility': 15435}
#  177: {'name': '1077', 'exp_sup': 8.05, 'utility': 15455}
#  178: {'name': '951', 'exp_sup': 8.05, 'utility': 9457}
#  179: {'name': '225', 'exp_sup': 8.04, 'utility': 22951}
#  180: {'name': '1478', 'exp_sup': 8.03, 'utility': 9044}
#  181: {'name': '1056', 'exp_sup': 8.03, 'utility': 10835}
#  182: {'name': '284', 'exp_sup': 8.02, 'utility': 4950}
#  183: {'name': '521', 'exp_sup': 8.02, 'utility': 14155}
#  184: {'name': '1165', 'exp_sup': 8.01, 'utility': 12690}
#  185: {'name': '907', 'exp_sup': 8.01, 'utility': 17100}
#  186: {'name': '1154', 'exp_sup': 8.01, 'utility': 7304}
#  187: {'name': '464', 'exp_sup': 8.01, 'utility': 14952}
#  188: {'name': '1380', 'exp_sup': 7.99, 'utility': 19548}
#  189: {'name': '703', 'exp_sup': 7.98, 'utility': 13959}
#  190: {'name': '980', 'exp_sup': 7.98, 'utility': 7740}
#  191: {'name': '117', 'exp_sup': 7.97, 'utility': 10175}
#  192: {'name': '919', 'exp_sup': 7.96, 'utility': 6930}
#  193: {'name': '1079', 'exp_sup': 7.96, 'utility': 7072}
#  194: {'name': '528', 'exp_sup': 7.96, 'utility': 5952}
#  195: {'name': '541', 'exp_sup': 7.95, 'utility': 8272}
#  196: {'name': '313', 'exp_sup': 7.94, 'utility': 16245}
#  197: {'name': '1518', 'exp_sup': 7.94, 'utility': 20416}
#  198: {'name': '376', 'exp_sup': 7.93, 'utility': 9988}
#  199: {'name': '479', 'exp_sup': 7.93, 'utility': 8385}
#  200: {'name': '563', 'exp_sup': 7.92, 'utility': 6216}
#  201: {'name': '774', 'exp_sup': 7.9, 'utility': 12005}
#  202: {'name': '650', 'exp_sup': 7.88, 'utility': 8370}
#  203: {'name': '415', 'exp_sup': 7.88, 'utility': 11640}
#  204: {'name': '618', 'exp_sup': 7.88, 'utility': 5600}
#  205: {'name': '721', 'exp_sup': 7.86, 'utility': 9485}
#  206: {'name': '374', 'exp_sup': 7.83, 'utility': 6407}
#  207: {'name': '153', 'exp_sup': 7.83, 'utility': 14144}
#  208: {'name': '1410', 'exp_sup': 7.82, 'utility': 6536}
#  209: {'name': '742', 'exp_sup': 7.8, 'utility': 12350}
#  210: {'name': '1346', 'exp_sup': 7.77, 'utility': 10105}
#  211: {'name': '851', 'exp_sup': 7.76, 'utility': 9030}
#  212: {'name': '836', 'exp_sup': 7.75, 'utility': 5428}
#  213: {'name': '877', 'exp_sup': 7.74, 'utility': 8374}
#  214: {'name': '529', 'exp_sup': 7.74, 'utility': 10074}
#  215: {'name': '878', 'exp_sup': 7.74, 'utility': 9724}
#  216: {'name': '913', 'exp_sup': 7.74, 'utility': 7476}
#  217: {'name': '1029', 'exp_sup': 7.74, 'utility': 8736}
#  218: {'name': '1254', 'exp_sup': 7.73, 'utility': 14680}
#  219: {'name': '1116', 'exp_sup': 7.73, 'utility': 11377}
#  220: {'name': '375', 'exp_sup': 7.72, 'utility': 8931}
#  221: {'name': '1250', 'exp_sup': 7.71, 'utility': 10368}
#  222: {'name': '1086', 'exp_sup': 7.69, 'utility': 10365}
#  223: {'name': '816', 'exp_sup': 7.69, 'utility': 10992}
#  224: {'name': '924', 'exp_sup': 7.69, 'utility': 14040}
#  225: {'name': '1372', 'exp_sup': 7.69, 'utility': 10458}
#  226: {'name': '1237', 'exp_sup': 7.68, 'utility': 13750}
#  227: {'name': '834', 'exp_sup': 7.67, 'utility': 10656}
#  228: {'name': '915', 'exp_sup': 7.67, 'utility': 12341}
#  229: {'name': '49', 'exp_sup': 7.66, 'utility': 17238}
#  230: {'name': '824', 'exp_sup': 7.64, 'utility': 10550}
#  231: {'name': '992', 'exp_sup': 7.64, 'utility': 9486}
#  232: {'name': '787', 'exp_sup': 7.64, 'utility': 5662}
#  233: {'name': '1241', 'exp_sup': 7.62, 'utility': 12516}
#  234: {'name': '1463', 'exp_sup': 7.62, 'utility': 8118}
#  235: {'name': '600', 'exp_sup': 7.62, 'utility': 9471}
#  236: {'name': '1416', 'exp_sup': 7.62, 'utility': 12788}
#  237: {'name': '24', 'exp_sup': 7.6, 'utility': 10726}
#  238: {'name': '619', 'exp_sup': 7.59, 'utility': 10575}
#  239: {'name': '555', 'exp_sup': 7.59, 'utility': 12960}
#  240: {'name': '1540', 'exp_sup': 7.59, 'utility': 14432}
#  241: {'name': '418', 'exp_sup': 7.58, 'utility': 14536}
#  242: {'name': '1368', 'exp_sup': 7.57, 'utility': 19525}
#  243: {'name': '1019', 'exp_sup': 7.56, 'utility': 11968}
#  244: {'name': '385', 'exp_sup': 7.55, 'utility': 5148}
#  245: {'name': '1493', 'exp_sup': 7.55, 'utility': 16632}
#  246: {'name': '191', 'exp_sup': 7.54, 'utility': 12054}
#  247: {'name': '882', 'exp_sup': 7.54, 'utility': 12201}
#  248: {'name': '1142', 'exp_sup': 7.54, 'utility': 11800}
#  249: {'name': '922', 'exp_sup': 7.53, 'utility': 12950}
#  250: {'name': '853', 'exp_sup': 7.52, 'utility': 12804}
#  251: {'name': '261', 'exp_sup': 7.52, 'utility': 12844}
#  252: {'name': '789', 'exp_sup': 7.51, 'utility': 12670}
#  253: {'name': '125', 'exp_sup': 7.51, 'utility': 9737}
#  254: {'name': '756', 'exp_sup': 7.5, 'utility': 13393}
#  255: {'name': '179', 'exp_sup': 7.5, 'utility': 17875}
#  256: {'name': '410', 'exp_sup': 7.49, 'utility': 6174}
#  257: {'name': '488', 'exp_sup': 7.49, 'utility': 10101}
#  258: {'name': '522', 'exp_sup': 7.49, 'utility': 8140}
#  259: {'name': '1408', 'exp_sup': 7.49, 'utility': 9805}
#  260: {'name': '1222', 'exp_sup': 7.48, 'utility': 9555}
#  261: {'name': '1252', 'exp_sup': 7.48, 'utility': 11391}
#  262: {'name': '811', 'exp_sup': 7.48, 'utility': 14256}
#  263: {'name': '1366', 'exp_sup': 7.46, 'utility': 11311}
#  264: {'name': '534', 'exp_sup': 7.46, 'utility': 11491}
#  265: {'name': '854', 'exp_sup': 7.45, 'utility': 7040}
#  266: {'name': '365', 'exp_sup': 7.45, 'utility': 17424}
#  267: {'name': '832', 'exp_sup': 7.45, 'utility': 15552}
#  268: {'name': '82', 'exp_sup': 7.45, 'utility': 12150}
#  269: {'name': '575', 'exp_sup': 7.44, 'utility': 13769}
#  270: {'name': '1063', 'exp_sup': 7.43, 'utility': 14303}
#  271: {'name': '739', 'exp_sup': 7.43, 'utility': 8568}
#  272: {'name': '547', 'exp_sup': 7.41, 'utility': 9702}
#  273: {'name': '730', 'exp_sup': 7.39, 'utility': 8084}
#  274: {'name': '800', 'exp_sup': 7.39, 'utility': 11729}
#  275: {'name': '792', 'exp_sup': 7.39, 'utility': 7668}
#  276: {'name': '370', 'exp_sup': 7.38, 'utility': 4968}
#  277: {'name': '1007', 'exp_sup': 7.37, 'utility': 13166}
#  278: {'name': '1418', 'exp_sup': 7.36, 'utility': 6279}
#  279: {'name': '662', 'exp_sup': 7.35, 'utility': 7585}
#  280: {'name': '288', 'exp_sup': 7.35, 'utility': 10582}
#  281: {'name': '1088', 'exp_sup': 7.34, 'utility': 15604}
#  282: {'name': '805', 'exp_sup': 7.33, 'utility': 9216}
#  283: {'name': '1070', 'exp_sup': 7.32, 'utility': 13689}
#  284: {'name': '1361', 'exp_sup': 7.32, 'utility': 7240}
#  285: {'name': '556', 'exp_sup': 7.3, 'utility': 13975}
#  286: {'name': '767', 'exp_sup': 7.3, 'utility': 6662}
#  287: {'name': '963', 'exp_sup': 7.3, 'utility': 12000}
#  288: {'name': '303', 'exp_sup': 7.29, 'utility': 9030}
#  289: {'name': '189', 'exp_sup': 7.29, 'utility': 14835}
#  290: {'name': '546', 'exp_sup': 7.28, 'utility': 10842}
#  291: {'name': '129', 'exp_sup': 7.28, 'utility': 5115}
#  292: {'name': '914', 'exp_sup': 7.27, 'utility': 9594}
#  293: {'name': '285', 'exp_sup': 7.27, 'utility': 7626}
#  294: {'name': '942', 'exp_sup': 7.26, 'utility': 7722}
#  295: {'name': '468', 'exp_sup': 7.26, 'utility': 7830}
#  296: {'name': '691', 'exp_sup': 7.26, 'utility': 11685}
#  297: {'name': '1538', 'exp_sup': 7.26, 'utility': 11893}
#  298: {'name': '158', 'exp_sup': 7.26, 'utility': 6004}
#  299: {'name': '1094', 'exp_sup': 7.26, 'utility': 17342}
#  300: {'name': '1324', 'exp_sup': 7.25, 'utility': 12578}
#  301: {'name': '346', 'exp_sup': 7.24, 'utility': 9752}
#  302: {'name': '937', 'exp_sup': 7.24, 'utility': 19133}
#  303: {'name': '1358', 'exp_sup': 7.22, 'utility': 6720}
#  304: {'name': '234', 'exp_sup': 7.22, 'utility': 12690}
#  305: {'name': '11', 'exp_sup': 7.21, 'utility': 16497}
#  306: {'name': '100', 'exp_sup': 7.2, 'utility': 8580}
#  307: {'name': '1497', 'exp_sup': 7.19, 'utility': 19406}
#  308: {'name': '1279', 'exp_sup': 7.18, 'utility': 11840}
#  309: {'name': '1055', 'exp_sup': 7.18, 'utility': 5184}
#  310: {'name': '1096', 'exp_sup': 7.17, 'utility': 9984}
#  311: {'name': '491', 'exp_sup': 7.17, 'utility': 14742}
#  312: {'name': '957', 'exp_sup': 7.17, 'utility': 10395}
#  313: {'name': '17', 'exp_sup': 7.16, 'utility': 11063}
#  314: {'name': '923', 'exp_sup': 7.16, 'utility': 7056}
#  315: {'name': '887', 'exp_sup': 7.14, 'utility': 7200}
#  316: {'name': '408', 'exp_sup': 7.14, 'utility': 11000}
#  317: {'name': '322', 'exp_sup': 7.14, 'utility': 13112}
#  318: {'name': '495', 'exp_sup': 7.14, 'utility': 5265}
#  319: {'name': '1267', 'exp_sup': 7.13, 'utility': 7520}
#  320: {'name': '149', 'exp_sup': 7.13, 'utility': 11952}
#  321: {'name': '1114', 'exp_sup': 7.13, 'utility': 11286}
#  322: {'name': '377', 'exp_sup': 7.13, 'utility': 10290}
#  323: {'name': '300', 'exp_sup': 7.12, 'utility': 14700}
#  324: {'name': '387', 'exp_sup': 7.12, 'utility': 13014}
#  325: {'name': '715', 'exp_sup': 7.11, 'utility': 6665}
#  326: {'name': '753', 'exp_sup': 7.11, 'utility': 8315}
#  327: {'name': '1001', 'exp_sup': 7.11, 'utility': 12852}
#  328: {'name': '1277', 'exp_sup': 7.1, 'utility': 8890}
#  329: {'name': '283', 'exp_sup': 7.09, 'utility': 14469}
#  330: {'name': '503', 'exp_sup': 7.07, 'utility': 8742}
#  331: {'name': '10', 'exp_sup': 7.07, 'utility': 5538}
#  332: {'name': '46', 'exp_sup': 7.06, 'utility': 11008}
#  333: {'name': '1190', 'exp_sup': 7.06, 'utility': 6110}
#  334: {'name': '178', 'exp_sup': 7.06, 'utility': 5320}
#  335: {'name': '865', 'exp_sup': 7.05, 'utility': 9758}
#  336: {'name': '1179', 'exp_sup': 7.04, 'utility': 11046}
#  337: {'name': '874', 'exp_sup': 7.04, 'utility': 7146}
#  338: {'name': '1134', 'exp_sup': 7.03, 'utility': 7098}
#  339: {'name': '1376', 'exp_sup': 7.03, 'utility': 6720}
#  340: {'name': '958', 'exp_sup': 7.03, 'utility': 6392}
#  341: {'name': '1417', 'exp_sup': 7.03, 'utility': 13357}
#  342: {'name': '1412', 'exp_sup': 7.03, 'utility': 7137}
#  343: {'name': '639', 'exp_sup': 7.03, 'utility': 15415}
#  344: {'name': '1081', 'exp_sup': 7.03, 'utility': 15423}
#  345: {'name': '1272', 'exp_sup': 7.02, 'utility': 12152}
#  346: {'name': '860', 'exp_sup': 7.02, 'utility': 10296}
#  347: {'name': '934', 'exp_sup': 7.01, 'utility': 5610}
#  348: {'name': '1209', 'exp_sup': 7.01, 'utility': 10530}
#  349: {'name': '991', 'exp_sup': 7.01, 'utility': 13650}
#  350: {'name': '1506', 'exp_sup': 7.0, 'utility': 9604}
#  351: {'name': '891', 'exp_sup': 6.99, 'utility': 12844}
#  352: {'name': '223', 'exp_sup': 6.97, 'utility': 14036}
#  353: {'name': '1353', 'exp_sup': 6.97, 'utility': 8064}
#  354: {'name': '1184', 'exp_sup': 6.96, 'utility': 11928}
#  355: {'name': '1328', 'exp_sup': 6.96, 'utility': 10165}
#  356: {'name': '953', 'exp_sup': 6.96, 'utility': 8768}
#  357: {'name': '727', 'exp_sup': 6.95, 'utility': 7640}
#  358: {'name': '725', 'exp_sup': 6.95, 'utility': 6407}
#  359: {'name': '667', 'exp_sup': 6.94, 'utility': 10906}
#  360: {'name': '1117', 'exp_sup': 6.93, 'utility': 14560}
#  361: {'name': '339', 'exp_sup': 6.93, 'utility': 6300}
#  362: {'name': '446', 'exp_sup': 6.93, 'utility': 20625}
#  363: {'name': '516', 'exp_sup': 6.93, 'utility': 7770}
#  364: {'name': '80', 'exp_sup': 6.92, 'utility': 17060}
#  365: {'name': '1062', 'exp_sup': 6.91, 'utility': 8330}
#  366: {'name': '1049', 'exp_sup': 6.91, 'utility': 15327}
#  367: {'name': '489', 'exp_sup': 6.9, 'utility': 12291}
#  368: {'name': '104', 'exp_sup': 6.89, 'utility': 15171}
#  369: {'name': '48', 'exp_sup': 6.89, 'utility': 6204}
#  370: {'name': '269', 'exp_sup': 6.89, 'utility': 8520}
#  371: {'name': '896', 'exp_sup': 6.88, 'utility': 13127}
#  372: {'name': '1106', 'exp_sup': 6.88, 'utility': 6073}
#  373: {'name': '760', 'exp_sup': 6.86, 'utility': 6919}
#  374: {'name': '1398', 'exp_sup': 6.86, 'utility': 17002}
#  375: {'name': '1386', 'exp_sup': 6.86, 'utility': 7544}
#  376: {'name': '1544', 'exp_sup': 6.85, 'utility': 5256}
#  377: {'name': '1145', 'exp_sup': 6.85, 'utility': 6594}
#  378: {'name': '1554', 'exp_sup': 6.84, 'utility': 8636}
#  379: {'name': '312', 'exp_sup': 6.84, 'utility': 8520}
#  380: {'name': '1028', 'exp_sup': 6.83, 'utility': 8960}
#  381: {'name': '1455', 'exp_sup': 6.82, 'utility': 10364}
#  382: {'name': '67', 'exp_sup': 6.82, 'utility': 10416}
#  383: {'name': '23', 'exp_sup': 6.81, 'utility': 5600}
#  384: {'name': '202', 'exp_sup': 6.8, 'utility': 5364}
#  385: {'name': '1438', 'exp_sup': 6.79, 'utility': 5754}
#  386: {'name': '1530', 'exp_sup': 6.78, 'utility': 6096}
#  387: {'name': '1485', 'exp_sup': 6.77, 'utility': 6750}
#  388: {'name': '22', 'exp_sup': 6.77, 'utility': 10763}
#  389: {'name': '394', 'exp_sup': 6.77, 'utility': 12520}
#  390: {'name': '747', 'exp_sup': 6.76, 'utility': 7137}
#  391: {'name': '751', 'exp_sup': 6.76, 'utility': 11607}
#  392: {'name': '560', 'exp_sup': 6.76, 'utility': 5160}
#  393: {'name': '58', 'exp_sup': 6.75, 'utility': 8778}
#  394: {'name': '63', 'exp_sup': 6.74, 'utility': 12390}
#  395: {'name': '898', 'exp_sup': 6.72, 'utility': 7308}
#  396: {'name': '911', 'exp_sup': 6.71, 'utility': 5910}
#  397: {'name': '1383', 'exp_sup': 6.71, 'utility': 9583}
#  398: {'name': '1136', 'exp_sup': 6.71, 'utility': 15162}
#  399: {'name': '587', 'exp_sup': 6.69, 'utility': 10464}
#  400: {'name': '1465', 'exp_sup': 6.69, 'utility': 11430}
#  401: {'name': '999', 'exp_sup': 6.69, 'utility': 10027}
#  402: {'name': '1363', 'exp_sup': 6.68, 'utility': 9044}
#  403: {'name': '1242', 'exp_sup': 6.68, 'utility': 7326}
#  404: {'name': '83', 'exp_sup': 6.68, 'utility': 20563}
#  405: {'name': '16', 'exp_sup': 6.67, 'utility': 13788}
#  406: {'name': '138', 'exp_sup': 6.67, 'utility': 9180}
#  407: {'name': '554', 'exp_sup': 6.66, 'utility': 14130}
#  408: {'name': '136', 'exp_sup': 6.66, 'utility': 13932}
#  409: {'name': '105', 'exp_sup': 6.66, 'utility': 13020}
#  410: {'name': '174', 'exp_sup': 6.66, 'utility': 5472}
#  411: {'name': '1491', 'exp_sup': 6.65, 'utility': 9030}
#  412: {'name': '931', 'exp_sup': 6.65, 'utility': 6270}
#  413: {'name': '785', 'exp_sup': 6.64, 'utility': 7517}
#  414: {'name': '341', 'exp_sup': 6.64, 'utility': 9418}
#  415: {'name': '9', 'exp_sup': 6.63, 'utility': 9922}
#  416: {'name': '1082', 'exp_sup': 6.63, 'utility': 8404}
#  417: {'name': '33', 'exp_sup': 6.62, 'utility': 6936}
#  418: {'name': '28', 'exp_sup': 6.61, 'utility': 14076}
#  419: {'name': '609', 'exp_sup': 6.61, 'utility': 13986}
#  420: {'name': '952', 'exp_sup': 6.61, 'utility': 11931}
#  421: {'name': '137', 'exp_sup': 6.61, 'utility': 17020}
#  422: {'name': '333', 'exp_sup': 6.59, 'utility': 6336}
#  423: {'name': '95', 'exp_sup': 6.59, 'utility': 5548}
#  424: {'name': '438', 'exp_sup': 6.58, 'utility': 5404}
#  425: {'name': '1459', 'exp_sup': 6.57, 'utility': 7007}
#  426: {'name': '548', 'exp_sup': 6.56, 'utility': 10433}
#  427: {'name': '68', 'exp_sup': 6.55, 'utility': 12104}
#  428: {'name': '274', 'exp_sup': 6.55, 'utility': 16456}
#  429: {'name': '430', 'exp_sup': 6.55, 'utility': 7920}
#  430: {'name': '480', 'exp_sup': 6.54, 'utility': 6927}
#  431: {'name': '299', 'exp_sup': 6.54, 'utility': 5880}
#  432: {'name': '1152', 'exp_sup': 6.54, 'utility': 10520}
#  433: {'name': '369', 'exp_sup': 6.54, 'utility': 8042}
#  434: {'name': '856', 'exp_sup': 6.53, 'utility': 10755}
#  435: {'name': '1259', 'exp_sup': 6.53, 'utility': 7918}
#  436: {'name': '131', 'exp_sup': 6.53, 'utility': 8160}
#  437: {'name': '902', 'exp_sup': 6.52, 'utility': 5043}
#  438: {'name': '523', 'exp_sup': 6.52, 'utility': 6536}
#  439: {'name': '537', 'exp_sup': 6.51, 'utility': 9010}
#  440: {'name': '1312', 'exp_sup': 6.5, 'utility': 5508}
#  441: {'name': '437', 'exp_sup': 6.5, 'utility': 5910}
#  442: {'name': '373', 'exp_sup': 6.5, 'utility': 11311}
#  443: {'name': '1500', 'exp_sup': 6.5, 'utility': 9640}
#  444: {'name': '1457', 'exp_sup': 6.5, 'utility': 9018}
#  445: {'name': '803', 'exp_sup': 6.49, 'utility': 13338}
#  446: {'name': '1067', 'exp_sup': 6.49, 'utility': 5742}
#  447: {'name': '559', 'exp_sup': 6.48, 'utility': 13983}
#  448: {'name': '653', 'exp_sup': 6.48, 'utility': 10286}
#  449: {'name': '53', 'exp_sup': 6.48, 'utility': 14801}
#  450: {'name': '1492', 'exp_sup': 6.48, 'utility': 5467}
#  451: {'name': '196', 'exp_sup': 6.48, 'utility': 8645}
#  452: {'name': '8', 'exp_sup': 6.47, 'utility': 12691}
#  453: {'name': '1156', 'exp_sup': 6.46, 'utility': 6916}
#  454: {'name': '372', 'exp_sup': 6.46, 'utility': 10746}
#  455: {'name': '519', 'exp_sup': 6.46, 'utility': 12606}
#  456: {'name': '292', 'exp_sup': 6.44, 'utility': 5611}
#  457: {'name': '864', 'exp_sup': 6.43, 'utility': 6189}
#  458: {'name': '1550', 'exp_sup': 6.43, 'utility': 8869}
#  459: {'name': '316', 'exp_sup': 6.43, 'utility': 5764}
#  460: {'name': '182', 'exp_sup': 6.43, 'utility': 6440}
#  461: {'name': '1437', 'exp_sup': 6.43, 'utility': 6090}
#  462: {'name': '409', 'exp_sup': 6.42, 'utility': 18768}
#  463: {'name': '1159', 'exp_sup': 6.42, 'utility': 15498}
#  464: {'name': '544', 'exp_sup': 6.41, 'utility': 10915}
#  465: {'name': '130', 'exp_sup': 6.41, 'utility': 9366}
#  466: {'name': '442', 'exp_sup': 6.41, 'utility': 9184}
#  467: {'name': '862', 'exp_sup': 6.41, 'utility': 10101}
#  468: {'name': '656', 'exp_sup': 6.41, 'utility': 13475}
#  469: {'name': '123', 'exp_sup': 6.4, 'utility': 14976}
#  470: {'name': '1002', 'exp_sup': 6.4, 'utility': 11308}
#  471: {'name': '613', 'exp_sup': 6.4, 'utility': 5824}
#  472: {'name': '323', 'exp_sup': 6.38, 'utility': 15400}
#  473: {'name': '235', 'exp_sup': 6.38, 'utility': 15265}
#  474: {'name': '1489', 'exp_sup': 6.38, 'utility': 7266}
#  475: {'name': '1253', 'exp_sup': 6.38, 'utility': 7182}
#  476: {'name': '140', 'exp_sup': 6.36, 'utility': 6188}
#  477: {'name': '921', 'exp_sup': 6.36, 'utility': 6345}
#  478: {'name': '1329', 'exp_sup': 6.36, 'utility': 5280}
#  479: {'name': '1213', 'exp_sup': 6.35, 'utility': 12301}
#  480: {'name': '160', 'exp_sup': 6.35, 'utility': 7668}
#  481: {'name': '1066', 'exp_sup': 6.33, 'utility': 11271}
#  482: {'name': '702', 'exp_sup': 6.33, 'utility': 18048}
#  483: {'name': '1379', 'exp_sup': 6.33, 'utility': 5952}
#  484: {'name': '1323', 'exp_sup': 6.32, 'utility': 8232}
#  485: {'name': '675', 'exp_sup': 6.32, 'utility': 10770}
#  486: {'name': '568', 'exp_sup': 6.31, 'utility': 12654}
#  487: {'name': '807', 'exp_sup': 6.3, 'utility': 5499}
#  488: {'name': '186', 'exp_sup': 6.3, 'utility': 9366}
#  489: {'name': '402', 'exp_sup': 6.3, 'utility': 4851}
#  490: {'name': '1504', 'exp_sup': 6.28, 'utility': 5082}
#  491: {'name': '218', 'exp_sup': 6.27, 'utility': 14448}
#  492: {'name': '72', 'exp_sup': 6.27, 'utility': 8768}
#  493: {'name': '835', 'exp_sup': 6.26, 'utility': 14309}
#  494: {'name': '7', 'exp_sup': 6.25, 'utility': 8352}
#  495: {'name': '242', 'exp_sup': 6.25, 'utility': 10101}
#  496: {'name': '1248', 'exp_sup': 6.25, 'utility': 12653}
#  497: {'name': '610', 'exp_sup': 6.23, 'utility': 11577}
#  498: {'name': '268', 'exp_sup': 6.23, 'utility': 5536}
#  499: {'name': '1375', 'exp_sup': 6.23, 'utility': 8733}
#  500: {'name': '78', 'exp_sup': 6.22, 'utility': 8103}
#  501: {'name': '798', 'exp_sup': 6.21, 'utility': 10569}
#  502: {'name': '690', 'exp_sup': 6.21, 'utility': 5328}
#  503: {'name': '1336', 'exp_sup': 6.2, 'utility': 14916}
#  504: {'name': '1146', 'exp_sup': 6.2, 'utility': 12336}
#  505: {'name': '652', 'exp_sup': 6.19, 'utility': 5010}
#  506: {'name': '1107', 'exp_sup': 6.18, 'utility': 9990}
#  507: {'name': '930', 'exp_sup': 6.18, 'utility': 6512}
#  508: {'name': '1345', 'exp_sup': 6.17, 'utility': 16927}
#  509: {'name': '121', 'exp_sup': 6.16, 'utility': 11920}
#  510: {'name': '899', 'exp_sup': 6.16, 'utility': 7296}
#  511: {'name': '1006', 'exp_sup': 6.15, 'utility': 8988}
#  512: {'name': '504', 'exp_sup': 6.15, 'utility': 6992}
#  513: {'name': '474', 'exp_sup': 6.15, 'utility': 16192}
#  514: {'name': '1076', 'exp_sup': 6.15, 'utility': 14580}
#  515: {'name': '1502', 'exp_sup': 6.14, 'utility': 11521}
#  516: {'name': '1402', 'exp_sup': 6.13, 'utility': 10360}
#  517: {'name': '356', 'exp_sup': 6.12, 'utility': 8496}
#  518: {'name': '553', 'exp_sup': 6.12, 'utility': 6303}
#  519: {'name': '273', 'exp_sup': 6.12, 'utility': 8284}
#  520: {'name': '277', 'exp_sup': 6.12, 'utility': 9881}
#  521: {'name': '695', 'exp_sup': 6.12, 'utility': 14432}
#  522: {'name': '518', 'exp_sup': 6.12, 'utility': 6664}
#  523: {'name': '840', 'exp_sup': 6.12, 'utility': 5206}
#  524: {'name': '445', 'exp_sup': 6.11, 'utility': 14878}
#  525: {'name': '933', 'exp_sup': 6.11, 'utility': 12844}
#  526: {'name': '143', 'exp_sup': 6.11, 'utility': 8118}
#  527: {'name': '530', 'exp_sup': 6.11, 'utility': 16168}
#  528: {'name': '1278', 'exp_sup': 6.11, 'utility': 14382}
#  529: {'name': '614', 'exp_sup': 6.1, 'utility': 18522}
#  530: {'name': '1343', 'exp_sup': 6.1, 'utility': 11767}
#  531: {'name': '700', 'exp_sup': 6.1, 'utility': 6695}
#  532: {'name': '204', 'exp_sup': 6.09, 'utility': 5440}
#  533: {'name': '406', 'exp_sup': 6.09, 'utility': 7051}
#  534: {'name': '972', 'exp_sup': 6.09, 'utility': 7359}
#  535: {'name': '1411', 'exp_sup': 6.09, 'utility': 7220}
#  536: {'name': '532', 'exp_sup': 6.09, 'utility': 15867}
#  537: {'name': '188', 'exp_sup': 6.09, 'utility': 9030}
#  538: {'name': '1320', 'exp_sup': 6.09, 'utility': 8246}
#  539: {'name': '657', 'exp_sup': 6.08, 'utility': 7632}
#  540: {'name': '201', 'exp_sup': 6.08, 'utility': 6975}
#  541: {'name': '330', 'exp_sup': 6.08, 'utility': 14726}
#  542: {'name': '940', 'exp_sup': 6.07, 'utility': 11360}
#  543: {'name': '85', 'exp_sup': 6.07, 'utility': 5032}
#  544: {'name': '533', 'exp_sup': 6.06, 'utility': 8228}
#  545: {'name': '1177', 'exp_sup': 6.06, 'utility': 7700}
#  546: {'name': '1047', 'exp_sup': 6.06, 'utility': 11951}
#  547: {'name': '1227', 'exp_sup': 6.05, 'utility': 8992}
#  548: {'name': '1080', 'exp_sup': 6.04, 'utility': 10074}
#  549: {'name': '676', 'exp_sup': 6.04, 'utility': 12824}
#  550: {'name': '1359', 'exp_sup': 6.04, 'utility': 5828}
#  551: {'name': '1093', 'exp_sup': 6.04, 'utility': 15174}
#  552: {'name': '34', 'exp_sup': 6.04, 'utility': 6421}
#  553: {'name': '689', 'exp_sup': 6.03, 'utility': 6864}
#  554: {'name': '1099', 'exp_sup': 6.02, 'utility': 13932}
#  555: {'name': '436', 'exp_sup': 6.02, 'utility': 6579}
#  556: {'name': '876', 'exp_sup': 6.02, 'utility': 6156}
#  557: {'name': '1150', 'exp_sup': 6.02, 'utility': 15631}
#  558: {'name': '270', 'exp_sup': 6.02, 'utility': 11424}
#  559: {'name': '714', 'exp_sup': 6.02, 'utility': 9720}
#  560: {'name': '152', 'exp_sup': 6.01, 'utility': 10115}
#  561: {'name': '1162', 'exp_sup': 6.01, 'utility': 6195}
#  562: {'name': '102', 'exp_sup': 6.0, 'utility': 11270}
#  563: {'name': '51', 'exp_sup': 6.0, 'utility': 5586}
#  564: {'name': '1313', 'exp_sup': 5.99, 'utility': 12152}
#  565: {'name': '13', 'exp_sup': 5.98, 'utility': 9540}
#  566: {'name': '848', 'exp_sup': 5.97, 'utility': 8357}
#  567: {'name': '744', 'exp_sup': 5.96, 'utility': 14467}
#  568: {'name': '360', 'exp_sup': 5.96, 'utility': 5371}
#  569: {'name': '648', 'exp_sup': 5.95, 'utility': 7888}
#  570: {'name': '164', 'exp_sup': 5.95, 'utility': 11286}
#  571: {'name': '1085', 'exp_sup': 5.94, 'utility': 7168}
#  572: {'name': '750', 'exp_sup': 5.94, 'utility': 5460}
#  573: {'name': '1499, 1056', 'exp_sup': 1.52, 'utility': 4891}
#  574: {'name': '890, 191', 'exp_sup': 1.37, 'utility': 5715}
#  575: {'name': '819, 1279', 'exp_sup': 1.27, 'utility': 6303}
#  576: {'name': '1282, 1066', 'exp_sup': 1.17, 'utility': 5408}
#  577: {'name': '789, 556', 'exp_sup': 1.1, 'utility': 5496}
#  578: {'name': '789, 1248', 'exp_sup': 0.99, 'utility': 4865}
#  579: {'name': '890, 1410, 1493', 'exp_sup': 0.91, 'utility': 4876}
#  580: {'name': '491, 1227', 'exp_sup': 0.88, 'utility': 5407}
#  581: {'name': '1399, 1426', 'exp_sup': 0.86, 'utility': 5680}
#  582: {'name': '285, 1094', 'exp_sup': 0.86, 'utility': 4881}
#  583: {'name': '111, 937', 'exp_sup': 0.81, 'utility': 4963}
#  584: {'name': '916, 379, 922', 'exp_sup': 0.78, 'utility': 5532}
#  585: {'name': '222, 1497', 'exp_sup': 0.78, 'utility': 5726}
#  586: {'name': '365, 53', 'exp_sup': 0.73, 'utility': 4938}
#  587: {'name': '1399, 1426, 1365', 'exp_sup': 0.7, 'utility': 6104}
#  588: {'name': '952, 559', 'exp_sup': 0.69, 'utility': 5060}
#  589: {'name': '1426, 727', 'exp_sup': 0.67, 'utility': 6589}
#  590: {'name': '1338, 1049', 'exp_sup': 0.67, 'utility': 5928}
#  591: {'name': '896, 530', 'exp_sup': 0.63, 'utility': 5686}
#  592: {'name': '890, 1410, 191', 'exp_sup': 0.61, 'utility': 5301}
#  593: {'name': '1389, 1279', 'exp_sup': 0.61, 'utility': 5360}
#  594: {'name': '136, 702', 'exp_sup': 0.58, 'utility': 5010}
#  595: {'name': '1077, 721', 'exp_sup': 0.56, 'utility': 4892}
#  596: {'name': '890, 1410, 1493, 191', 'exp_sup': 0.54, 'utility': 6885}
#  597: {'name': '1493, 164', 'exp_sup': 0.52, 'utility': 4851}
#  598: {'name': '656, 13', 'exp_sup': 0.48, 'utility': 4815}
#  599: {'name': '1399, 1426, 1043, 1365', 'exp_sup': 0.47, 'utility': 5106}
#  600: {'name': '1426, 1093', 'exp_sup': 0.46, 'utility': 4959}
#  601: {'name': '918, 136, 702', 'exp_sup': 0.43, 'utility': 6495}
#  602: {'name': '1472, 1389, 819', 'exp_sup': 0.43, 'utility': 4851}
#  603: {'name': '1399, 1426, 1043, 217', 'exp_sup': 0.4, 'utility': 5128}
#  604: {'name': '1389, 907, 930', 'exp_sup': 0.38, 'utility': 4814}
#  605: {'name': '285, 1094, 518', 'exp_sup': 0.38, 'utility': 5969}
#  606: {'name': '988, 1281', 'exp_sup': 0.36, 'utility': 5826}
#  607: {'name': '1180, 614', 'exp_sup': 0.36, 'utility': 6912}
#  608: {'name': '1472, 170', 'exp_sup': 0.35, 'utility': 4860}
#  609: {'name': '1399, 1426, 1043, 217, 1365', 'exp_sup': 0.34, 'utility': 5446}
#  610: {'name': '1436, 111, 937', 'exp_sup': 0.34, 'utility': 5607}
#  611: {'name': '1389, 819, 1279', 'exp_sup': 0.34, 'utility': 5899}
#  612: {'name': '1472, 819, 1279', 'exp_sup': 0.32, 'utility': 5904}
#  613: {'name': '1426, 727, 1365', 'exp_sup': 0.3, 'utility': 5318}
#  614: {'name': '640, 324, 234', 'exp_sup': 0.28, 'utility': 4947}
#  615: {'name': '502, 968, 415', 'exp_sup': 0.28, 'utility': 5152}
#  616: {'name': '1210, 844, 1493', 'exp_sup': 0.27, 'utility': 5114}
#  617: {'name': '1118, 502, 968', 'exp_sup': 0.26, 'utility': 4873}
#  618: {'name': '1399, 1426, 1043, 1542', 'exp_sup': 0.25, 'utility': 5263}
#  619: {'name': '1472, 1389, 1279', 'exp_sup': 0.25, 'utility': 5003}
#  620: {'name': '489, 532', 'exp_sup': 0.25, 'utility': 5557}
#  621: {'name': '1118, 502, 415', 'exp_sup': 0.23, 'utility': 6014}
#  622: {'name': '988, 772', 'exp_sup': 0.23, 'utility': 7188}
#  623: {'name': '1291, 941, 914', 'exp_sup': 0.22, 'utility': 5226}
#  624: {'name': '1338, 789, 1028, 373, 1248, 972', 'exp_sup': 0.21, 'utility': 5196}
#  625: {'name': '988, 1281, 339', 'exp_sup': 0.19, 'utility': 6806}
#  626: {'name': '1399, 1426, 1043, 1542, 1365', 'exp_sup': 0.18, 'utility': 5581}
#  627: {'name': '1399, 1426, 727', 'exp_sup': 0.17, 'utility': 7208}
#  628: {'name': '1426, 217, 727', 'exp_sup': 0.17, 'utility': 5697}
#  629: {'name': '1472, 1389, 819, 1279', 'exp_sup': 0.17, 'utility': 7219}
#  630: {'name': '1399, 1426, 1043, 217, 1542', 'exp_sup': 0.16, 'utility': 5603}
#  631: {'name': '1118, 502, 968, 415', 'exp_sup': 0.16, 'utility': 6910}
#  632: {'name': '1045, 529, 136, 519', 'exp_sup': 0.15, 'utility': 5050}
#  633: {'name': '988, 1281, 772', 'exp_sup': 0.15, 'utility': 7378}
#  634: {'name': '1389, 907, 541, 930', 'exp_sup': 0.14, 'utility': 5942}
#  635: {'name': '937, 1047', 'exp_sup': 0.14, 'utility': 5111}
#  636: {'name': '1399, 1426, 1043, 217, 1542, 1365', 'exp_sup': 0.13, 'utility': 5921}
#  637: {'name': '1472, 1389, 819, 430', 'exp_sup': 0.13, 'utility': 6111}
#  638: {'name': '1045, 812, 313, 1049', 'exp_sup': 0.12, 'utility': 5243}
#  639: {'name': '640, 104, 940', 'exp_sup': 0.12, 'utility': 5746}
#  640: {'name': '1399, 1426, 727, 1365', 'exp_sup': 0.11, 'utility': 7632}
#  641: {'name': '1291, 941, 914, 958', 'exp_sup': 0.11, 'utility': 5906}
#  642: {'name': '988, 772, 339', 'exp_sup': 0.11, 'utility': 6142}
#  643: {'name': '819, 1279, 430', 'exp_sup': 0.11, 'utility': 5844}
#  644: {'name': '1351, 625, 824, 835', 'exp_sup': 0.1, 'utility': 5495}
#  645: {'name': '1362, 946, 742', 'exp_sup': 0.09, 'utility': 4827}
#  646: {'name': '988, 1281, 772, 339', 'exp_sup': 0.08, 'utility': 8358}
#  647: {'name': '1472, 1279, 430', 'exp_sup': 0.08, 'utility': 4948}
#  648: {'name': '1389, 1279, 430', 'exp_sup': 0.08, 'utility': 4943}
#  649: {'name': '1399, 1426, 1043, 727', 'exp_sup': 0.07, 'utility': 5934}
#  650: {'name': '1389, 907, 1500', 'exp_sup': 0.07, 'utility': 5317}
#  651: {'name': '662, 446, 656, 13', 'exp_sup': 0.07, 'utility': 5250}
#  652: {'name': '1399, 1426, 1043, 1542, 727', 'exp_sup': 0.06, 'utility': 6409}
#  653: {'name': '1472, 819, 1279, 430', 'exp_sup': 0.06, 'utility': 7164}
#  654: {'name': '1389, 819, 1279, 430', 'exp_sup': 0.06, 'utility': 7159}
#  655: {'name': '1389, 907, 1500, 930', 'exp_sup': 0.06, 'utility': 6501}
#  656: {'name': '520, 326, 83, 1402, 676, 876', 'exp_sup': 0.05, 'utility': 5062}
#  657: {'name': '175, 418, 651', 'exp_sup': 0.05, 'utility': 5162}
#  658: {'name': '225, 614', 'exp_sup': 0.05, 'utility': 5380}
#  659: {'name': '1399, 1426, 217, 727', 'exp_sup': 0.04, 'utility': 5332}
#  660: {'name': '1426, 1043, 217, 727, 1365', 'exp_sup': 0.04, 'utility': 4990}
#  661: {'name': '988, 1281, 772, 1142, 339', 'exp_sup': 0.04, 'utility': 5134}
#  662: {'name': '1472, 1389, 1279, 430', 'exp_sup': 0.04, 'utility': 6263}
#  663: {'name': '379, 446, 656, 13', 'exp_sup': 0.04, 'utility': 5255}
#  664: {'name': '1019, 17, 104, 67', 'exp_sup': 0.04, 'utility': 5462}
#  665: {'name': '1398, 83', 'exp_sup': 0.04, 'utility': 5695}
#  666: {'name': '1508, 626, 825, 1019, 963', 'exp_sup': 0.03, 'utility': 4992}
#  667: {'name': '1399, 1426, 1043, 217, 727', 'exp_sup': 0.03, 'utility': 6274}
#  668: {'name': '1399, 1426, 1043, 727, 1365', 'exp_sup': 0.03, 'utility': 6252}
#  669: {'name': '1426, 756, 727', 'exp_sup': 0.03, 'utility': 5370}
#  670: {'name': '1045, 812, 313, 1049, 695', 'exp_sup': 0.03, 'utility': 6299}
#  671: {'name': '1045, 812, 1049, 695', 'exp_sup': 0.03, 'utility': 5444}
#  672: {'name': '604, 321, 49, 1314', 'exp_sup': 0.03, 'utility': 4922}
#  673: {'name': '1472, 1389, 819, 1279, 430', 'exp_sup': 0.03, 'utility': 8479}
#  674: {'name': '1165, 189, 372, 1248, 616', 'exp_sup': 0.03, 'utility': 5002}
#  675: {'name': '907, 541, 1500', 'exp_sup': 0.03, 'utility': 4867}
#  676: {'name': '907, 541, 1500, 930', 'exp_sup': 0.03, 'utility': 6051}
#  677: {'name': '1508, 626, 825, 1019, 963, 1329', 'exp_sup': 0.02, 'utility': 5652}
#  678: {'name': '1508, 825, 1019, 963, 1329', 'exp_sup': 0.02, 'utility': 5007}
#  679: {'name': '1399, 1426, 1043, 217, 1542, 727', 'exp_sup': 0.02, 'utility': 6749}
#  680: {'name': '1399, 1426, 1043, 217, 727, 1365', 'exp_sup': 0.02, 'utility': 6592}
#  681: {'name': '1399, 1426, 1043, 1542, 727, 1365', 'exp_sup': 0.02, 'utility': 6727}
#  682: {'name': '1399, 1426, 217, 727, 1365', 'exp_sup': 0.02, 'utility': 5650}
#  683: {'name': '1426, 217, 756, 727', 'exp_sup': 0.02, 'utility': 5778}
#  684: {'name': '1045, 812, 1049, 1554', 'exp_sup': 0.02, 'utility': 5150}
#  685: {'name': '1473, 924, 1081, 544', 'exp_sup': 0.02, 'utility': 4844}
#  686: {'name': '1389, 907, 541, 1500', 'exp_sup': 0.02, 'utility': 6445}
#  687: {'name': '1389, 907, 541, 1500, 930', 'exp_sup': 0.02, 'utility': 7629}
#  688: {'name': '1165, 189, 300, 372, 1248', 'exp_sup': 0.02, 'utility': 5352}
#  689: {'name': '1373, 617, 321, 1077, 620, 1096, 327', 'exp_sup': 0.01, 'utility': 4950}
#  690: {'name': '1373, 617, 321, 1077, 773, 1096, 327', 'exp_sup': 0.01, 'utility': 4944}
#  691: {'name': '545, 219, 422, 1098, 479, 1254', 'exp_sup': 0.01, 'utility': 5030}
#  692: {'name': '1423, 464, 853, 1113, 1107, 1313', 'exp_sup': 0.01, 'utility': 5553}
#  693: {'name': '1423, 464, 853, 1107, 1313', 'exp_sup': 0.01, 'utility': 5285}
#  694: {'name': '1161, 222, 312, 23, 1504', 'exp_sup': 0.01, 'utility': 4816}
#  695: {'name': '1399, 1426, 1043, 217, 1542, 727, 1365', 'exp_sup': 0.01, 'utility': 7067}
#  696: {'name': '1045, 812, 313, 1049, 1554', 'exp_sup': 0.01, 'utility': 6005}
#  697: {'name': '1473, 924, 1081, 544, 1107', 'exp_sup': 0.01, 'utility': 5654}
#  698: {'name': '1473, 1184, 544, 1107', 'exp_sup': 0.01, 'utility': 4837}
#  699: {'name': '728, 1310, 528, 1254, 1493', 'exp_sup': 0.01, 'utility': 5039}
#  700: {'name': '728, 1310, 528, 1254, 372', 'exp_sup': 0.01, 'utility': 5047}

# %%
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_foodmart.txt, ./data/foodmart_utility.txt", 0.0004, 900)
algorithm.print_stats("./out/TUHUFP/foodmart/output_foodmart_top_900.txt")
# Out:
# Reading data . . .
# Minimum utility set to: 4804
# {'database util: ': 12011023}
# Top 900 CUPs:
#  1: {'name': '304', 'exp_sup': 14.23, 'utility': 13607}
#  2: {'name': '1373', 'exp_sup': 13.55, 'utility': 25560}
#  3: {'name': '272', 'exp_sup': 13.54, 'utility': 22678}
#  4: {'name': '1293', 'exp_sup': 12.66, 'utility': 8352}
#  5: {'name': '1292', 'exp_sup': 12.6, 'utility': 24642}
#  6: {'name': '545', 'exp_sup': 12.1, 'utility': 9419}
#  7: {'name': '357', 'exp_sup': 11.97, 'utility': 11520}
#  8: {'name': '634', 'exp_sup': 11.88, 'utility': 11881}
#  9: {'name': '617', 'exp_sup': 11.75, 'utility': 7527}
#  10: {'name': '1423', 'exp_sup': 11.75, 'utility': 16116}
#  11: {'name': '916', 'exp_sup': 11.68, 'utility': 15163}
#  12: {'name': '1012', 'exp_sup': 11.65, 'utility': 19861}
#  13: {'name': '903', 'exp_sup': 11.62, 'utility': 14616}
#  14: {'name': '831', 'exp_sup': 11.39, 'utility': 8848}
#  15: {'name': '888', 'exp_sup': 11.38, 'utility': 5280}
#  16: {'name': '918', 'exp_sup': 11.38, 'utility': 18414}
#  17: {'name': '1390', 'exp_sup': 11.26, 'utility': 12415}
#  18: {'name': '404', 'exp_sup': 11.02, 'utility': 7000}
#  19: {'name': '308', 'exp_sup': 10.94, 'utility': 11554}
#  20: {'name': '1351', 'exp_sup': 10.9, 'utility': 9352}
#  21: {'name': '1451', 'exp_sup': 10.9, 'utility': 7614}
#  22: {'name': '1315', 'exp_sup': 10.88, 'utility': 9612}
#  23: {'name': '599', 'exp_sup': 10.79, 'utility': 12519}
#  24: {'name': '932', 'exp_sup': 10.78, 'utility': 8262}
#  25: {'name': '1161', 'exp_sup': 10.54, 'utility': 21540}
#  26: {'name': '276', 'exp_sup': 10.37, 'utility': 18528}
#  27: {'name': '718', 'exp_sup': 10.36, 'utility': 9741}
#  28: {'name': '520', 'exp_sup': 10.36, 'utility': 14840}
#  29: {'name': '386', 'exp_sup': 10.29, 'utility': 10927}
#  30: {'name': '1362', 'exp_sup': 10.29, 'utility': 8046}
#  31: {'name': '1439', 'exp_sup': 10.25, 'utility': 8400}
#  32: {'name': '447', 'exp_sup': 10.23, 'utility': 17856}
#  33: {'name': '1220', 'exp_sup': 10.18, 'utility': 11700}
#  34: {'name': '1508', 'exp_sup': 10.16, 'utility': 19116}
#  35: {'name': '1399', 'exp_sup': 10.11, 'utility': 10324}
#  36: {'name': '1110', 'exp_sup': 10.1, 'utility': 17920}
#  37: {'name': '378', 'exp_sup': 10.08, 'utility': 5994}
#  38: {'name': '69', 'exp_sup': 10.07, 'utility': 16430}
#  39: {'name': '1282', 'exp_sup': 10.05, 'utility': 18232}
#  40: {'name': '749', 'exp_sup': 10.03, 'utility': 11748}
#  41: {'name': '602', 'exp_sup': 10.0, 'utility': 13696}
#  42: {'name': '1442', 'exp_sup': 9.99, 'utility': 10332}
#  43: {'name': '1426', 'exp_sup': 9.96, 'utility': 21692}
#  44: {'name': '391', 'exp_sup': 9.95, 'utility': 8777}
#  45: {'name': '501', 'exp_sup': 9.87, 'utility': 6227}
#  46: {'name': '307', 'exp_sup': 9.83, 'utility': 7400}
#  47: {'name': '1456', 'exp_sup': 9.82, 'utility': 8784}
#  48: {'name': '200', 'exp_sup': 9.8, 'utility': 12190}
#  49: {'name': '326', 'exp_sup': 9.77, 'utility': 13091}
#  50: {'name': '1347', 'exp_sup': 9.71, 'utility': 9912}
#  51: {'name': '1224', 'exp_sup': 9.67, 'utility': 6944}
#  52: {'name': '1291', 'exp_sup': 9.65, 'utility': 12642}
#  53: {'name': '73', 'exp_sup': 9.65, 'utility': 11184}
#  54: {'name': '1487', 'exp_sup': 9.64, 'utility': 5320}
#  55: {'name': '246', 'exp_sup': 9.63, 'utility': 17655}
#  56: {'name': '1257', 'exp_sup': 9.62, 'utility': 9505}
#  57: {'name': '311', 'exp_sup': 9.57, 'utility': 8600}
#  58: {'name': '247', 'exp_sup': 9.52, 'utility': 9256}
#  59: {'name': '54', 'exp_sup': 9.51, 'utility': 12889}
#  60: {'name': '1118', 'exp_sup': 9.5, 'utility': 13178}
#  61: {'name': '1045', 'exp_sup': 9.48, 'utility': 21090}
#  62: {'name': '27', 'exp_sup': 9.44, 'utility': 16165}
#  63: {'name': '1464', 'exp_sup': 9.44, 'utility': 14800}
#  64: {'name': '1048', 'exp_sup': 9.43, 'utility': 11713}
#  65: {'name': '812', 'exp_sup': 9.41, 'utility': 14696}
#  66: {'name': '1473', 'exp_sup': 9.4, 'utility': 13452}
#  67: {'name': '640', 'exp_sup': 9.36, 'utility': 13209}
#  68: {'name': '1264', 'exp_sup': 9.35, 'utility': 11985}
#  69: {'name': '222', 'exp_sup': 9.33, 'utility': 22910}
#  70: {'name': '969', 'exp_sup': 9.33, 'utility': 7920}
#  71: {'name': '278', 'exp_sup': 9.33, 'utility': 18480}
#  72: {'name': '434', 'exp_sup': 9.33, 'utility': 7384}
#  73: {'name': '988', 'exp_sup': 9.3, 'utility': 24187}
#  74: {'name': '266', 'exp_sup': 9.29, 'utility': 10692}
#  75: {'name': '419', 'exp_sup': 9.29, 'utility': 14994}
#  76: {'name': '219', 'exp_sup': 9.27, 'utility': 11844}
#  77: {'name': '382', 'exp_sup': 9.27, 'utility': 9072}
#  78: {'name': '435', 'exp_sup': 9.24, 'utility': 14433}
#  79: {'name': '1516', 'exp_sup': 9.22, 'utility': 15792}
#  80: {'name': '1217', 'exp_sup': 9.21, 'utility': 7239}
#  81: {'name': '890', 'exp_sup': 9.18, 'utility': 12789}
#  82: {'name': '1308', 'exp_sup': 9.18, 'utility': 12642}
#  83: {'name': '728', 'exp_sup': 9.17, 'utility': 11528}
#  84: {'name': '175', 'exp_sup': 9.14, 'utility': 19635}
#  85: {'name': '449', 'exp_sup': 9.12, 'utility': 15867}
#  86: {'name': '1357', 'exp_sup': 9.1, 'utility': 11653}
#  87: {'name': '1281', 'exp_sup': 9.1, 'utility': 13573}
#  88: {'name': '813', 'exp_sup': 9.09, 'utility': 7967}
#  89: {'name': '566', 'exp_sup': 9.05, 'utility': 7120}
#  90: {'name': '604', 'exp_sup': 9.04, 'utility': 6250}
#  91: {'name': '1394', 'exp_sup': 9.01, 'utility': 10870}
#  92: {'name': '1547', 'exp_sup': 9.0, 'utility': 12614}
#  93: {'name': '1338', 'exp_sup': 8.99, 'utility': 10656}
#  94: {'name': '281', 'exp_sup': 8.97, 'utility': 14465}
#  95: {'name': '470', 'exp_sup': 8.96, 'utility': 18259}
#  96: {'name': '941', 'exp_sup': 8.96, 'utility': 18565}
#  97: {'name': '1104', 'exp_sup': 8.96, 'utility': 13965}
#  98: {'name': '383', 'exp_sup': 8.89, 'utility': 14300}
#  99: {'name': '685', 'exp_sup': 8.87, 'utility': 9333}
#  100: {'name': '1119', 'exp_sup': 8.86, 'utility': 13314}
#  101: {'name': '1472', 'exp_sup': 8.86, 'utility': 12760}
#  102: {'name': '111', 'exp_sup': 8.85, 'utility': 17052}
#  103: {'name': '380', 'exp_sup': 8.84, 'utility': 4880}
#  104: {'name': '1348', 'exp_sup': 8.83, 'utility': 14326}
#  105: {'name': '1306', 'exp_sup': 8.83, 'utility': 10127}
#  106: {'name': '584', 'exp_sup': 8.8, 'utility': 12173}
#  107: {'name': '1432', 'exp_sup': 8.77, 'utility': 9180}
#  108: {'name': '1444', 'exp_sup': 8.77, 'utility': 10384}
#  109: {'name': '1397', 'exp_sup': 8.76, 'utility': 5577}
#  110: {'name': '231', 'exp_sup': 8.75, 'utility': 14575}
#  111: {'name': '863', 'exp_sup': 8.74, 'utility': 14006}
#  112: {'name': '1526', 'exp_sup': 8.73, 'utility': 8085}
#  113: {'name': '422', 'exp_sup': 8.73, 'utility': 17616}
#  114: {'name': '236', 'exp_sup': 8.72, 'utility': 9412}
#  115: {'name': '55', 'exp_sup': 8.72, 'utility': 15750}
#  116: {'name': '497', 'exp_sup': 8.66, 'utility': 10472}
#  117: {'name': '606', 'exp_sup': 8.66, 'utility': 12720}
#  118: {'name': '1268', 'exp_sup': 8.66, 'utility': 7150}
#  119: {'name': '1043', 'exp_sup': 8.65, 'utility': 6908}
#  120: {'name': '1470', 'exp_sup': 8.64, 'utility': 11327}
#  121: {'name': '1210', 'exp_sup': 8.63, 'utility': 9681}
#  122: {'name': '883', 'exp_sup': 8.63, 'utility': 13041}
#  123: {'name': '1522', 'exp_sup': 8.62, 'utility': 6147}
#  124: {'name': '1384', 'exp_sup': 8.61, 'utility': 12593}
#  125: {'name': '1296', 'exp_sup': 8.6, 'utility': 14548}
#  126: {'name': '626', 'exp_sup': 8.6, 'utility': 4902}
#  127: {'name': '389', 'exp_sup': 8.59, 'utility': 8771}
#  128: {'name': '1098', 'exp_sup': 8.58, 'utility': 6255}
#  129: {'name': '946', 'exp_sup': 8.55, 'utility': 13965}
#  130: {'name': '943', 'exp_sup': 8.54, 'utility': 10621}
#  131: {'name': '1499', 'exp_sup': 8.53, 'utility': 6255}
#  132: {'name': '1310', 'exp_sup': 8.53, 'utility': 19102}
#  133: {'name': '108', 'exp_sup': 8.52, 'utility': 9417}
#  134: {'name': '260', 'exp_sup': 8.51, 'utility': 11592}
#  135: {'name': '772', 'exp_sup': 8.5, 'utility': 9894}
#  136: {'name': '414', 'exp_sup': 8.49, 'utility': 12188}
#  137: {'name': '844', 'exp_sup': 8.48, 'utility': 14564}
#  138: {'name': '580', 'exp_sup': 8.45, 'utility': 12532}
#  139: {'name': '170', 'exp_sup': 8.45, 'utility': 14080}
#  140: {'name': '1089', 'exp_sup': 8.41, 'utility': 10621}
#  141: {'name': '502', 'exp_sup': 8.39, 'utility': 16801}
#  142: {'name': '1543', 'exp_sup': 8.36, 'utility': 10912}
#  143: {'name': '44', 'exp_sup': 8.34, 'utility': 12298}
#  144: {'name': '379', 'exp_sup': 8.34, 'utility': 15785}
#  145: {'name': '469', 'exp_sup': 8.32, 'utility': 6837}
#  146: {'name': '493', 'exp_sup': 8.31, 'utility': 12408}
#  147: {'name': '625', 'exp_sup': 8.31, 'utility': 9821}
#  148: {'name': '825', 'exp_sup': 8.29, 'utility': 12452}
#  149: {'name': '154', 'exp_sup': 8.29, 'utility': 9016}
#  150: {'name': '321', 'exp_sup': 8.28, 'utility': 12291}
#  151: {'name': '1247', 'exp_sup': 8.26, 'utility': 8064}
#  152: {'name': '1340', 'exp_sup': 8.25, 'utility': 13107}
#  153: {'name': '324', 'exp_sup': 8.24, 'utility': 7289}
#  154: {'name': '508', 'exp_sup': 8.23, 'utility': 17055}
#  155: {'name': '577', 'exp_sup': 8.22, 'utility': 11004}
#  156: {'name': '448', 'exp_sup': 8.21, 'utility': 9086}
#  157: {'name': '673', 'exp_sup': 8.2, 'utility': 11782}
#  158: {'name': '20', 'exp_sup': 8.2, 'utility': 14178}
#  159: {'name': '968', 'exp_sup': 8.19, 'utility': 5760}
#  160: {'name': '1160', 'exp_sup': 8.19, 'utility': 13517}
#  161: {'name': '795', 'exp_sup': 8.18, 'utility': 4992}
#  162: {'name': '1389', 'exp_sup': 8.17, 'utility': 15254}
#  163: {'name': '1251', 'exp_sup': 8.15, 'utility': 14320}
#  164: {'name': '1483', 'exp_sup': 8.14, 'utility': 8520}
#  165: {'name': '1075', 'exp_sup': 8.12, 'utility': 6314}
#  166: {'name': '227', 'exp_sup': 8.09, 'utility': 7722}
#  167: {'name': '1174', 'exp_sup': 8.09, 'utility': 8853}
#  168: {'name': '1468', 'exp_sup': 8.08, 'utility': 5670}
#  169: {'name': '443', 'exp_sup': 8.08, 'utility': 6783}
#  170: {'name': '1294', 'exp_sup': 8.07, 'utility': 7052}
#  171: {'name': '1061', 'exp_sup': 8.07, 'utility': 8466}
#  172: {'name': '1050', 'exp_sup': 8.06, 'utility': 5632}
#  173: {'name': '1180', 'exp_sup': 8.06, 'utility': 19890}
#  174: {'name': '173', 'exp_sup': 8.06, 'utility': 6864}
#  175: {'name': '819', 'exp_sup': 8.06, 'utility': 11634}
#  176: {'name': '823', 'exp_sup': 8.05, 'utility': 15435}
#  177: {'name': '1077', 'exp_sup': 8.05, 'utility': 15455}
#  178: {'name': '951', 'exp_sup': 8.05, 'utility': 9457}
#  179: {'name': '225', 'exp_sup': 8.04, 'utility': 22951}
#  180: {'name': '1478', 'exp_sup': 8.03, 'utility': 9044}
#  181: {'name': '1056', 'exp_sup': 8.03, 'utility': 10835}
#  182: {'name': '284', 'exp_sup': 8.02, 'utility': 4950}
#  183: {'name': '521', 'exp_sup': 8.02, 'utility': 14155}
#  184: {'name': '1165', 'exp_sup': 8.01, 'utility': 12690}
#  185: {'name': '907', 'exp_sup': 8.01, 'utility': 17100}
#  186: {'name': '1154', 'exp_sup': 8.01, 'utility': 7304}
#  187: {'name': '464', 'exp_sup': 8.01, 'utility': 14952}
#  188: {'name': '1380', 'exp_sup': 7.99, 'utility': 19548}
#  189: {'name': '703', 'exp_sup': 7.98, 'utility': 13959}
#  190: {'name': '980', 'exp_sup': 7.98, 'utility': 7740}
#  191: {'name': '117', 'exp_sup': 7.97, 'utility': 10175}
#  192: {'name': '919', 'exp_sup': 7.96, 'utility': 6930}
#  193: {'name': '1079', 'exp_sup': 7.96, 'utility': 7072}
#  194: {'name': '528', 'exp_sup': 7.96, 'utility': 5952}
#  195: {'name': '541', 'exp_sup': 7.95, 'utility': 8272}
#  196: {'name': '313', 'exp_sup': 7.94, 'utility': 16245}
#  197: {'name': '1518', 'exp_sup': 7.94, 'utility': 20416}
#  198: {'name': '376', 'exp_sup': 7.93, 'utility': 9988}
#  199: {'name': '479', 'exp_sup': 7.93, 'utility': 8385}
#  200: {'name': '563', 'exp_sup': 7.92, 'utility': 6216}
#  201: {'name': '774', 'exp_sup': 7.9, 'utility': 12005}
#  202: {'name': '650', 'exp_sup': 7.88, 'utility': 8370}
#  203: {'name': '415', 'exp_sup': 7.88, 'utility': 11640}
#  204: {'name': '618', 'exp_sup': 7.88, 'utility': 5600}
#  205: {'name': '721', 'exp_sup': 7.86, 'utility': 9485}
#  206: {'name': '374', 'exp_sup': 7.83, 'utility': 6407}
#  207: {'name': '153', 'exp_sup': 7.83, 'utility': 14144}
#  208: {'name': '1410', 'exp_sup': 7.82, 'utility': 6536}
#  209: {'name': '742', 'exp_sup': 7.8, 'utility': 12350}
#  210: {'name': '1346', 'exp_sup': 7.77, 'utility': 10105}
#  211: {'name': '851', 'exp_sup': 7.76, 'utility': 9030}
#  212: {'name': '836', 'exp_sup': 7.75, 'utility': 5428}
#  213: {'name': '877', 'exp_sup': 7.74, 'utility': 8374}
#  214: {'name': '529', 'exp_sup': 7.74, 'utility': 10074}
#  215: {'name': '878', 'exp_sup': 7.74, 'utility': 9724}
#  216: {'name': '913', 'exp_sup': 7.74, 'utility': 7476}
#  217: {'name': '1029', 'exp_sup': 7.74, 'utility': 8736}
#  218: {'name': '1254', 'exp_sup': 7.73, 'utility': 14680}
#  219: {'name': '1116', 'exp_sup': 7.73, 'utility': 11377}
#  220: {'name': '375', 'exp_sup': 7.72, 'utility': 8931}
#  221: {'name': '1250', 'exp_sup': 7.71, 'utility': 10368}
#  222: {'name': '1086', 'exp_sup': 7.69, 'utility': 10365}
#  223: {'name': '816', 'exp_sup': 7.69, 'utility': 10992}
#  224: {'name': '924', 'exp_sup': 7.69, 'utility': 14040}
#  225: {'name': '1372', 'exp_sup': 7.69, 'utility': 10458}
#  226: {'name': '1237', 'exp_sup': 7.68, 'utility': 13750}
#  227: {'name': '834', 'exp_sup': 7.67, 'utility': 10656}
#  228: {'name': '915', 'exp_sup': 7.67, 'utility': 12341}
#  229: {'name': '49', 'exp_sup': 7.66, 'utility': 17238}
#  230: {'name': '824', 'exp_sup': 7.64, 'utility': 10550}
#  231: {'name': '992', 'exp_sup': 7.64, 'utility': 9486}
#  232: {'name': '787', 'exp_sup': 7.64, 'utility': 5662}
#  233: {'name': '1241', 'exp_sup': 7.62, 'utility': 12516}
#  234: {'name': '1463', 'exp_sup': 7.62, 'utility': 8118}
#  235: {'name': '600', 'exp_sup': 7.62, 'utility': 9471}
#  236: {'name': '1416', 'exp_sup': 7.62, 'utility': 12788}
#  237: {'name': '24', 'exp_sup': 7.6, 'utility': 10726}
#  238: {'name': '619', 'exp_sup': 7.59, 'utility': 10575}
#  239: {'name': '555', 'exp_sup': 7.59, 'utility': 12960}
#  240: {'name': '1540', 'exp_sup': 7.59, 'utility': 14432}
#  241: {'name': '418', 'exp_sup': 7.58, 'utility': 14536}
#  242: {'name': '1368', 'exp_sup': 7.57, 'utility': 19525}
#  243: {'name': '1019', 'exp_sup': 7.56, 'utility': 11968}
#  244: {'name': '385', 'exp_sup': 7.55, 'utility': 5148}
#  245: {'name': '1493', 'exp_sup': 7.55, 'utility': 16632}
#  246: {'name': '191', 'exp_sup': 7.54, 'utility': 12054}
#  247: {'name': '882', 'exp_sup': 7.54, 'utility': 12201}
#  248: {'name': '1142', 'exp_sup': 7.54, 'utility': 11800}
#  249: {'name': '922', 'exp_sup': 7.53, 'utility': 12950}
#  250: {'name': '853', 'exp_sup': 7.52, 'utility': 12804}
#  251: {'name': '261', 'exp_sup': 7.52, 'utility': 12844}
#  252: {'name': '789', 'exp_sup': 7.51, 'utility': 12670}
#  253: {'name': '125', 'exp_sup': 7.51, 'utility': 9737}
#  254: {'name': '756', 'exp_sup': 7.5, 'utility': 13393}
#  255: {'name': '179', 'exp_sup': 7.5, 'utility': 17875}
#  256: {'name': '410', 'exp_sup': 7.49, 'utility': 6174}
#  257: {'name': '488', 'exp_sup': 7.49, 'utility': 10101}
#  258: {'name': '522', 'exp_sup': 7.49, 'utility': 8140}
#  259: {'name': '1408', 'exp_sup': 7.49, 'utility': 9805}
#  260: {'name': '1222', 'exp_sup': 7.48, 'utility': 9555}
#  261: {'name': '1252', 'exp_sup': 7.48, 'utility': 11391}
#  262: {'name': '811', 'exp_sup': 7.48, 'utility': 14256}
#  263: {'name': '1366', 'exp_sup': 7.46, 'utility': 11311}
#  264: {'name': '534', 'exp_sup': 7.46, 'utility': 11491}
#  265: {'name': '854', 'exp_sup': 7.45, 'utility': 7040}
#  266: {'name': '365', 'exp_sup': 7.45, 'utility': 17424}
#  267: {'name': '832', 'exp_sup': 7.45, 'utility': 15552}
#  268: {'name': '82', 'exp_sup': 7.45, 'utility': 12150}
#  269: {'name': '575', 'exp_sup': 7.44, 'utility': 13769}
#  270: {'name': '1063', 'exp_sup': 7.43, 'utility': 14303}
#  271: {'name': '739', 'exp_sup': 7.43, 'utility': 8568}
#  272: {'name': '547', 'exp_sup': 7.41, 'utility': 9702}
#  273: {'name': '730', 'exp_sup': 7.39, 'utility': 8084}
#  274: {'name': '800', 'exp_sup': 7.39, 'utility': 11729}
#  275: {'name': '792', 'exp_sup': 7.39, 'utility': 7668}
#  276: {'name': '370', 'exp_sup': 7.38, 'utility': 4968}
#  277: {'name': '1007', 'exp_sup': 7.37, 'utility': 13166}
#  278: {'name': '1418', 'exp_sup': 7.36, 'utility': 6279}
#  279: {'name': '662', 'exp_sup': 7.35, 'utility': 7585}
#  280: {'name': '288', 'exp_sup': 7.35, 'utility': 10582}
#  281: {'name': '1088', 'exp_sup': 7.34, 'utility': 15604}
#  282: {'name': '805', 'exp_sup': 7.33, 'utility': 9216}
#  283: {'name': '1070', 'exp_sup': 7.32, 'utility': 13689}
#  284: {'name': '1361', 'exp_sup': 7.32, 'utility': 7240}
#  285: {'name': '556', 'exp_sup': 7.3, 'utility': 13975}
#  286: {'name': '767', 'exp_sup': 7.3, 'utility': 6662}
#  287: {'name': '963', 'exp_sup': 7.3, 'utility': 12000}
#  288: {'name': '303', 'exp_sup': 7.29, 'utility': 9030}
#  289: {'name': '189', 'exp_sup': 7.29, 'utility': 14835}
#  290: {'name': '546', 'exp_sup': 7.28, 'utility': 10842}
#  291: {'name': '129', 'exp_sup': 7.28, 'utility': 5115}
#  292: {'name': '914', 'exp_sup': 7.27, 'utility': 9594}
#  293: {'name': '285', 'exp_sup': 7.27, 'utility': 7626}
#  294: {'name': '942', 'exp_sup': 7.26, 'utility': 7722}
#  295: {'name': '468', 'exp_sup': 7.26, 'utility': 7830}
#  296: {'name': '691', 'exp_sup': 7.26, 'utility': 11685}
#  297: {'name': '1538', 'exp_sup': 7.26, 'utility': 11893}
#  298: {'name': '158', 'exp_sup': 7.26, 'utility': 6004}
#  299: {'name': '1094', 'exp_sup': 7.26, 'utility': 17342}
#  300: {'name': '1324', 'exp_sup': 7.25, 'utility': 12578}
#  301: {'name': '346', 'exp_sup': 7.24, 'utility': 9752}
#  302: {'name': '937', 'exp_sup': 7.24, 'utility': 19133}
#  303: {'name': '1358', 'exp_sup': 7.22, 'utility': 6720}
#  304: {'name': '234', 'exp_sup': 7.22, 'utility': 12690}
#  305: {'name': '11', 'exp_sup': 7.21, 'utility': 16497}
#  306: {'name': '100', 'exp_sup': 7.2, 'utility': 8580}
#  307: {'name': '1497', 'exp_sup': 7.19, 'utility': 19406}
#  308: {'name': '1279', 'exp_sup': 7.18, 'utility': 11840}
#  309: {'name': '1055', 'exp_sup': 7.18, 'utility': 5184}
#  310: {'name': '1096', 'exp_sup': 7.17, 'utility': 9984}
#  311: {'name': '491', 'exp_sup': 7.17, 'utility': 14742}
#  312: {'name': '957', 'exp_sup': 7.17, 'utility': 10395}
#  313: {'name': '17', 'exp_sup': 7.16, 'utility': 11063}
#  314: {'name': '923', 'exp_sup': 7.16, 'utility': 7056}
#  315: {'name': '887', 'exp_sup': 7.14, 'utility': 7200}
#  316: {'name': '408', 'exp_sup': 7.14, 'utility': 11000}
#  317: {'name': '322', 'exp_sup': 7.14, 'utility': 13112}
#  318: {'name': '495', 'exp_sup': 7.14, 'utility': 5265}
#  319: {'name': '1267', 'exp_sup': 7.13, 'utility': 7520}
#  320: {'name': '149', 'exp_sup': 7.13, 'utility': 11952}
#  321: {'name': '1114', 'exp_sup': 7.13, 'utility': 11286}
#  322: {'name': '377', 'exp_sup': 7.13, 'utility': 10290}
#  323: {'name': '300', 'exp_sup': 7.12, 'utility': 14700}
#  324: {'name': '387', 'exp_sup': 7.12, 'utility': 13014}
#  325: {'name': '715', 'exp_sup': 7.11, 'utility': 6665}
#  326: {'name': '753', 'exp_sup': 7.11, 'utility': 8315}
#  327: {'name': '1001', 'exp_sup': 7.11, 'utility': 12852}
#  328: {'name': '1277', 'exp_sup': 7.1, 'utility': 8890}
#  329: {'name': '283', 'exp_sup': 7.09, 'utility': 14469}
#  330: {'name': '503', 'exp_sup': 7.07, 'utility': 8742}
#  331: {'name': '10', 'exp_sup': 7.07, 'utility': 5538}
#  332: {'name': '46', 'exp_sup': 7.06, 'utility': 11008}
#  333: {'name': '1190', 'exp_sup': 7.06, 'utility': 6110}
#  334: {'name': '178', 'exp_sup': 7.06, 'utility': 5320}
#  335: {'name': '865', 'exp_sup': 7.05, 'utility': 9758}
#  336: {'name': '1179', 'exp_sup': 7.04, 'utility': 11046}
#  337: {'name': '874', 'exp_sup': 7.04, 'utility': 7146}
#  338: {'name': '1134', 'exp_sup': 7.03, 'utility': 7098}
#  339: {'name': '1376', 'exp_sup': 7.03, 'utility': 6720}
#  340: {'name': '958', 'exp_sup': 7.03, 'utility': 6392}
#  341: {'name': '1417', 'exp_sup': 7.03, 'utility': 13357}
#  342: {'name': '1412', 'exp_sup': 7.03, 'utility': 7137}
#  343: {'name': '639', 'exp_sup': 7.03, 'utility': 15415}
#  344: {'name': '1081', 'exp_sup': 7.03, 'utility': 15423}
#  345: {'name': '1272', 'exp_sup': 7.02, 'utility': 12152}
#  346: {'name': '860', 'exp_sup': 7.02, 'utility': 10296}
#  347: {'name': '934', 'exp_sup': 7.01, 'utility': 5610}
#  348: {'name': '1209', 'exp_sup': 7.01, 'utility': 10530}
#  349: {'name': '991', 'exp_sup': 7.01, 'utility': 13650}
#  350: {'name': '1506', 'exp_sup': 7.0, 'utility': 9604}
#  351: {'name': '891', 'exp_sup': 6.99, 'utility': 12844}
#  352: {'name': '223', 'exp_sup': 6.97, 'utility': 14036}
#  353: {'name': '1353', 'exp_sup': 6.97, 'utility': 8064}
#  354: {'name': '1184', 'exp_sup': 6.96, 'utility': 11928}
#  355: {'name': '1328', 'exp_sup': 6.96, 'utility': 10165}
#  356: {'name': '953', 'exp_sup': 6.96, 'utility': 8768}
#  357: {'name': '727', 'exp_sup': 6.95, 'utility': 7640}
#  358: {'name': '725', 'exp_sup': 6.95, 'utility': 6407}
#  359: {'name': '667', 'exp_sup': 6.94, 'utility': 10906}
#  360: {'name': '1117', 'exp_sup': 6.93, 'utility': 14560}
#  361: {'name': '339', 'exp_sup': 6.93, 'utility': 6300}
#  362: {'name': '446', 'exp_sup': 6.93, 'utility': 20625}
#  363: {'name': '516', 'exp_sup': 6.93, 'utility': 7770}
#  364: {'name': '80', 'exp_sup': 6.92, 'utility': 17060}
#  365: {'name': '1062', 'exp_sup': 6.91, 'utility': 8330}
#  366: {'name': '1049', 'exp_sup': 6.91, 'utility': 15327}
#  367: {'name': '489', 'exp_sup': 6.9, 'utility': 12291}
#  368: {'name': '104', 'exp_sup': 6.89, 'utility': 15171}
#  369: {'name': '48', 'exp_sup': 6.89, 'utility': 6204}
#  370: {'name': '269', 'exp_sup': 6.89, 'utility': 8520}
#  371: {'name': '896', 'exp_sup': 6.88, 'utility': 13127}
#  372: {'name': '1106', 'exp_sup': 6.88, 'utility': 6073}
#  373: {'name': '760', 'exp_sup': 6.86, 'utility': 6919}
#  374: {'name': '1398', 'exp_sup': 6.86, 'utility': 17002}
#  375: {'name': '1386', 'exp_sup': 6.86, 'utility': 7544}
#  376: {'name': '1544', 'exp_sup': 6.85, 'utility': 5256}
#  377: {'name': '1145', 'exp_sup': 6.85, 'utility': 6594}
#  378: {'name': '1554', 'exp_sup': 6.84, 'utility': 8636}
#  379: {'name': '312', 'exp_sup': 6.84, 'utility': 8520}
#  380: {'name': '1028', 'exp_sup': 6.83, 'utility': 8960}
#  381: {'name': '1455', 'exp_sup': 6.82, 'utility': 10364}
#  382: {'name': '67', 'exp_sup': 6.82, 'utility': 10416}
#  383: {'name': '23', 'exp_sup': 6.81, 'utility': 5600}
#  384: {'name': '202', 'exp_sup': 6.8, 'utility': 5364}
#  385: {'name': '1438', 'exp_sup': 6.79, 'utility': 5754}
#  386: {'name': '1530', 'exp_sup': 6.78, 'utility': 6096}
#  387: {'name': '1485', 'exp_sup': 6.77, 'utility': 6750}
#  388: {'name': '22', 'exp_sup': 6.77, 'utility': 10763}
#  389: {'name': '394', 'exp_sup': 6.77, 'utility': 12520}
#  390: {'name': '747', 'exp_sup': 6.76, 'utility': 7137}
#  391: {'name': '751', 'exp_sup': 6.76, 'utility': 11607}
#  392: {'name': '560', 'exp_sup': 6.76, 'utility': 5160}
#  393: {'name': '58', 'exp_sup': 6.75, 'utility': 8778}
#  394: {'name': '63', 'exp_sup': 6.74, 'utility': 12390}
#  395: {'name': '898', 'exp_sup': 6.72, 'utility': 7308}
#  396: {'name': '911', 'exp_sup': 6.71, 'utility': 5910}
#  397: {'name': '1383', 'exp_sup': 6.71, 'utility': 9583}
#  398: {'name': '1136', 'exp_sup': 6.71, 'utility': 15162}
#  399: {'name': '587', 'exp_sup': 6.69, 'utility': 10464}
#  400: {'name': '1465', 'exp_sup': 6.69, 'utility': 11430}
#  401: {'name': '999', 'exp_sup': 6.69, 'utility': 10027}
#  402: {'name': '1363', 'exp_sup': 6.68, 'utility': 9044}
#  403: {'name': '1242', 'exp_sup': 6.68, 'utility': 7326}
#  404: {'name': '83', 'exp_sup': 6.68, 'utility': 20563}
#  405: {'name': '16', 'exp_sup': 6.67, 'utility': 13788}
#  406: {'name': '138', 'exp_sup': 6.67, 'utility': 9180}
#  407: {'name': '554', 'exp_sup': 6.66, 'utility': 14130}
#  408: {'name': '136', 'exp_sup': 6.66, 'utility': 13932}
#  409: {'name': '105', 'exp_sup': 6.66, 'utility': 13020}
#  410: {'name': '174', 'exp_sup': 6.66, 'utility': 5472}
#  411: {'name': '1491', 'exp_sup': 6.65, 'utility': 9030}
#  412: {'name': '931', 'exp_sup': 6.65, 'utility': 6270}
#  413: {'name': '785', 'exp_sup': 6.64, 'utility': 7517}
#  414: {'name': '341', 'exp_sup': 6.64, 'utility': 9418}
#  415: {'name': '9', 'exp_sup': 6.63, 'utility': 9922}
#  416: {'name': '1082', 'exp_sup': 6.63, 'utility': 8404}
#  417: {'name': '33', 'exp_sup': 6.62, 'utility': 6936}
#  418: {'name': '28', 'exp_sup': 6.61, 'utility': 14076}
#  419: {'name': '609', 'exp_sup': 6.61, 'utility': 13986}
#  420: {'name': '952', 'exp_sup': 6.61, 'utility': 11931}
#  421: {'name': '137', 'exp_sup': 6.61, 'utility': 17020}
#  422: {'name': '333', 'exp_sup': 6.59, 'utility': 6336}
#  423: {'name': '95', 'exp_sup': 6.59, 'utility': 5548}
#  424: {'name': '438', 'exp_sup': 6.58, 'utility': 5404}
#  425: {'name': '1459', 'exp_sup': 6.57, 'utility': 7007}
#  426: {'name': '548', 'exp_sup': 6.56, 'utility': 10433}
#  427: {'name': '68', 'exp_sup': 6.55, 'utility': 12104}
#  428: {'name': '274', 'exp_sup': 6.55, 'utility': 16456}
#  429: {'name': '430', 'exp_sup': 6.55, 'utility': 7920}
#  430: {'name': '480', 'exp_sup': 6.54, 'utility': 6927}
#  431: {'name': '299', 'exp_sup': 6.54, 'utility': 5880}
#  432: {'name': '1152', 'exp_sup': 6.54, 'utility': 10520}
#  433: {'name': '369', 'exp_sup': 6.54, 'utility': 8042}
#  434: {'name': '856', 'exp_sup': 6.53, 'utility': 10755}
#  435: {'name': '1259', 'exp_sup': 6.53, 'utility': 7918}
#  436: {'name': '131', 'exp_sup': 6.53, 'utility': 8160}
#  437: {'name': '902', 'exp_sup': 6.52, 'utility': 5043}
#  438: {'name': '523', 'exp_sup': 6.52, 'utility': 6536}
#  439: {'name': '537', 'exp_sup': 6.51, 'utility': 9010}
#  440: {'name': '1312', 'exp_sup': 6.5, 'utility': 5508}
#  441: {'name': '437', 'exp_sup': 6.5, 'utility': 5910}
#  442: {'name': '373', 'exp_sup': 6.5, 'utility': 11311}
#  443: {'name': '1500', 'exp_sup': 6.5, 'utility': 9640}
#  444: {'name': '1457', 'exp_sup': 6.5, 'utility': 9018}
#  445: {'name': '803', 'exp_sup': 6.49, 'utility': 13338}
#  446: {'name': '1067', 'exp_sup': 6.49, 'utility': 5742}
#  447: {'name': '559', 'exp_sup': 6.48, 'utility': 13983}
#  448: {'name': '653', 'exp_sup': 6.48, 'utility': 10286}
#  449: {'name': '53', 'exp_sup': 6.48, 'utility': 14801}
#  450: {'name': '1492', 'exp_sup': 6.48, 'utility': 5467}
#  451: {'name': '196', 'exp_sup': 6.48, 'utility': 8645}
#  452: {'name': '8', 'exp_sup': 6.47, 'utility': 12691}
#  453: {'name': '1156', 'exp_sup': 6.46, 'utility': 6916}
#  454: {'name': '372', 'exp_sup': 6.46, 'utility': 10746}
#  455: {'name': '519', 'exp_sup': 6.46, 'utility': 12606}
#  456: {'name': '292', 'exp_sup': 6.44, 'utility': 5611}
#  457: {'name': '864', 'exp_sup': 6.43, 'utility': 6189}
#  458: {'name': '1550', 'exp_sup': 6.43, 'utility': 8869}
#  459: {'name': '316', 'exp_sup': 6.43, 'utility': 5764}
#  460: {'name': '182', 'exp_sup': 6.43, 'utility': 6440}
#  461: {'name': '1437', 'exp_sup': 6.43, 'utility': 6090}
#  462: {'name': '409', 'exp_sup': 6.42, 'utility': 18768}
#  463: {'name': '1159', 'exp_sup': 6.42, 'utility': 15498}
#  464: {'name': '544', 'exp_sup': 6.41, 'utility': 10915}
#  465: {'name': '130', 'exp_sup': 6.41, 'utility': 9366}
#  466: {'name': '442', 'exp_sup': 6.41, 'utility': 9184}
#  467: {'name': '862', 'exp_sup': 6.41, 'utility': 10101}
#  468: {'name': '656', 'exp_sup': 6.41, 'utility': 13475}
#  469: {'name': '123', 'exp_sup': 6.4, 'utility': 14976}
#  470: {'name': '1002', 'exp_sup': 6.4, 'utility': 11308}
#  471: {'name': '613', 'exp_sup': 6.4, 'utility': 5824}
#  472: {'name': '323', 'exp_sup': 6.38, 'utility': 15400}
#  473: {'name': '235', 'exp_sup': 6.38, 'utility': 15265}
#  474: {'name': '1489', 'exp_sup': 6.38, 'utility': 7266}
#  475: {'name': '1253', 'exp_sup': 6.38, 'utility': 7182}
#  476: {'name': '140', 'exp_sup': 6.36, 'utility': 6188}
#  477: {'name': '921', 'exp_sup': 6.36, 'utility': 6345}
#  478: {'name': '1329', 'exp_sup': 6.36, 'utility': 5280}
#  479: {'name': '1213', 'exp_sup': 6.35, 'utility': 12301}
#  480: {'name': '160', 'exp_sup': 6.35, 'utility': 7668}
#  481: {'name': '1066', 'exp_sup': 6.33, 'utility': 11271}
#  482: {'name': '702', 'exp_sup': 6.33, 'utility': 18048}
#  483: {'name': '1379', 'exp_sup': 6.33, 'utility': 5952}
#  484: {'name': '1323', 'exp_sup': 6.32, 'utility': 8232}
#  485: {'name': '675', 'exp_sup': 6.32, 'utility': 10770}
#  486: {'name': '568', 'exp_sup': 6.31, 'utility': 12654}
#  487: {'name': '807', 'exp_sup': 6.3, 'utility': 5499}
#  488: {'name': '186', 'exp_sup': 6.3, 'utility': 9366}
#  489: {'name': '402', 'exp_sup': 6.3, 'utility': 4851}
#  490: {'name': '1504', 'exp_sup': 6.28, 'utility': 5082}
#  491: {'name': '218', 'exp_sup': 6.27, 'utility': 14448}
#  492: {'name': '72', 'exp_sup': 6.27, 'utility': 8768}
#  493: {'name': '835', 'exp_sup': 6.26, 'utility': 14309}
#  494: {'name': '7', 'exp_sup': 6.25, 'utility': 8352}
#  495: {'name': '242', 'exp_sup': 6.25, 'utility': 10101}
#  496: {'name': '1248', 'exp_sup': 6.25, 'utility': 12653}
#  497: {'name': '610', 'exp_sup': 6.23, 'utility': 11577}
#  498: {'name': '268', 'exp_sup': 6.23, 'utility': 5536}
#  499: {'name': '1375', 'exp_sup': 6.23, 'utility': 8733}
#  500: {'name': '78', 'exp_sup': 6.22, 'utility': 8103}
#  501: {'name': '798', 'exp_sup': 6.21, 'utility': 10569}
#  502: {'name': '690', 'exp_sup': 6.21, 'utility': 5328}
#  503: {'name': '1336', 'exp_sup': 6.2, 'utility': 14916}
#  504: {'name': '1146', 'exp_sup': 6.2, 'utility': 12336}
#  505: {'name': '652', 'exp_sup': 6.19, 'utility': 5010}
#  506: {'name': '1107', 'exp_sup': 6.18, 'utility': 9990}
#  507: {'name': '930', 'exp_sup': 6.18, 'utility': 6512}
#  508: {'name': '1345', 'exp_sup': 6.17, 'utility': 16927}
#  509: {'name': '121', 'exp_sup': 6.16, 'utility': 11920}
#  510: {'name': '899', 'exp_sup': 6.16, 'utility': 7296}
#  511: {'name': '1006', 'exp_sup': 6.15, 'utility': 8988}
#  512: {'name': '504', 'exp_sup': 6.15, 'utility': 6992}
#  513: {'name': '474', 'exp_sup': 6.15, 'utility': 16192}
#  514: {'name': '1076', 'exp_sup': 6.15, 'utility': 14580}
#  515: {'name': '1502', 'exp_sup': 6.14, 'utility': 11521}
#  516: {'name': '1402', 'exp_sup': 6.13, 'utility': 10360}
#  517: {'name': '356', 'exp_sup': 6.12, 'utility': 8496}
#  518: {'name': '553', 'exp_sup': 6.12, 'utility': 6303}
#  519: {'name': '273', 'exp_sup': 6.12, 'utility': 8284}
#  520: {'name': '277', 'exp_sup': 6.12, 'utility': 9881}
#  521: {'name': '695', 'exp_sup': 6.12, 'utility': 14432}
#  522: {'name': '518', 'exp_sup': 6.12, 'utility': 6664}
#  523: {'name': '840', 'exp_sup': 6.12, 'utility': 5206}
#  524: {'name': '445', 'exp_sup': 6.11, 'utility': 14878}
#  525: {'name': '933', 'exp_sup': 6.11, 'utility': 12844}
#  526: {'name': '143', 'exp_sup': 6.11, 'utility': 8118}
#  527: {'name': '530', 'exp_sup': 6.11, 'utility': 16168}
#  528: {'name': '1278', 'exp_sup': 6.11, 'utility': 14382}
#  529: {'name': '614', 'exp_sup': 6.1, 'utility': 18522}
#  530: {'name': '1343', 'exp_sup': 6.1, 'utility': 11767}
#  531: {'name': '700', 'exp_sup': 6.1, 'utility': 6695}
#  532: {'name': '204', 'exp_sup': 6.09, 'utility': 5440}
#  533: {'name': '406', 'exp_sup': 6.09, 'utility': 7051}
#  534: {'name': '972', 'exp_sup': 6.09, 'utility': 7359}
#  535: {'name': '1411', 'exp_sup': 6.09, 'utility': 7220}
#  536: {'name': '532', 'exp_sup': 6.09, 'utility': 15867}
#  537: {'name': '188', 'exp_sup': 6.09, 'utility': 9030}
#  538: {'name': '1320', 'exp_sup': 6.09, 'utility': 8246}
#  539: {'name': '657', 'exp_sup': 6.08, 'utility': 7632}
#  540: {'name': '201', 'exp_sup': 6.08, 'utility': 6975}
#  541: {'name': '330', 'exp_sup': 6.08, 'utility': 14726}
#  542: {'name': '940', 'exp_sup': 6.07, 'utility': 11360}
#  543: {'name': '85', 'exp_sup': 6.07, 'utility': 5032}
#  544: {'name': '533', 'exp_sup': 6.06, 'utility': 8228}
#  545: {'name': '1177', 'exp_sup': 6.06, 'utility': 7700}
#  546: {'name': '1047', 'exp_sup': 6.06, 'utility': 11951}
#  547: {'name': '1227', 'exp_sup': 6.05, 'utility': 8992}
#  548: {'name': '1080', 'exp_sup': 6.04, 'utility': 10074}
#  549: {'name': '676', 'exp_sup': 6.04, 'utility': 12824}
#  550: {'name': '1359', 'exp_sup': 6.04, 'utility': 5828}
#  551: {'name': '1093', 'exp_sup': 6.04, 'utility': 15174}
#  552: {'name': '34', 'exp_sup': 6.04, 'utility': 6421}
#  553: {'name': '689', 'exp_sup': 6.03, 'utility': 6864}
#  554: {'name': '1099', 'exp_sup': 6.02, 'utility': 13932}
#  555: {'name': '436', 'exp_sup': 6.02, 'utility': 6579}
#  556: {'name': '876', 'exp_sup': 6.02, 'utility': 6156}
#  557: {'name': '1150', 'exp_sup': 6.02, 'utility': 15631}
#  558: {'name': '270', 'exp_sup': 6.02, 'utility': 11424}
#  559: {'name': '714', 'exp_sup': 6.02, 'utility': 9720}
#  560: {'name': '152', 'exp_sup': 6.01, 'utility': 10115}
#  561: {'name': '1162', 'exp_sup': 6.01, 'utility': 6195}
#  562: {'name': '102', 'exp_sup': 6.0, 'utility': 11270}
#  563: {'name': '51', 'exp_sup': 6.0, 'utility': 5586}
#  564: {'name': '1313', 'exp_sup': 5.99, 'utility': 12152}
#  565: {'name': '13', 'exp_sup': 5.98, 'utility': 9540}
#  566: {'name': '848', 'exp_sup': 5.97, 'utility': 8357}
#  567: {'name': '744', 'exp_sup': 5.96, 'utility': 14467}
#  568: {'name': '360', 'exp_sup': 5.96, 'utility': 5371}
#  569: {'name': '648', 'exp_sup': 5.95, 'utility': 7888}
#  570: {'name': '164', 'exp_sup': 5.95, 'utility': 11286}
#  571: {'name': '1085', 'exp_sup': 5.94, 'utility': 7168}
#  572: {'name': '750', 'exp_sup': 5.94, 'utility': 5460}
#  573: {'name': '1130', 'exp_sup': 5.93, 'utility': 6665}
#  574: {'name': '623', 'exp_sup': 5.93, 'utility': 5040}
#  575: {'name': '145', 'exp_sup': 5.93, 'utility': 8172}
#  576: {'name': '986', 'exp_sup': 5.92, 'utility': 13650}
#  577: {'name': '1115', 'exp_sup': 5.92, 'utility': 7750}
#  578: {'name': '1555', 'exp_sup': 5.92, 'utility': 14160}
#  579: {'name': '722', 'exp_sup': 5.92, 'utility': 8773}
#  580: {'name': '1205', 'exp_sup': 5.91, 'utility': 7800}
#  581: {'name': '661', 'exp_sup': 5.91, 'utility': 8424}
#  582: {'name': '550', 'exp_sup': 5.91, 'utility': 9360}
#  583: {'name': '779', 'exp_sup': 5.91, 'utility': 6154}
#  584: {'name': '65', 'exp_sup': 5.91, 'utility': 10904}
#  585: {'name': '193', 'exp_sup': 5.91, 'utility': 12510}
#  586: {'name': '413', 'exp_sup': 5.9, 'utility': 7650}
#  587: {'name': '1431', 'exp_sup': 5.9, 'utility': 10434}
#  588: {'name': '155', 'exp_sup': 5.9, 'utility': 13335}
#  589: {'name': '861', 'exp_sup': 5.89, 'utility': 9065}
#  590: {'name': '397', 'exp_sup': 5.89, 'utility': 4995}
#  591: {'name': '765', 'exp_sup': 5.88, 'utility': 6144}
#  592: {'name': '950', 'exp_sup': 5.88, 'utility': 13533}
#  593: {'name': '1556', 'exp_sup': 5.88, 'utility': 9805}
#  594: {'name': '892', 'exp_sup': 5.87, 'utility': 8463}
#  595: {'name': '1245', 'exp_sup': 5.87, 'utility': 8116}
#  596: {'name': '680', 'exp_sup': 5.86, 'utility': 4998}
#  597: {'name': '1290', 'exp_sup': 5.86, 'utility': 11235}
#  598: {'name': '729', 'exp_sup': 5.85, 'utility': 4988}
#  599: {'name': '936', 'exp_sup': 5.85, 'utility': 10842}
#  600: {'name': '344', 'exp_sup': 5.84, 'utility': 8661}
#  601: {'name': '1218', 'exp_sup': 5.84, 'utility': 4941}
#  602: {'name': '712', 'exp_sup': 5.84, 'utility': 17028}
#  603: {'name': '1534', 'exp_sup': 5.84, 'utility': 10842}
#  604: {'name': '42', 'exp_sup': 5.84, 'utility': 9306}
#  605: {'name': '1374', 'exp_sup': 5.84, 'utility': 13005}
#  606: {'name': '1435', 'exp_sup': 5.83, 'utility': 10336}
#  607: {'name': '245', 'exp_sup': 5.83, 'utility': 6407}
#  608: {'name': '467', 'exp_sup': 5.82, 'utility': 12192}
#  609: {'name': '1529', 'exp_sup': 5.82, 'utility': 13407}
#  610: {'name': '52', 'exp_sup': 5.82, 'utility': 6944}
#  611: {'name': '719', 'exp_sup': 5.82, 'utility': 5390}
#  612: {'name': '455', 'exp_sup': 5.81, 'utility': 7224}
#  613: {'name': '884', 'exp_sup': 5.81, 'utility': 12480}
#  614: {'name': '755', 'exp_sup': 5.81, 'utility': 9238}
#  615: {'name': '909', 'exp_sup': 5.81, 'utility': 5735}
#  616: {'name': '869', 'exp_sup': 5.8, 'utility': 6572}
#  617: {'name': '275', 'exp_sup': 5.8, 'utility': 11118}
#  618: {'name': '928', 'exp_sup': 5.79, 'utility': 5115}
#  619: {'name': '1325', 'exp_sup': 5.78, 'utility': 4862}
#  620: {'name': '363', 'exp_sup': 5.78, 'utility': 8008}
#  621: {'name': '578', 'exp_sup': 5.77, 'utility': 8244}
#  622: {'name': '25', 'exp_sup': 5.77, 'utility': 5735}
#  623: {'name': '492', 'exp_sup': 5.76, 'utility': 9381}
#  624: {'name': '1527', 'exp_sup': 5.76, 'utility': 9688}
#  625: {'name': '358', 'exp_sup': 5.76, 'utility': 13125}
#  626: {'name': '1498', 'exp_sup': 5.75, 'utility': 7353}
#  627: {'name': '74', 'exp_sup': 5.75, 'utility': 4867}
#  628: {'name': '290', 'exp_sup': 5.74, 'utility': 6284}
#  629: {'name': '987', 'exp_sup': 5.74, 'utility': 9065}
#  630: {'name': '366', 'exp_sup': 5.73, 'utility': 9676}
#  631: {'name': '423', 'exp_sup': 5.72, 'utility': 5733}
#  632: {'name': '60', 'exp_sup': 5.72, 'utility': 5852}
#  633: {'name': '647', 'exp_sup': 5.71, 'utility': 10138}
#  634: {'name': '605', 'exp_sup': 5.71, 'utility': 6136}
#  635: {'name': '99', 'exp_sup': 5.7, 'utility': 8260}
#  636: {'name': '607', 'exp_sup': 5.7, 'utility': 9174}
#  637: {'name': '1044', 'exp_sup': 5.7, 'utility': 5080}
#  638: {'name': '465', 'exp_sup': 5.69, 'utility': 10030}
#  639: {'name': '190', 'exp_sup': 5.69, 'utility': 14960}
#  640: {'name': '208', 'exp_sup': 5.69, 'utility': 6175}
#  641: {'name': '1191', 'exp_sup': 5.68, 'utility': 5670}
#  642: {'name': '783', 'exp_sup': 5.67, 'utility': 10127}
#  643: {'name': '1155', 'exp_sup': 5.67, 'utility': 7144}
#  644: {'name': '1054', 'exp_sup': 5.67, 'utility': 6068}
#  645: {'name': '572', 'exp_sup': 5.67, 'utility': 9530}
#  646: {'name': '31', 'exp_sup': 5.66, 'utility': 6200}
#  647: {'name': '1095', 'exp_sup': 5.65, 'utility': 5372}
#  648: {'name': '183', 'exp_sup': 5.65, 'utility': 7230}
#  649: {'name': '237', 'exp_sup': 5.65, 'utility': 7769}
#  650: {'name': '325', 'exp_sup': 5.65, 'utility': 6342}
#  651: {'name': '1401', 'exp_sup': 5.65, 'utility': 5084}
#  652: {'name': '879', 'exp_sup': 5.65, 'utility': 4884}
#  653: {'name': '229', 'exp_sup': 5.65, 'utility': 8697}
#  654: {'name': '1430', 'exp_sup': 5.64, 'utility': 13440}
#  655: {'name': '962', 'exp_sup': 5.64, 'utility': 8602}
#  656: {'name': '1175', 'exp_sup': 5.64, 'utility': 6401}
#  657: {'name': '1326', 'exp_sup': 5.64, 'utility': 5985}
#  658: {'name': '512', 'exp_sup': 5.63, 'utility': 12056}
#  659: {'name': '476', 'exp_sup': 5.63, 'utility': 11284}
#  660: {'name': '433', 'exp_sup': 5.63, 'utility': 7829}
#  661: {'name': '66', 'exp_sup': 5.62, 'utility': 11352}
#  662: {'name': '1387', 'exp_sup': 5.62, 'utility': 14658}
#  663: {'name': '872', 'exp_sup': 5.62, 'utility': 6804}
#  664: {'name': '487', 'exp_sup': 5.61, 'utility': 10400}
#  665: {'name': '1511', 'exp_sup': 5.61, 'utility': 6240}
#  666: {'name': '1269', 'exp_sup': 5.6, 'utility': 13895}
#  667: {'name': '829', 'exp_sup': 5.6, 'utility': 5642}
#  668: {'name': '517', 'exp_sup': 5.6, 'utility': 9516}
#  669: {'name': '1072', 'exp_sup': 5.6, 'utility': 6240}
#  670: {'name': '797', 'exp_sup': 5.59, 'utility': 8541}
#  671: {'name': '1148', 'exp_sup': 5.59, 'utility': 8070}
#  672: {'name': '515', 'exp_sup': 5.58, 'utility': 6685}
#  673: {'name': '1354', 'exp_sup': 5.58, 'utility': 5920}
#  674: {'name': '736', 'exp_sup': 5.57, 'utility': 7242}
#  675: {'name': '395', 'exp_sup': 5.57, 'utility': 9324}
#  676: {'name': '1360', 'exp_sup': 5.57, 'utility': 7260}
#  677: {'name': '141', 'exp_sup': 5.57, 'utility': 13362}
#  678: {'name': '527', 'exp_sup': 5.57, 'utility': 6426}
#  679: {'name': '678', 'exp_sup': 5.56, 'utility': 12546}
#  680: {'name': '761', 'exp_sup': 5.56, 'utility': 6792}
#  681: {'name': '659', 'exp_sup': 5.56, 'utility': 12519}
#  682: {'name': '1025', 'exp_sup': 5.56, 'utility': 5213}
#  683: {'name': '808', 'exp_sup': 5.53, 'utility': 5282}
#  684: {'name': '107', 'exp_sup': 5.53, 'utility': 6335}
#  685: {'name': '624', 'exp_sup': 5.52, 'utility': 10824}
#  686: {'name': '216', 'exp_sup': 5.51, 'utility': 10440}
#  687: {'name': '593', 'exp_sup': 5.51, 'utility': 4862}
#  688: {'name': '881', 'exp_sup': 5.5, 'utility': 8507}
#  689: {'name': '1147', 'exp_sup': 5.49, 'utility': 5822}
#  690: {'name': '1240', 'exp_sup': 5.49, 'utility': 10385}
#  691: {'name': '403', 'exp_sup': 5.49, 'utility': 5890}
#  692: {'name': '1285', 'exp_sup': 5.48, 'utility': 8041}
#  693: {'name': '1367', 'exp_sup': 5.47, 'utility': 11424}
#  694: {'name': '569', 'exp_sup': 5.47, 'utility': 11692}
#  695: {'name': '1120', 'exp_sup': 5.47, 'utility': 7011}
#  696: {'name': '1168', 'exp_sup': 5.47, 'utility': 12988}
#  697: {'name': '320', 'exp_sup': 5.47, 'utility': 16947}
#  698: {'name': '1073', 'exp_sup': 5.46, 'utility': 12765}
#  699: {'name': '1344', 'exp_sup': 5.46, 'utility': 5470}
#  700: {'name': '362', 'exp_sup': 5.45, 'utility': 16674}
#  701: {'name': '1074', 'exp_sup': 5.45, 'utility': 11894}
#  702: {'name': '354', 'exp_sup': 5.44, 'utility': 8100}
#  703: {'name': '1297', 'exp_sup': 5.44, 'utility': 6474}
#  704: {'name': '457', 'exp_sup': 5.44, 'utility': 6095}
#  705: {'name': '1196', 'exp_sup': 5.43, 'utility': 10220}
#  706: {'name': '342', 'exp_sup': 5.43, 'utility': 5400}
#  707: {'name': '30', 'exp_sup': 5.43, 'utility': 8319}
#  708: {'name': '885', 'exp_sup': 5.42, 'utility': 4962}
#  709: {'name': '484', 'exp_sup': 5.42, 'utility': 12376}
#  710: {'name': '1225', 'exp_sup': 5.42, 'utility': 5160}
#  711: {'name': '595', 'exp_sup': 5.41, 'utility': 5254}
#  712: {'name': '1421', 'exp_sup': 5.41, 'utility': 7952}
#  713: {'name': '1216', 'exp_sup': 5.41, 'utility': 6963}
#  714: {'name': '959', 'exp_sup': 5.4, 'utility': 5100}
#  715: {'name': '1477', 'exp_sup': 5.39, 'utility': 7830}
#  716: {'name': '1342', 'exp_sup': 5.38, 'utility': 11936}
#  717: {'name': '306', 'exp_sup': 5.37, 'utility': 14652}
#  718: {'name': '1403', 'exp_sup': 5.37, 'utility': 7564}
#  719: {'name': '843', 'exp_sup': 5.36, 'utility': 10584}
#  720: {'name': '574', 'exp_sup': 5.36, 'utility': 10680}
#  721: {'name': '912', 'exp_sup': 5.36, 'utility': 8153}
#  722: {'name': '1200', 'exp_sup': 5.35, 'utility': 7667}
#  723: {'name': '663', 'exp_sup': 5.35, 'utility': 5632}
#  724: {'name': '1139', 'exp_sup': 5.35, 'utility': 10868}
#  725: {'name': '84', 'exp_sup': 5.34, 'utility': 8149}
#  726: {'name': '965', 'exp_sup': 5.33, 'utility': 5661}
#  727: {'name': '47', 'exp_sup': 5.32, 'utility': 6682}
#  728: {'name': '1429', 'exp_sup': 5.32, 'utility': 8880}
#  729: {'name': '96', 'exp_sup': 5.31, 'utility': 6541}
#  730: {'name': '1321', 'exp_sup': 5.31, 'utility': 6723}
#  731: {'name': '249', 'exp_sup': 5.31, 'utility': 8421}
#  732: {'name': '1499, 1056', 'exp_sup': 1.52, 'utility': 4891}
#  733: {'name': '890, 191', 'exp_sup': 1.37, 'utility': 5715}
#  734: {'name': '819, 1279', 'exp_sup': 1.27, 'utility': 6303}
#  735: {'name': '419, 1511', 'exp_sup': 1.18, 'utility': 5127}
#  736: {'name': '1282, 1066', 'exp_sup': 1.17, 'utility': 5408}
#  737: {'name': '789, 556', 'exp_sup': 1.1, 'utility': 5496}
#  738: {'name': '789, 1248', 'exp_sup': 0.99, 'utility': 4865}
#  739: {'name': '1506, 487', 'exp_sup': 0.93, 'utility': 5167}
#  740: {'name': '890, 1410, 1493', 'exp_sup': 0.91, 'utility': 4876}
#  741: {'name': '988, 1431', 'exp_sup': 0.9, 'utility': 6949}
#  742: {'name': '491, 1227', 'exp_sup': 0.88, 'utility': 5407}
#  743: {'name': '1399, 1426', 'exp_sup': 0.86, 'utility': 5680}
#  744: {'name': '285, 1094', 'exp_sup': 0.86, 'utility': 4881}
#  745: {'name': '111, 937', 'exp_sup': 0.81, 'utility': 4963}
#  746: {'name': '916, 379, 922', 'exp_sup': 0.78, 'utility': 5532}
#  747: {'name': '222, 1497', 'exp_sup': 0.78, 'utility': 5726}
#  748: {'name': '365, 53', 'exp_sup': 0.73, 'utility': 4938}
#  749: {'name': '1399, 1426, 1365', 'exp_sup': 0.7, 'utility': 6104}
#  750: {'name': '952, 559', 'exp_sup': 0.69, 'utility': 5060}
#  751: {'name': '1426, 727', 'exp_sup': 0.67, 'utility': 6589}
#  752: {'name': '1338, 1049', 'exp_sup': 0.67, 'utility': 5928}
#  753: {'name': '896, 530', 'exp_sup': 0.63, 'utility': 5686}
#  754: {'name': '1161, 512', 'exp_sup': 0.62, 'utility': 5423}
#  755: {'name': '890, 1410, 191', 'exp_sup': 0.61, 'utility': 5301}
#  756: {'name': '1389, 1279', 'exp_sup': 0.61, 'utility': 5360}
#  757: {'name': '136, 702', 'exp_sup': 0.58, 'utility': 5010}
#  758: {'name': '1077, 721', 'exp_sup': 0.56, 'utility': 4892}
#  759: {'name': '890, 1410, 1493, 191', 'exp_sup': 0.54, 'utility': 6885}
#  760: {'name': '1493, 164', 'exp_sup': 0.52, 'utility': 4851}
#  761: {'name': '449, 387, 193, 936', 'exp_sup': 0.48, 'utility': 5150}
#  762: {'name': '656, 13', 'exp_sup': 0.48, 'utility': 4815}
#  763: {'name': '1399, 1426, 1043, 1365', 'exp_sup': 0.47, 'utility': 5106}
#  764: {'name': '656, 323, 623', 'exp_sup': 0.47, 'utility': 5815}
#  765: {'name': '1426, 1093', 'exp_sup': 0.46, 'utility': 4959}
#  766: {'name': '918, 136, 702', 'exp_sup': 0.43, 'utility': 6495}
#  767: {'name': '1110, 261, 987', 'exp_sup': 0.43, 'utility': 6118}
#  768: {'name': '1472, 1389, 819', 'exp_sup': 0.43, 'utility': 4851}
#  769: {'name': '446, 80, 729', 'exp_sup': 0.42, 'utility': 5460}
#  770: {'name': '1399, 1426, 1043, 217', 'exp_sup': 0.4, 'utility': 5128}
#  771: {'name': '946, 154, 1136, 1529', 'exp_sup': 0.4, 'utility': 5037}
#  772: {'name': '1389, 907, 930', 'exp_sup': 0.38, 'utility': 4814}
#  773: {'name': '285, 1094, 518', 'exp_sup': 0.38, 'utility': 5969}
#  774: {'name': '988, 1281', 'exp_sup': 0.36, 'utility': 5826}
#  775: {'name': '1180, 614', 'exp_sup': 0.36, 'utility': 6912}
#  776: {'name': '449, 387, 193, 936, 1325', 'exp_sup': 0.35, 'utility': 5436}
#  777: {'name': '1472, 170', 'exp_sup': 0.35, 'utility': 4860}
#  778: {'name': '1399, 1426, 1043, 217, 1365', 'exp_sup': 0.34, 'utility': 5446}
#  779: {'name': '1436, 111, 937', 'exp_sup': 0.34, 'utility': 5607}
#  780: {'name': '1389, 819, 1279', 'exp_sup': 0.34, 'utility': 5899}
#  781: {'name': '1472, 819, 1279', 'exp_sup': 0.32, 'utility': 5904}
#  782: {'name': '1426, 727, 1365', 'exp_sup': 0.3, 'utility': 5318}
#  783: {'name': '640, 324, 234', 'exp_sup': 0.28, 'utility': 4947}
#  784: {'name': '502, 968, 415', 'exp_sup': 0.28, 'utility': 5152}
#  785: {'name': '1210, 844, 1493', 'exp_sup': 0.27, 'utility': 5114}
#  786: {'name': '1118, 502, 968', 'exp_sup': 0.26, 'utility': 4873}
#  787: {'name': '932, 283, 193, 936', 'exp_sup': 0.25, 'utility': 4838}
#  788: {'name': '1399, 1426, 1043, 1542', 'exp_sup': 0.25, 'utility': 5263}
#  789: {'name': '449, 387, 283, 193', 'exp_sup': 0.25, 'utility': 5130}
#  790: {'name': '1472, 1389, 1279', 'exp_sup': 0.25, 'utility': 5003}
#  791: {'name': '489, 532', 'exp_sup': 0.25, 'utility': 5557}
#  792: {'name': '69, 435, 1290', 'exp_sup': 0.24, 'utility': 5484}
#  793: {'name': '1118, 502, 415', 'exp_sup': 0.23, 'utility': 6014}
#  794: {'name': '988, 772', 'exp_sup': 0.23, 'utility': 7188}
#  795: {'name': '1291, 941, 914', 'exp_sup': 0.22, 'utility': 5226}
#  796: {'name': '304, 813, 1256, 1529', 'exp_sup': 0.21, 'utility': 5336}
#  797: {'name': '932, 387, 283, 193, 936', 'exp_sup': 0.21, 'utility': 5561}
#  798: {'name': '1257, 49, 1374', 'exp_sup': 0.21, 'utility': 5409}
#  799: {'name': '1338, 789, 1028, 373, 1248, 972', 'exp_sup': 0.21, 'utility': 5196}
#  800: {'name': '449, 387, 283, 193, 936', 'exp_sup': 0.2, 'utility': 6242}
#  801: {'name': '988, 1281, 339', 'exp_sup': 0.19, 'utility': 6806}
#  802: {'name': '932, 283, 193, 936, 1325', 'exp_sup': 0.18, 'utility': 5124}
#  803: {'name': '1399, 1426, 1043, 1542, 1365', 'exp_sup': 0.18, 'utility': 5581}
#  804: {'name': '449, 387, 283, 193, 1325', 'exp_sup': 0.18, 'utility': 5416}
#  805: {'name': '1161, 1544, 202, 751, 512', 'exp_sup': 0.17, 'utility': 5002}
#  806: {'name': '1399, 1426, 727', 'exp_sup': 0.17, 'utility': 7208}
#  807: {'name': '1426, 217, 727', 'exp_sup': 0.17, 'utility': 5697}
#  808: {'name': '1472, 1389, 819, 1279', 'exp_sup': 0.17, 'utility': 7219}
#  809: {'name': '1161, 1544, 751, 9, 512', 'exp_sup': 0.16, 'utility': 5374}
#  810: {'name': '1399, 1426, 1043, 217, 1542', 'exp_sup': 0.16, 'utility': 5603}
#  811: {'name': '1118, 502, 968, 415', 'exp_sup': 0.16, 'utility': 6910}
#  812: {'name': '634, 497, 1050, 1200', 'exp_sup': 0.15, 'utility': 4910}
#  813: {'name': '932, 387, 283, 193, 936, 1325', 'exp_sup': 0.15, 'utility': 5847}
#  814: {'name': '1045, 529, 136, 519', 'exp_sup': 0.15, 'utility': 5050}
#  815: {'name': '988, 1281, 772', 'exp_sup': 0.15, 'utility': 7378}
#  816: {'name': '932, 170, 387, 193, 936', 'exp_sup': 0.14, 'utility': 5429}
#  817: {'name': '449, 387, 283, 193, 936, 1325', 'exp_sup': 0.14, 'utility': 6528}
#  818: {'name': '883, 446, 80, 722, 729, 512', 'exp_sup': 0.14, 'utility': 4806}
#  819: {'name': '1389, 907, 541, 930', 'exp_sup': 0.14, 'utility': 5942}
#  820: {'name': '1372, 1212, 430, 1555', 'exp_sup': 0.14, 'utility': 4948}
#  821: {'name': '937, 1047', 'exp_sup': 0.14, 'utility': 5111}
#  822: {'name': '304, 813, 254, 1529', 'exp_sup': 0.13, 'utility': 4818}
#  823: {'name': '932, 170, 193, 936, 1325', 'exp_sup': 0.13, 'utility': 4992}
#  824: {'name': '1161, 202, 751, 9, 512', 'exp_sup': 0.13, 'utility': 5386}
#  825: {'name': '1399, 1426, 1043, 217, 1542, 1365', 'exp_sup': 0.13, 'utility': 5921}
#  826: {'name': '1257, 558, 49, 1374', 'exp_sup': 0.13, 'utility': 5969}
#  827: {'name': '1281, 772, 1431', 'exp_sup': 0.13, 'utility': 5178}
#  828: {'name': '1472, 1389, 819, 430', 'exp_sup': 0.13, 'utility': 6111}
#  829: {'name': '1045, 812, 313, 1049', 'exp_sup': 0.12, 'utility': 5243}
#  830: {'name': '640, 104, 940', 'exp_sup': 0.12, 'utility': 5746}
#  831: {'name': '1399, 1426, 727, 1365', 'exp_sup': 0.11, 'utility': 7632}
#  832: {'name': '1291, 941, 914, 958', 'exp_sup': 0.11, 'utility': 5906}
#  833: {'name': '988, 772, 339', 'exp_sup': 0.11, 'utility': 6142}
#  834: {'name': '1389, 907, 930, 25', 'exp_sup': 0.11, 'utility': 5744}
#  835: {'name': '819, 1279, 430', 'exp_sup': 0.11, 'utility': 5844}
#  836: {'name': '1351, 625, 824, 835', 'exp_sup': 0.1, 'utility': 5495}
#  837: {'name': '932, 170, 387, 193, 936, 1325', 'exp_sup': 0.1, 'utility': 5715}
#  838: {'name': '988, 339, 1431', 'exp_sup': 0.1, 'utility': 6000}
#  839: {'name': '175, 125, 275', 'exp_sup': 0.1, 'utility': 5337}
#  840: {'name': '260, 676, 986', 'exp_sup': 0.1, 'utility': 5506}
#  841: {'name': '1161, 1544, 202, 9, 512', 'exp_sup': 0.09, 'utility': 5313}
#  842: {'name': '1362, 946, 742', 'exp_sup': 0.09, 'utility': 4827}
#  843: {'name': '946, 154, 1136, 397, 1529', 'exp_sup': 0.09, 'utility': 5442}
#  844: {'name': '1161, 1544, 202, 751, 9, 512', 'exp_sup': 0.08, 'utility': 5970}
#  845: {'name': '988, 1281, 1431', 'exp_sup': 0.08, 'utility': 7236}
#  846: {'name': '988, 1281, 772, 339', 'exp_sup': 0.08, 'utility': 8358}
#  847: {'name': '1472, 1279, 430', 'exp_sup': 0.08, 'utility': 4948}
#  848: {'name': '1389, 1279, 430', 'exp_sup': 0.08, 'utility': 4943}
#  849: {'name': '932, 170, 387, 283, 193', 'exp_sup': 0.07, 'utility': 5409}
#  850: {'name': '932, 170, 283, 193, 936', 'exp_sup': 0.07, 'utility': 5798}
#  851: {'name': '1399, 1426, 1043, 727', 'exp_sup': 0.07, 'utility': 5934}
#  852: {'name': '1394, 80, 712, 569, 1321', 'exp_sup': 0.07, 'utility': 5067}
#  853: {'name': '1389, 907, 1500', 'exp_sup': 0.07, 'utility': 5317}
#  854: {'name': '662, 446, 656, 13', 'exp_sup': 0.07, 'utility': 5250}
#  855: {'name': '304, 813, 254, 1256, 1529', 'exp_sup': 0.06, 'utility': 5672}
#  856: {'name': '932, 170, 387, 283, 193, 936', 'exp_sup': 0.06, 'utility': 6521}
#  857: {'name': '932, 170, 283, 193, 1325', 'exp_sup': 0.06, 'utility': 4972}
#  858: {'name': '1399, 1426, 1043, 1542, 727', 'exp_sup': 0.06, 'utility': 6409}
#  859: {'name': '1281, 772, 339, 1431', 'exp_sup': 0.06, 'utility': 6158}
#  860: {'name': '1472, 819, 1279, 430', 'exp_sup': 0.06, 'utility': 7164}
#  861: {'name': '1389, 819, 1279, 430', 'exp_sup': 0.06, 'utility': 7159}
#  862: {'name': '1389, 907, 541, 25', 'exp_sup': 0.06, 'utility': 5688}
#  863: {'name': '1389, 907, 1500, 930', 'exp_sup': 0.06, 'utility': 6501}
#  864: {'name': '907, 541, 930, 25', 'exp_sup': 0.06, 'utility': 5294}
#  865: {'name': '304, 1485, 1529', 'exp_sup': 0.05, 'utility': 4812}
#  866: {'name': '932, 170, 387, 283, 193, 1325', 'exp_sup': 0.05, 'utility': 5695}
#  867: {'name': '932, 170, 387, 283, 936, 1325', 'exp_sup': 0.05, 'utility': 4968}
#  868: {'name': '932, 170, 283, 193, 936, 1325', 'exp_sup': 0.05, 'utility': 6084}
#  869: {'name': '520, 326, 83, 1402, 676, 876', 'exp_sup': 0.05, 'utility': 5062}
#  870: {'name': '988, 772, 1431', 'exp_sup': 0.05, 'utility': 6572}
#  871: {'name': '225, 614', 'exp_sup': 0.05, 'utility': 5380}
#  872: {'name': '1179, 320', 'exp_sup': 0.05, 'utility': 5038}
#  873: {'name': '932, 170, 387, 283, 193, 936, 1325', 'exp_sup': 0.04, 'utility': 6807}
#  874: {'name': '1399, 1426, 217, 727', 'exp_sup': 0.04, 'utility': 5332}
#  875: {'name': '1426, 1043, 217, 727, 1365', 'exp_sup': 0.04, 'utility': 4990}
#  876: {'name': '988, 1281, 772, 1431', 'exp_sup': 0.04, 'utility': 8788}
#  877: {'name': '988, 1281, 772, 1142, 339', 'exp_sup': 0.04, 'utility': 5134}
#  878: {'name': '988, 1281, 339, 1431', 'exp_sup': 0.04, 'utility': 8216}
#  879: {'name': '1472, 1389, 1279, 430', 'exp_sup': 0.04, 'utility': 6263}
#  880: {'name': '1210, 844, 1493, 245', 'exp_sup': 0.04, 'utility': 6157}
#  881: {'name': '379, 446, 656, 13', 'exp_sup': 0.04, 'utility': 5255}
#  882: {'name': '1398, 83', 'exp_sup': 0.04, 'utility': 5695}
#  883: {'name': '1373, 321, 1077, 1342', 'exp_sup': 0.03, 'utility': 5008}
#  884: {'name': '617, 321, 1077, 1096, 1342', 'exp_sup': 0.03, 'utility': 4903}
#  885: {'name': '617, 321, 1077, 1096, 327, 1342', 'exp_sup': 0.03, 'utility': 5143}
#  886: {'name': '520, 54, 953, 1163, 909', 'exp_sup': 0.03, 'utility': 4984}
#  887: {'name': '1508, 626, 825, 1019, 963', 'exp_sup': 0.03, 'utility': 4992}
#  888: {'name': '1508, 626, 1019, 963, 1329, 779', 'exp_sup': 0.03, 'utility': 5346}
#  889: {'name': '1399, 1426, 1043, 217, 727', 'exp_sup': 0.03, 'utility': 6274}
#  890: {'name': '1399, 1426, 1043, 727, 1365', 'exp_sup': 0.03, 'utility': 6252}
#  891: {'name': '1110, 534, 57, 1073', 'exp_sup': 0.03, 'utility': 4839}
#  892: {'name': '1426, 756, 727', 'exp_sup': 0.03, 'utility': 5370}
#  893: {'name': '1045, 812, 313, 1049, 695', 'exp_sup': 0.03, 'utility': 6299}
#  894: {'name': '1045, 812, 1049, 695', 'exp_sup': 0.03, 'utility': 5444}
#  895: {'name': '1045, 270, 569, 47', 'exp_sup': 0.03, 'utility': 4984}
#  896: {'name': '1472, 1389, 819, 1279, 430', 'exp_sup': 0.03, 'utility': 8479}
#  897: {'name': '907, 541, 1500', 'exp_sup': 0.03, 'utility': 4867}
#  898: {'name': '304, 254, 1485, 1529', 'exp_sup': 0.02, 'utility': 5148}
#  899: {'name': '304, 1485, 1256, 1529', 'exp_sup': 0.02, 'utility': 5666}
#  900: {'name': '1373, 617, 1077, 1096, 1342', 'exp_sup': 0.02, 'utility': 5019}

# %% [markdown]
# ## Hiện thực Chess

# %%
# chạy với chess
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_chess.txt, ./data/chess_utility.txt", 0.001, 100)
algorithm.print_stats("./out/TUHUFP/chess/output_chess_top_100.txt")
# Out:
# Reading data . . .
# Minimum utility set to: 2156
# {'database util: ': 2156659}
# Top 100 CUPs:
#  1: {'name': '52', 'exp_sup': 1616.54, 'utility': 104178}
#  2: {'name': '29', 'exp_sup': 1598.92, 'utility': 70088}
#  3: {'name': '58', 'exp_sup': 1595.58, 'utility': 17462}
#  4: {'name': '40', 'exp_sup': 1579.27, 'utility': 188760}
#  5: {'name': '60', 'exp_sup': 1565.64, 'utility': 68908}
#  6: {'name': '62', 'exp_sup': 1537.33, 'utility': 16784}
#  7: {'name': '7', 'exp_sup': 1535.24, 'utility': 50790}
#  8: {'name': '36', 'exp_sup': 1530.49, 'utility': 16934}
#  9: {'name': '56', 'exp_sup': 1513.93, 'utility': 66780}
#  10: {'name': '48', 'exp_sup': 1500.86, 'utility': 115367}
#  11: {'name': '66', 'exp_sup': 1498.92, 'utility': 66644}
#  12: {'name': '34', 'exp_sup': 1493.64, 'utility': 99330}
#  13: {'name': '5', 'exp_sup': 1466.73, 'utility': 48369}
#  14: {'name': '9', 'exp_sup': 1446.46, 'utility': 31818}
#  15: {'name': '25', 'exp_sup': 1445.46, 'utility': 15465}
#  16: {'name': '3', 'exp_sup': 1407.44, 'utility': 61608}
#  17: {'name': '42', 'exp_sup': 1355.91, 'utility': 14849}
#  18: {'name': '64', 'exp_sup': 1337.59, 'utility': 56768}
#  19: {'name': '44', 'exp_sup': 1325.93, 'utility': 14261}
#  20: {'name': '46', 'exp_sup': 1284.58, 'utility': 14045}
#  21: {'name': '31', 'exp_sup': 1274.29, 'utility': 41649}
#  22: {'name': '17', 'exp_sup': 1251.12, 'utility': 40662}
#  23: {'name': '74', 'exp_sup': 1237.31, 'utility': 13298}
#  24: {'name': '72', 'exp_sup': 1177.8, 'utility': 77802}
#  25: {'name': '21', 'exp_sup': 1128.59, 'utility': 12263}
#  26: {'name': '54', 'exp_sup': 1105.31, 'utility': 11965}
#  27: {'name': '38', 'exp_sup': 1101.41, 'utility': 12130}
#  28: {'name': '27', 'exp_sup': 1098.98, 'utility': 24398}
#  29: {'name': '11', 'exp_sup': 1066.24, 'utility': 58730}
#  30: {'name': '15', 'exp_sup': 1008.29, 'utility': 32700}
#  31: {'name': '70', 'exp_sup': 1005.64, 'utility': 21824}
#  32: {'name': '68', 'exp_sup': 1003.26, 'utility': 75341}
#  33: {'name': '50', 'exp_sup': 965.12, 'utility': 54140}
#  34: {'name': '19', 'exp_sup': 958.74, 'utility': 32565}
#  35: {'name': '23', 'exp_sup': 919.58, 'utility': 48960}
#  36: {'name': '13', 'exp_sup': 860.84, 'utility': 9269}
#  37: {'name': '1', 'exp_sup': 832.29, 'utility': 65471}
#  38: {'name': '52, 58', 'exp_sup': 806.57, 'utility': 121139}
#  39: {'name': '52, 29', 'exp_sup': 802.29, 'utility': 172766}
#  40: {'name': '52, 40', 'exp_sup': 800.33, 'utility': 290726}
#  41: {'name': '52, 60', 'exp_sup': 797.15, 'utility': 170582}
#  42: {'name': '29, 58', 'exp_sup': 794.58, 'utility': 87031}
#  43: {'name': '29, 40', 'exp_sup': 792.51, 'utility': 255631}
#  44: {'name': '58, 40', 'exp_sup': 790.04, 'utility': 205017}
#  45: {'name': '58, 60', 'exp_sup': 784.78, 'utility': 85721}
#  46: {'name': '52, 62', 'exp_sup': 781.35, 'utility': 115661}
#  47: {'name': '29, 60', 'exp_sup': 777.6, 'utility': 136920}
#  48: {'name': '52, 56', 'exp_sup': 776.21, 'utility': 164720}
#  49: {'name': '52, 7', 'exp_sup': 774.06, 'utility': 150447}
#  50: {'name': '40, 60', 'exp_sup': 773.52, 'utility': 253428}
#  51: {'name': '29, 62', 'exp_sup': 772.37, 'utility': 83526}
#  52: {'name': '58, 62', 'exp_sup': 769.84, 'utility': 33329}
#  53: {'name': '58, 36', 'exp_sup': 767.98, 'utility': 33744}
#  54: {'name': '29, 7', 'exp_sup': 767.86, 'utility': 117944}
#  55: {'name': '29, 36', 'exp_sup': 765.95, 'utility': 84385}
#  56: {'name': '58, 7', 'exp_sup': 765.83, 'utility': 67239}
#  57: {'name': '52, 36', 'exp_sup': 764.38, 'utility': 117430}
#  58: {'name': '40, 62', 'exp_sup': 764.28, 'utility': 197416}
#  59: {'name': '60, 62', 'exp_sup': 762.34, 'utility': 82302}
#  60: {'name': '52, 48', 'exp_sup': 761.78, 'utility': 212460}
#  61: {'name': '40, 36', 'exp_sup': 761.32, 'utility': 198648}
#  62: {'name': '58, 56', 'exp_sup': 759.72, 'utility': 82803}
#  63: {'name': '52, 66', 'exp_sup': 759.17, 'utility': 164458}
#  64: {'name': '40, 7', 'exp_sup': 758.2, 'utility': 231271}
#  65: {'name': '2', 'exp_sup': 757.95, 'utility': 24618}
#  66: {'name': '29, 56', 'exp_sup': 757.1, 'utility': 132152}
#  67: {'name': '14', 'exp_sup': 755.4, 'utility': 8252}
#  68: {'name': '58, 48', 'exp_sup': 753.39, 'utility': 131386}
#  69: {'name': '60, 7', 'exp_sup': 752.4, 'utility': 115497}
#  70: {'name': '52, 34', 'exp_sup': 750.57, 'utility': 197472}
#  71: {'name': '60, 36', 'exp_sup': 750.51, 'utility': 83055}
#  72: {'name': '60, 66', 'exp_sup': 748.87, 'utility': 132064}
#  73: {'name': '29, 34', 'exp_sup': 748.84, 'utility': 165212}
#  74: {'name': '29, 66', 'exp_sup': 748.18, 'utility': 132172}
#  75: {'name': '58, 66', 'exp_sup': 747.26, 'utility': 82834}
#  76: {'name': '40, 56', 'exp_sup': 746.88, 'utility': 243050}
#  77: {'name': '52, 5', 'exp_sup': 745.02, 'utility': 144276}
#  78: {'name': '29, 48', 'exp_sup': 744.94, 'utility': 179722}
#  79: {'name': '40, 48', 'exp_sup': 741.87, 'utility': 290391}
#  80: {'name': '60, 48', 'exp_sup': 741.31, 'utility': 178947}
#  81: {'name': '29, 5', 'exp_sup': 739.46, 'utility': 112623}
#  82: {'name': '60, 56', 'exp_sup': 739.43, 'utility': 130088}
#  83: {'name': '40, 34', 'exp_sup': 737.74, 'utility': 277239}
#  84: {'name': '7, 36', 'exp_sup': 736.85, 'utility': 65158}
#  85: {'name': '58, 5', 'exp_sup': 736.2, 'utility': 64234}
#  86: {'name': '62, 36', 'exp_sup': 735.64, 'utility': 32252}
#  87: {'name': '40, 66', 'exp_sup': 734.99, 'utility': 243649}
#  88: {'name': '58, 34', 'exp_sup': 734.32, 'utility': 115440}
#  89: {'name': '29, 25', 'exp_sup': 733.79, 'utility': 77685}
#  90: {'name': '60, 34', 'exp_sup': 732.14, 'utility': 162688}
#  91: {'name': '7, 34', 'exp_sup': 731.86, 'utility': 143691}
#  92: {'name': '52, 25', 'exp_sup': 731.26, 'utility': 107984}
#  93: {'name': '62, 7', 'exp_sup': 731.07, 'utility': 64443}
#  94: {'name': '62, 56', 'exp_sup': 730.52, 'utility': 79966}
#  95: {'name': '36, 48', 'exp_sup': 729.26, 'utility': 129898}
#  96: {'name': '52, 9', 'exp_sup': 728.24, 'utility': 124558}
#  97: {'name': '36, 56', 'exp_sup': 727.83, 'utility': 80092}
#  98: {'name': '7, 66', 'exp_sup': 727.27, 'utility': 111671}
#  99: {'name': '60, 5', 'exp_sup': 725.51, 'utility': 110905}
#  100: {'name': '62, 66', 'exp_sup': 725.14, 'utility': 79147}

# %%
# chạy với chess
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_chess.txt, ./data/chess_utility.txt", 0.001, 300)
algorithm.print_stats("./out/TUHUFP/chess/output_chess_top_300.txt")
# Out:
# Reading data . . .
# Minimum utility set to: 2156
# {'database util: ': 2156659}
# Top 300 CUPs:
#  1: {'name': '52', 'exp_sup': 1616.54, 'utility': 104178}
#  2: {'name': '29', 'exp_sup': 1598.92, 'utility': 70088}
#  3: {'name': '58', 'exp_sup': 1595.58, 'utility': 17462}
#  4: {'name': '40', 'exp_sup': 1579.27, 'utility': 188760}
#  5: {'name': '60', 'exp_sup': 1565.64, 'utility': 68908}
#  6: {'name': '62', 'exp_sup': 1537.33, 'utility': 16784}
#  7: {'name': '7', 'exp_sup': 1535.24, 'utility': 50790}
#  8: {'name': '36', 'exp_sup': 1530.49, 'utility': 16934}
#  9: {'name': '56', 'exp_sup': 1513.93, 'utility': 66780}
#  10: {'name': '48', 'exp_sup': 1500.86, 'utility': 115367}
#  11: {'name': '66', 'exp_sup': 1498.92, 'utility': 66644}
#  12: {'name': '34', 'exp_sup': 1493.64, 'utility': 99330}
#  13: {'name': '5', 'exp_sup': 1466.73, 'utility': 48369}
#  14: {'name': '9', 'exp_sup': 1446.46, 'utility': 31818}
#  15: {'name': '25', 'exp_sup': 1445.46, 'utility': 15465}
#  16: {'name': '3', 'exp_sup': 1407.44, 'utility': 61608}
#  17: {'name': '42', 'exp_sup': 1355.91, 'utility': 14849}
#  18: {'name': '64', 'exp_sup': 1337.59, 'utility': 56768}
#  19: {'name': '44', 'exp_sup': 1325.93, 'utility': 14261}
#  20: {'name': '46', 'exp_sup': 1284.58, 'utility': 14045}
#  21: {'name': '31', 'exp_sup': 1274.29, 'utility': 41649}
#  22: {'name': '17', 'exp_sup': 1251.12, 'utility': 40662}
#  23: {'name': '74', 'exp_sup': 1237.31, 'utility': 13298}
#  24: {'name': '72', 'exp_sup': 1177.8, 'utility': 77802}
#  25: {'name': '21', 'exp_sup': 1128.59, 'utility': 12263}
#  26: {'name': '54', 'exp_sup': 1105.31, 'utility': 11965}
#  27: {'name': '38', 'exp_sup': 1101.41, 'utility': 12130}
#  28: {'name': '27', 'exp_sup': 1098.98, 'utility': 24398}
#  29: {'name': '11', 'exp_sup': 1066.24, 'utility': 58730}
#  30: {'name': '15', 'exp_sup': 1008.29, 'utility': 32700}
#  31: {'name': '70', 'exp_sup': 1005.64, 'utility': 21824}
#  32: {'name': '68', 'exp_sup': 1003.26, 'utility': 75341}
#  33: {'name': '50', 'exp_sup': 965.12, 'utility': 54140}
#  34: {'name': '19', 'exp_sup': 958.74, 'utility': 32565}
#  35: {'name': '23', 'exp_sup': 919.58, 'utility': 48960}
#  36: {'name': '13', 'exp_sup': 860.84, 'utility': 9269}
#  37: {'name': '1', 'exp_sup': 832.29, 'utility': 65471}
#  38: {'name': '52, 58', 'exp_sup': 806.57, 'utility': 121139}
#  39: {'name': '52, 29', 'exp_sup': 802.29, 'utility': 172766}
#  40: {'name': '52, 40', 'exp_sup': 800.33, 'utility': 290726}
#  41: {'name': '52, 60', 'exp_sup': 797.15, 'utility': 170582}
#  42: {'name': '29, 58', 'exp_sup': 794.58, 'utility': 87031}
#  43: {'name': '29, 40', 'exp_sup': 792.51, 'utility': 255631}
#  44: {'name': '58, 40', 'exp_sup': 790.04, 'utility': 205017}
#  45: {'name': '58, 60', 'exp_sup': 784.78, 'utility': 85721}
#  46: {'name': '52, 62', 'exp_sup': 781.35, 'utility': 115661}
#  47: {'name': '29, 60', 'exp_sup': 777.6, 'utility': 136920}
#  48: {'name': '52, 56', 'exp_sup': 776.21, 'utility': 164720}
#  49: {'name': '52, 7', 'exp_sup': 774.06, 'utility': 150447}
#  50: {'name': '40, 60', 'exp_sup': 773.52, 'utility': 253428}
#  51: {'name': '29, 62', 'exp_sup': 772.37, 'utility': 83526}
#  52: {'name': '58, 62', 'exp_sup': 769.84, 'utility': 33329}
#  53: {'name': '58, 36', 'exp_sup': 767.98, 'utility': 33744}
#  54: {'name': '29, 7', 'exp_sup': 767.86, 'utility': 117944}
#  55: {'name': '29, 36', 'exp_sup': 765.95, 'utility': 84385}
#  56: {'name': '58, 7', 'exp_sup': 765.83, 'utility': 67239}
#  57: {'name': '52, 36', 'exp_sup': 764.38, 'utility': 117430}
#  58: {'name': '40, 62', 'exp_sup': 764.28, 'utility': 197416}
#  59: {'name': '60, 62', 'exp_sup': 762.34, 'utility': 82302}
#  60: {'name': '52, 48', 'exp_sup': 761.78, 'utility': 212460}
#  61: {'name': '40, 36', 'exp_sup': 761.32, 'utility': 198648}
#  62: {'name': '58, 56', 'exp_sup': 759.72, 'utility': 82803}
#  63: {'name': '52, 66', 'exp_sup': 759.17, 'utility': 164458}
#  64: {'name': '40, 7', 'exp_sup': 758.2, 'utility': 231271}
#  65: {'name': '2', 'exp_sup': 757.95, 'utility': 24618}
#  66: {'name': '29, 56', 'exp_sup': 757.1, 'utility': 132152}
#  67: {'name': '14', 'exp_sup': 755.4, 'utility': 8252}
#  68: {'name': '58, 48', 'exp_sup': 753.39, 'utility': 131386}
#  69: {'name': '60, 7', 'exp_sup': 752.4, 'utility': 115497}
#  70: {'name': '52, 34', 'exp_sup': 750.57, 'utility': 197472}
#  71: {'name': '60, 36', 'exp_sup': 750.51, 'utility': 83055}
#  72: {'name': '60, 66', 'exp_sup': 748.87, 'utility': 132064}
#  73: {'name': '29, 34', 'exp_sup': 748.84, 'utility': 165212}
#  74: {'name': '29, 66', 'exp_sup': 748.18, 'utility': 132172}
#  75: {'name': '58, 66', 'exp_sup': 747.26, 'utility': 82834}
#  76: {'name': '40, 56', 'exp_sup': 746.88, 'utility': 243050}
#  77: {'name': '52, 5', 'exp_sup': 745.02, 'utility': 144276}
#  78: {'name': '29, 48', 'exp_sup': 744.94, 'utility': 179722}
#  79: {'name': '40, 48', 'exp_sup': 741.87, 'utility': 290391}
#  80: {'name': '60, 48', 'exp_sup': 741.31, 'utility': 178947}
#  81: {'name': '29, 5', 'exp_sup': 739.46, 'utility': 112623}
#  82: {'name': '60, 56', 'exp_sup': 739.43, 'utility': 130088}
#  83: {'name': '40, 34', 'exp_sup': 737.74, 'utility': 277239}
#  84: {'name': '7, 36', 'exp_sup': 736.85, 'utility': 65158}
#  85: {'name': '58, 5', 'exp_sup': 736.2, 'utility': 64234}
#  86: {'name': '62, 36', 'exp_sup': 735.64, 'utility': 32252}
#  87: {'name': '40, 66', 'exp_sup': 734.99, 'utility': 243649}
#  88: {'name': '58, 34', 'exp_sup': 734.32, 'utility': 115440}
#  89: {'name': '29, 25', 'exp_sup': 733.79, 'utility': 77685}
#  90: {'name': '60, 34', 'exp_sup': 732.14, 'utility': 162688}
#  91: {'name': '7, 34', 'exp_sup': 731.86, 'utility': 143691}
#  92: {'name': '52, 25', 'exp_sup': 731.26, 'utility': 107984}
#  93: {'name': '62, 7', 'exp_sup': 731.07, 'utility': 64443}
#  94: {'name': '62, 56', 'exp_sup': 730.52, 'utility': 79966}
#  95: {'name': '36, 48', 'exp_sup': 729.26, 'utility': 129898}
#  96: {'name': '52, 9', 'exp_sup': 728.24, 'utility': 124558}
#  97: {'name': '36, 56', 'exp_sup': 727.83, 'utility': 80092}
#  98: {'name': '7, 66', 'exp_sup': 727.27, 'utility': 111671}
#  99: {'name': '60, 5', 'exp_sup': 725.51, 'utility': 110905}
#  100: {'name': '62, 66', 'exp_sup': 725.14, 'utility': 79147}
#  101: {'name': '7, 56', 'exp_sup': 721.02, 'utility': 112322}
#  102: {'name': '58, 9', 'exp_sup': 720.18, 'utility': 47296}
#  103: {'name': '29, 9', 'exp_sup': 720.07, 'utility': 94064}
#  104: {'name': '7, 48', 'exp_sup': 719.89, 'utility': 158110}
#  105: {'name': '52, 3', 'exp_sup': 718.73, 'utility': 153244}
#  106: {'name': '40, 5', 'exp_sup': 718.05, 'utility': 223282}
#  107: {'name': '36, 34', 'exp_sup': 716.91, 'utility': 111964}
#  108: {'name': '58, 25', 'exp_sup': 716.42, 'utility': 30961}
#  109: {'name': '60, 25', 'exp_sup': 715.42, 'utility': 77075}
#  110: {'name': '62, 48', 'exp_sup': 715.39, 'utility': 125379}
#  111: {'name': '62, 34', 'exp_sup': 714.96, 'utility': 110832}
#  112: {'name': '7, 5', 'exp_sup': 713.08, 'utility': 93495}
#  113: {'name': '40, 25', 'exp_sup': 712.24, 'utility': 183618}
#  114: {'name': '36, 66', 'exp_sup': 709.93, 'utility': 80135}
#  115: {'name': '56, 66', 'exp_sup': 708.94, 'utility': 125068}
#  116: {'name': '62, 5', 'exp_sup': 708.88, 'utility': 61882}
#  117: {'name': '29, 3', 'exp_sup': 708.45, 'utility': 123288}
#  118: {'name': '36, 5', 'exp_sup': 707.41, 'utility': 62205}
#  119: {'name': '48, 66', 'exp_sup': 706.37, 'utility': 172697}
#  120: {'name': '58, 3', 'exp_sup': 706.12, 'utility': 76772}
#  121: {'name': '40, 9', 'exp_sup': 704.32, 'utility': 200832}
#  122: {'name': '56, 34', 'exp_sup': 703.99, 'utility': 156636}
#  123: {'name': '66, 5', 'exp_sup': 703.33, 'utility': 108091}
#  124: {'name': '60, 9', 'exp_sup': 702.33, 'utility': 92804}
#  125: {'name': '56, 48', 'exp_sup': 700.91, 'utility': 169695}
#  126: {'name': '66, 34', 'exp_sup': 699.99, 'utility': 157508}
#  127: {'name': '36, 25', 'exp_sup': 699.95, 'utility': 30388}
#  128: {'name': '48, 34', 'exp_sup': 699.74, 'utility': 201383}
#  129: {'name': '62, 25', 'exp_sup': 697.0, 'utility': 29738}
#  130: {'name': '34, 5', 'exp_sup': 695.45, 'utility': 140856}
#  131: {'name': '40, 3', 'exp_sup': 693.84, 'utility': 226522}
#  132: {'name': '62, 9', 'exp_sup': 692.12, 'utility': 45217}
#  133: {'name': '48, 25', 'exp_sup': 690.07, 'utility': 119915}
#  134: {'name': '7, 25', 'exp_sup': 689.09, 'utility': 59938}
#  135: {'name': '56, 5', 'exp_sup': 689.09, 'utility': 106663}
#  136: {'name': '60, 3', 'exp_sup': 688.27, 'utility': 121992}
#  137: {'name': '56, 9', 'exp_sup': 688.26, 'utility': 91078}
#  138: {'name': '52, 42', 'exp_sup': 688.23, 'utility': 102622}
#  139: {'name': '7, 9', 'exp_sup': 687.7, 'utility': 75723}
#  140: {'name': '48, 5', 'exp_sup': 684.69, 'utility': 151382}
#  141: {'name': '52, 64', 'exp_sup': 684.06, 'utility': 141962}
#  142: {'name': '36, 9', 'exp_sup': 683.24, 'utility': 45683}
#  143: {'name': '58, 42', 'exp_sup': 682.92, 'utility': 29567}
#  144: {'name': '56, 25', 'exp_sup': 682.7, 'utility': 73534}
#  145: {'name': '34, 9', 'exp_sup': 682.1, 'utility': 119678}
#  146: {'name': '48, 9', 'exp_sup': 681.86, 'utility': 131587}
#  147: {'name': '66, 25', 'exp_sup': 681.41, 'utility': 74411}
#  148: {'name': '29, 42', 'exp_sup': 680.22, 'utility': 73789}
#  149: {'name': '36, 3', 'exp_sup': 679.53, 'utility': 74325}
#  150: {'name': '60, 42', 'exp_sup': 676.51, 'utility': 73376}
#  151: {'name': '7, 3', 'exp_sup': 676.28, 'utility': 105239}
#  152: {'name': '34, 25', 'exp_sup': 676.03, 'utility': 103024}
#  153: {'name': '62, 3', 'exp_sup': 675.43, 'utility': 73985}
#  154: {'name': '56, 3', 'exp_sup': 674.81, 'utility': 118028}
#  155: {'name': '24', 'exp_sup': 673.83, 'utility': 14996}
#  156: {'name': '40, 64', 'exp_sup': 671.11, 'utility': 212460}
#  157: {'name': '40, 42', 'exp_sup': 670.8, 'utility': 174811}
#  158: {'name': '66, 9', 'exp_sup': 670.36, 'utility': 89714}
#  159: {'name': '52, 44', 'exp_sup': 667.7, 'utility': 98857}
#  160: {'name': '5, 9', 'exp_sup': 665.83, 'utility': 72391}
#  161: {'name': '66, 3', 'exp_sup': 662.17, 'utility': 117072}
#  162: {'name': '29, 64', 'exp_sup': 661.85, 'utility': 113308}
#  163: {'name': '29, 44', 'exp_sup': 660.91, 'utility': 70749}
#  164: {'name': '34, 3', 'exp_sup': 660.29, 'utility': 146622}
#  165: {'name': '5, 3', 'exp_sup': 659.41, 'utility': 99860}
#  166: {'name': '60, 64', 'exp_sup': 659.26, 'utility': 112012}
#  167: {'name': '58, 44', 'exp_sup': 658.05, 'utility': 28302}
#  168: {'name': '58, 64', 'exp_sup': 657.97, 'utility': 70620}
#  169: {'name': '5, 25', 'exp_sup': 656.29, 'utility': 57086}
#  170: {'name': '48, 3', 'exp_sup': 653.87, 'utility': 160071}
#  171: {'name': '60, 44', 'exp_sup': 652.46, 'utility': 69435}
#  172: {'name': '40, 44', 'exp_sup': 652.34, 'utility': 167125}
#  173: {'name': '66, 42', 'exp_sup': 652.23, 'utility': 71539}
#  174: {'name': '52, 46', 'exp_sup': 650.66, 'utility': 96676}
#  175: {'name': '48, 42', 'exp_sup': 650.48, 'utility': 111887}
#  176: {'name': '62, 42', 'exp_sup': 650.04, 'utility': 28297}
#  177: {'name': '36, 42', 'exp_sup': 649.16, 'utility': 28659}
#  178: {'name': '7, 42', 'exp_sup': 648.95, 'utility': 56926}
#  179: {'name': '9, 25', 'exp_sup': 647.8, 'utility': 41598}
#  180: {'name': '56, 42', 'exp_sup': 643.85, 'utility': 70665}
#  181: {'name': '62, 44', 'exp_sup': 643.15, 'utility': 27376}
#  182: {'name': '29, 46', 'exp_sup': 642.56, 'utility': 69514}
#  183: {'name': '62, 64', 'exp_sup': 641.93, 'utility': 68111}
#  184: {'name': '52, 31', 'exp_sup': 641.53, 'utility': 123555}
#  185: {'name': '36, 64', 'exp_sup': 641.43, 'utility': 68775}
#  186: {'name': '9, 3', 'exp_sup': 640.82, 'utility': 83696}
#  187: {'name': '34, 42', 'exp_sup': 639.83, 'utility': 99078}
#  188: {'name': '58, 46', 'exp_sup': 638.37, 'utility': 27774}
#  189: {'name': '48, 64', 'exp_sup': 636.88, 'utility': 148284}
#  190: {'name': '7, 44', 'exp_sup': 636.1, 'utility': 54652}
#  191: {'name': '36, 44', 'exp_sup': 636.1, 'utility': 27450}
#  192: {'name': '60, 31', 'exp_sup': 636.0, 'utility': 96146}
#  193: {'name': '29, 31', 'exp_sup': 635.75, 'utility': 95917}
#  194: {'name': '7, 64', 'exp_sup': 635.34, 'utility': 95825}
#  195: {'name': '56, 64', 'exp_sup': 634.6, 'utility': 108348}
#  196: {'name': '40, 46', 'exp_sup': 631.52, 'utility': 163761}
#  197: {'name': '5, 64', 'exp_sup': 630.61, 'utility': 93701}
#  198: {'name': '60, 46', 'exp_sup': 630.42, 'utility': 68407}
#  199: {'name': '58, 31', 'exp_sup': 630.18, 'utility': 55149}
#  200: {'name': '40, 31', 'exp_sup': 630.06, 'utility': 190050}
#  201: {'name': '66, 64', 'exp_sup': 630.04, 'utility': 108260}
#  202: {'name': '52, 17', 'exp_sup': 629.95, 'utility': 120894}
#  203: {'name': '29, 17', 'exp_sup': 628.98, 'utility': 94380}
#  204: {'name': '56, 44', 'exp_sup': 628.92, 'utility': 67713}
#  205: {'name': '48, 44', 'exp_sup': 628.53, 'utility': 106483}
#  206: {'name': '42, 64', 'exp_sup': 628.12, 'utility': 66152}
#  207: {'name': '34, 64', 'exp_sup': 628.05, 'utility': 136476}
#  208: {'name': '52, 74', 'exp_sup': 624.53, 'utility': 91129}
#  209: {'name': '25, 3', 'exp_sup': 623.94, 'utility': 67954}
#  210: {'name': '58, 17', 'exp_sup': 622.77, 'utility': 54101}
#  211: {'name': '40, 74', 'exp_sup': 621.61, 'utility': 155667}
#  212: {'name': '62, 46', 'exp_sup': 621.29, 'utility': 26646}
#  213: {'name': '5, 44', 'exp_sup': 620.76, 'utility': 53341}
#  214: {'name': '40, 17', 'exp_sup': 618.04, 'utility': 186881}
#  215: {'name': '58, 74', 'exp_sup': 617.98, 'utility': 26237}
#  216: {'name': '36, 46', 'exp_sup': 617.5, 'utility': 26984}
#  217: {'name': '7, 46', 'exp_sup': 616.25, 'utility': 53348}
#  218: {'name': '66, 31', 'exp_sup': 615.35, 'utility': 92680}
#  219: {'name': '29, 74', 'exp_sup': 613.71, 'utility': 65434}
#  220: {'name': '34, 44', 'exp_sup': 613.63, 'utility': 94149}
#  221: {'name': '69', 'exp_sup': 612.53, 'utility': 53240}
#  222: {'name': '5, 42', 'exp_sup': 612.15, 'utility': 55630}
#  223: {'name': '52, 72', 'exp_sup': 611.88, 'utility': 154086}
#  224: {'name': '25, 42', 'exp_sup': 611.6, 'utility': 26177}
#  225: {'name': '36, 31', 'exp_sup': 611.47, 'utility': 53422}
#  226: {'name': '7, 31', 'exp_sup': 609.45, 'utility': 80313}
#  227: {'name': '66, 44', 'exp_sup': 609.19, 'utility': 66997}
#  228: {'name': '66, 46', 'exp_sup': 608.12, 'utility': 66721}
#  229: {'name': '60, 17', 'exp_sup': 606.34, 'utility': 93374}
#  230: {'name': '9, 42', 'exp_sup': 605.77, 'utility': 40290}
#  231: {'name': '56, 46', 'exp_sup': 604.82, 'utility': 66085}
#  232: {'name': '3, 42', 'exp_sup': 604.76, 'utility': 65633}
#  233: {'name': '25, 44', 'exp_sup': 604.42, 'utility': 25613}
#  234: {'name': '71', 'exp_sup': 603.72, 'utility': 25236}
#  235: {'name': '51', 'exp_sup': 603.41, 'utility': 13402}
#  236: {'name': '9, 44', 'exp_sup': 603.07, 'utility': 38704}
#  237: {'name': '20', 'exp_sup': 602.48, 'utility': 6792}
#  238: {'name': '62, 31', 'exp_sup': 602.29, 'utility': 52712}
#  239: {'name': '25, 64', 'exp_sup': 601.92, 'utility': 62889}
#  240: {'name': '5, 31', 'exp_sup': 601.28, 'utility': 77079}
#  241: {'name': '3, 64', 'exp_sup': 600.44, 'utility': 101888}
#  242: {'name': '56, 74', 'exp_sup': 599.4, 'utility': 64482}
#  243: {'name': '62, 74', 'exp_sup': 598.58, 'utility': 25672}
#  244: {'name': '7, 17', 'exp_sup': 598.52, 'utility': 78828}
#  245: {'name': '48, 46', 'exp_sup': 597.25, 'utility': 104640}
#  246: {'name': '34, 46', 'exp_sup': 596.46, 'utility': 92120}
#  247: {'name': '9, 64', 'exp_sup': 594.91, 'utility': 76712}
#  248: {'name': '34, 31', 'exp_sup': 593.91, 'utility': 117591}
#  249: {'name': '56, 17', 'exp_sup': 593.84, 'utility': 90871}
#  250: {'name': '62, 17', 'exp_sup': 593.59, 'utility': 51403}
#  251: {'name': '36, 74', 'exp_sup': 593.11, 'utility': 25246}
#  252: {'name': '56, 31', 'exp_sup': 593.05, 'utility': 91111}
#  253: {'name': '16', 'exp_sup': 592.57, 'utility': 18978}
#  254: {'name': '7, 74', 'exp_sup': 590.57, 'utility': 50739}
#  255: {'name': '60, 74', 'exp_sup': 590.1, 'utility': 64078}
#  256: {'name': '48, 17', 'exp_sup': 589.75, 'utility': 127394}
#  257: {'name': '60, 72', 'exp_sup': 589.49, 'utility': 129080}
#  258: {'name': '5, 46', 'exp_sup': 588.84, 'utility': 51865}
#  259: {'name': '48, 74', 'exp_sup': 588.19, 'utility': 96589}
#  260: {'name': '58, 72', 'exp_sup': 587.43, 'utility': 90250}
#  261: {'name': '48, 31', 'exp_sup': 587.31, 'utility': 128218}
#  262: {'name': '66, 17', 'exp_sup': 586.04, 'utility': 89435}
#  263: {'name': '29, 72', 'exp_sup': 585.77, 'utility': 128596}
#  264: {'name': '34, 74', 'exp_sup': 584.6, 'utility': 86946}
#  265: {'name': '3, 31', 'exp_sup': 584.39, 'utility': 89594}
#  266: {'name': '36, 17', 'exp_sup': 584.25, 'utility': 52175}
#  267: {'name': '34, 17', 'exp_sup': 583.64, 'utility': 115869}
#  268: {'name': '66, 72', 'exp_sup': 583.0, 'utility': 128876}
#  269: {'name': '40, 72', 'exp_sup': 582.56, 'utility': 214715}
#  270: {'name': '25, 46', 'exp_sup': 582.0, 'utility': 24911}
#  271: {'name': '42, 31', 'exp_sup': 576.46, 'utility': 49457}
#  272: {'name': '9, 31', 'exp_sup': 576.09, 'utility': 62063}
#  273: {'name': '9, 74', 'exp_sup': 573.91, 'utility': 36189}
#  274: {'name': '9, 17', 'exp_sup': 573.65, 'utility': 62169}
#  275: {'name': '9, 46', 'exp_sup': 572.93, 'utility': 37634}
#  276: {'name': '42, 44', 'exp_sup': 572.47, 'utility': 24538}
#  277: {'name': '3, 44', 'exp_sup': 572.11, 'utility': 60943}
#  278: {'name': '66, 74', 'exp_sup': 571.5, 'utility': 60991}
#  279: {'name': '64, 44', 'exp_sup': 571.09, 'utility': 59379}
#  280: {'name': '62, 72', 'exp_sup': 568.8, 'utility': 86521}
#  281: {'name': '7, 72', 'exp_sup': 567.94, 'utility': 111501}
#  282: {'name': '36, 72', 'exp_sup': 567.77, 'utility': 86942}
#  283: {'name': '25, 31', 'exp_sup': 566.32, 'utility': 48756}
#  284: {'name': '29, 21', 'exp_sup': 565.61, 'utility': 60591}
#  285: {'name': '52, 21', 'exp_sup': 565.54, 'utility': 84050}
#  286: {'name': '5, 74', 'exp_sup': 563.51, 'utility': 48294}
#  287: {'name': '3, 17', 'exp_sup': 562.07, 'utility': 85238}
#  288: {'name': '3, 46', 'exp_sup': 561.56, 'utility': 61011}
#  289: {'name': '25, 74', 'exp_sup': 561.49, 'utility': 23488}
#  290: {'name': '5, 17', 'exp_sup': 561.22, 'utility': 73545}
#  291: {'name': '34, 72', 'exp_sup': 560.36, 'utility': 148908}
#  292: {'name': '52, 38', 'exp_sup': 559.97, 'utility': 83539}
#  293: {'name': '25, 17', 'exp_sup': 559.2, 'utility': 47079}
#  294: {'name': '29, 54', 'exp_sup': 559.15, 'utility': 60167}
#  295: {'name': '58, 38', 'exp_sup': 559.14, 'utility': 24011}
#  296: {'name': '48, 72', 'exp_sup': 558.53, 'utility': 158007}
#  297: {'name': '52, 54', 'exp_sup': 556.59, 'utility': 83439}
#  298: {'name': '58, 21', 'exp_sup': 556.21, 'utility': 24285}
#  299: {'name': '42, 46', 'exp_sup': 556.1, 'utility': 24096}
#  300: {'name': '64, 31', 'exp_sup': 555.28, 'utility': 83623}

# %%
# chạy với chess
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_chess.txt, ./data/chess_utility.txt", 0.001, 500)
algorithm.print_stats("./out/TUHUFP/chess/output_chess_top_500.txt")
# Out:
# Reading data . . .
# Minimum utility set to: 2156
# {'database util: ': 2156659}
# Top 500 CUPs:
#  1: {'name': '52', 'exp_sup': 1616.54, 'utility': 104178}
#  2: {'name': '29', 'exp_sup': 1598.92, 'utility': 70088}
#  3: {'name': '58', 'exp_sup': 1595.58, 'utility': 17462}
#  4: {'name': '40', 'exp_sup': 1579.27, 'utility': 188760}
#  5: {'name': '60', 'exp_sup': 1565.64, 'utility': 68908}
#  6: {'name': '62', 'exp_sup': 1537.33, 'utility': 16784}
#  7: {'name': '7', 'exp_sup': 1535.24, 'utility': 50790}
#  8: {'name': '36', 'exp_sup': 1530.49, 'utility': 16934}
#  9: {'name': '56', 'exp_sup': 1513.93, 'utility': 66780}
#  10: {'name': '48', 'exp_sup': 1500.86, 'utility': 115367}
#  11: {'name': '66', 'exp_sup': 1498.92, 'utility': 66644}
#  12: {'name': '34', 'exp_sup': 1493.64, 'utility': 99330}
#  13: {'name': '5', 'exp_sup': 1466.73, 'utility': 48369}
#  14: {'name': '9', 'exp_sup': 1446.46, 'utility': 31818}
#  15: {'name': '25', 'exp_sup': 1445.46, 'utility': 15465}
#  16: {'name': '3', 'exp_sup': 1407.44, 'utility': 61608}
#  17: {'name': '42', 'exp_sup': 1355.91, 'utility': 14849}
#  18: {'name': '64', 'exp_sup': 1337.59, 'utility': 56768}
#  19: {'name': '44', 'exp_sup': 1325.93, 'utility': 14261}
#  20: {'name': '46', 'exp_sup': 1284.58, 'utility': 14045}
#  21: {'name': '31', 'exp_sup': 1274.29, 'utility': 41649}
#  22: {'name': '17', 'exp_sup': 1251.12, 'utility': 40662}
#  23: {'name': '74', 'exp_sup': 1237.31, 'utility': 13298}
#  24: {'name': '72', 'exp_sup': 1177.8, 'utility': 77802}
#  25: {'name': '21', 'exp_sup': 1128.59, 'utility': 12263}
#  26: {'name': '54', 'exp_sup': 1105.31, 'utility': 11965}
#  27: {'name': '38', 'exp_sup': 1101.41, 'utility': 12130}
#  28: {'name': '27', 'exp_sup': 1098.98, 'utility': 24398}
#  29: {'name': '11', 'exp_sup': 1066.24, 'utility': 58730}
#  30: {'name': '15', 'exp_sup': 1008.29, 'utility': 32700}
#  31: {'name': '70', 'exp_sup': 1005.64, 'utility': 21824}
#  32: {'name': '68', 'exp_sup': 1003.26, 'utility': 75341}
#  33: {'name': '50', 'exp_sup': 965.12, 'utility': 54140}
#  34: {'name': '19', 'exp_sup': 958.74, 'utility': 32565}
#  35: {'name': '23', 'exp_sup': 919.58, 'utility': 48960}
#  36: {'name': '13', 'exp_sup': 860.84, 'utility': 9269}
#  37: {'name': '1', 'exp_sup': 832.29, 'utility': 65471}
#  38: {'name': '52, 58', 'exp_sup': 806.57, 'utility': 121139}
#  39: {'name': '52, 29', 'exp_sup': 802.29, 'utility': 172766}
#  40: {'name': '52, 40', 'exp_sup': 800.33, 'utility': 290726}
#  41: {'name': '52, 60', 'exp_sup': 797.15, 'utility': 170582}
#  42: {'name': '29, 58', 'exp_sup': 794.58, 'utility': 87031}
#  43: {'name': '29, 40', 'exp_sup': 792.51, 'utility': 255631}
#  44: {'name': '58, 40', 'exp_sup': 790.04, 'utility': 205017}
#  45: {'name': '58, 60', 'exp_sup': 784.78, 'utility': 85721}
#  46: {'name': '52, 62', 'exp_sup': 781.35, 'utility': 115661}
#  47: {'name': '29, 60', 'exp_sup': 777.6, 'utility': 136920}
#  48: {'name': '52, 56', 'exp_sup': 776.21, 'utility': 164720}
#  49: {'name': '52, 7', 'exp_sup': 774.06, 'utility': 150447}
#  50: {'name': '40, 60', 'exp_sup': 773.52, 'utility': 253428}
#  51: {'name': '29, 62', 'exp_sup': 772.37, 'utility': 83526}
#  52: {'name': '58, 62', 'exp_sup': 769.84, 'utility': 33329}
#  53: {'name': '58, 36', 'exp_sup': 767.98, 'utility': 33744}
#  54: {'name': '29, 7', 'exp_sup': 767.86, 'utility': 117944}
#  55: {'name': '29, 36', 'exp_sup': 765.95, 'utility': 84385}
#  56: {'name': '58, 7', 'exp_sup': 765.83, 'utility': 67239}
#  57: {'name': '52, 36', 'exp_sup': 764.38, 'utility': 117430}
#  58: {'name': '40, 62', 'exp_sup': 764.28, 'utility': 197416}
#  59: {'name': '60, 62', 'exp_sup': 762.34, 'utility': 82302}
#  60: {'name': '52, 48', 'exp_sup': 761.78, 'utility': 212460}
#  61: {'name': '40, 36', 'exp_sup': 761.32, 'utility': 198648}
#  62: {'name': '58, 56', 'exp_sup': 759.72, 'utility': 82803}
#  63: {'name': '52, 66', 'exp_sup': 759.17, 'utility': 164458}
#  64: {'name': '40, 7', 'exp_sup': 758.2, 'utility': 231271}
#  65: {'name': '2', 'exp_sup': 757.95, 'utility': 24618}
#  66: {'name': '29, 56', 'exp_sup': 757.1, 'utility': 132152}
#  67: {'name': '14', 'exp_sup': 755.4, 'utility': 8252}
#  68: {'name': '58, 48', 'exp_sup': 753.39, 'utility': 131386}
#  69: {'name': '60, 7', 'exp_sup': 752.4, 'utility': 115497}
#  70: {'name': '52, 34', 'exp_sup': 750.57, 'utility': 197472}
#  71: {'name': '60, 36', 'exp_sup': 750.51, 'utility': 83055}
#  72: {'name': '60, 66', 'exp_sup': 748.87, 'utility': 132064}
#  73: {'name': '29, 34', 'exp_sup': 748.84, 'utility': 165212}
#  74: {'name': '29, 66', 'exp_sup': 748.18, 'utility': 132172}
#  75: {'name': '58, 66', 'exp_sup': 747.26, 'utility': 82834}
#  76: {'name': '40, 56', 'exp_sup': 746.88, 'utility': 243050}
#  77: {'name': '52, 5', 'exp_sup': 745.02, 'utility': 144276}
#  78: {'name': '29, 48', 'exp_sup': 744.94, 'utility': 179722}
#  79: {'name': '40, 48', 'exp_sup': 741.87, 'utility': 290391}
#  80: {'name': '60, 48', 'exp_sup': 741.31, 'utility': 178947}
#  81: {'name': '29, 5', 'exp_sup': 739.46, 'utility': 112623}
#  82: {'name': '60, 56', 'exp_sup': 739.43, 'utility': 130088}
#  83: {'name': '40, 34', 'exp_sup': 737.74, 'utility': 277239}
#  84: {'name': '7, 36', 'exp_sup': 736.85, 'utility': 65158}
#  85: {'name': '58, 5', 'exp_sup': 736.2, 'utility': 64234}
#  86: {'name': '62, 36', 'exp_sup': 735.64, 'utility': 32252}
#  87: {'name': '40, 66', 'exp_sup': 734.99, 'utility': 243649}
#  88: {'name': '58, 34', 'exp_sup': 734.32, 'utility': 115440}
#  89: {'name': '29, 25', 'exp_sup': 733.79, 'utility': 77685}
#  90: {'name': '60, 34', 'exp_sup': 732.14, 'utility': 162688}
#  91: {'name': '7, 34', 'exp_sup': 731.86, 'utility': 143691}
#  92: {'name': '52, 25', 'exp_sup': 731.26, 'utility': 107984}
#  93: {'name': '62, 7', 'exp_sup': 731.07, 'utility': 64443}
#  94: {'name': '62, 56', 'exp_sup': 730.52, 'utility': 79966}
#  95: {'name': '36, 48', 'exp_sup': 729.26, 'utility': 129898}
#  96: {'name': '52, 9', 'exp_sup': 728.24, 'utility': 124558}
#  97: {'name': '36, 56', 'exp_sup': 727.83, 'utility': 80092}
#  98: {'name': '7, 66', 'exp_sup': 727.27, 'utility': 111671}
#  99: {'name': '60, 5', 'exp_sup': 725.51, 'utility': 110905}
#  100: {'name': '62, 66', 'exp_sup': 725.14, 'utility': 79147}
#  101: {'name': '7, 56', 'exp_sup': 721.02, 'utility': 112322}
#  102: {'name': '58, 9', 'exp_sup': 720.18, 'utility': 47296}
#  103: {'name': '29, 9', 'exp_sup': 720.07, 'utility': 94064}
#  104: {'name': '7, 48', 'exp_sup': 719.89, 'utility': 158110}
#  105: {'name': '52, 3', 'exp_sup': 718.73, 'utility': 153244}
#  106: {'name': '40, 5', 'exp_sup': 718.05, 'utility': 223282}
#  107: {'name': '36, 34', 'exp_sup': 716.91, 'utility': 111964}
#  108: {'name': '58, 25', 'exp_sup': 716.42, 'utility': 30961}
#  109: {'name': '60, 25', 'exp_sup': 715.42, 'utility': 77075}
#  110: {'name': '62, 48', 'exp_sup': 715.39, 'utility': 125379}
#  111: {'name': '62, 34', 'exp_sup': 714.96, 'utility': 110832}
#  112: {'name': '7, 5', 'exp_sup': 713.08, 'utility': 93495}
#  113: {'name': '40, 25', 'exp_sup': 712.24, 'utility': 183618}
#  114: {'name': '36, 66', 'exp_sup': 709.93, 'utility': 80135}
#  115: {'name': '56, 66', 'exp_sup': 708.94, 'utility': 125068}
#  116: {'name': '62, 5', 'exp_sup': 708.88, 'utility': 61882}
#  117: {'name': '29, 3', 'exp_sup': 708.45, 'utility': 123288}
#  118: {'name': '36, 5', 'exp_sup': 707.41, 'utility': 62205}
#  119: {'name': '48, 66', 'exp_sup': 706.37, 'utility': 172697}
#  120: {'name': '58, 3', 'exp_sup': 706.12, 'utility': 76772}
#  121: {'name': '40, 9', 'exp_sup': 704.32, 'utility': 200832}
#  122: {'name': '56, 34', 'exp_sup': 703.99, 'utility': 156636}
#  123: {'name': '66, 5', 'exp_sup': 703.33, 'utility': 108091}
#  124: {'name': '60, 9', 'exp_sup': 702.33, 'utility': 92804}
#  125: {'name': '56, 48', 'exp_sup': 700.91, 'utility': 169695}
#  126: {'name': '66, 34', 'exp_sup': 699.99, 'utility': 157508}
#  127: {'name': '36, 25', 'exp_sup': 699.95, 'utility': 30388}
#  128: {'name': '48, 34', 'exp_sup': 699.74, 'utility': 201383}
#  129: {'name': '62, 25', 'exp_sup': 697.0, 'utility': 29738}
#  130: {'name': '34, 5', 'exp_sup': 695.45, 'utility': 140856}
#  131: {'name': '40, 3', 'exp_sup': 693.84, 'utility': 226522}
#  132: {'name': '62, 9', 'exp_sup': 692.12, 'utility': 45217}
#  133: {'name': '48, 25', 'exp_sup': 690.07, 'utility': 119915}
#  134: {'name': '7, 25', 'exp_sup': 689.09, 'utility': 59938}
#  135: {'name': '56, 5', 'exp_sup': 689.09, 'utility': 106663}
#  136: {'name': '60, 3', 'exp_sup': 688.27, 'utility': 121992}
#  137: {'name': '56, 9', 'exp_sup': 688.26, 'utility': 91078}
#  138: {'name': '52, 42', 'exp_sup': 688.23, 'utility': 102622}
#  139: {'name': '7, 9', 'exp_sup': 687.7, 'utility': 75723}
#  140: {'name': '48, 5', 'exp_sup': 684.69, 'utility': 151382}
#  141: {'name': '52, 64', 'exp_sup': 684.06, 'utility': 141962}
#  142: {'name': '36, 9', 'exp_sup': 683.24, 'utility': 45683}
#  143: {'name': '58, 42', 'exp_sup': 682.92, 'utility': 29567}
#  144: {'name': '56, 25', 'exp_sup': 682.7, 'utility': 73534}
#  145: {'name': '34, 9', 'exp_sup': 682.1, 'utility': 119678}
#  146: {'name': '48, 9', 'exp_sup': 681.86, 'utility': 131587}
#  147: {'name': '66, 25', 'exp_sup': 681.41, 'utility': 74411}
#  148: {'name': '29, 42', 'exp_sup': 680.22, 'utility': 73789}
#  149: {'name': '36, 3', 'exp_sup': 679.53, 'utility': 74325}
#  150: {'name': '60, 42', 'exp_sup': 676.51, 'utility': 73376}
#  151: {'name': '7, 3', 'exp_sup': 676.28, 'utility': 105239}
#  152: {'name': '34, 25', 'exp_sup': 676.03, 'utility': 103024}
#  153: {'name': '62, 3', 'exp_sup': 675.43, 'utility': 73985}
#  154: {'name': '56, 3', 'exp_sup': 674.81, 'utility': 118028}
#  155: {'name': '24', 'exp_sup': 673.83, 'utility': 14996}
#  156: {'name': '40, 64', 'exp_sup': 671.11, 'utility': 212460}
#  157: {'name': '40, 42', 'exp_sup': 670.8, 'utility': 174811}
#  158: {'name': '66, 9', 'exp_sup': 670.36, 'utility': 89714}
#  159: {'name': '52, 44', 'exp_sup': 667.7, 'utility': 98857}
#  160: {'name': '5, 9', 'exp_sup': 665.83, 'utility': 72391}
#  161: {'name': '66, 3', 'exp_sup': 662.17, 'utility': 117072}
#  162: {'name': '29, 64', 'exp_sup': 661.85, 'utility': 113308}
#  163: {'name': '29, 44', 'exp_sup': 660.91, 'utility': 70749}
#  164: {'name': '34, 3', 'exp_sup': 660.29, 'utility': 146622}
#  165: {'name': '5, 3', 'exp_sup': 659.41, 'utility': 99860}
#  166: {'name': '60, 64', 'exp_sup': 659.26, 'utility': 112012}
#  167: {'name': '58, 44', 'exp_sup': 658.05, 'utility': 28302}
#  168: {'name': '58, 64', 'exp_sup': 657.97, 'utility': 70620}
#  169: {'name': '5, 25', 'exp_sup': 656.29, 'utility': 57086}
#  170: {'name': '48, 3', 'exp_sup': 653.87, 'utility': 160071}
#  171: {'name': '60, 44', 'exp_sup': 652.46, 'utility': 69435}
#  172: {'name': '40, 44', 'exp_sup': 652.34, 'utility': 167125}
#  173: {'name': '66, 42', 'exp_sup': 652.23, 'utility': 71539}
#  174: {'name': '52, 46', 'exp_sup': 650.66, 'utility': 96676}
#  175: {'name': '48, 42', 'exp_sup': 650.48, 'utility': 111887}
#  176: {'name': '62, 42', 'exp_sup': 650.04, 'utility': 28297}
#  177: {'name': '36, 42', 'exp_sup': 649.16, 'utility': 28659}
#  178: {'name': '7, 42', 'exp_sup': 648.95, 'utility': 56926}
#  179: {'name': '9, 25', 'exp_sup': 647.8, 'utility': 41598}
#  180: {'name': '56, 42', 'exp_sup': 643.85, 'utility': 70665}
#  181: {'name': '62, 44', 'exp_sup': 643.15, 'utility': 27376}
#  182: {'name': '29, 46', 'exp_sup': 642.56, 'utility': 69514}
#  183: {'name': '62, 64', 'exp_sup': 641.93, 'utility': 68111}
#  184: {'name': '52, 31', 'exp_sup': 641.53, 'utility': 123555}
#  185: {'name': '36, 64', 'exp_sup': 641.43, 'utility': 68775}
#  186: {'name': '9, 3', 'exp_sup': 640.82, 'utility': 83696}
#  187: {'name': '34, 42', 'exp_sup': 639.83, 'utility': 99078}
#  188: {'name': '58, 46', 'exp_sup': 638.37, 'utility': 27774}
#  189: {'name': '48, 64', 'exp_sup': 636.88, 'utility': 148284}
#  190: {'name': '7, 44', 'exp_sup': 636.1, 'utility': 54652}
#  191: {'name': '36, 44', 'exp_sup': 636.1, 'utility': 27450}
#  192: {'name': '60, 31', 'exp_sup': 636.0, 'utility': 96146}
#  193: {'name': '29, 31', 'exp_sup': 635.75, 'utility': 95917}
#  194: {'name': '7, 64', 'exp_sup': 635.34, 'utility': 95825}
#  195: {'name': '56, 64', 'exp_sup': 634.6, 'utility': 108348}
#  196: {'name': '40, 46', 'exp_sup': 631.52, 'utility': 163761}
#  197: {'name': '5, 64', 'exp_sup': 630.61, 'utility': 93701}
#  198: {'name': '60, 46', 'exp_sup': 630.42, 'utility': 68407}
#  199: {'name': '58, 31', 'exp_sup': 630.18, 'utility': 55149}
#  200: {'name': '40, 31', 'exp_sup': 630.06, 'utility': 190050}
#  201: {'name': '66, 64', 'exp_sup': 630.04, 'utility': 108260}
#  202: {'name': '52, 17', 'exp_sup': 629.95, 'utility': 120894}
#  203: {'name': '29, 17', 'exp_sup': 628.98, 'utility': 94380}
#  204: {'name': '56, 44', 'exp_sup': 628.92, 'utility': 67713}
#  205: {'name': '48, 44', 'exp_sup': 628.53, 'utility': 106483}
#  206: {'name': '42, 64', 'exp_sup': 628.12, 'utility': 66152}
#  207: {'name': '34, 64', 'exp_sup': 628.05, 'utility': 136476}
#  208: {'name': '52, 74', 'exp_sup': 624.53, 'utility': 91129}
#  209: {'name': '25, 3', 'exp_sup': 623.94, 'utility': 67954}
#  210: {'name': '58, 17', 'exp_sup': 622.77, 'utility': 54101}
#  211: {'name': '40, 74', 'exp_sup': 621.61, 'utility': 155667}
#  212: {'name': '62, 46', 'exp_sup': 621.29, 'utility': 26646}
#  213: {'name': '5, 44', 'exp_sup': 620.76, 'utility': 53341}
#  214: {'name': '40, 17', 'exp_sup': 618.04, 'utility': 186881}
#  215: {'name': '58, 74', 'exp_sup': 617.98, 'utility': 26237}
#  216: {'name': '36, 46', 'exp_sup': 617.5, 'utility': 26984}
#  217: {'name': '7, 46', 'exp_sup': 616.25, 'utility': 53348}
#  218: {'name': '66, 31', 'exp_sup': 615.35, 'utility': 92680}
#  219: {'name': '29, 74', 'exp_sup': 613.71, 'utility': 65434}
#  220: {'name': '34, 44', 'exp_sup': 613.63, 'utility': 94149}
#  221: {'name': '69', 'exp_sup': 612.53, 'utility': 53240}
#  222: {'name': '5, 42', 'exp_sup': 612.15, 'utility': 55630}
#  223: {'name': '52, 72', 'exp_sup': 611.88, 'utility': 154086}
#  224: {'name': '25, 42', 'exp_sup': 611.6, 'utility': 26177}
#  225: {'name': '36, 31', 'exp_sup': 611.47, 'utility': 53422}
#  226: {'name': '7, 31', 'exp_sup': 609.45, 'utility': 80313}
#  227: {'name': '66, 44', 'exp_sup': 609.19, 'utility': 66997}
#  228: {'name': '66, 46', 'exp_sup': 608.12, 'utility': 66721}
#  229: {'name': '60, 17', 'exp_sup': 606.34, 'utility': 93374}
#  230: {'name': '9, 42', 'exp_sup': 605.77, 'utility': 40290}
#  231: {'name': '56, 46', 'exp_sup': 604.82, 'utility': 66085}
#  232: {'name': '3, 42', 'exp_sup': 604.76, 'utility': 65633}
#  233: {'name': '25, 44', 'exp_sup': 604.42, 'utility': 25613}
#  234: {'name': '71', 'exp_sup': 603.72, 'utility': 25236}
#  235: {'name': '51', 'exp_sup': 603.41, 'utility': 13402}
#  236: {'name': '9, 44', 'exp_sup': 603.07, 'utility': 38704}
#  237: {'name': '20', 'exp_sup': 602.48, 'utility': 6792}
#  238: {'name': '62, 31', 'exp_sup': 602.29, 'utility': 52712}
#  239: {'name': '25, 64', 'exp_sup': 601.92, 'utility': 62889}
#  240: {'name': '5, 31', 'exp_sup': 601.28, 'utility': 77079}
#  241: {'name': '3, 64', 'exp_sup': 600.44, 'utility': 101888}
#  242: {'name': '56, 74', 'exp_sup': 599.4, 'utility': 64482}
#  243: {'name': '62, 74', 'exp_sup': 598.58, 'utility': 25672}
#  244: {'name': '7, 17', 'exp_sup': 598.52, 'utility': 78828}
#  245: {'name': '48, 46', 'exp_sup': 597.25, 'utility': 104640}
#  246: {'name': '34, 46', 'exp_sup': 596.46, 'utility': 92120}
#  247: {'name': '9, 64', 'exp_sup': 594.91, 'utility': 76712}
#  248: {'name': '34, 31', 'exp_sup': 593.91, 'utility': 117591}
#  249: {'name': '56, 17', 'exp_sup': 593.84, 'utility': 90871}
#  250: {'name': '62, 17', 'exp_sup': 593.59, 'utility': 51403}
#  251: {'name': '36, 74', 'exp_sup': 593.11, 'utility': 25246}
#  252: {'name': '56, 31', 'exp_sup': 593.05, 'utility': 91111}
#  253: {'name': '16', 'exp_sup': 592.57, 'utility': 18978}
#  254: {'name': '7, 74', 'exp_sup': 590.57, 'utility': 50739}
#  255: {'name': '60, 74', 'exp_sup': 590.1, 'utility': 64078}
#  256: {'name': '48, 17', 'exp_sup': 589.75, 'utility': 127394}
#  257: {'name': '60, 72', 'exp_sup': 589.49, 'utility': 129080}
#  258: {'name': '5, 46', 'exp_sup': 588.84, 'utility': 51865}
#  259: {'name': '48, 74', 'exp_sup': 588.19, 'utility': 96589}
#  260: {'name': '58, 72', 'exp_sup': 587.43, 'utility': 90250}
#  261: {'name': '48, 31', 'exp_sup': 587.31, 'utility': 128218}
#  262: {'name': '66, 17', 'exp_sup': 586.04, 'utility': 89435}
#  263: {'name': '29, 72', 'exp_sup': 585.77, 'utility': 128596}
#  264: {'name': '34, 74', 'exp_sup': 584.6, 'utility': 86946}
#  265: {'name': '3, 31', 'exp_sup': 584.39, 'utility': 89594}
#  266: {'name': '36, 17', 'exp_sup': 584.25, 'utility': 52175}
#  267: {'name': '34, 17', 'exp_sup': 583.64, 'utility': 115869}
#  268: {'name': '66, 72', 'exp_sup': 583.0, 'utility': 128876}
#  269: {'name': '40, 72', 'exp_sup': 582.56, 'utility': 214715}
#  270: {'name': '25, 46', 'exp_sup': 582.0, 'utility': 24911}
#  271: {'name': '42, 31', 'exp_sup': 576.46, 'utility': 49457}
#  272: {'name': '9, 31', 'exp_sup': 576.09, 'utility': 62063}
#  273: {'name': '9, 74', 'exp_sup': 573.91, 'utility': 36189}
#  274: {'name': '9, 17', 'exp_sup': 573.65, 'utility': 62169}
#  275: {'name': '9, 46', 'exp_sup': 572.93, 'utility': 37634}
#  276: {'name': '42, 44', 'exp_sup': 572.47, 'utility': 24538}
#  277: {'name': '3, 44', 'exp_sup': 572.11, 'utility': 60943}
#  278: {'name': '66, 74', 'exp_sup': 571.5, 'utility': 60991}
#  279: {'name': '64, 44', 'exp_sup': 571.09, 'utility': 59379}
#  280: {'name': '62, 72', 'exp_sup': 568.8, 'utility': 86521}
#  281: {'name': '7, 72', 'exp_sup': 567.94, 'utility': 111501}
#  282: {'name': '36, 72', 'exp_sup': 567.77, 'utility': 86942}
#  283: {'name': '25, 31', 'exp_sup': 566.32, 'utility': 48756}
#  284: {'name': '29, 21', 'exp_sup': 565.61, 'utility': 60591}
#  285: {'name': '52, 21', 'exp_sup': 565.54, 'utility': 84050}
#  286: {'name': '5, 74', 'exp_sup': 563.51, 'utility': 48294}
#  287: {'name': '3, 17', 'exp_sup': 562.07, 'utility': 85238}
#  288: {'name': '3, 46', 'exp_sup': 561.56, 'utility': 61011}
#  289: {'name': '25, 74', 'exp_sup': 561.49, 'utility': 23488}
#  290: {'name': '5, 17', 'exp_sup': 561.22, 'utility': 73545}
#  291: {'name': '34, 72', 'exp_sup': 560.36, 'utility': 148908}
#  292: {'name': '52, 38', 'exp_sup': 559.97, 'utility': 83539}
#  293: {'name': '25, 17', 'exp_sup': 559.2, 'utility': 47079}
#  294: {'name': '29, 54', 'exp_sup': 559.15, 'utility': 60167}
#  295: {'name': '58, 38', 'exp_sup': 559.14, 'utility': 24011}
#  296: {'name': '48, 72', 'exp_sup': 558.53, 'utility': 158007}
#  297: {'name': '52, 54', 'exp_sup': 556.59, 'utility': 83439}
#  298: {'name': '58, 21', 'exp_sup': 556.21, 'utility': 24285}
#  299: {'name': '42, 46', 'exp_sup': 556.1, 'utility': 24096}
#  300: {'name': '64, 31', 'exp_sup': 555.28, 'utility': 83623}
#  301: {'name': '58, 54', 'exp_sup': 554.91, 'utility': 23977}
#  302: {'name': '29, 27', 'exp_sup': 554.89, 'utility': 72626}
#  303: {'name': '40, 21', 'exp_sup': 553.74, 'utility': 142736}
#  304: {'name': '29, 38', 'exp_sup': 552.56, 'utility': 59510}
#  305: {'name': '5, 72', 'exp_sup': 552.47, 'utility': 108591}
#  306: {'name': '58, 27', 'exp_sup': 551.33, 'utility': 36318}
#  307: {'name': '56, 72', 'exp_sup': 547.29, 'utility': 121376}
#  308: {'name': '60, 21', 'exp_sup': 546.88, 'utility': 59235}
#  309: {'name': '52, 27', 'exp_sup': 546.14, 'utility': 95334}
#  310: {'name': '40, 54', 'exp_sup': 545.72, 'utility': 143216}
#  311: {'name': '42, 72', 'exp_sup': 544.27, 'utility': 84056}
#  312: {'name': '44, 46', 'exp_sup': 544.2, 'utility': 22992}
#  313: {'name': '62, 38', 'exp_sup': 543.85, 'utility': 23601}
#  314: {'name': '7, 21', 'exp_sup': 543.82, 'utility': 47229}
#  315: {'name': '60, 38', 'exp_sup': 543.48, 'utility': 58592}
#  316: {'name': '64, 46', 'exp_sup': 542.52, 'utility': 57437}
#  317: {'name': '3, 72', 'exp_sup': 542.39, 'utility': 119164}
#  318: {'name': '12', 'exp_sup': 541.74, 'utility': 11854}
#  319: {'name': '64, 72', 'exp_sup': 540.83, 'utility': 116362}
#  320: {'name': '60, 54', 'exp_sup': 540.7, 'utility': 58256}
#  321: {'name': '40, 38', 'exp_sup': 540.48, 'utility': 143849}
#  322: {'name': '36, 21', 'exp_sup': 540.41, 'utility': 23785}
#  323: {'name': '52, 11', 'exp_sup': 539.09, 'utility': 127387}
#  324: {'name': '25, 72', 'exp_sup': 538.97, 'utility': 80836}
#  325: {'name': '40, 27', 'exp_sup': 537.21, 'utility': 152164}
#  326: {'name': '56, 54', 'exp_sup': 536.79, 'utility': 58402}
#  327: {'name': '7, 54', 'exp_sup': 535.72, 'utility': 46077}
#  328: {'name': '29, 11', 'exp_sup': 535.32, 'utility': 103978}
#  329: {'name': '62, 54', 'exp_sup': 534.73, 'utility': 23131}
#  330: {'name': '56, 38', 'exp_sup': 534.47, 'utility': 57305}
#  331: {'name': '42, 17', 'exp_sup': 533.76, 'utility': 45714}
#  332: {'name': '5, 21', 'exp_sup': 532.86, 'utility': 45086}
#  333: {'name': '58, 11', 'exp_sup': 532.83, 'utility': 70332}
#  334: {'name': '34, 21', 'exp_sup': 531.2, 'utility': 79670}
#  335: {'name': '7, 38', 'exp_sup': 530.68, 'utility': 46576}
#  336: {'name': '44, 31', 'exp_sup': 530.68, 'utility': 45378}
#  337: {'name': '36, 54', 'exp_sup': 530.65, 'utility': 23075}
#  338: {'name': '60, 27', 'exp_sup': 529.61, 'utility': 71510}
#  339: {'name': '62, 27', 'exp_sup': 527.13, 'utility': 34383}
#  340: {'name': '36, 27', 'exp_sup': 526.74, 'utility': 35491}
#  341: {'name': '48, 21', 'exp_sup': 526.71, 'utility': 92215}
#  342: {'name': '44, 74', 'exp_sup': 526.0, 'utility': 22045}
#  343: {'name': '7, 27', 'exp_sup': 525.99, 'utility': 58671}
#  344: {'name': '48, 27', 'exp_sup': 525.01, 'utility': 104130}
#  345: {'name': '40, 11', 'exp_sup': 524.87, 'utility': 182648}
#  346: {'name': '62, 21', 'exp_sup': 524.33, 'utility': 22863}
#  347: {'name': '66, 21', 'exp_sup': 524.23, 'utility': 56837}
#  348: {'name': '34, 54', 'exp_sup': 523.85, 'utility': 79939}
#  349: {'name': '36, 38', 'exp_sup': 522.95, 'utility': 23006}
#  350: {'name': '56, 21', 'exp_sup': 522.39, 'utility': 57808}
#  351: {'name': '3, 74', 'exp_sup': 521.62, 'utility': 55406}
#  352: {'name': '66, 38', 'exp_sup': 521.11, 'utility': 57237}
#  353: {'name': '5, 38', 'exp_sup': 520.61, 'utility': 46561}
#  354: {'name': '9, 72', 'exp_sup': 519.88, 'utility': 91332}
#  355: {'name': '34, 27', 'exp_sup': 518.28, 'utility': 89930}
#  356: {'name': '56, 27', 'exp_sup': 518.07, 'utility': 68662}
#  357: {'name': '48, 54', 'exp_sup': 517.36, 'utility': 89313}
#  358: {'name': '25, 21', 'exp_sup': 517.29, 'utility': 21605}
#  359: {'name': '46, 31', 'exp_sup': 516.22, 'utility': 44386}
#  360: {'name': '34, 38', 'exp_sup': 516.15, 'utility': 80999}
#  361: {'name': '7, 11', 'exp_sup': 515.72, 'utility': 90027}
#  362: {'name': '52, 68', 'exp_sup': 515.51, 'utility': 139110}
#  363: {'name': '52, 15', 'exp_sup': 515.33, 'utility': 97941}
#  364: {'name': '56, 11', 'exp_sup': 514.71, 'utility': 101096}
#  365: {'name': '60, 11', 'exp_sup': 514.05, 'utility': 102938}
#  366: {'name': '66, 27', 'exp_sup': 513.51, 'utility': 68712}
#  367: {'name': '9, 54', 'exp_sup': 512.11, 'utility': 33130}
#  368: {'name': '39', 'exp_sup': 510.62, 'utility': 10976}
#  369: {'name': '58, 15', 'exp_sup': 509.46, 'utility': 43721}
#  370: {'name': '31, 72', 'exp_sup': 508.88, 'utility': 98595}
#  371: {'name': '9, 21', 'exp_sup': 508.43, 'utility': 32601}
#  372: {'name': '66, 54', 'exp_sup': 508.32, 'utility': 55935}
#  373: {'name': '52, 70', 'exp_sup': 506.32, 'utility': 86740}
#  374: {'name': '36, 11', 'exp_sup': 506.15, 'utility': 66822}
#  375: {'name': '74, 54', 'exp_sup': 506.03, 'utility': 21409}
#  376: {'name': '9, 27', 'exp_sup': 504.51, 'utility': 43648}
#  377: {'name': '5, 54', 'exp_sup': 504.22, 'utility': 44308}
#  378: {'name': '29, 15', 'exp_sup': 504.0, 'utility': 76601}
#  379: {'name': '62, 11', 'exp_sup': 503.39, 'utility': 66448}
#  380: {'name': '9, 38', 'exp_sup': 503.38, 'utility': 33115}
#  381: {'name': '58, 70', 'exp_sup': 503.26, 'utility': 32574}
#  382: {'name': '46, 17', 'exp_sup': 502.81, 'utility': 42540}
#  383: {'name': '29, 70', 'exp_sup': 502.66, 'utility': 65230}
#  384: {'name': '25, 54', 'exp_sup': 502.18, 'utility': 21425}
#  385: {'name': '60, 15', 'exp_sup': 501.5, 'utility': 76507}
#  386: {'name': '31, 17', 'exp_sup': 500.45, 'utility': 64563}
#  387: {'name': '34, 11', 'exp_sup': 500.43, 'utility': 120145}
#  388: {'name': '64, 17', 'exp_sup': 500.39, 'utility': 74383}
#  389: {'name': '58, 68', 'exp_sup': 499.89, 'utility': 85587}
#  390: {'name': '40, 70', 'exp_sup': 499.81, 'utility': 140900}
#  391: {'name': '48, 38', 'exp_sup': 498.91, 'utility': 88005}
#  392: {'name': '66, 11', 'exp_sup': 498.33, 'utility': 97861}
#  393: {'name': '44, 17', 'exp_sup': 498.18, 'utility': 42116}
#  394: {'name': '52, 50', 'exp_sup': 498.15, 'utility': 117882}
#  395: {'name': '28', 'exp_sup': 497.37, 'utility': 10432}
#  396: {'name': '60, 70', 'exp_sup': 497.35, 'utility': 63658}
#  397: {'name': '64, 74', 'exp_sup': 497.33, 'utility': 49938}
#  398: {'name': '62, 68', 'exp_sup': 496.9, 'utility': 83679}
#  399: {'name': '29, 68', 'exp_sup': 496.06, 'utility': 118037}
#  400: {'name': '40, 68', 'exp_sup': 495.91, 'utility': 190386}
#  401: {'name': '62, 70', 'exp_sup': 494.57, 'utility': 31849}
#  402: {'name': '9, 11', 'exp_sup': 494.42, 'utility': 75435}
#  403: {'name': '7, 70', 'exp_sup': 493.65, 'utility': 54067}
#  404: {'name': '42, 74', 'exp_sup': 493.55, 'utility': 21039}
#  405: {'name': '40, 15', 'exp_sup': 491.54, 'utility': 150509}
#  406: {'name': '25, 27', 'exp_sup': 491.3, 'utility': 32290}
#  407: {'name': '56, 68', 'exp_sup': 491.28, 'utility': 117696}
#  408: {'name': '7, 15', 'exp_sup': 490.97, 'utility': 64860}
#  409: {'name': '25, 38', 'exp_sup': 490.86, 'utility': 21298}
#  410: {'name': '52, 19', 'exp_sup': 488.3, 'utility': 95715}
#  411: {'name': '55', 'exp_sup': 488.08, 'utility': 10932}
#  412: {'name': '17, 15', 'exp_sup': 487.74, 'utility': 62502}
#  413: {'name': '62, 15', 'exp_sup': 486.53, 'utility': 41072}
#  414: {'name': '46, 74', 'exp_sup': 486.2, 'utility': 21118}
#  415: {'name': '22', 'exp_sup': 486.0, 'utility': 5224}
#  416: {'name': '58, 50', 'exp_sup': 485.96, 'utility': 64399}
#  417: {'name': '58, 19', 'exp_sup': 485.92, 'utility': 43126}
#  418: {'name': '34, 70', 'exp_sup': 485.91, 'utility': 86000}
#  419: {'name': '42, 38', 'exp_sup': 485.91, 'utility': 21144}
#  420: {'name': '64, 38', 'exp_sup': 485.09, 'utility': 51319}
#  421: {'name': '17, 19', 'exp_sup': 483.63, 'utility': 64071}
#  422: {'name': '3, 21', 'exp_sup': 483.38, 'utility': 52213}
#  423: {'name': '42, 21', 'exp_sup': 483.33, 'utility': 20825}
#  424: {'name': '36, 15', 'exp_sup': 482.97, 'utility': 41591}
#  425: {'name': '40, 50', 'exp_sup': 482.74, 'utility': 171658}
#  426: {'name': '60, 68', 'exp_sup': 482.72, 'utility': 115545}
#  427: {'name': '44, 38', 'exp_sup': 481.96, 'utility': 20975}
#  428: {'name': '9, 70', 'exp_sup': 481.9, 'utility': 41458}
#  429: {'name': '29, 19', 'exp_sup': 481.88, 'utility': 75214}
#  430: {'name': '44, 72', 'exp_sup': 481.8, 'utility': 72245}
#  431: {'name': '48, 11', 'exp_sup': 481.74, 'utility': 126971}
#  432: {'name': '62, 50', 'exp_sup': 481.19, 'utility': 62935}
#  433: {'name': '5, 11', 'exp_sup': 480.39, 'utility': 83830}
#  434: {'name': '3, 27', 'exp_sup': 479.88, 'utility': 63366}
#  435: {'name': '56, 70', 'exp_sup': 479.52, 'utility': 63252}
#  436: {'name': '36, 70', 'exp_sup': 478.81, 'utility': 31066}
#  437: {'name': '29, 50', 'exp_sup': 478.64, 'utility': 97116}
#  438: {'name': '46, 19', 'exp_sup': 478.26, 'utility': 43262}
#  439: {'name': '5, 27', 'exp_sup': 478.12, 'utility': 54209}
#  440: {'name': '46, 72', 'exp_sup': 478.09, 'utility': 72497}
#  441: {'name': '66, 15', 'exp_sup': 477.52, 'utility': 72754}
#  442: {'name': '7, 68', 'exp_sup': 477.35, 'utility': 103406}
#  443: {'name': '17, 21', 'exp_sup': 476.11, 'utility': 41106}
#  444: {'name': '44, 54', 'exp_sup': 476.0, 'utility': 20319}
#  445: {'name': '7, 50', 'exp_sup': 475.03, 'utility': 86352}
#  446: {'name': '17, 74', 'exp_sup': 474.08, 'utility': 40517}
#  447: {'name': '3, 38', 'exp_sup': 473.56, 'utility': 52164}
#  448: {'name': '36, 68', 'exp_sup': 473.51, 'utility': 82920}
#  449: {'name': '34, 68', 'exp_sup': 473.15, 'utility': 135817}
#  450: {'name': '44, 21', 'exp_sup': 472.01, 'utility': 20488}
#  451: {'name': '60, 50', 'exp_sup': 471.58, 'utility': 94933}
#  452: {'name': '5, 70', 'exp_sup': 471.08, 'utility': 52514}
#  453: {'name': '60, 19', 'exp_sup': 470.23, 'utility': 74127}
#  454: {'name': '34, 15', 'exp_sup': 470.13, 'utility': 93456}
#  455: {'name': '48, 15', 'exp_sup': 469.8, 'utility': 103145}
#  456: {'name': '66, 68', 'exp_sup': 468.37, 'utility': 109420}
#  457: {'name': '58, 23', 'exp_sup': 467.76, 'utility': 58714}
#  458: {'name': '29, 23', 'exp_sup': 467.44, 'utility': 88003}
#  459: {'name': '66, 70', 'exp_sup': 466.51, 'utility': 61306}
#  460: {'name': '3, 11', 'exp_sup': 466.5, 'utility': 92869}
#  461: {'name': '56, 15', 'exp_sup': 464.5, 'utility': 72408}
#  462: {'name': '40, 19', 'exp_sup': 464.15, 'utility': 148348}
#  463: {'name': '52, 23', 'exp_sup': 462.85, 'utility': 108098}
#  464: {'name': '48, 68', 'exp_sup': 462.5, 'utility': 138936}
#  465: {'name': '56, 50', 'exp_sup': 461.94, 'utility': 92346}
#  466: {'name': '25, 11', 'exp_sup': 461.86, 'utility': 58768}
#  467: {'name': '7, 19', 'exp_sup': 460.92, 'utility': 62187}
#  468: {'name': '36, 50', 'exp_sup': 460.77, 'utility': 61972}
#  469: {'name': '3, 15', 'exp_sup': 460.51, 'utility': 69920}
#  470: {'name': '3, 70', 'exp_sup': 459.71, 'utility': 60074}
#  471: {'name': '5, 68', 'exp_sup': 459.04, 'utility': 99567}
#  472: {'name': '17, 72', 'exp_sup': 458.35, 'utility': 90147}
#  473: {'name': '64, 23', 'exp_sup': 458.1, 'utility': 85945}
#  474: {'name': '31, 21', 'exp_sup': 457.67, 'utility': 38322}
#  475: {'name': '48, 70', 'exp_sup': 456.81, 'utility': 89878}
#  476: {'name': '34, 50', 'exp_sup': 456.37, 'utility': 113418}
#  477: {'name': '17, 11', 'exp_sup': 456.21, 'utility': 79699}
#  478: {'name': '62, 19', 'exp_sup': 456.05, 'utility': 40751}
#  479: {'name': '3, 54', 'exp_sup': 455.17, 'utility': 50081}
#  480: {'name': '9, 68', 'exp_sup': 454.28, 'utility': 87852}
#  481: {'name': '36, 19', 'exp_sup': 454.15, 'utility': 41505}
#  482: {'name': '3, 23', 'exp_sup': 453.65, 'utility': 86718}
#  483: {'name': '25, 68', 'exp_sup': 453.24, 'utility': 76818}
#  484: {'name': '9, 15', 'exp_sup': 451.24, 'utility': 48938}
#  485: {'name': '66, 50', 'exp_sup': 450.94, 'utility': 92357}
#  486: {'name': '66, 19', 'exp_sup': 450.3, 'utility': 71932}
#  487: {'name': '60, 23', 'exp_sup': 449.47, 'utility': 86861}
#  488: {'name': '64, 21', 'exp_sup': 448.37, 'utility': 47814}
#  489: {'name': '25, 15', 'exp_sup': 447.77, 'utility': 37548}
#  490: {'name': '34, 19', 'exp_sup': 447.23, 'utility': 92061}
#  491: {'name': '31, 23', 'exp_sup': 447.19, 'utility': 75415}
#  492: {'name': '40, 23', 'exp_sup': 446.6, 'utility': 156025}
#  493: {'name': '74, 38', 'exp_sup': 446.22, 'utility': 18918}
#  494: {'name': '46, 27', 'exp_sup': 445.96, 'utility': 28925}
#  495: {'name': '17, 27', 'exp_sup': 445.4, 'utility': 47508}
#  496: {'name': '5, 15', 'exp_sup': 444.97, 'utility': 58275}
#  497: {'name': '44, 27', 'exp_sup': 444.43, 'utility': 28593}
#  498: {'name': '9, 50', 'exp_sup': 443.02, 'utility': 69405}
#  499: {'name': '48, 50', 'exp_sup': 442.41, 'utility': 119180}
#  500: {'name': '38, 70', 'exp_sup': 441.9, 'utility': 29391}

# %%
# chạy với chess
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_chess.txt, ./data/chess_utility.txt", 0.001, 700)
algorithm.print_stats("./out/TUHUFP/chess/output_chess_top_700.txt")
# Out:
# Reading data . . .
# Minimum utility set to: 2156
# {'database util: ': 2156659}
# Top 700 CUPs:
#  1: {'name': '52', 'exp_sup': 1616.54, 'utility': 104178}
#  2: {'name': '29', 'exp_sup': 1598.92, 'utility': 70088}
#  3: {'name': '58', 'exp_sup': 1595.58, 'utility': 17462}
#  4: {'name': '40', 'exp_sup': 1579.27, 'utility': 188760}
#  5: {'name': '60', 'exp_sup': 1565.64, 'utility': 68908}
#  6: {'name': '62', 'exp_sup': 1537.33, 'utility': 16784}
#  7: {'name': '7', 'exp_sup': 1535.24, 'utility': 50790}
#  8: {'name': '36', 'exp_sup': 1530.49, 'utility': 16934}
#  9: {'name': '56', 'exp_sup': 1513.93, 'utility': 66780}
#  10: {'name': '48', 'exp_sup': 1500.86, 'utility': 115367}
#  11: {'name': '66', 'exp_sup': 1498.92, 'utility': 66644}
#  12: {'name': '34', 'exp_sup': 1493.64, 'utility': 99330}
#  13: {'name': '5', 'exp_sup': 1466.73, 'utility': 48369}
#  14: {'name': '9', 'exp_sup': 1446.46, 'utility': 31818}
#  15: {'name': '25', 'exp_sup': 1445.46, 'utility': 15465}
#  16: {'name': '3', 'exp_sup': 1407.44, 'utility': 61608}
#  17: {'name': '42', 'exp_sup': 1355.91, 'utility': 14849}
#  18: {'name': '64', 'exp_sup': 1337.59, 'utility': 56768}
#  19: {'name': '44', 'exp_sup': 1325.93, 'utility': 14261}
#  20: {'name': '46', 'exp_sup': 1284.58, 'utility': 14045}
#  21: {'name': '31', 'exp_sup': 1274.29, 'utility': 41649}
#  22: {'name': '17', 'exp_sup': 1251.12, 'utility': 40662}
#  23: {'name': '74', 'exp_sup': 1237.31, 'utility': 13298}
#  24: {'name': '72', 'exp_sup': 1177.8, 'utility': 77802}
#  25: {'name': '21', 'exp_sup': 1128.59, 'utility': 12263}
#  26: {'name': '54', 'exp_sup': 1105.31, 'utility': 11965}
#  27: {'name': '38', 'exp_sup': 1101.41, 'utility': 12130}
#  28: {'name': '27', 'exp_sup': 1098.98, 'utility': 24398}
#  29: {'name': '11', 'exp_sup': 1066.24, 'utility': 58730}
#  30: {'name': '15', 'exp_sup': 1008.29, 'utility': 32700}
#  31: {'name': '70', 'exp_sup': 1005.64, 'utility': 21824}
#  32: {'name': '68', 'exp_sup': 1003.26, 'utility': 75341}
#  33: {'name': '50', 'exp_sup': 965.12, 'utility': 54140}
#  34: {'name': '19', 'exp_sup': 958.74, 'utility': 32565}
#  35: {'name': '23', 'exp_sup': 919.58, 'utility': 48960}
#  36: {'name': '13', 'exp_sup': 860.84, 'utility': 9269}
#  37: {'name': '1', 'exp_sup': 832.29, 'utility': 65471}
#  38: {'name': '52, 58', 'exp_sup': 806.57, 'utility': 121139}
#  39: {'name': '52, 29', 'exp_sup': 802.29, 'utility': 172766}
#  40: {'name': '52, 40', 'exp_sup': 800.33, 'utility': 290726}
#  41: {'name': '52, 60', 'exp_sup': 797.15, 'utility': 170582}
#  42: {'name': '29, 58', 'exp_sup': 794.58, 'utility': 87031}
#  43: {'name': '29, 40', 'exp_sup': 792.51, 'utility': 255631}
#  44: {'name': '58, 40', 'exp_sup': 790.04, 'utility': 205017}
#  45: {'name': '58, 60', 'exp_sup': 784.78, 'utility': 85721}
#  46: {'name': '52, 62', 'exp_sup': 781.35, 'utility': 115661}
#  47: {'name': '29, 60', 'exp_sup': 777.6, 'utility': 136920}
#  48: {'name': '52, 56', 'exp_sup': 776.21, 'utility': 164720}
#  49: {'name': '52, 7', 'exp_sup': 774.06, 'utility': 150447}
#  50: {'name': '40, 60', 'exp_sup': 773.52, 'utility': 253428}
#  51: {'name': '29, 62', 'exp_sup': 772.37, 'utility': 83526}
#  52: {'name': '58, 62', 'exp_sup': 769.84, 'utility': 33329}
#  53: {'name': '58, 36', 'exp_sup': 767.98, 'utility': 33744}
#  54: {'name': '29, 7', 'exp_sup': 767.86, 'utility': 117944}
#  55: {'name': '29, 36', 'exp_sup': 765.95, 'utility': 84385}
#  56: {'name': '58, 7', 'exp_sup': 765.83, 'utility': 67239}
#  57: {'name': '52, 36', 'exp_sup': 764.38, 'utility': 117430}
#  58: {'name': '40, 62', 'exp_sup': 764.28, 'utility': 197416}
#  59: {'name': '60, 62', 'exp_sup': 762.34, 'utility': 82302}
#  60: {'name': '52, 48', 'exp_sup': 761.78, 'utility': 212460}
#  61: {'name': '40, 36', 'exp_sup': 761.32, 'utility': 198648}
#  62: {'name': '58, 56', 'exp_sup': 759.72, 'utility': 82803}
#  63: {'name': '52, 66', 'exp_sup': 759.17, 'utility': 164458}
#  64: {'name': '40, 7', 'exp_sup': 758.2, 'utility': 231271}
#  65: {'name': '2', 'exp_sup': 757.95, 'utility': 24618}
#  66: {'name': '29, 56', 'exp_sup': 757.1, 'utility': 132152}
#  67: {'name': '14', 'exp_sup': 755.4, 'utility': 8252}
#  68: {'name': '58, 48', 'exp_sup': 753.39, 'utility': 131386}
#  69: {'name': '60, 7', 'exp_sup': 752.4, 'utility': 115497}
#  70: {'name': '52, 34', 'exp_sup': 750.57, 'utility': 197472}
#  71: {'name': '60, 36', 'exp_sup': 750.51, 'utility': 83055}
#  72: {'name': '60, 66', 'exp_sup': 748.87, 'utility': 132064}
#  73: {'name': '29, 34', 'exp_sup': 748.84, 'utility': 165212}
#  74: {'name': '29, 66', 'exp_sup': 748.18, 'utility': 132172}
#  75: {'name': '58, 66', 'exp_sup': 747.26, 'utility': 82834}
#  76: {'name': '40, 56', 'exp_sup': 746.88, 'utility': 243050}
#  77: {'name': '52, 5', 'exp_sup': 745.02, 'utility': 144276}
#  78: {'name': '29, 48', 'exp_sup': 744.94, 'utility': 179722}
#  79: {'name': '40, 48', 'exp_sup': 741.87, 'utility': 290391}
#  80: {'name': '60, 48', 'exp_sup': 741.31, 'utility': 178947}
#  81: {'name': '29, 5', 'exp_sup': 739.46, 'utility': 112623}
#  82: {'name': '60, 56', 'exp_sup': 739.43, 'utility': 130088}
#  83: {'name': '40, 34', 'exp_sup': 737.74, 'utility': 277239}
#  84: {'name': '7, 36', 'exp_sup': 736.85, 'utility': 65158}
#  85: {'name': '58, 5', 'exp_sup': 736.2, 'utility': 64234}
#  86: {'name': '62, 36', 'exp_sup': 735.64, 'utility': 32252}
#  87: {'name': '40, 66', 'exp_sup': 734.99, 'utility': 243649}
#  88: {'name': '58, 34', 'exp_sup': 734.32, 'utility': 115440}
#  89: {'name': '29, 25', 'exp_sup': 733.79, 'utility': 77685}
#  90: {'name': '60, 34', 'exp_sup': 732.14, 'utility': 162688}
#  91: {'name': '7, 34', 'exp_sup': 731.86, 'utility': 143691}
#  92: {'name': '52, 25', 'exp_sup': 731.26, 'utility': 107984}
#  93: {'name': '62, 7', 'exp_sup': 731.07, 'utility': 64443}
#  94: {'name': '62, 56', 'exp_sup': 730.52, 'utility': 79966}
#  95: {'name': '36, 48', 'exp_sup': 729.26, 'utility': 129898}
#  96: {'name': '52, 9', 'exp_sup': 728.24, 'utility': 124558}
#  97: {'name': '36, 56', 'exp_sup': 727.83, 'utility': 80092}
#  98: {'name': '7, 66', 'exp_sup': 727.27, 'utility': 111671}
#  99: {'name': '60, 5', 'exp_sup': 725.51, 'utility': 110905}
#  100: {'name': '62, 66', 'exp_sup': 725.14, 'utility': 79147}
#  101: {'name': '7, 56', 'exp_sup': 721.02, 'utility': 112322}
#  102: {'name': '58, 9', 'exp_sup': 720.18, 'utility': 47296}
#  103: {'name': '29, 9', 'exp_sup': 720.07, 'utility': 94064}
#  104: {'name': '7, 48', 'exp_sup': 719.89, 'utility': 158110}
#  105: {'name': '52, 3', 'exp_sup': 718.73, 'utility': 153244}
#  106: {'name': '40, 5', 'exp_sup': 718.05, 'utility': 223282}
#  107: {'name': '36, 34', 'exp_sup': 716.91, 'utility': 111964}
#  108: {'name': '58, 25', 'exp_sup': 716.42, 'utility': 30961}
#  109: {'name': '60, 25', 'exp_sup': 715.42, 'utility': 77075}
#  110: {'name': '62, 48', 'exp_sup': 715.39, 'utility': 125379}
#  111: {'name': '62, 34', 'exp_sup': 714.96, 'utility': 110832}
#  112: {'name': '7, 5', 'exp_sup': 713.08, 'utility': 93495}
#  113: {'name': '40, 25', 'exp_sup': 712.24, 'utility': 183618}
#  114: {'name': '36, 66', 'exp_sup': 709.93, 'utility': 80135}
#  115: {'name': '56, 66', 'exp_sup': 708.94, 'utility': 125068}
#  116: {'name': '62, 5', 'exp_sup': 708.88, 'utility': 61882}
#  117: {'name': '29, 3', 'exp_sup': 708.45, 'utility': 123288}
#  118: {'name': '36, 5', 'exp_sup': 707.41, 'utility': 62205}
#  119: {'name': '48, 66', 'exp_sup': 706.37, 'utility': 172697}
#  120: {'name': '58, 3', 'exp_sup': 706.12, 'utility': 76772}
#  121: {'name': '40, 9', 'exp_sup': 704.32, 'utility': 200832}
#  122: {'name': '56, 34', 'exp_sup': 703.99, 'utility': 156636}
#  123: {'name': '66, 5', 'exp_sup': 703.33, 'utility': 108091}
#  124: {'name': '60, 9', 'exp_sup': 702.33, 'utility': 92804}
#  125: {'name': '56, 48', 'exp_sup': 700.91, 'utility': 169695}
#  126: {'name': '66, 34', 'exp_sup': 699.99, 'utility': 157508}
#  127: {'name': '36, 25', 'exp_sup': 699.95, 'utility': 30388}
#  128: {'name': '48, 34', 'exp_sup': 699.74, 'utility': 201383}
#  129: {'name': '62, 25', 'exp_sup': 697.0, 'utility': 29738}
#  130: {'name': '34, 5', 'exp_sup': 695.45, 'utility': 140856}
#  131: {'name': '40, 3', 'exp_sup': 693.84, 'utility': 226522}
#  132: {'name': '62, 9', 'exp_sup': 692.12, 'utility': 45217}
#  133: {'name': '48, 25', 'exp_sup': 690.07, 'utility': 119915}
#  134: {'name': '7, 25', 'exp_sup': 689.09, 'utility': 59938}
#  135: {'name': '56, 5', 'exp_sup': 689.09, 'utility': 106663}
#  136: {'name': '60, 3', 'exp_sup': 688.27, 'utility': 121992}
#  137: {'name': '56, 9', 'exp_sup': 688.26, 'utility': 91078}
#  138: {'name': '52, 42', 'exp_sup': 688.23, 'utility': 102622}
#  139: {'name': '7, 9', 'exp_sup': 687.7, 'utility': 75723}
#  140: {'name': '48, 5', 'exp_sup': 684.69, 'utility': 151382}
#  141: {'name': '52, 64', 'exp_sup': 684.06, 'utility': 141962}
#  142: {'name': '36, 9', 'exp_sup': 683.24, 'utility': 45683}
#  143: {'name': '58, 42', 'exp_sup': 682.92, 'utility': 29567}
#  144: {'name': '56, 25', 'exp_sup': 682.7, 'utility': 73534}
#  145: {'name': '34, 9', 'exp_sup': 682.1, 'utility': 119678}
#  146: {'name': '48, 9', 'exp_sup': 681.86, 'utility': 131587}
#  147: {'name': '66, 25', 'exp_sup': 681.41, 'utility': 74411}
#  148: {'name': '29, 42', 'exp_sup': 680.22, 'utility': 73789}
#  149: {'name': '36, 3', 'exp_sup': 679.53, 'utility': 74325}
#  150: {'name': '60, 42', 'exp_sup': 676.51, 'utility': 73376}
#  151: {'name': '7, 3', 'exp_sup': 676.28, 'utility': 105239}
#  152: {'name': '34, 25', 'exp_sup': 676.03, 'utility': 103024}
#  153: {'name': '62, 3', 'exp_sup': 675.43, 'utility': 73985}
#  154: {'name': '56, 3', 'exp_sup': 674.81, 'utility': 118028}
#  155: {'name': '24', 'exp_sup': 673.83, 'utility': 14996}
#  156: {'name': '40, 64', 'exp_sup': 671.11, 'utility': 212460}
#  157: {'name': '40, 42', 'exp_sup': 670.8, 'utility': 174811}
#  158: {'name': '66, 9', 'exp_sup': 670.36, 'utility': 89714}
#  159: {'name': '52, 44', 'exp_sup': 667.7, 'utility': 98857}
#  160: {'name': '5, 9', 'exp_sup': 665.83, 'utility': 72391}
#  161: {'name': '66, 3', 'exp_sup': 662.17, 'utility': 117072}
#  162: {'name': '29, 64', 'exp_sup': 661.85, 'utility': 113308}
#  163: {'name': '29, 44', 'exp_sup': 660.91, 'utility': 70749}
#  164: {'name': '34, 3', 'exp_sup': 660.29, 'utility': 146622}
#  165: {'name': '5, 3', 'exp_sup': 659.41, 'utility': 99860}
#  166: {'name': '60, 64', 'exp_sup': 659.26, 'utility': 112012}
#  167: {'name': '58, 44', 'exp_sup': 658.05, 'utility': 28302}
#  168: {'name': '58, 64', 'exp_sup': 657.97, 'utility': 70620}
#  169: {'name': '5, 25', 'exp_sup': 656.29, 'utility': 57086}
#  170: {'name': '48, 3', 'exp_sup': 653.87, 'utility': 160071}
#  171: {'name': '60, 44', 'exp_sup': 652.46, 'utility': 69435}
#  172: {'name': '40, 44', 'exp_sup': 652.34, 'utility': 167125}
#  173: {'name': '66, 42', 'exp_sup': 652.23, 'utility': 71539}
#  174: {'name': '52, 46', 'exp_sup': 650.66, 'utility': 96676}
#  175: {'name': '48, 42', 'exp_sup': 650.48, 'utility': 111887}
#  176: {'name': '62, 42', 'exp_sup': 650.04, 'utility': 28297}
#  177: {'name': '36, 42', 'exp_sup': 649.16, 'utility': 28659}
#  178: {'name': '7, 42', 'exp_sup': 648.95, 'utility': 56926}
#  179: {'name': '9, 25', 'exp_sup': 647.8, 'utility': 41598}
#  180: {'name': '56, 42', 'exp_sup': 643.85, 'utility': 70665}
#  181: {'name': '62, 44', 'exp_sup': 643.15, 'utility': 27376}
#  182: {'name': '29, 46', 'exp_sup': 642.56, 'utility': 69514}
#  183: {'name': '62, 64', 'exp_sup': 641.93, 'utility': 68111}
#  184: {'name': '52, 31', 'exp_sup': 641.53, 'utility': 123555}
#  185: {'name': '36, 64', 'exp_sup': 641.43, 'utility': 68775}
#  186: {'name': '9, 3', 'exp_sup': 640.82, 'utility': 83696}
#  187: {'name': '34, 42', 'exp_sup': 639.83, 'utility': 99078}
#  188: {'name': '58, 46', 'exp_sup': 638.37, 'utility': 27774}
#  189: {'name': '48, 64', 'exp_sup': 636.88, 'utility': 148284}
#  190: {'name': '7, 44', 'exp_sup': 636.1, 'utility': 54652}
#  191: {'name': '36, 44', 'exp_sup': 636.1, 'utility': 27450}
#  192: {'name': '60, 31', 'exp_sup': 636.0, 'utility': 96146}
#  193: {'name': '29, 31', 'exp_sup': 635.75, 'utility': 95917}
#  194: {'name': '7, 64', 'exp_sup': 635.34, 'utility': 95825}
#  195: {'name': '56, 64', 'exp_sup': 634.6, 'utility': 108348}
#  196: {'name': '40, 46', 'exp_sup': 631.52, 'utility': 163761}
#  197: {'name': '5, 64', 'exp_sup': 630.61, 'utility': 93701}
#  198: {'name': '60, 46', 'exp_sup': 630.42, 'utility': 68407}
#  199: {'name': '58, 31', 'exp_sup': 630.18, 'utility': 55149}
#  200: {'name': '40, 31', 'exp_sup': 630.06, 'utility': 190050}
#  201: {'name': '66, 64', 'exp_sup': 630.04, 'utility': 108260}
#  202: {'name': '52, 17', 'exp_sup': 629.95, 'utility': 120894}
#  203: {'name': '29, 17', 'exp_sup': 628.98, 'utility': 94380}
#  204: {'name': '56, 44', 'exp_sup': 628.92, 'utility': 67713}
#  205: {'name': '48, 44', 'exp_sup': 628.53, 'utility': 106483}
#  206: {'name': '42, 64', 'exp_sup': 628.12, 'utility': 66152}
#  207: {'name': '34, 64', 'exp_sup': 628.05, 'utility': 136476}
#  208: {'name': '52, 74', 'exp_sup': 624.53, 'utility': 91129}
#  209: {'name': '25, 3', 'exp_sup': 623.94, 'utility': 67954}
#  210: {'name': '58, 17', 'exp_sup': 622.77, 'utility': 54101}
#  211: {'name': '40, 74', 'exp_sup': 621.61, 'utility': 155667}
#  212: {'name': '62, 46', 'exp_sup': 621.29, 'utility': 26646}
#  213: {'name': '5, 44', 'exp_sup': 620.76, 'utility': 53341}
#  214: {'name': '40, 17', 'exp_sup': 618.04, 'utility': 186881}
#  215: {'name': '58, 74', 'exp_sup': 617.98, 'utility': 26237}
#  216: {'name': '36, 46', 'exp_sup': 617.5, 'utility': 26984}
#  217: {'name': '7, 46', 'exp_sup': 616.25, 'utility': 53348}
#  218: {'name': '66, 31', 'exp_sup': 615.35, 'utility': 92680}
#  219: {'name': '29, 74', 'exp_sup': 613.71, 'utility': 65434}
#  220: {'name': '34, 44', 'exp_sup': 613.63, 'utility': 94149}
#  221: {'name': '69', 'exp_sup': 612.53, 'utility': 53240}
#  222: {'name': '5, 42', 'exp_sup': 612.15, 'utility': 55630}
#  223: {'name': '52, 72', 'exp_sup': 611.88, 'utility': 154086}
#  224: {'name': '25, 42', 'exp_sup': 611.6, 'utility': 26177}
#  225: {'name': '36, 31', 'exp_sup': 611.47, 'utility': 53422}
#  226: {'name': '7, 31', 'exp_sup': 609.45, 'utility': 80313}
#  227: {'name': '66, 44', 'exp_sup': 609.19, 'utility': 66997}
#  228: {'name': '66, 46', 'exp_sup': 608.12, 'utility': 66721}
#  229: {'name': '60, 17', 'exp_sup': 606.34, 'utility': 93374}
#  230: {'name': '9, 42', 'exp_sup': 605.77, 'utility': 40290}
#  231: {'name': '56, 46', 'exp_sup': 604.82, 'utility': 66085}
#  232: {'name': '3, 42', 'exp_sup': 604.76, 'utility': 65633}
#  233: {'name': '25, 44', 'exp_sup': 604.42, 'utility': 25613}
#  234: {'name': '71', 'exp_sup': 603.72, 'utility': 25236}
#  235: {'name': '51', 'exp_sup': 603.41, 'utility': 13402}
#  236: {'name': '9, 44', 'exp_sup': 603.07, 'utility': 38704}
#  237: {'name': '20', 'exp_sup': 602.48, 'utility': 6792}
#  238: {'name': '62, 31', 'exp_sup': 602.29, 'utility': 52712}
#  239: {'name': '25, 64', 'exp_sup': 601.92, 'utility': 62889}
#  240: {'name': '5, 31', 'exp_sup': 601.28, 'utility': 77079}
#  241: {'name': '3, 64', 'exp_sup': 600.44, 'utility': 101888}
#  242: {'name': '56, 74', 'exp_sup': 599.4, 'utility': 64482}
#  243: {'name': '62, 74', 'exp_sup': 598.58, 'utility': 25672}
#  244: {'name': '7, 17', 'exp_sup': 598.52, 'utility': 78828}
#  245: {'name': '48, 46', 'exp_sup': 597.25, 'utility': 104640}
#  246: {'name': '34, 46', 'exp_sup': 596.46, 'utility': 92120}
#  247: {'name': '9, 64', 'exp_sup': 594.91, 'utility': 76712}
#  248: {'name': '34, 31', 'exp_sup': 593.91, 'utility': 117591}
#  249: {'name': '56, 17', 'exp_sup': 593.84, 'utility': 90871}
#  250: {'name': '62, 17', 'exp_sup': 593.59, 'utility': 51403}
#  251: {'name': '36, 74', 'exp_sup': 593.11, 'utility': 25246}
#  252: {'name': '56, 31', 'exp_sup': 593.05, 'utility': 91111}
#  253: {'name': '16', 'exp_sup': 592.57, 'utility': 18978}
#  254: {'name': '7, 74', 'exp_sup': 590.57, 'utility': 50739}
#  255: {'name': '60, 74', 'exp_sup': 590.1, 'utility': 64078}
#  256: {'name': '48, 17', 'exp_sup': 589.75, 'utility': 127394}
#  257: {'name': '60, 72', 'exp_sup': 589.49, 'utility': 129080}
#  258: {'name': '5, 46', 'exp_sup': 588.84, 'utility': 51865}
#  259: {'name': '48, 74', 'exp_sup': 588.19, 'utility': 96589}
#  260: {'name': '58, 72', 'exp_sup': 587.43, 'utility': 90250}
#  261: {'name': '48, 31', 'exp_sup': 587.31, 'utility': 128218}
#  262: {'name': '66, 17', 'exp_sup': 586.04, 'utility': 89435}
#  263: {'name': '29, 72', 'exp_sup': 585.77, 'utility': 128596}
#  264: {'name': '34, 74', 'exp_sup': 584.6, 'utility': 86946}
#  265: {'name': '3, 31', 'exp_sup': 584.39, 'utility': 89594}
#  266: {'name': '36, 17', 'exp_sup': 584.25, 'utility': 52175}
#  267: {'name': '34, 17', 'exp_sup': 583.64, 'utility': 115869}
#  268: {'name': '66, 72', 'exp_sup': 583.0, 'utility': 128876}
#  269: {'name': '40, 72', 'exp_sup': 582.56, 'utility': 214715}
#  270: {'name': '25, 46', 'exp_sup': 582.0, 'utility': 24911}
#  271: {'name': '42, 31', 'exp_sup': 576.46, 'utility': 49457}
#  272: {'name': '9, 31', 'exp_sup': 576.09, 'utility': 62063}
#  273: {'name': '9, 74', 'exp_sup': 573.91, 'utility': 36189}
#  274: {'name': '9, 17', 'exp_sup': 573.65, 'utility': 62169}
#  275: {'name': '9, 46', 'exp_sup': 572.93, 'utility': 37634}
#  276: {'name': '42, 44', 'exp_sup': 572.47, 'utility': 24538}
#  277: {'name': '3, 44', 'exp_sup': 572.11, 'utility': 60943}
#  278: {'name': '66, 74', 'exp_sup': 571.5, 'utility': 60991}
#  279: {'name': '64, 44', 'exp_sup': 571.09, 'utility': 59379}
#  280: {'name': '62, 72', 'exp_sup': 568.8, 'utility': 86521}
#  281: {'name': '7, 72', 'exp_sup': 567.94, 'utility': 111501}
#  282: {'name': '36, 72', 'exp_sup': 567.77, 'utility': 86942}
#  283: {'name': '25, 31', 'exp_sup': 566.32, 'utility': 48756}
#  284: {'name': '29, 21', 'exp_sup': 565.61, 'utility': 60591}
#  285: {'name': '52, 21', 'exp_sup': 565.54, 'utility': 84050}
#  286: {'name': '5, 74', 'exp_sup': 563.51, 'utility': 48294}
#  287: {'name': '3, 17', 'exp_sup': 562.07, 'utility': 85238}
#  288: {'name': '3, 46', 'exp_sup': 561.56, 'utility': 61011}
#  289: {'name': '25, 74', 'exp_sup': 561.49, 'utility': 23488}
#  290: {'name': '5, 17', 'exp_sup': 561.22, 'utility': 73545}
#  291: {'name': '34, 72', 'exp_sup': 560.36, 'utility': 148908}
#  292: {'name': '52, 38', 'exp_sup': 559.97, 'utility': 83539}
#  293: {'name': '25, 17', 'exp_sup': 559.2, 'utility': 47079}
#  294: {'name': '29, 54', 'exp_sup': 559.15, 'utility': 60167}
#  295: {'name': '58, 38', 'exp_sup': 559.14, 'utility': 24011}
#  296: {'name': '48, 72', 'exp_sup': 558.53, 'utility': 158007}
#  297: {'name': '52, 54', 'exp_sup': 556.59, 'utility': 83439}
#  298: {'name': '58, 21', 'exp_sup': 556.21, 'utility': 24285}
#  299: {'name': '42, 46', 'exp_sup': 556.1, 'utility': 24096}
#  300: {'name': '64, 31', 'exp_sup': 555.28, 'utility': 83623}
#  301: {'name': '58, 54', 'exp_sup': 554.91, 'utility': 23977}
#  302: {'name': '29, 27', 'exp_sup': 554.89, 'utility': 72626}
#  303: {'name': '40, 21', 'exp_sup': 553.74, 'utility': 142736}
#  304: {'name': '29, 38', 'exp_sup': 552.56, 'utility': 59510}
#  305: {'name': '5, 72', 'exp_sup': 552.47, 'utility': 108591}
#  306: {'name': '58, 27', 'exp_sup': 551.33, 'utility': 36318}
#  307: {'name': '56, 72', 'exp_sup': 547.29, 'utility': 121376}
#  308: {'name': '60, 21', 'exp_sup': 546.88, 'utility': 59235}
#  309: {'name': '52, 27', 'exp_sup': 546.14, 'utility': 95334}
#  310: {'name': '40, 54', 'exp_sup': 545.72, 'utility': 143216}
#  311: {'name': '42, 72', 'exp_sup': 544.27, 'utility': 84056}
#  312: {'name': '44, 46', 'exp_sup': 544.2, 'utility': 22992}
#  313: {'name': '62, 38', 'exp_sup': 543.85, 'utility': 23601}
#  314: {'name': '7, 21', 'exp_sup': 543.82, 'utility': 47229}
#  315: {'name': '60, 38', 'exp_sup': 543.48, 'utility': 58592}
#  316: {'name': '64, 46', 'exp_sup': 542.52, 'utility': 57437}
#  317: {'name': '3, 72', 'exp_sup': 542.39, 'utility': 119164}
#  318: {'name': '12', 'exp_sup': 541.74, 'utility': 11854}
#  319: {'name': '64, 72', 'exp_sup': 540.83, 'utility': 116362}
#  320: {'name': '60, 54', 'exp_sup': 540.7, 'utility': 58256}
#  321: {'name': '40, 38', 'exp_sup': 540.48, 'utility': 143849}
#  322: {'name': '36, 21', 'exp_sup': 540.41, 'utility': 23785}
#  323: {'name': '52, 11', 'exp_sup': 539.09, 'utility': 127387}
#  324: {'name': '25, 72', 'exp_sup': 538.97, 'utility': 80836}
#  325: {'name': '40, 27', 'exp_sup': 537.21, 'utility': 152164}
#  326: {'name': '56, 54', 'exp_sup': 536.79, 'utility': 58402}
#  327: {'name': '7, 54', 'exp_sup': 535.72, 'utility': 46077}
#  328: {'name': '29, 11', 'exp_sup': 535.32, 'utility': 103978}
#  329: {'name': '62, 54', 'exp_sup': 534.73, 'utility': 23131}
#  330: {'name': '56, 38', 'exp_sup': 534.47, 'utility': 57305}
#  331: {'name': '42, 17', 'exp_sup': 533.76, 'utility': 45714}
#  332: {'name': '5, 21', 'exp_sup': 532.86, 'utility': 45086}
#  333: {'name': '58, 11', 'exp_sup': 532.83, 'utility': 70332}
#  334: {'name': '34, 21', 'exp_sup': 531.2, 'utility': 79670}
#  335: {'name': '7, 38', 'exp_sup': 530.68, 'utility': 46576}
#  336: {'name': '44, 31', 'exp_sup': 530.68, 'utility': 45378}
#  337: {'name': '36, 54', 'exp_sup': 530.65, 'utility': 23075}
#  338: {'name': '60, 27', 'exp_sup': 529.61, 'utility': 71510}
#  339: {'name': '62, 27', 'exp_sup': 527.13, 'utility': 34383}
#  340: {'name': '36, 27', 'exp_sup': 526.74, 'utility': 35491}
#  341: {'name': '48, 21', 'exp_sup': 526.71, 'utility': 92215}
#  342: {'name': '44, 74', 'exp_sup': 526.0, 'utility': 22045}
#  343: {'name': '7, 27', 'exp_sup': 525.99, 'utility': 58671}
#  344: {'name': '48, 27', 'exp_sup': 525.01, 'utility': 104130}
#  345: {'name': '40, 11', 'exp_sup': 524.87, 'utility': 182648}
#  346: {'name': '62, 21', 'exp_sup': 524.33, 'utility': 22863}
#  347: {'name': '66, 21', 'exp_sup': 524.23, 'utility': 56837}
#  348: {'name': '34, 54', 'exp_sup': 523.85, 'utility': 79939}
#  349: {'name': '36, 38', 'exp_sup': 522.95, 'utility': 23006}
#  350: {'name': '56, 21', 'exp_sup': 522.39, 'utility': 57808}
#  351: {'name': '3, 74', 'exp_sup': 521.62, 'utility': 55406}
#  352: {'name': '66, 38', 'exp_sup': 521.11, 'utility': 57237}
#  353: {'name': '5, 38', 'exp_sup': 520.61, 'utility': 46561}
#  354: {'name': '9, 72', 'exp_sup': 519.88, 'utility': 91332}
#  355: {'name': '34, 27', 'exp_sup': 518.28, 'utility': 89930}
#  356: {'name': '56, 27', 'exp_sup': 518.07, 'utility': 68662}
#  357: {'name': '48, 54', 'exp_sup': 517.36, 'utility': 89313}
#  358: {'name': '25, 21', 'exp_sup': 517.29, 'utility': 21605}
#  359: {'name': '46, 31', 'exp_sup': 516.22, 'utility': 44386}
#  360: {'name': '34, 38', 'exp_sup': 516.15, 'utility': 80999}
#  361: {'name': '7, 11', 'exp_sup': 515.72, 'utility': 90027}
#  362: {'name': '52, 68', 'exp_sup': 515.51, 'utility': 139110}
#  363: {'name': '52, 15', 'exp_sup': 515.33, 'utility': 97941}
#  364: {'name': '56, 11', 'exp_sup': 514.71, 'utility': 101096}
#  365: {'name': '60, 11', 'exp_sup': 514.05, 'utility': 102938}
#  366: {'name': '66, 27', 'exp_sup': 513.51, 'utility': 68712}
#  367: {'name': '9, 54', 'exp_sup': 512.11, 'utility': 33130}
#  368: {'name': '39', 'exp_sup': 510.62, 'utility': 10976}
#  369: {'name': '58, 15', 'exp_sup': 509.46, 'utility': 43721}
#  370: {'name': '31, 72', 'exp_sup': 508.88, 'utility': 98595}
#  371: {'name': '9, 21', 'exp_sup': 508.43, 'utility': 32601}
#  372: {'name': '66, 54', 'exp_sup': 508.32, 'utility': 55935}
#  373: {'name': '52, 70', 'exp_sup': 506.32, 'utility': 86740}
#  374: {'name': '36, 11', 'exp_sup': 506.15, 'utility': 66822}
#  375: {'name': '74, 54', 'exp_sup': 506.03, 'utility': 21409}
#  376: {'name': '9, 27', 'exp_sup': 504.51, 'utility': 43648}
#  377: {'name': '5, 54', 'exp_sup': 504.22, 'utility': 44308}
#  378: {'name': '29, 15', 'exp_sup': 504.0, 'utility': 76601}
#  379: {'name': '62, 11', 'exp_sup': 503.39, 'utility': 66448}
#  380: {'name': '9, 38', 'exp_sup': 503.38, 'utility': 33115}
#  381: {'name': '58, 70', 'exp_sup': 503.26, 'utility': 32574}
#  382: {'name': '46, 17', 'exp_sup': 502.81, 'utility': 42540}
#  383: {'name': '29, 70', 'exp_sup': 502.66, 'utility': 65230}
#  384: {'name': '25, 54', 'exp_sup': 502.18, 'utility': 21425}
#  385: {'name': '60, 15', 'exp_sup': 501.5, 'utility': 76507}
#  386: {'name': '31, 17', 'exp_sup': 500.45, 'utility': 64563}
#  387: {'name': '34, 11', 'exp_sup': 500.43, 'utility': 120145}
#  388: {'name': '64, 17', 'exp_sup': 500.39, 'utility': 74383}
#  389: {'name': '58, 68', 'exp_sup': 499.89, 'utility': 85587}
#  390: {'name': '40, 70', 'exp_sup': 499.81, 'utility': 140900}
#  391: {'name': '48, 38', 'exp_sup': 498.91, 'utility': 88005}
#  392: {'name': '66, 11', 'exp_sup': 498.33, 'utility': 97861}
#  393: {'name': '44, 17', 'exp_sup': 498.18, 'utility': 42116}
#  394: {'name': '52, 50', 'exp_sup': 498.15, 'utility': 117882}
#  395: {'name': '28', 'exp_sup': 497.37, 'utility': 10432}
#  396: {'name': '60, 70', 'exp_sup': 497.35, 'utility': 63658}
#  397: {'name': '64, 74', 'exp_sup': 497.33, 'utility': 49938}
#  398: {'name': '62, 68', 'exp_sup': 496.9, 'utility': 83679}
#  399: {'name': '29, 68', 'exp_sup': 496.06, 'utility': 118037}
#  400: {'name': '40, 68', 'exp_sup': 495.91, 'utility': 190386}
#  401: {'name': '62, 70', 'exp_sup': 494.57, 'utility': 31849}
#  402: {'name': '9, 11', 'exp_sup': 494.42, 'utility': 75435}
#  403: {'name': '7, 70', 'exp_sup': 493.65, 'utility': 54067}
#  404: {'name': '42, 74', 'exp_sup': 493.55, 'utility': 21039}
#  405: {'name': '40, 15', 'exp_sup': 491.54, 'utility': 150509}
#  406: {'name': '25, 27', 'exp_sup': 491.3, 'utility': 32290}
#  407: {'name': '56, 68', 'exp_sup': 491.28, 'utility': 117696}
#  408: {'name': '7, 15', 'exp_sup': 490.97, 'utility': 64860}
#  409: {'name': '25, 38', 'exp_sup': 490.86, 'utility': 21298}
#  410: {'name': '52, 19', 'exp_sup': 488.3, 'utility': 95715}
#  411: {'name': '55', 'exp_sup': 488.08, 'utility': 10932}
#  412: {'name': '17, 15', 'exp_sup': 487.74, 'utility': 62502}
#  413: {'name': '62, 15', 'exp_sup': 486.53, 'utility': 41072}
#  414: {'name': '46, 74', 'exp_sup': 486.2, 'utility': 21118}
#  415: {'name': '22', 'exp_sup': 486.0, 'utility': 5224}
#  416: {'name': '58, 50', 'exp_sup': 485.96, 'utility': 64399}
#  417: {'name': '58, 19', 'exp_sup': 485.92, 'utility': 43126}
#  418: {'name': '34, 70', 'exp_sup': 485.91, 'utility': 86000}
#  419: {'name': '42, 38', 'exp_sup': 485.91, 'utility': 21144}
#  420: {'name': '64, 38', 'exp_sup': 485.09, 'utility': 51319}
#  421: {'name': '17, 19', 'exp_sup': 483.63, 'utility': 64071}
#  422: {'name': '3, 21', 'exp_sup': 483.38, 'utility': 52213}
#  423: {'name': '42, 21', 'exp_sup': 483.33, 'utility': 20825}
#  424: {'name': '36, 15', 'exp_sup': 482.97, 'utility': 41591}
#  425: {'name': '40, 50', 'exp_sup': 482.74, 'utility': 171658}
#  426: {'name': '60, 68', 'exp_sup': 482.72, 'utility': 115545}
#  427: {'name': '44, 38', 'exp_sup': 481.96, 'utility': 20975}
#  428: {'name': '9, 70', 'exp_sup': 481.9, 'utility': 41458}
#  429: {'name': '29, 19', 'exp_sup': 481.88, 'utility': 75214}
#  430: {'name': '44, 72', 'exp_sup': 481.8, 'utility': 72245}
#  431: {'name': '48, 11', 'exp_sup': 481.74, 'utility': 126971}
#  432: {'name': '62, 50', 'exp_sup': 481.19, 'utility': 62935}
#  433: {'name': '5, 11', 'exp_sup': 480.39, 'utility': 83830}
#  434: {'name': '3, 27', 'exp_sup': 479.88, 'utility': 63366}
#  435: {'name': '56, 70', 'exp_sup': 479.52, 'utility': 63252}
#  436: {'name': '36, 70', 'exp_sup': 478.81, 'utility': 31066}
#  437: {'name': '29, 50', 'exp_sup': 478.64, 'utility': 97116}
#  438: {'name': '46, 19', 'exp_sup': 478.26, 'utility': 43262}
#  439: {'name': '5, 27', 'exp_sup': 478.12, 'utility': 54209}
#  440: {'name': '46, 72', 'exp_sup': 478.09, 'utility': 72497}
#  441: {'name': '66, 15', 'exp_sup': 477.52, 'utility': 72754}
#  442: {'name': '7, 68', 'exp_sup': 477.35, 'utility': 103406}
#  443: {'name': '17, 21', 'exp_sup': 476.11, 'utility': 41106}
#  444: {'name': '44, 54', 'exp_sup': 476.0, 'utility': 20319}
#  445: {'name': '7, 50', 'exp_sup': 475.03, 'utility': 86352}
#  446: {'name': '17, 74', 'exp_sup': 474.08, 'utility': 40517}
#  447: {'name': '3, 38', 'exp_sup': 473.56, 'utility': 52164}
#  448: {'name': '36, 68', 'exp_sup': 473.51, 'utility': 82920}
#  449: {'name': '34, 68', 'exp_sup': 473.15, 'utility': 135817}
#  450: {'name': '44, 21', 'exp_sup': 472.01, 'utility': 20488}
#  451: {'name': '60, 50', 'exp_sup': 471.58, 'utility': 94933}
#  452: {'name': '5, 70', 'exp_sup': 471.08, 'utility': 52514}
#  453: {'name': '60, 19', 'exp_sup': 470.23, 'utility': 74127}
#  454: {'name': '34, 15', 'exp_sup': 470.13, 'utility': 93456}
#  455: {'name': '48, 15', 'exp_sup': 469.8, 'utility': 103145}
#  456: {'name': '66, 68', 'exp_sup': 468.37, 'utility': 109420}
#  457: {'name': '58, 23', 'exp_sup': 467.76, 'utility': 58714}
#  458: {'name': '29, 23', 'exp_sup': 467.44, 'utility': 88003}
#  459: {'name': '66, 70', 'exp_sup': 466.51, 'utility': 61306}
#  460: {'name': '3, 11', 'exp_sup': 466.5, 'utility': 92869}
#  461: {'name': '56, 15', 'exp_sup': 464.5, 'utility': 72408}
#  462: {'name': '40, 19', 'exp_sup': 464.15, 'utility': 148348}
#  463: {'name': '52, 23', 'exp_sup': 462.85, 'utility': 108098}
#  464: {'name': '48, 68', 'exp_sup': 462.5, 'utility': 138936}
#  465: {'name': '56, 50', 'exp_sup': 461.94, 'utility': 92346}
#  466: {'name': '25, 11', 'exp_sup': 461.86, 'utility': 58768}
#  467: {'name': '7, 19', 'exp_sup': 460.92, 'utility': 62187}
#  468: {'name': '36, 50', 'exp_sup': 460.77, 'utility': 61972}
#  469: {'name': '3, 15', 'exp_sup': 460.51, 'utility': 69920}
#  470: {'name': '3, 70', 'exp_sup': 459.71, 'utility': 60074}
#  471: {'name': '5, 68', 'exp_sup': 459.04, 'utility': 99567}
#  472: {'name': '17, 72', 'exp_sup': 458.35, 'utility': 90147}
#  473: {'name': '64, 23', 'exp_sup': 458.1, 'utility': 85945}
#  474: {'name': '31, 21', 'exp_sup': 457.67, 'utility': 38322}
#  475: {'name': '48, 70', 'exp_sup': 456.81, 'utility': 89878}
#  476: {'name': '34, 50', 'exp_sup': 456.37, 'utility': 113418}
#  477: {'name': '17, 11', 'exp_sup': 456.21, 'utility': 79699}
#  478: {'name': '62, 19', 'exp_sup': 456.05, 'utility': 40751}
#  479: {'name': '3, 54', 'exp_sup': 455.17, 'utility': 50081}
#  480: {'name': '9, 68', 'exp_sup': 454.28, 'utility': 87852}
#  481: {'name': '36, 19', 'exp_sup': 454.15, 'utility': 41505}
#  482: {'name': '3, 23', 'exp_sup': 453.65, 'utility': 86718}
#  483: {'name': '25, 68', 'exp_sup': 453.24, 'utility': 76818}
#  484: {'name': '9, 15', 'exp_sup': 451.24, 'utility': 48938}
#  485: {'name': '66, 50', 'exp_sup': 450.94, 'utility': 92357}
#  486: {'name': '66, 19', 'exp_sup': 450.3, 'utility': 71932}
#  487: {'name': '60, 23', 'exp_sup': 449.47, 'utility': 86861}
#  488: {'name': '64, 21', 'exp_sup': 448.37, 'utility': 47814}
#  489: {'name': '25, 15', 'exp_sup': 447.77, 'utility': 37548}
#  490: {'name': '34, 19', 'exp_sup': 447.23, 'utility': 92061}
#  491: {'name': '31, 23', 'exp_sup': 447.19, 'utility': 75415}
#  492: {'name': '40, 23', 'exp_sup': 446.6, 'utility': 156025}
#  493: {'name': '74, 38', 'exp_sup': 446.22, 'utility': 18918}
#  494: {'name': '46, 27', 'exp_sup': 445.96, 'utility': 28925}
#  495: {'name': '17, 27', 'exp_sup': 445.4, 'utility': 47508}
#  496: {'name': '5, 15', 'exp_sup': 444.97, 'utility': 58275}
#  497: {'name': '44, 27', 'exp_sup': 444.43, 'utility': 28593}
#  498: {'name': '9, 50', 'exp_sup': 443.02, 'utility': 69405}
#  499: {'name': '48, 50', 'exp_sup': 442.41, 'utility': 119180}
#  500: {'name': '38, 70', 'exp_sup': 441.9, 'utility': 29391}
#  501: {'name': '25, 70', 'exp_sup': 441.5, 'utility': 28181}
#  502: {'name': '48, 19', 'exp_sup': 441.19, 'utility': 101117}
#  503: {'name': '74, 21', 'exp_sup': 440.5, 'utility': 18577}
#  504: {'name': '46, 54', 'exp_sup': 440.28, 'utility': 19507}
#  505: {'name': '56, 19', 'exp_sup': 440.16, 'utility': 71763}
#  506: {'name': '5, 50', 'exp_sup': 439.93, 'utility': 79716}
#  507: {'name': '31, 74', 'exp_sup': 439.62, 'utility': 38002}
#  508: {'name': '46, 11', 'exp_sup': 439.59, 'utility': 56984}
#  509: {'name': '36, 23', 'exp_sup': 439.48, 'utility': 57813}
#  510: {'name': '62, 23', 'exp_sup': 439.3, 'utility': 55847}
#  511: {'name': '42, 23', 'exp_sup': 438.06, 'utility': 56084}
#  512: {'name': '64, 70', 'exp_sup': 437.31, 'utility': 55356}
#  513: {'name': '31, 38', 'exp_sup': 435.9, 'utility': 38414}
#  514: {'name': '25, 19', 'exp_sup': 434.95, 'utility': 37749}
#  515: {'name': '34, 23', 'exp_sup': 434.84, 'utility': 102806}
#  516: {'name': '42, 70', 'exp_sup': 434.81, 'utility': 28360}
#  517: {'name': '48, 23', 'exp_sup': 434.64, 'utility': 112602}
#  518: {'name': '9, 19', 'exp_sup': 434.6, 'utility': 48822}
#  519: {'name': '3, 50', 'exp_sup': 434.32, 'utility': 87753}
#  520: {'name': '44, 68', 'exp_sup': 434.29, 'utility': 73708}
#  521: {'name': '29, 13', 'exp_sup': 433.56, 'utility': 46896}
#  522: {'name': '42, 27', 'exp_sup': 433.08, 'utility': 28730}
#  523: {'name': '42, 11', 'exp_sup': 432.87, 'utility': 57194}
#  524: {'name': '64, 68', 'exp_sup': 432.85, 'utility': 97966}
#  525: {'name': '3, 68', 'exp_sup': 432.62, 'utility': 101921}
#  526: {'name': '3, 19', 'exp_sup': 432.39, 'utility': 67492}
#  527: {'name': '42, 15', 'exp_sup': 432.15, 'utility': 37290}
#  528: {'name': '5, 23', 'exp_sup': 432.09, 'utility': 73034}
#  529: {'name': '5, 19', 'exp_sup': 431.98, 'utility': 58833}
#  530: {'name': '52, 13', 'exp_sup': 431.69, 'utility': 64458}
#  531: {'name': '7, 23', 'exp_sup': 430.05, 'utility': 75742}
#  532: {'name': '44, 11', 'exp_sup': 429.84, 'utility': 56268}
#  533: {'name': '56, 23', 'exp_sup': 429.38, 'utility': 83517}
#  534: {'name': '40, 13', 'exp_sup': 429.18, 'utility': 111059}
#  535: {'name': '17, 54', 'exp_sup': 427.51, 'utility': 37098}
#  536: {'name': '42, 54', 'exp_sup': 426.86, 'utility': 18680}
#  537: {'name': '58, 13', 'exp_sup': 426.01, 'utility': 18638}
#  538: {'name': '25, 50', 'exp_sup': 425.5, 'utility': 56700}
#  539: {'name': '58, 1', 'exp_sup': 423.53, 'utility': 74378}
#  540: {'name': '42, 68', 'exp_sup': 422.91, 'utility': 72868}
#  541: {'name': '64, 54', 'exp_sup': 422.76, 'utility': 44266}
#  542: {'name': '46, 38', 'exp_sup': 422.51, 'utility': 18715}
#  543: {'name': '64, 27', 'exp_sup': 422.45, 'utility': 53546}
#  544: {'name': '44, 70', 'exp_sup': 421.35, 'utility': 27039}
#  545: {'name': '60, 1', 'exp_sup': 419.94, 'utility': 101305}
#  546: {'name': '74, 11', 'exp_sup': 419.73, 'utility': 55086}
#  547: {'name': '60, 13', 'exp_sup': 419.5, 'utility': 45586}
#  548: {'name': '74, 27', 'exp_sup': 418.79, 'utility': 27602}
#  549: {'name': '64, 11', 'exp_sup': 418.5, 'utility': 80407}
#  550: {'name': '52, 1', 'exp_sup': 418.44, 'utility': 119401}
#  551: {'name': '72, 23', 'exp_sup': 417.09, 'utility': 98356}
#  552: {'name': '31, 15', 'exp_sup': 416.51, 'utility': 52419}
#  553: {'name': '74, 68', 'exp_sup': 416.19, 'utility': 68779}
#  554: {'name': '72, 38', 'exp_sup': 415.69, 'utility': 63069}
#  555: {'name': '66, 23', 'exp_sup': 414.21, 'utility': 80194}
#  556: {'name': '9, 13', 'exp_sup': 413.42, 'utility': 26653}
#  557: {'name': '72, 21', 'exp_sup': 413.41, 'utility': 60606}
#  558: {'name': '7, 13', 'exp_sup': 412.12, 'utility': 36433}
#  559: {'name': '42, 19', 'exp_sup': 410.87, 'utility': 37484}
#  560: {'name': '31, 11', 'exp_sup': 410.63, 'utility': 71945}
#  561: {'name': '29, 1', 'exp_sup': 410.29, 'utility': 102202}
#  562: {'name': '17, 70', 'exp_sup': 409.14, 'utility': 45387}
#  563: {'name': '73', 'exp_sup': 408.83, 'utility': 8920}
#  564: {'name': '36, 13', 'exp_sup': 408.77, 'utility': 17814}
#  565: {'name': '17, 38', 'exp_sup': 408.23, 'utility': 36915}
#  566: {'name': '42, 50', 'exp_sup': 407.9, 'utility': 54183}
#  567: {'name': '40, 1', 'exp_sup': 407.89, 'utility': 162170}
#  568: {'name': '62, 13', 'exp_sup': 407.72, 'utility': 17519}
#  569: {'name': '9, 23', 'exp_sup': 407.43, 'utility': 61129}
#  570: {'name': '34, 1', 'exp_sup': 407.34, 'utility': 116728}
#  571: {'name': '46, 15', 'exp_sup': 406.55, 'utility': 34724}
#  572: {'name': '31, 27', 'exp_sup': 405.86, 'utility': 45132}
#  573: {'name': '25, 23', 'exp_sup': 404.91, 'utility': 51029}
#  574: {'name': '66, 1', 'exp_sup': 404.59, 'utility': 100195}
#  575: {'name': '7, 1', 'exp_sup': 404.53, 'utility': 90833}
#  576: {'name': '31, 70', 'exp_sup': 404.5, 'utility': 43690}
#  577: {'name': '46, 21', 'exp_sup': 403.57, 'utility': 17644}
#  578: {'name': '11, 15', 'exp_sup': 401.83, 'utility': 70972}
#  579: {'name': '52, 58, 40', 'exp_sup': 401.39, 'utility': 306482}
#  580: {'name': '56, 13', 'exp_sup': 400.59, 'utility': 44164}
#  581: {'name': '34, 13', 'exp_sup': 400.58, 'utility': 61896}
#  582: {'name': '48, 1', 'exp_sup': 400.36, 'utility': 123739}
#  583: {'name': '74, 70', 'exp_sup': 399.49, 'utility': 25654}
#  584: {'name': '52, 29, 58', 'exp_sup': 399.36, 'utility': 189208}
#  585: {'name': '62, 1', 'exp_sup': 398.67, 'utility': 70664}
#  586: {'name': '52, 58, 60', 'exp_sup': 398.56, 'utility': 186894}
#  587: {'name': '52, 29, 40', 'exp_sup': 398.51, 'utility': 356097}
#  588: {'name': '56, 1', 'exp_sup': 398.08, 'utility': 99138}
#  589: {'name': '74, 72', 'exp_sup': 397.49, 'utility': 60250}
#  590: {'name': '5, 13', 'exp_sup': 396.92, 'utility': 33913}
#  591: {'name': '36, 1', 'exp_sup': 396.53, 'utility': 71813}
#  592: {'name': '64, 50', 'exp_sup': 395.02, 'utility': 80137}
#  593: {'name': '29, 58, 40', 'exp_sup': 394.99, 'utility': 271369}
#  594: {'name': '46, 68', 'exp_sup': 394.91, 'utility': 67387}
#  595: {'name': '52, 29, 60', 'exp_sup': 394.42, 'utility': 237130}
#  596: {'name': '48, 13', 'exp_sup': 394.39, 'utility': 69181}
#  597: {'name': '52, 40, 60', 'exp_sup': 394.11, 'utility': 352926}
#  598: {'name': '21, 27', 'exp_sup': 393.92, 'utility': 25972}
#  599: {'name': '21, 54', 'exp_sup': 392.63, 'utility': 16625}
#  600: {'name': '52, 29, 62', 'exp_sup': 391.99, 'utility': 181017}
#  601: {'name': '17, 68', 'exp_sup': 391.81, 'utility': 85384}
#  602: {'name': '52, 58, 62', 'exp_sup': 391.73, 'utility': 131741}
#  603: {'name': '27, 11', 'exp_sup': 391.33, 'utility': 59310}
#  604: {'name': '52, 40, 62', 'exp_sup': 391.2, 'utility': 294543}
#  605: {'name': '46, 70', 'exp_sup': 390.87, 'utility': 24590}
#  606: {'name': '52, 60, 62', 'exp_sup': 390.72, 'utility': 178783}
#  607: {'name': '5, 1', 'exp_sup': 390.1, 'utility': 85018}
#  608: {'name': '29, 58, 60', 'exp_sup': 389.81, 'utility': 153216}
#  609: {'name': '75', 'exp_sup': 389.53, 'utility': 12837}
#  610: {'name': '52, 58, 56', 'exp_sup': 389.51, 'utility': 180271}
#  611: {'name': '64, 19', 'exp_sup': 388.61, 'utility': 60535}
#  612: {'name': '58, 40, 60', 'exp_sup': 388.41, 'utility': 269050}
#  613: {'name': '44, 50', 'exp_sup': 387.07, 'utility': 52558}
#  614: {'name': '29, 40, 62', 'exp_sup': 385.97, 'utility': 261394}
#  615: {'name': '52, 29, 56', 'exp_sup': 385.86, 'utility': 228802}
#  616: {'name': '44, 2', 'exp_sup': 385.8, 'utility': 32777}
#  617: {'name': '52, 14', 'exp_sup': 385.09, 'utility': 56764}
#  618: {'name': '44, 15', 'exp_sup': 384.86, 'utility': 32270}
#  619: {'name': '54, 38', 'exp_sup': 384.71, 'utility': 16711}
#  620: {'name': '29, 40, 60', 'exp_sup': 384.66, 'utility': 318464}
#  621: {'name': '29, 58, 62', 'exp_sup': 384.62, 'utility': 99574}
#  622: {'name': '29, 58, 36', 'exp_sup': 384.49, 'utility': 100706}
#  623: {'name': '54, 27', 'exp_sup': 384.29, 'utility': 25849}
#  624: {'name': '52, 58, 7', 'exp_sup': 383.86, 'utility': 166437}
#  625: {'name': '58, 40, 36', 'exp_sup': 383.8, 'utility': 214341}
#  626: {'name': '64, 15', 'exp_sup': 383.58, 'utility': 58071}
#  627: {'name': '52, 29, 7', 'exp_sup': 383.56, 'utility': 216491}
#  628: {'name': '31, 54', 'exp_sup': 383.52, 'utility': 33383}
#  629: {'name': '58, 60, 62', 'exp_sup': 383.2, 'utility': 98229}
#  630: {'name': '52, 40, 7', 'exp_sup': 383.08, 'utility': 328740}
#  631: {'name': '58, 40, 62', 'exp_sup': 383.06, 'utility': 212854}
#  632: {'name': '52, 60, 56', 'exp_sup': 382.78, 'utility': 225700}
#  633: {'name': '29, 60, 62', 'exp_sup': 382.69, 'utility': 147078}
#  634: {'name': '52, 60, 66', 'exp_sup': 382.65, 'utility': 228982}
#  635: {'name': '29, 2', 'exp_sup': 382.45, 'utility': 56992}
#  636: {'name': '9, 1', 'exp_sup': 382.38, 'utility': 75132}
#  637: {'name': '52, 58, 48', 'exp_sup': 382.36, 'utility': 228022}
#  638: {'name': '52, 40, 36', 'exp_sup': 382.28, 'utility': 296932}
#  639: {'name': '52, 60, 7', 'exp_sup': 382.28, 'utility': 212686}
#  640: {'name': '3, 13', 'exp_sup': 382.28, 'utility': 40981}
#  641: {'name': '31, 19', 'exp_sup': 382.25, 'utility': 51636}
#  642: {'name': '52, 40, 56', 'exp_sup': 382.07, 'utility': 339206}
#  643: {'name': '72, 27', 'exp_sup': 381.75, 'utility': 65880}
#  644: {'name': '31, 50', 'exp_sup': 381.48, 'utility': 69167}
#  645: {'name': '52, 58, 36', 'exp_sup': 381.39, 'utility': 133745}
#  646: {'name': '25, 1', 'exp_sup': 381.32, 'utility': 65630}
#  647: {'name': '29, 40, 7', 'exp_sup': 381.05, 'utility': 296027}
#  648: {'name': '44, 19', 'exp_sup': 380.96, 'utility': 33878}
#  649: {'name': '52, 60, 48', 'exp_sup': 380.75, 'utility': 274296}
#  650: {'name': '29, 40, 36', 'exp_sup': 380.42, 'utility': 262915}
#  651: {'name': '58, 14', 'exp_sup': 379.88, 'utility': 16202}
#  652: {'name': '52, 29, 66', 'exp_sup': 379.66, 'utility': 228708}
#  653: {'name': '66, 14', 'exp_sup': 379.64, 'utility': 40392}
#  654: {'name': '58, 40, 7', 'exp_sup': 379.34, 'utility': 246553}
#  655: {'name': '29, 14', 'exp_sup': 379.08, 'utility': 40258}
#  656: {'name': '29, 58, 56', 'exp_sup': 378.92, 'utility': 147661}
#  657: {'name': '29, 58, 7', 'exp_sup': 378.91, 'utility': 133951}
#  658: {'name': '72, 15', 'exp_sup': 378.69, 'utility': 74307}
#  659: {'name': '54, 11', 'exp_sup': 378.55, 'utility': 51498}
#  660: {'name': '52, 40, 48', 'exp_sup': 378.53, 'utility': 385381}
#  661: {'name': '52, 2', 'exp_sup': 378.36, 'utility': 74265}
#  662: {'name': '58, 60, 36', 'exp_sup': 378.01, 'utility': 99248}
#  663: {'name': '40, 60, 62', 'exp_sup': 377.86, 'utility': 259047}
#  664: {'name': '72, 68', 'exp_sup': 377.79, 'utility': 103308}
#  665: {'name': '52, 58, 66', 'exp_sup': 377.53, 'utility': 180201}
#  666: {'name': '58, 60, 66', 'exp_sup': 377.49, 'utility': 147841}
#  667: {'name': '52, 60, 36', 'exp_sup': 377.32, 'utility': 181047}
#  668: {'name': '46, 50', 'exp_sup': 377.25, 'utility': 50337}
#  669: {'name': '29, 60, 7', 'exp_sup': 376.87, 'utility': 180819}
#  670: {'name': '52, 29, 36', 'exp_sup': 376.83, 'utility': 183387}
#  671: {'name': '52, 29, 48', 'exp_sup': 375.92, 'utility': 275331}
#  672: {'name': '58, 2', 'exp_sup': 375.7, 'utility': 32799}
#  673: {'name': '58, 60, 7', 'exp_sup': 375.55, 'utility': 131327}
#  674: {'name': '52, 29, 5', 'exp_sup': 375.38, 'utility': 207390}
#  675: {'name': '58, 40, 56', 'exp_sup': 375.29, 'utility': 257871}
#  676: {'name': '52, 58, 5', 'exp_sup': 375.18, 'utility': 159640}
#  677: {'name': '21, 68', 'exp_sup': 375.15, 'utility': 63833}
#  678: {'name': '58, 60, 48', 'exp_sup': 374.97, 'utility': 194450}
#  679: {'name': '29, 60, 36', 'exp_sup': 374.96, 'utility': 148457}
#  680: {'name': '66, 13', 'exp_sup': 374.95, 'utility': 42498}
#  681: {'name': '40, 2', 'exp_sup': 374.68, 'utility': 114946}
#  682: {'name': '52, 62, 56', 'exp_sup': 374.6, 'utility': 173982}
#  683: {'name': '54, 68', 'exp_sup': 374.42, 'utility': 63202}
#  684: {'name': '40, 14', 'exp_sup': 374.29, 'utility': 94272}
#  685: {'name': '52, 40, 34', 'exp_sup': 373.87, 'utility': 373506}
#  686: {'name': '21, 1', 'exp_sup': 373.7, 'utility': 64208}
#  687: {'name': '25, 13', 'exp_sup': 373.67, 'utility': 16045}
#  688: {'name': '52, 40, 66', 'exp_sup': 373.61, 'utility': 339395}
#  689: {'name': '72, 70', 'exp_sup': 373.38, 'utility': 65056}
#  690: {'name': '3, 1', 'exp_sup': 373.24, 'utility': 89646}
#  691: {'name': '62, 2', 'exp_sup': 373.18, 'utility': 31744}
#  692: {'name': '29, 40, 56', 'exp_sup': 373.12, 'utility': 305344}
#  693: {'name': '52, 60, 5', 'exp_sup': 373.09, 'utility': 204434}
#  694: {'name': '58, 40, 48', 'exp_sup': 372.95, 'utility': 305339}
#  695: {'name': '40, 60, 7', 'exp_sup': 372.95, 'utility': 292006}
#  696: {'name': '29, 58, 48', 'exp_sup': 372.15, 'utility': 195266}
#  697: {'name': '58, 60, 56', 'exp_sup': 371.94, 'utility': 145465}
#  698: {'name': '29, 62, 36', 'exp_sup': 371.68, 'utility': 96365}
#  699: {'name': '29, 60, 66', 'exp_sup': 371.66, 'utility': 196620}
#  700: {'name': '44, 23', 'exp_sup': 371.37, 'utility': 46146}

# %%
# chạy với chess
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_chess.txt, ./data/chess_utility.txt", 0.001, 900)
algorithm.print_stats("./out/TUHUFP/chess/output_chess_top_900.txt")
# Out:
# Reading data . . .
# Minimum utility set to: 2156
# {'database util: ': 2156659}
# Top 900 CUPs:
#  1: {'name': '52', 'exp_sup': 1616.54, 'utility': 104178}
#  2: {'name': '29', 'exp_sup': 1598.92, 'utility': 70088}
#  3: {'name': '58', 'exp_sup': 1595.58, 'utility': 17462}
#  4: {'name': '40', 'exp_sup': 1579.27, 'utility': 188760}
#  5: {'name': '60', 'exp_sup': 1565.64, 'utility': 68908}
#  6: {'name': '62', 'exp_sup': 1537.33, 'utility': 16784}
#  7: {'name': '7', 'exp_sup': 1535.24, 'utility': 50790}
#  8: {'name': '36', 'exp_sup': 1530.49, 'utility': 16934}
#  9: {'name': '56', 'exp_sup': 1513.93, 'utility': 66780}
#  10: {'name': '48', 'exp_sup': 1500.86, 'utility': 115367}
#  11: {'name': '66', 'exp_sup': 1498.92, 'utility': 66644}
#  12: {'name': '34', 'exp_sup': 1493.64, 'utility': 99330}
#  13: {'name': '5', 'exp_sup': 1466.73, 'utility': 48369}
#  14: {'name': '9', 'exp_sup': 1446.46, 'utility': 31818}
#  15: {'name': '25', 'exp_sup': 1445.46, 'utility': 15465}
#  16: {'name': '3', 'exp_sup': 1407.44, 'utility': 61608}
#  17: {'name': '42', 'exp_sup': 1355.91, 'utility': 14849}
#  18: {'name': '64', 'exp_sup': 1337.59, 'utility': 56768}
#  19: {'name': '44', 'exp_sup': 1325.93, 'utility': 14261}
#  20: {'name': '46', 'exp_sup': 1284.58, 'utility': 14045}
#  21: {'name': '31', 'exp_sup': 1274.29, 'utility': 41649}
#  22: {'name': '17', 'exp_sup': 1251.12, 'utility': 40662}
#  23: {'name': '74', 'exp_sup': 1237.31, 'utility': 13298}
#  24: {'name': '72', 'exp_sup': 1177.8, 'utility': 77802}
#  25: {'name': '21', 'exp_sup': 1128.59, 'utility': 12263}
#  26: {'name': '54', 'exp_sup': 1105.31, 'utility': 11965}
#  27: {'name': '38', 'exp_sup': 1101.41, 'utility': 12130}
#  28: {'name': '27', 'exp_sup': 1098.98, 'utility': 24398}
#  29: {'name': '11', 'exp_sup': 1066.24, 'utility': 58730}
#  30: {'name': '15', 'exp_sup': 1008.29, 'utility': 32700}
#  31: {'name': '70', 'exp_sup': 1005.64, 'utility': 21824}
#  32: {'name': '68', 'exp_sup': 1003.26, 'utility': 75341}
#  33: {'name': '50', 'exp_sup': 965.12, 'utility': 54140}
#  34: {'name': '19', 'exp_sup': 958.74, 'utility': 32565}
#  35: {'name': '23', 'exp_sup': 919.58, 'utility': 48960}
#  36: {'name': '13', 'exp_sup': 860.84, 'utility': 9269}
#  37: {'name': '1', 'exp_sup': 832.29, 'utility': 65471}
#  38: {'name': '52, 58', 'exp_sup': 806.57, 'utility': 121139}
#  39: {'name': '52, 29', 'exp_sup': 802.29, 'utility': 172766}
#  40: {'name': '52, 40', 'exp_sup': 800.33, 'utility': 290726}
#  41: {'name': '52, 60', 'exp_sup': 797.15, 'utility': 170582}
#  42: {'name': '29, 58', 'exp_sup': 794.58, 'utility': 87031}
#  43: {'name': '29, 40', 'exp_sup': 792.51, 'utility': 255631}
#  44: {'name': '58, 40', 'exp_sup': 790.04, 'utility': 205017}
#  45: {'name': '58, 60', 'exp_sup': 784.78, 'utility': 85721}
#  46: {'name': '52, 62', 'exp_sup': 781.35, 'utility': 115661}
#  47: {'name': '29, 60', 'exp_sup': 777.6, 'utility': 136920}
#  48: {'name': '52, 56', 'exp_sup': 776.21, 'utility': 164720}
#  49: {'name': '52, 7', 'exp_sup': 774.06, 'utility': 150447}
#  50: {'name': '40, 60', 'exp_sup': 773.52, 'utility': 253428}
#  51: {'name': '29, 62', 'exp_sup': 772.37, 'utility': 83526}
#  52: {'name': '58, 62', 'exp_sup': 769.84, 'utility': 33329}
#  53: {'name': '58, 36', 'exp_sup': 767.98, 'utility': 33744}
#  54: {'name': '29, 7', 'exp_sup': 767.86, 'utility': 117944}
#  55: {'name': '29, 36', 'exp_sup': 765.95, 'utility': 84385}
#  56: {'name': '58, 7', 'exp_sup': 765.83, 'utility': 67239}
#  57: {'name': '52, 36', 'exp_sup': 764.38, 'utility': 117430}
#  58: {'name': '40, 62', 'exp_sup': 764.28, 'utility': 197416}
#  59: {'name': '60, 62', 'exp_sup': 762.34, 'utility': 82302}
#  60: {'name': '52, 48', 'exp_sup': 761.78, 'utility': 212460}
#  61: {'name': '40, 36', 'exp_sup': 761.32, 'utility': 198648}
#  62: {'name': '58, 56', 'exp_sup': 759.72, 'utility': 82803}
#  63: {'name': '52, 66', 'exp_sup': 759.17, 'utility': 164458}
#  64: {'name': '40, 7', 'exp_sup': 758.2, 'utility': 231271}
#  65: {'name': '2', 'exp_sup': 757.95, 'utility': 24618}
#  66: {'name': '29, 56', 'exp_sup': 757.1, 'utility': 132152}
#  67: {'name': '14', 'exp_sup': 755.4, 'utility': 8252}
#  68: {'name': '58, 48', 'exp_sup': 753.39, 'utility': 131386}
#  69: {'name': '60, 7', 'exp_sup': 752.4, 'utility': 115497}
#  70: {'name': '52, 34', 'exp_sup': 750.57, 'utility': 197472}
#  71: {'name': '60, 36', 'exp_sup': 750.51, 'utility': 83055}
#  72: {'name': '60, 66', 'exp_sup': 748.87, 'utility': 132064}
#  73: {'name': '29, 34', 'exp_sup': 748.84, 'utility': 165212}
#  74: {'name': '29, 66', 'exp_sup': 748.18, 'utility': 132172}
#  75: {'name': '58, 66', 'exp_sup': 747.26, 'utility': 82834}
#  76: {'name': '40, 56', 'exp_sup': 746.88, 'utility': 243050}
#  77: {'name': '52, 5', 'exp_sup': 745.02, 'utility': 144276}
#  78: {'name': '29, 48', 'exp_sup': 744.94, 'utility': 179722}
#  79: {'name': '40, 48', 'exp_sup': 741.87, 'utility': 290391}
#  80: {'name': '60, 48', 'exp_sup': 741.31, 'utility': 178947}
#  81: {'name': '29, 5', 'exp_sup': 739.46, 'utility': 112623}
#  82: {'name': '60, 56', 'exp_sup': 739.43, 'utility': 130088}
#  83: {'name': '40, 34', 'exp_sup': 737.74, 'utility': 277239}
#  84: {'name': '7, 36', 'exp_sup': 736.85, 'utility': 65158}
#  85: {'name': '58, 5', 'exp_sup': 736.2, 'utility': 64234}
#  86: {'name': '62, 36', 'exp_sup': 735.64, 'utility': 32252}
#  87: {'name': '40, 66', 'exp_sup': 734.99, 'utility': 243649}
#  88: {'name': '58, 34', 'exp_sup': 734.32, 'utility': 115440}
#  89: {'name': '29, 25', 'exp_sup': 733.79, 'utility': 77685}
#  90: {'name': '60, 34', 'exp_sup': 732.14, 'utility': 162688}
#  91: {'name': '7, 34', 'exp_sup': 731.86, 'utility': 143691}
#  92: {'name': '52, 25', 'exp_sup': 731.26, 'utility': 107984}
#  93: {'name': '62, 7', 'exp_sup': 731.07, 'utility': 64443}
#  94: {'name': '62, 56', 'exp_sup': 730.52, 'utility': 79966}
#  95: {'name': '36, 48', 'exp_sup': 729.26, 'utility': 129898}
#  96: {'name': '52, 9', 'exp_sup': 728.24, 'utility': 124558}
#  97: {'name': '36, 56', 'exp_sup': 727.83, 'utility': 80092}
#  98: {'name': '7, 66', 'exp_sup': 727.27, 'utility': 111671}
#  99: {'name': '60, 5', 'exp_sup': 725.51, 'utility': 110905}
#  100: {'name': '62, 66', 'exp_sup': 725.14, 'utility': 79147}
#  101: {'name': '7, 56', 'exp_sup': 721.02, 'utility': 112322}
#  102: {'name': '58, 9', 'exp_sup': 720.18, 'utility': 47296}
#  103: {'name': '29, 9', 'exp_sup': 720.07, 'utility': 94064}
#  104: {'name': '7, 48', 'exp_sup': 719.89, 'utility': 158110}
#  105: {'name': '52, 3', 'exp_sup': 718.73, 'utility': 153244}
#  106: {'name': '40, 5', 'exp_sup': 718.05, 'utility': 223282}
#  107: {'name': '36, 34', 'exp_sup': 716.91, 'utility': 111964}
#  108: {'name': '58, 25', 'exp_sup': 716.42, 'utility': 30961}
#  109: {'name': '60, 25', 'exp_sup': 715.42, 'utility': 77075}
#  110: {'name': '62, 48', 'exp_sup': 715.39, 'utility': 125379}
#  111: {'name': '62, 34', 'exp_sup': 714.96, 'utility': 110832}
#  112: {'name': '7, 5', 'exp_sup': 713.08, 'utility': 93495}
#  113: {'name': '40, 25', 'exp_sup': 712.24, 'utility': 183618}
#  114: {'name': '36, 66', 'exp_sup': 709.93, 'utility': 80135}
#  115: {'name': '56, 66', 'exp_sup': 708.94, 'utility': 125068}
#  116: {'name': '62, 5', 'exp_sup': 708.88, 'utility': 61882}
#  117: {'name': '29, 3', 'exp_sup': 708.45, 'utility': 123288}
#  118: {'name': '36, 5', 'exp_sup': 707.41, 'utility': 62205}
#  119: {'name': '48, 66', 'exp_sup': 706.37, 'utility': 172697}
#  120: {'name': '58, 3', 'exp_sup': 706.12, 'utility': 76772}
#  121: {'name': '40, 9', 'exp_sup': 704.32, 'utility': 200832}
#  122: {'name': '56, 34', 'exp_sup': 703.99, 'utility': 156636}
#  123: {'name': '66, 5', 'exp_sup': 703.33, 'utility': 108091}
#  124: {'name': '60, 9', 'exp_sup': 702.33, 'utility': 92804}
#  125: {'name': '56, 48', 'exp_sup': 700.91, 'utility': 169695}
#  126: {'name': '66, 34', 'exp_sup': 699.99, 'utility': 157508}
#  127: {'name': '36, 25', 'exp_sup': 699.95, 'utility': 30388}
#  128: {'name': '48, 34', 'exp_sup': 699.74, 'utility': 201383}
#  129: {'name': '62, 25', 'exp_sup': 697.0, 'utility': 29738}
#  130: {'name': '34, 5', 'exp_sup': 695.45, 'utility': 140856}
#  131: {'name': '40, 3', 'exp_sup': 693.84, 'utility': 226522}
#  132: {'name': '62, 9', 'exp_sup': 692.12, 'utility': 45217}
#  133: {'name': '48, 25', 'exp_sup': 690.07, 'utility': 119915}
#  134: {'name': '7, 25', 'exp_sup': 689.09, 'utility': 59938}
#  135: {'name': '56, 5', 'exp_sup': 689.09, 'utility': 106663}
#  136: {'name': '60, 3', 'exp_sup': 688.27, 'utility': 121992}
#  137: {'name': '56, 9', 'exp_sup': 688.26, 'utility': 91078}
#  138: {'name': '52, 42', 'exp_sup': 688.23, 'utility': 102622}
#  139: {'name': '7, 9', 'exp_sup': 687.7, 'utility': 75723}
#  140: {'name': '48, 5', 'exp_sup': 684.69, 'utility': 151382}
#  141: {'name': '52, 64', 'exp_sup': 684.06, 'utility': 141962}
#  142: {'name': '36, 9', 'exp_sup': 683.24, 'utility': 45683}
#  143: {'name': '58, 42', 'exp_sup': 682.92, 'utility': 29567}
#  144: {'name': '56, 25', 'exp_sup': 682.7, 'utility': 73534}
#  145: {'name': '34, 9', 'exp_sup': 682.1, 'utility': 119678}
#  146: {'name': '48, 9', 'exp_sup': 681.86, 'utility': 131587}
#  147: {'name': '66, 25', 'exp_sup': 681.41, 'utility': 74411}
#  148: {'name': '29, 42', 'exp_sup': 680.22, 'utility': 73789}
#  149: {'name': '36, 3', 'exp_sup': 679.53, 'utility': 74325}
#  150: {'name': '60, 42', 'exp_sup': 676.51, 'utility': 73376}
#  151: {'name': '7, 3', 'exp_sup': 676.28, 'utility': 105239}
#  152: {'name': '34, 25', 'exp_sup': 676.03, 'utility': 103024}
#  153: {'name': '62, 3', 'exp_sup': 675.43, 'utility': 73985}
#  154: {'name': '56, 3', 'exp_sup': 674.81, 'utility': 118028}
#  155: {'name': '24', 'exp_sup': 673.83, 'utility': 14996}
#  156: {'name': '40, 64', 'exp_sup': 671.11, 'utility': 212460}
#  157: {'name': '40, 42', 'exp_sup': 670.8, 'utility': 174811}
#  158: {'name': '66, 9', 'exp_sup': 670.36, 'utility': 89714}
#  159: {'name': '52, 44', 'exp_sup': 667.7, 'utility': 98857}
#  160: {'name': '5, 9', 'exp_sup': 665.83, 'utility': 72391}
#  161: {'name': '66, 3', 'exp_sup': 662.17, 'utility': 117072}
#  162: {'name': '29, 64', 'exp_sup': 661.85, 'utility': 113308}
#  163: {'name': '29, 44', 'exp_sup': 660.91, 'utility': 70749}
#  164: {'name': '34, 3', 'exp_sup': 660.29, 'utility': 146622}
#  165: {'name': '5, 3', 'exp_sup': 659.41, 'utility': 99860}
#  166: {'name': '60, 64', 'exp_sup': 659.26, 'utility': 112012}
#  167: {'name': '58, 44', 'exp_sup': 658.05, 'utility': 28302}
#  168: {'name': '58, 64', 'exp_sup': 657.97, 'utility': 70620}
#  169: {'name': '5, 25', 'exp_sup': 656.29, 'utility': 57086}
#  170: {'name': '48, 3', 'exp_sup': 653.87, 'utility': 160071}
#  171: {'name': '60, 44', 'exp_sup': 652.46, 'utility': 69435}
#  172: {'name': '40, 44', 'exp_sup': 652.34, 'utility': 167125}
#  173: {'name': '66, 42', 'exp_sup': 652.23, 'utility': 71539}
#  174: {'name': '52, 46', 'exp_sup': 650.66, 'utility': 96676}
#  175: {'name': '48, 42', 'exp_sup': 650.48, 'utility': 111887}
#  176: {'name': '62, 42', 'exp_sup': 650.04, 'utility': 28297}
#  177: {'name': '36, 42', 'exp_sup': 649.16, 'utility': 28659}
#  178: {'name': '7, 42', 'exp_sup': 648.95, 'utility': 56926}
#  179: {'name': '9, 25', 'exp_sup': 647.8, 'utility': 41598}
#  180: {'name': '56, 42', 'exp_sup': 643.85, 'utility': 70665}
#  181: {'name': '62, 44', 'exp_sup': 643.15, 'utility': 27376}
#  182: {'name': '29, 46', 'exp_sup': 642.56, 'utility': 69514}
#  183: {'name': '62, 64', 'exp_sup': 641.93, 'utility': 68111}
#  184: {'name': '52, 31', 'exp_sup': 641.53, 'utility': 123555}
#  185: {'name': '36, 64', 'exp_sup': 641.43, 'utility': 68775}
#  186: {'name': '9, 3', 'exp_sup': 640.82, 'utility': 83696}
#  187: {'name': '34, 42', 'exp_sup': 639.83, 'utility': 99078}
#  188: {'name': '58, 46', 'exp_sup': 638.37, 'utility': 27774}
#  189: {'name': '48, 64', 'exp_sup': 636.88, 'utility': 148284}
#  190: {'name': '7, 44', 'exp_sup': 636.1, 'utility': 54652}
#  191: {'name': '36, 44', 'exp_sup': 636.1, 'utility': 27450}
#  192: {'name': '60, 31', 'exp_sup': 636.0, 'utility': 96146}
#  193: {'name': '29, 31', 'exp_sup': 635.75, 'utility': 95917}
#  194: {'name': '7, 64', 'exp_sup': 635.34, 'utility': 95825}
#  195: {'name': '56, 64', 'exp_sup': 634.6, 'utility': 108348}
#  196: {'name': '40, 46', 'exp_sup': 631.52, 'utility': 163761}
#  197: {'name': '5, 64', 'exp_sup': 630.61, 'utility': 93701}
#  198: {'name': '60, 46', 'exp_sup': 630.42, 'utility': 68407}
#  199: {'name': '58, 31', 'exp_sup': 630.18, 'utility': 55149}
#  200: {'name': '40, 31', 'exp_sup': 630.06, 'utility': 190050}
#  201: {'name': '66, 64', 'exp_sup': 630.04, 'utility': 108260}
#  202: {'name': '52, 17', 'exp_sup': 629.95, 'utility': 120894}
#  203: {'name': '29, 17', 'exp_sup': 628.98, 'utility': 94380}
#  204: {'name': '56, 44', 'exp_sup': 628.92, 'utility': 67713}
#  205: {'name': '48, 44', 'exp_sup': 628.53, 'utility': 106483}
#  206: {'name': '42, 64', 'exp_sup': 628.12, 'utility': 66152}
#  207: {'name': '34, 64', 'exp_sup': 628.05, 'utility': 136476}
#  208: {'name': '52, 74', 'exp_sup': 624.53, 'utility': 91129}
#  209: {'name': '25, 3', 'exp_sup': 623.94, 'utility': 67954}
#  210: {'name': '58, 17', 'exp_sup': 622.77, 'utility': 54101}
#  211: {'name': '40, 74', 'exp_sup': 621.61, 'utility': 155667}
#  212: {'name': '62, 46', 'exp_sup': 621.29, 'utility': 26646}
#  213: {'name': '5, 44', 'exp_sup': 620.76, 'utility': 53341}
#  214: {'name': '40, 17', 'exp_sup': 618.04, 'utility': 186881}
#  215: {'name': '58, 74', 'exp_sup': 617.98, 'utility': 26237}
#  216: {'name': '36, 46', 'exp_sup': 617.5, 'utility': 26984}
#  217: {'name': '7, 46', 'exp_sup': 616.25, 'utility': 53348}
#  218: {'name': '66, 31', 'exp_sup': 615.35, 'utility': 92680}
#  219: {'name': '29, 74', 'exp_sup': 613.71, 'utility': 65434}
#  220: {'name': '34, 44', 'exp_sup': 613.63, 'utility': 94149}
#  221: {'name': '69', 'exp_sup': 612.53, 'utility': 53240}
#  222: {'name': '5, 42', 'exp_sup': 612.15, 'utility': 55630}
#  223: {'name': '52, 72', 'exp_sup': 611.88, 'utility': 154086}
#  224: {'name': '25, 42', 'exp_sup': 611.6, 'utility': 26177}
#  225: {'name': '36, 31', 'exp_sup': 611.47, 'utility': 53422}
#  226: {'name': '7, 31', 'exp_sup': 609.45, 'utility': 80313}
#  227: {'name': '66, 44', 'exp_sup': 609.19, 'utility': 66997}
#  228: {'name': '66, 46', 'exp_sup': 608.12, 'utility': 66721}
#  229: {'name': '60, 17', 'exp_sup': 606.34, 'utility': 93374}
#  230: {'name': '9, 42', 'exp_sup': 605.77, 'utility': 40290}
#  231: {'name': '56, 46', 'exp_sup': 604.82, 'utility': 66085}
#  232: {'name': '3, 42', 'exp_sup': 604.76, 'utility': 65633}
#  233: {'name': '25, 44', 'exp_sup': 604.42, 'utility': 25613}
#  234: {'name': '71', 'exp_sup': 603.72, 'utility': 25236}
#  235: {'name': '51', 'exp_sup': 603.41, 'utility': 13402}
#  236: {'name': '9, 44', 'exp_sup': 603.07, 'utility': 38704}
#  237: {'name': '20', 'exp_sup': 602.48, 'utility': 6792}
#  238: {'name': '62, 31', 'exp_sup': 602.29, 'utility': 52712}
#  239: {'name': '25, 64', 'exp_sup': 601.92, 'utility': 62889}
#  240: {'name': '5, 31', 'exp_sup': 601.28, 'utility': 77079}
#  241: {'name': '3, 64', 'exp_sup': 600.44, 'utility': 101888}
#  242: {'name': '56, 74', 'exp_sup': 599.4, 'utility': 64482}
#  243: {'name': '62, 74', 'exp_sup': 598.58, 'utility': 25672}
#  244: {'name': '7, 17', 'exp_sup': 598.52, 'utility': 78828}
#  245: {'name': '48, 46', 'exp_sup': 597.25, 'utility': 104640}
#  246: {'name': '34, 46', 'exp_sup': 596.46, 'utility': 92120}
#  247: {'name': '9, 64', 'exp_sup': 594.91, 'utility': 76712}
#  248: {'name': '34, 31', 'exp_sup': 593.91, 'utility': 117591}
#  249: {'name': '56, 17', 'exp_sup': 593.84, 'utility': 90871}
#  250: {'name': '62, 17', 'exp_sup': 593.59, 'utility': 51403}
#  251: {'name': '36, 74', 'exp_sup': 593.11, 'utility': 25246}
#  252: {'name': '56, 31', 'exp_sup': 593.05, 'utility': 91111}
#  253: {'name': '16', 'exp_sup': 592.57, 'utility': 18978}
#  254: {'name': '7, 74', 'exp_sup': 590.57, 'utility': 50739}
#  255: {'name': '60, 74', 'exp_sup': 590.1, 'utility': 64078}
#  256: {'name': '48, 17', 'exp_sup': 589.75, 'utility': 127394}
#  257: {'name': '60, 72', 'exp_sup': 589.49, 'utility': 129080}
#  258: {'name': '5, 46', 'exp_sup': 588.84, 'utility': 51865}
#  259: {'name': '48, 74', 'exp_sup': 588.19, 'utility': 96589}
#  260: {'name': '58, 72', 'exp_sup': 587.43, 'utility': 90250}
#  261: {'name': '48, 31', 'exp_sup': 587.31, 'utility': 128218}
#  262: {'name': '66, 17', 'exp_sup': 586.04, 'utility': 89435}
#  263: {'name': '29, 72', 'exp_sup': 585.77, 'utility': 128596}
#  264: {'name': '34, 74', 'exp_sup': 584.6, 'utility': 86946}
#  265: {'name': '3, 31', 'exp_sup': 584.39, 'utility': 89594}
#  266: {'name': '36, 17', 'exp_sup': 584.25, 'utility': 52175}
#  267: {'name': '34, 17', 'exp_sup': 583.64, 'utility': 115869}
#  268: {'name': '66, 72', 'exp_sup': 583.0, 'utility': 128876}
#  269: {'name': '40, 72', 'exp_sup': 582.56, 'utility': 214715}
#  270: {'name': '25, 46', 'exp_sup': 582.0, 'utility': 24911}
#  271: {'name': '42, 31', 'exp_sup': 576.46, 'utility': 49457}
#  272: {'name': '9, 31', 'exp_sup': 576.09, 'utility': 62063}
#  273: {'name': '9, 74', 'exp_sup': 573.91, 'utility': 36189}
#  274: {'name': '9, 17', 'exp_sup': 573.65, 'utility': 62169}
#  275: {'name': '9, 46', 'exp_sup': 572.93, 'utility': 37634}
#  276: {'name': '42, 44', 'exp_sup': 572.47, 'utility': 24538}
#  277: {'name': '3, 44', 'exp_sup': 572.11, 'utility': 60943}
#  278: {'name': '66, 74', 'exp_sup': 571.5, 'utility': 60991}
#  279: {'name': '64, 44', 'exp_sup': 571.09, 'utility': 59379}
#  280: {'name': '62, 72', 'exp_sup': 568.8, 'utility': 86521}
#  281: {'name': '7, 72', 'exp_sup': 567.94, 'utility': 111501}
#  282: {'name': '36, 72', 'exp_sup': 567.77, 'utility': 86942}
#  283: {'name': '25, 31', 'exp_sup': 566.32, 'utility': 48756}
#  284: {'name': '29, 21', 'exp_sup': 565.61, 'utility': 60591}
#  285: {'name': '52, 21', 'exp_sup': 565.54, 'utility': 84050}
#  286: {'name': '5, 74', 'exp_sup': 563.51, 'utility': 48294}
#  287: {'name': '3, 17', 'exp_sup': 562.07, 'utility': 85238}
#  288: {'name': '3, 46', 'exp_sup': 561.56, 'utility': 61011}
#  289: {'name': '25, 74', 'exp_sup': 561.49, 'utility': 23488}
#  290: {'name': '5, 17', 'exp_sup': 561.22, 'utility': 73545}
#  291: {'name': '34, 72', 'exp_sup': 560.36, 'utility': 148908}
#  292: {'name': '52, 38', 'exp_sup': 559.97, 'utility': 83539}
#  293: {'name': '25, 17', 'exp_sup': 559.2, 'utility': 47079}
#  294: {'name': '29, 54', 'exp_sup': 559.15, 'utility': 60167}
#  295: {'name': '58, 38', 'exp_sup': 559.14, 'utility': 24011}
#  296: {'name': '48, 72', 'exp_sup': 558.53, 'utility': 158007}
#  297: {'name': '52, 54', 'exp_sup': 556.59, 'utility': 83439}
#  298: {'name': '58, 21', 'exp_sup': 556.21, 'utility': 24285}
#  299: {'name': '42, 46', 'exp_sup': 556.1, 'utility': 24096}
#  300: {'name': '64, 31', 'exp_sup': 555.28, 'utility': 83623}
#  301: {'name': '58, 54', 'exp_sup': 554.91, 'utility': 23977}
#  302: {'name': '29, 27', 'exp_sup': 554.89, 'utility': 72626}
#  303: {'name': '40, 21', 'exp_sup': 553.74, 'utility': 142736}
#  304: {'name': '29, 38', 'exp_sup': 552.56, 'utility': 59510}
#  305: {'name': '5, 72', 'exp_sup': 552.47, 'utility': 108591}
#  306: {'name': '58, 27', 'exp_sup': 551.33, 'utility': 36318}
#  307: {'name': '56, 72', 'exp_sup': 547.29, 'utility': 121376}
#  308: {'name': '60, 21', 'exp_sup': 546.88, 'utility': 59235}
#  309: {'name': '52, 27', 'exp_sup': 546.14, 'utility': 95334}
#  310: {'name': '40, 54', 'exp_sup': 545.72, 'utility': 143216}
#  311: {'name': '42, 72', 'exp_sup': 544.27, 'utility': 84056}
#  312: {'name': '44, 46', 'exp_sup': 544.2, 'utility': 22992}
#  313: {'name': '62, 38', 'exp_sup': 543.85, 'utility': 23601}
#  314: {'name': '7, 21', 'exp_sup': 543.82, 'utility': 47229}
#  315: {'name': '60, 38', 'exp_sup': 543.48, 'utility': 58592}
#  316: {'name': '64, 46', 'exp_sup': 542.52, 'utility': 57437}
#  317: {'name': '3, 72', 'exp_sup': 542.39, 'utility': 119164}
#  318: {'name': '12', 'exp_sup': 541.74, 'utility': 11854}
#  319: {'name': '64, 72', 'exp_sup': 540.83, 'utility': 116362}
#  320: {'name': '60, 54', 'exp_sup': 540.7, 'utility': 58256}
#  321: {'name': '40, 38', 'exp_sup': 540.48, 'utility': 143849}
#  322: {'name': '36, 21', 'exp_sup': 540.41, 'utility': 23785}
#  323: {'name': '52, 11', 'exp_sup': 539.09, 'utility': 127387}
#  324: {'name': '25, 72', 'exp_sup': 538.97, 'utility': 80836}
#  325: {'name': '40, 27', 'exp_sup': 537.21, 'utility': 152164}
#  326: {'name': '56, 54', 'exp_sup': 536.79, 'utility': 58402}
#  327: {'name': '7, 54', 'exp_sup': 535.72, 'utility': 46077}
#  328: {'name': '29, 11', 'exp_sup': 535.32, 'utility': 103978}
#  329: {'name': '62, 54', 'exp_sup': 534.73, 'utility': 23131}
#  330: {'name': '56, 38', 'exp_sup': 534.47, 'utility': 57305}
#  331: {'name': '42, 17', 'exp_sup': 533.76, 'utility': 45714}
#  332: {'name': '5, 21', 'exp_sup': 532.86, 'utility': 45086}
#  333: {'name': '58, 11', 'exp_sup': 532.83, 'utility': 70332}
#  334: {'name': '34, 21', 'exp_sup': 531.2, 'utility': 79670}
#  335: {'name': '7, 38', 'exp_sup': 530.68, 'utility': 46576}
#  336: {'name': '44, 31', 'exp_sup': 530.68, 'utility': 45378}
#  337: {'name': '36, 54', 'exp_sup': 530.65, 'utility': 23075}
#  338: {'name': '60, 27', 'exp_sup': 529.61, 'utility': 71510}
#  339: {'name': '62, 27', 'exp_sup': 527.13, 'utility': 34383}
#  340: {'name': '36, 27', 'exp_sup': 526.74, 'utility': 35491}
#  341: {'name': '48, 21', 'exp_sup': 526.71, 'utility': 92215}
#  342: {'name': '44, 74', 'exp_sup': 526.0, 'utility': 22045}
#  343: {'name': '7, 27', 'exp_sup': 525.99, 'utility': 58671}
#  344: {'name': '48, 27', 'exp_sup': 525.01, 'utility': 104130}
#  345: {'name': '40, 11', 'exp_sup': 524.87, 'utility': 182648}
#  346: {'name': '62, 21', 'exp_sup': 524.33, 'utility': 22863}
#  347: {'name': '66, 21', 'exp_sup': 524.23, 'utility': 56837}
#  348: {'name': '34, 54', 'exp_sup': 523.85, 'utility': 79939}
#  349: {'name': '36, 38', 'exp_sup': 522.95, 'utility': 23006}
#  350: {'name': '56, 21', 'exp_sup': 522.39, 'utility': 57808}
#  351: {'name': '3, 74', 'exp_sup': 521.62, 'utility': 55406}
#  352: {'name': '66, 38', 'exp_sup': 521.11, 'utility': 57237}
#  353: {'name': '5, 38', 'exp_sup': 520.61, 'utility': 46561}
#  354: {'name': '9, 72', 'exp_sup': 519.88, 'utility': 91332}
#  355: {'name': '34, 27', 'exp_sup': 518.28, 'utility': 89930}
#  356: {'name': '56, 27', 'exp_sup': 518.07, 'utility': 68662}
#  357: {'name': '48, 54', 'exp_sup': 517.36, 'utility': 89313}
#  358: {'name': '25, 21', 'exp_sup': 517.29, 'utility': 21605}
#  359: {'name': '46, 31', 'exp_sup': 516.22, 'utility': 44386}
#  360: {'name': '34, 38', 'exp_sup': 516.15, 'utility': 80999}
#  361: {'name': '7, 11', 'exp_sup': 515.72, 'utility': 90027}
#  362: {'name': '52, 68', 'exp_sup': 515.51, 'utility': 139110}
#  363: {'name': '52, 15', 'exp_sup': 515.33, 'utility': 97941}
#  364: {'name': '56, 11', 'exp_sup': 514.71, 'utility': 101096}
#  365: {'name': '60, 11', 'exp_sup': 514.05, 'utility': 102938}
#  366: {'name': '66, 27', 'exp_sup': 513.51, 'utility': 68712}
#  367: {'name': '9, 54', 'exp_sup': 512.11, 'utility': 33130}
#  368: {'name': '39', 'exp_sup': 510.62, 'utility': 10976}
#  369: {'name': '58, 15', 'exp_sup': 509.46, 'utility': 43721}
#  370: {'name': '31, 72', 'exp_sup': 508.88, 'utility': 98595}
#  371: {'name': '9, 21', 'exp_sup': 508.43, 'utility': 32601}
#  372: {'name': '66, 54', 'exp_sup': 508.32, 'utility': 55935}
#  373: {'name': '52, 70', 'exp_sup': 506.32, 'utility': 86740}
#  374: {'name': '36, 11', 'exp_sup': 506.15, 'utility': 66822}
#  375: {'name': '74, 54', 'exp_sup': 506.03, 'utility': 21409}
#  376: {'name': '9, 27', 'exp_sup': 504.51, 'utility': 43648}
#  377: {'name': '5, 54', 'exp_sup': 504.22, 'utility': 44308}
#  378: {'name': '29, 15', 'exp_sup': 504.0, 'utility': 76601}
#  379: {'name': '62, 11', 'exp_sup': 503.39, 'utility': 66448}
#  380: {'name': '9, 38', 'exp_sup': 503.38, 'utility': 33115}
#  381: {'name': '58, 70', 'exp_sup': 503.26, 'utility': 32574}
#  382: {'name': '46, 17', 'exp_sup': 502.81, 'utility': 42540}
#  383: {'name': '29, 70', 'exp_sup': 502.66, 'utility': 65230}
#  384: {'name': '25, 54', 'exp_sup': 502.18, 'utility': 21425}
#  385: {'name': '60, 15', 'exp_sup': 501.5, 'utility': 76507}
#  386: {'name': '31, 17', 'exp_sup': 500.45, 'utility': 64563}
#  387: {'name': '34, 11', 'exp_sup': 500.43, 'utility': 120145}
#  388: {'name': '64, 17', 'exp_sup': 500.39, 'utility': 74383}
#  389: {'name': '58, 68', 'exp_sup': 499.89, 'utility': 85587}
#  390: {'name': '40, 70', 'exp_sup': 499.81, 'utility': 140900}
#  391: {'name': '48, 38', 'exp_sup': 498.91, 'utility': 88005}
#  392: {'name': '66, 11', 'exp_sup': 498.33, 'utility': 97861}
#  393: {'name': '44, 17', 'exp_sup': 498.18, 'utility': 42116}
#  394: {'name': '52, 50', 'exp_sup': 498.15, 'utility': 117882}
#  395: {'name': '28', 'exp_sup': 497.37, 'utility': 10432}
#  396: {'name': '60, 70', 'exp_sup': 497.35, 'utility': 63658}
#  397: {'name': '64, 74', 'exp_sup': 497.33, 'utility': 49938}
#  398: {'name': '62, 68', 'exp_sup': 496.9, 'utility': 83679}
#  399: {'name': '29, 68', 'exp_sup': 496.06, 'utility': 118037}
#  400: {'name': '40, 68', 'exp_sup': 495.91, 'utility': 190386}
#  401: {'name': '62, 70', 'exp_sup': 494.57, 'utility': 31849}
#  402: {'name': '9, 11', 'exp_sup': 494.42, 'utility': 75435}
#  403: {'name': '7, 70', 'exp_sup': 493.65, 'utility': 54067}
#  404: {'name': '42, 74', 'exp_sup': 493.55, 'utility': 21039}
#  405: {'name': '40, 15', 'exp_sup': 491.54, 'utility': 150509}
#  406: {'name': '25, 27', 'exp_sup': 491.3, 'utility': 32290}
#  407: {'name': '56, 68', 'exp_sup': 491.28, 'utility': 117696}
#  408: {'name': '7, 15', 'exp_sup': 490.97, 'utility': 64860}
#  409: {'name': '25, 38', 'exp_sup': 490.86, 'utility': 21298}
#  410: {'name': '52, 19', 'exp_sup': 488.3, 'utility': 95715}
#  411: {'name': '55', 'exp_sup': 488.08, 'utility': 10932}
#  412: {'name': '17, 15', 'exp_sup': 487.74, 'utility': 62502}
#  413: {'name': '62, 15', 'exp_sup': 486.53, 'utility': 41072}
#  414: {'name': '46, 74', 'exp_sup': 486.2, 'utility': 21118}
#  415: {'name': '22', 'exp_sup': 486.0, 'utility': 5224}
#  416: {'name': '58, 50', 'exp_sup': 485.96, 'utility': 64399}
#  417: {'name': '58, 19', 'exp_sup': 485.92, 'utility': 43126}
#  418: {'name': '34, 70', 'exp_sup': 485.91, 'utility': 86000}
#  419: {'name': '42, 38', 'exp_sup': 485.91, 'utility': 21144}
#  420: {'name': '64, 38', 'exp_sup': 485.09, 'utility': 51319}
#  421: {'name': '17, 19', 'exp_sup': 483.63, 'utility': 64071}
#  422: {'name': '3, 21', 'exp_sup': 483.38, 'utility': 52213}
#  423: {'name': '42, 21', 'exp_sup': 483.33, 'utility': 20825}
#  424: {'name': '36, 15', 'exp_sup': 482.97, 'utility': 41591}
#  425: {'name': '40, 50', 'exp_sup': 482.74, 'utility': 171658}
#  426: {'name': '60, 68', 'exp_sup': 482.72, 'utility': 115545}
#  427: {'name': '44, 38', 'exp_sup': 481.96, 'utility': 20975}
#  428: {'name': '9, 70', 'exp_sup': 481.9, 'utility': 41458}
#  429: {'name': '29, 19', 'exp_sup': 481.88, 'utility': 75214}
#  430: {'name': '44, 72', 'exp_sup': 481.8, 'utility': 72245}
#  431: {'name': '48, 11', 'exp_sup': 481.74, 'utility': 126971}
#  432: {'name': '62, 50', 'exp_sup': 481.19, 'utility': 62935}
#  433: {'name': '5, 11', 'exp_sup': 480.39, 'utility': 83830}
#  434: {'name': '3, 27', 'exp_sup': 479.88, 'utility': 63366}
#  435: {'name': '56, 70', 'exp_sup': 479.52, 'utility': 63252}
#  436: {'name': '36, 70', 'exp_sup': 478.81, 'utility': 31066}
#  437: {'name': '29, 50', 'exp_sup': 478.64, 'utility': 97116}
#  438: {'name': '46, 19', 'exp_sup': 478.26, 'utility': 43262}
#  439: {'name': '5, 27', 'exp_sup': 478.12, 'utility': 54209}
#  440: {'name': '46, 72', 'exp_sup': 478.09, 'utility': 72497}
#  441: {'name': '66, 15', 'exp_sup': 477.52, 'utility': 72754}
#  442: {'name': '7, 68', 'exp_sup': 477.35, 'utility': 103406}
#  443: {'name': '17, 21', 'exp_sup': 476.11, 'utility': 41106}
#  444: {'name': '44, 54', 'exp_sup': 476.0, 'utility': 20319}
#  445: {'name': '7, 50', 'exp_sup': 475.03, 'utility': 86352}
#  446: {'name': '17, 74', 'exp_sup': 474.08, 'utility': 40517}
#  447: {'name': '3, 38', 'exp_sup': 473.56, 'utility': 52164}
#  448: {'name': '36, 68', 'exp_sup': 473.51, 'utility': 82920}
#  449: {'name': '34, 68', 'exp_sup': 473.15, 'utility': 135817}
#  450: {'name': '44, 21', 'exp_sup': 472.01, 'utility': 20488}
#  451: {'name': '60, 50', 'exp_sup': 471.58, 'utility': 94933}
#  452: {'name': '5, 70', 'exp_sup': 471.08, 'utility': 52514}
#  453: {'name': '60, 19', 'exp_sup': 470.23, 'utility': 74127}
#  454: {'name': '34, 15', 'exp_sup': 470.13, 'utility': 93456}
#  455: {'name': '48, 15', 'exp_sup': 469.8, 'utility': 103145}
#  456: {'name': '66, 68', 'exp_sup': 468.37, 'utility': 109420}
#  457: {'name': '58, 23', 'exp_sup': 467.76, 'utility': 58714}
#  458: {'name': '29, 23', 'exp_sup': 467.44, 'utility': 88003}
#  459: {'name': '66, 70', 'exp_sup': 466.51, 'utility': 61306}
#  460: {'name': '3, 11', 'exp_sup': 466.5, 'utility': 92869}
#  461: {'name': '56, 15', 'exp_sup': 464.5, 'utility': 72408}
#  462: {'name': '40, 19', 'exp_sup': 464.15, 'utility': 148348}
#  463: {'name': '52, 23', 'exp_sup': 462.85, 'utility': 108098}
#  464: {'name': '48, 68', 'exp_sup': 462.5, 'utility': 138936}
#  465: {'name': '56, 50', 'exp_sup': 461.94, 'utility': 92346}
#  466: {'name': '25, 11', 'exp_sup': 461.86, 'utility': 58768}
#  467: {'name': '7, 19', 'exp_sup': 460.92, 'utility': 62187}
#  468: {'name': '36, 50', 'exp_sup': 460.77, 'utility': 61972}
#  469: {'name': '3, 15', 'exp_sup': 460.51, 'utility': 69920}
#  470: {'name': '3, 70', 'exp_sup': 459.71, 'utility': 60074}
#  471: {'name': '5, 68', 'exp_sup': 459.04, 'utility': 99567}
#  472: {'name': '17, 72', 'exp_sup': 458.35, 'utility': 90147}
#  473: {'name': '64, 23', 'exp_sup': 458.1, 'utility': 85945}
#  474: {'name': '31, 21', 'exp_sup': 457.67, 'utility': 38322}
#  475: {'name': '48, 70', 'exp_sup': 456.81, 'utility': 89878}
#  476: {'name': '34, 50', 'exp_sup': 456.37, 'utility': 113418}
#  477: {'name': '17, 11', 'exp_sup': 456.21, 'utility': 79699}
#  478: {'name': '62, 19', 'exp_sup': 456.05, 'utility': 40751}
#  479: {'name': '3, 54', 'exp_sup': 455.17, 'utility': 50081}
#  480: {'name': '9, 68', 'exp_sup': 454.28, 'utility': 87852}
#  481: {'name': '36, 19', 'exp_sup': 454.15, 'utility': 41505}
#  482: {'name': '3, 23', 'exp_sup': 453.65, 'utility': 86718}
#  483: {'name': '25, 68', 'exp_sup': 453.24, 'utility': 76818}
#  484: {'name': '9, 15', 'exp_sup': 451.24, 'utility': 48938}
#  485: {'name': '66, 50', 'exp_sup': 450.94, 'utility': 92357}
#  486: {'name': '66, 19', 'exp_sup': 450.3, 'utility': 71932}
#  487: {'name': '60, 23', 'exp_sup': 449.47, 'utility': 86861}
#  488: {'name': '64, 21', 'exp_sup': 448.37, 'utility': 47814}
#  489: {'name': '25, 15', 'exp_sup': 447.77, 'utility': 37548}
#  490: {'name': '34, 19', 'exp_sup': 447.23, 'utility': 92061}
#  491: {'name': '31, 23', 'exp_sup': 447.19, 'utility': 75415}
#  492: {'name': '40, 23', 'exp_sup': 446.6, 'utility': 156025}
#  493: {'name': '74, 38', 'exp_sup': 446.22, 'utility': 18918}
#  494: {'name': '46, 27', 'exp_sup': 445.96, 'utility': 28925}
#  495: {'name': '17, 27', 'exp_sup': 445.4, 'utility': 47508}
#  496: {'name': '5, 15', 'exp_sup': 444.97, 'utility': 58275}
#  497: {'name': '44, 27', 'exp_sup': 444.43, 'utility': 28593}
#  498: {'name': '9, 50', 'exp_sup': 443.02, 'utility': 69405}
#  499: {'name': '48, 50', 'exp_sup': 442.41, 'utility': 119180}
#  500: {'name': '38, 70', 'exp_sup': 441.9, 'utility': 29391}
#  501: {'name': '25, 70', 'exp_sup': 441.5, 'utility': 28181}
#  502: {'name': '48, 19', 'exp_sup': 441.19, 'utility': 101117}
#  503: {'name': '74, 21', 'exp_sup': 440.5, 'utility': 18577}
#  504: {'name': '46, 54', 'exp_sup': 440.28, 'utility': 19507}
#  505: {'name': '56, 19', 'exp_sup': 440.16, 'utility': 71763}
#  506: {'name': '5, 50', 'exp_sup': 439.93, 'utility': 79716}
#  507: {'name': '31, 74', 'exp_sup': 439.62, 'utility': 38002}
#  508: {'name': '46, 11', 'exp_sup': 439.59, 'utility': 56984}
#  509: {'name': '36, 23', 'exp_sup': 439.48, 'utility': 57813}
#  510: {'name': '62, 23', 'exp_sup': 439.3, 'utility': 55847}
#  511: {'name': '42, 23', 'exp_sup': 438.06, 'utility': 56084}
#  512: {'name': '64, 70', 'exp_sup': 437.31, 'utility': 55356}
#  513: {'name': '31, 38', 'exp_sup': 435.9, 'utility': 38414}
#  514: {'name': '25, 19', 'exp_sup': 434.95, 'utility': 37749}
#  515: {'name': '34, 23', 'exp_sup': 434.84, 'utility': 102806}
#  516: {'name': '42, 70', 'exp_sup': 434.81, 'utility': 28360}
#  517: {'name': '48, 23', 'exp_sup': 434.64, 'utility': 112602}
#  518: {'name': '9, 19', 'exp_sup': 434.6, 'utility': 48822}
#  519: {'name': '3, 50', 'exp_sup': 434.32, 'utility': 87753}
#  520: {'name': '44, 68', 'exp_sup': 434.29, 'utility': 73708}
#  521: {'name': '29, 13', 'exp_sup': 433.56, 'utility': 46896}
#  522: {'name': '42, 27', 'exp_sup': 433.08, 'utility': 28730}
#  523: {'name': '42, 11', 'exp_sup': 432.87, 'utility': 57194}
#  524: {'name': '64, 68', 'exp_sup': 432.85, 'utility': 97966}
#  525: {'name': '3, 68', 'exp_sup': 432.62, 'utility': 101921}
#  526: {'name': '3, 19', 'exp_sup': 432.39, 'utility': 67492}
#  527: {'name': '42, 15', 'exp_sup': 432.15, 'utility': 37290}
#  528: {'name': '5, 23', 'exp_sup': 432.09, 'utility': 73034}
#  529: {'name': '5, 19', 'exp_sup': 431.98, 'utility': 58833}
#  530: {'name': '52, 13', 'exp_sup': 431.69, 'utility': 64458}
#  531: {'name': '7, 23', 'exp_sup': 430.05, 'utility': 75742}
#  532: {'name': '44, 11', 'exp_sup': 429.84, 'utility': 56268}
#  533: {'name': '56, 23', 'exp_sup': 429.38, 'utility': 83517}
#  534: {'name': '40, 13', 'exp_sup': 429.18, 'utility': 111059}
#  535: {'name': '17, 54', 'exp_sup': 427.51, 'utility': 37098}
#  536: {'name': '42, 54', 'exp_sup': 426.86, 'utility': 18680}
#  537: {'name': '58, 13', 'exp_sup': 426.01, 'utility': 18638}
#  538: {'name': '25, 50', 'exp_sup': 425.5, 'utility': 56700}
#  539: {'name': '58, 1', 'exp_sup': 423.53, 'utility': 74378}
#  540: {'name': '42, 68', 'exp_sup': 422.91, 'utility': 72868}
#  541: {'name': '64, 54', 'exp_sup': 422.76, 'utility': 44266}
#  542: {'name': '46, 38', 'exp_sup': 422.51, 'utility': 18715}
#  543: {'name': '64, 27', 'exp_sup': 422.45, 'utility': 53546}
#  544: {'name': '44, 70', 'exp_sup': 421.35, 'utility': 27039}
#  545: {'name': '60, 1', 'exp_sup': 419.94, 'utility': 101305}
#  546: {'name': '74, 11', 'exp_sup': 419.73, 'utility': 55086}
#  547: {'name': '60, 13', 'exp_sup': 419.5, 'utility': 45586}
#  548: {'name': '74, 27', 'exp_sup': 418.79, 'utility': 27602}
#  549: {'name': '64, 11', 'exp_sup': 418.5, 'utility': 80407}
#  550: {'name': '52, 1', 'exp_sup': 418.44, 'utility': 119401}
#  551: {'name': '72, 23', 'exp_sup': 417.09, 'utility': 98356}
#  552: {'name': '31, 15', 'exp_sup': 416.51, 'utility': 52419}
#  553: {'name': '74, 68', 'exp_sup': 416.19, 'utility': 68779}
#  554: {'name': '72, 38', 'exp_sup': 415.69, 'utility': 63069}
#  555: {'name': '66, 23', 'exp_sup': 414.21, 'utility': 80194}
#  556: {'name': '9, 13', 'exp_sup': 413.42, 'utility': 26653}
#  557: {'name': '72, 21', 'exp_sup': 413.41, 'utility': 60606}
#  558: {'name': '7, 13', 'exp_sup': 412.12, 'utility': 36433}
#  559: {'name': '42, 19', 'exp_sup': 410.87, 'utility': 37484}
#  560: {'name': '31, 11', 'exp_sup': 410.63, 'utility': 71945}
#  561: {'name': '29, 1', 'exp_sup': 410.29, 'utility': 102202}
#  562: {'name': '17, 70', 'exp_sup': 409.14, 'utility': 45387}
#  563: {'name': '73', 'exp_sup': 408.83, 'utility': 8920}
#  564: {'name': '36, 13', 'exp_sup': 408.77, 'utility': 17814}
#  565: {'name': '17, 38', 'exp_sup': 408.23, 'utility': 36915}
#  566: {'name': '42, 50', 'exp_sup': 407.9, 'utility': 54183}
#  567: {'name': '40, 1', 'exp_sup': 407.89, 'utility': 162170}
#  568: {'name': '62, 13', 'exp_sup': 407.72, 'utility': 17519}
#  569: {'name': '9, 23', 'exp_sup': 407.43, 'utility': 61129}
#  570: {'name': '34, 1', 'exp_sup': 407.34, 'utility': 116728}
#  571: {'name': '46, 15', 'exp_sup': 406.55, 'utility': 34724}
#  572: {'name': '31, 27', 'exp_sup': 405.86, 'utility': 45132}
#  573: {'name': '25, 23', 'exp_sup': 404.91, 'utility': 51029}
#  574: {'name': '66, 1', 'exp_sup': 404.59, 'utility': 100195}
#  575: {'name': '7, 1', 'exp_sup': 404.53, 'utility': 90833}
#  576: {'name': '31, 70', 'exp_sup': 404.5, 'utility': 43690}
#  577: {'name': '46, 21', 'exp_sup': 403.57, 'utility': 17644}
#  578: {'name': '11, 15', 'exp_sup': 401.83, 'utility': 70972}
#  579: {'name': '52, 58, 40', 'exp_sup': 401.39, 'utility': 306482}
#  580: {'name': '56, 13', 'exp_sup': 400.59, 'utility': 44164}
#  581: {'name': '34, 13', 'exp_sup': 400.58, 'utility': 61896}
#  582: {'name': '48, 1', 'exp_sup': 400.36, 'utility': 123739}
#  583: {'name': '74, 70', 'exp_sup': 399.49, 'utility': 25654}
#  584: {'name': '52, 29, 58', 'exp_sup': 399.36, 'utility': 189208}
#  585: {'name': '62, 1', 'exp_sup': 398.67, 'utility': 70664}
#  586: {'name': '52, 58, 60', 'exp_sup': 398.56, 'utility': 186894}
#  587: {'name': '52, 29, 40', 'exp_sup': 398.51, 'utility': 356097}
#  588: {'name': '56, 1', 'exp_sup': 398.08, 'utility': 99138}
#  589: {'name': '74, 72', 'exp_sup': 397.49, 'utility': 60250}
#  590: {'name': '5, 13', 'exp_sup': 396.92, 'utility': 33913}
#  591: {'name': '36, 1', 'exp_sup': 396.53, 'utility': 71813}
#  592: {'name': '64, 50', 'exp_sup': 395.02, 'utility': 80137}
#  593: {'name': '29, 58, 40', 'exp_sup': 394.99, 'utility': 271369}
#  594: {'name': '46, 68', 'exp_sup': 394.91, 'utility': 67387}
#  595: {'name': '52, 29, 60', 'exp_sup': 394.42, 'utility': 237130}
#  596: {'name': '48, 13', 'exp_sup': 394.39, 'utility': 69181}
#  597: {'name': '52, 40, 60', 'exp_sup': 394.11, 'utility': 352926}
#  598: {'name': '21, 27', 'exp_sup': 393.92, 'utility': 25972}
#  599: {'name': '21, 54', 'exp_sup': 392.63, 'utility': 16625}
#  600: {'name': '52, 29, 62', 'exp_sup': 391.99, 'utility': 181017}
#  601: {'name': '17, 68', 'exp_sup': 391.81, 'utility': 85384}
#  602: {'name': '52, 58, 62', 'exp_sup': 391.73, 'utility': 131741}
#  603: {'name': '27, 11', 'exp_sup': 391.33, 'utility': 59310}
#  604: {'name': '52, 40, 62', 'exp_sup': 391.2, 'utility': 294543}
#  605: {'name': '46, 70', 'exp_sup': 390.87, 'utility': 24590}
#  606: {'name': '52, 60, 62', 'exp_sup': 390.72, 'utility': 178783}
#  607: {'name': '5, 1', 'exp_sup': 390.1, 'utility': 85018}
#  608: {'name': '29, 58, 60', 'exp_sup': 389.81, 'utility': 153216}
#  609: {'name': '75', 'exp_sup': 389.53, 'utility': 12837}
#  610: {'name': '52, 58, 56', 'exp_sup': 389.51, 'utility': 180271}
#  611: {'name': '64, 19', 'exp_sup': 388.61, 'utility': 60535}
#  612: {'name': '58, 40, 60', 'exp_sup': 388.41, 'utility': 269050}
#  613: {'name': '44, 50', 'exp_sup': 387.07, 'utility': 52558}
#  614: {'name': '29, 40, 62', 'exp_sup': 385.97, 'utility': 261394}
#  615: {'name': '52, 29, 56', 'exp_sup': 385.86, 'utility': 228802}
#  616: {'name': '44, 2', 'exp_sup': 385.8, 'utility': 32777}
#  617: {'name': '52, 14', 'exp_sup': 385.09, 'utility': 56764}
#  618: {'name': '44, 15', 'exp_sup': 384.86, 'utility': 32270}
#  619: {'name': '54, 38', 'exp_sup': 384.71, 'utility': 16711}
#  620: {'name': '29, 40, 60', 'exp_sup': 384.66, 'utility': 318464}
#  621: {'name': '29, 58, 62', 'exp_sup': 384.62, 'utility': 99574}
#  622: {'name': '29, 58, 36', 'exp_sup': 384.49, 'utility': 100706}
#  623: {'name': '54, 27', 'exp_sup': 384.29, 'utility': 25849}
#  624: {'name': '52, 58, 7', 'exp_sup': 383.86, 'utility': 166437}
#  625: {'name': '58, 40, 36', 'exp_sup': 383.8, 'utility': 214341}
#  626: {'name': '64, 15', 'exp_sup': 383.58, 'utility': 58071}
#  627: {'name': '52, 29, 7', 'exp_sup': 383.56, 'utility': 216491}
#  628: {'name': '31, 54', 'exp_sup': 383.52, 'utility': 33383}
#  629: {'name': '58, 60, 62', 'exp_sup': 383.2, 'utility': 98229}
#  630: {'name': '52, 40, 7', 'exp_sup': 383.08, 'utility': 328740}
#  631: {'name': '58, 40, 62', 'exp_sup': 383.06, 'utility': 212854}
#  632: {'name': '52, 60, 56', 'exp_sup': 382.78, 'utility': 225700}
#  633: {'name': '29, 60, 62', 'exp_sup': 382.69, 'utility': 147078}
#  634: {'name': '52, 60, 66', 'exp_sup': 382.65, 'utility': 228982}
#  635: {'name': '29, 2', 'exp_sup': 382.45, 'utility': 56992}
#  636: {'name': '9, 1', 'exp_sup': 382.38, 'utility': 75132}
#  637: {'name': '52, 58, 48', 'exp_sup': 382.36, 'utility': 228022}
#  638: {'name': '52, 40, 36', 'exp_sup': 382.28, 'utility': 296932}
#  639: {'name': '52, 60, 7', 'exp_sup': 382.28, 'utility': 212686}
#  640: {'name': '3, 13', 'exp_sup': 382.28, 'utility': 40981}
#  641: {'name': '31, 19', 'exp_sup': 382.25, 'utility': 51636}
#  642: {'name': '52, 40, 56', 'exp_sup': 382.07, 'utility': 339206}
#  643: {'name': '72, 27', 'exp_sup': 381.75, 'utility': 65880}
#  644: {'name': '31, 50', 'exp_sup': 381.48, 'utility': 69167}
#  645: {'name': '52, 58, 36', 'exp_sup': 381.39, 'utility': 133745}
#  646: {'name': '25, 1', 'exp_sup': 381.32, 'utility': 65630}
#  647: {'name': '29, 40, 7', 'exp_sup': 381.05, 'utility': 296027}
#  648: {'name': '44, 19', 'exp_sup': 380.96, 'utility': 33878}
#  649: {'name': '52, 60, 48', 'exp_sup': 380.75, 'utility': 274296}
#  650: {'name': '29, 40, 36', 'exp_sup': 380.42, 'utility': 262915}
#  651: {'name': '58, 14', 'exp_sup': 379.88, 'utility': 16202}
#  652: {'name': '52, 29, 66', 'exp_sup': 379.66, 'utility': 228708}
#  653: {'name': '66, 14', 'exp_sup': 379.64, 'utility': 40392}
#  654: {'name': '58, 40, 7', 'exp_sup': 379.34, 'utility': 246553}
#  655: {'name': '29, 14', 'exp_sup': 379.08, 'utility': 40258}
#  656: {'name': '29, 58, 56', 'exp_sup': 378.92, 'utility': 147661}
#  657: {'name': '29, 58, 7', 'exp_sup': 378.91, 'utility': 133951}
#  658: {'name': '72, 15', 'exp_sup': 378.69, 'utility': 74307}
#  659: {'name': '54, 11', 'exp_sup': 378.55, 'utility': 51498}
#  660: {'name': '52, 40, 48', 'exp_sup': 378.53, 'utility': 385381}
#  661: {'name': '52, 2', 'exp_sup': 378.36, 'utility': 74265}
#  662: {'name': '58, 60, 36', 'exp_sup': 378.01, 'utility': 99248}
#  663: {'name': '40, 60, 62', 'exp_sup': 377.86, 'utility': 259047}
#  664: {'name': '72, 68', 'exp_sup': 377.79, 'utility': 103308}
#  665: {'name': '52, 58, 66', 'exp_sup': 377.53, 'utility': 180201}
#  666: {'name': '58, 60, 66', 'exp_sup': 377.49, 'utility': 147841}
#  667: {'name': '52, 60, 36', 'exp_sup': 377.32, 'utility': 181047}
#  668: {'name': '46, 50', 'exp_sup': 377.25, 'utility': 50337}
#  669: {'name': '29, 60, 7', 'exp_sup': 376.87, 'utility': 180819}
#  670: {'name': '52, 29, 36', 'exp_sup': 376.83, 'utility': 183387}
#  671: {'name': '52, 29, 48', 'exp_sup': 375.92, 'utility': 275331}
#  672: {'name': '58, 2', 'exp_sup': 375.7, 'utility': 32799}
#  673: {'name': '58, 60, 7', 'exp_sup': 375.55, 'utility': 131327}
#  674: {'name': '52, 29, 5', 'exp_sup': 375.38, 'utility': 207390}
#  675: {'name': '58, 40, 56', 'exp_sup': 375.29, 'utility': 257871}
#  676: {'name': '52, 58, 5', 'exp_sup': 375.18, 'utility': 159640}
#  677: {'name': '21, 68', 'exp_sup': 375.15, 'utility': 63833}
#  678: {'name': '58, 60, 48', 'exp_sup': 374.97, 'utility': 194450}
#  679: {'name': '29, 60, 36', 'exp_sup': 374.96, 'utility': 148457}
#  680: {'name': '66, 13', 'exp_sup': 374.95, 'utility': 42498}
#  681: {'name': '40, 2', 'exp_sup': 374.68, 'utility': 114946}
#  682: {'name': '52, 62, 56', 'exp_sup': 374.6, 'utility': 173982}
#  683: {'name': '54, 68', 'exp_sup': 374.42, 'utility': 63202}
#  684: {'name': '40, 14', 'exp_sup': 374.29, 'utility': 94272}
#  685: {'name': '52, 40, 34', 'exp_sup': 373.87, 'utility': 373506}
#  686: {'name': '21, 1', 'exp_sup': 373.7, 'utility': 64208}
#  687: {'name': '25, 13', 'exp_sup': 373.67, 'utility': 16045}
#  688: {'name': '52, 40, 66', 'exp_sup': 373.61, 'utility': 339395}
#  689: {'name': '72, 70', 'exp_sup': 373.38, 'utility': 65056}
#  690: {'name': '3, 1', 'exp_sup': 373.24, 'utility': 89646}
#  691: {'name': '62, 2', 'exp_sup': 373.18, 'utility': 31744}
#  692: {'name': '29, 40, 56', 'exp_sup': 373.12, 'utility': 305344}
#  693: {'name': '52, 60, 5', 'exp_sup': 373.09, 'utility': 204434}
#  694: {'name': '58, 40, 48', 'exp_sup': 372.95, 'utility': 305339}
#  695: {'name': '40, 60, 7', 'exp_sup': 372.95, 'utility': 292006}
#  696: {'name': '29, 58, 48', 'exp_sup': 372.15, 'utility': 195266}
#  697: {'name': '58, 60, 56', 'exp_sup': 371.94, 'utility': 145465}
#  698: {'name': '29, 62, 36', 'exp_sup': 371.68, 'utility': 96365}
#  699: {'name': '29, 60, 66', 'exp_sup': 371.66, 'utility': 196620}
#  700: {'name': '44, 23', 'exp_sup': 371.37, 'utility': 46146}
#  701: {'name': '52, 29, 34', 'exp_sup': 371.35, 'utility': 262342}
#  702: {'name': '52, 62, 66', 'exp_sup': 371.29, 'utility': 171804}
#  703: {'name': '40, 60, 36', 'exp_sup': 371.29, 'utility': 260533}
#  704: {'name': '29, 62, 7', 'exp_sup': 371.23, 'utility': 128389}
#  705: {'name': '52, 62, 36', 'exp_sup': 370.98, 'utility': 127447}
#  706: {'name': '74, 50', 'exp_sup': 370.92, 'utility': 48589}
#  707: {'name': '29, 58, 5', 'exp_sup': 370.52, 'utility': 128022}
#  708: {'name': '29, 58, 66', 'exp_sup': 370.46, 'utility': 147885}
#  709: {'name': '58, 62, 36', 'exp_sup': 370.32, 'utility': 48150}
#  710: {'name': '52, 60, 34', 'exp_sup': 370.22, 'utility': 258390}
#  711: {'name': '52, 29, 25', 'exp_sup': 370.09, 'utility': 168932}
#  712: {'name': '52, 58, 34', 'exp_sup': 369.79, 'utility': 213085}
#  713: {'name': '36, 2', 'exp_sup': 369.55, 'utility': 31898}
#  714: {'name': '40, 60, 66', 'exp_sup': 368.95, 'utility': 307626}
#  715: {'name': '60, 14', 'exp_sup': 368.91, 'utility': 40317}
#  716: {'name': '29, 40, 34', 'exp_sup': 368.8, 'utility': 340850}
#  717: {'name': '52, 40, 5', 'exp_sup': 368.71, 'utility': 317307}
#  718: {'name': '21, 15', 'exp_sup': 368.57, 'utility': 31911}
#  719: {'name': '56, 14', 'exp_sup': 368.53, 'utility': 38920}
#  720: {'name': '29, 60, 56', 'exp_sup': 368.5, 'utility': 193480}
#  721: {'name': '58, 7, 36', 'exp_sup': 368.44, 'utility': 81005}
#  722: {'name': '52, 7, 66', 'exp_sup': 368.23, 'utility': 205156}
#  723: {'name': '40, 62, 36', 'exp_sup': 368.15, 'utility': 205903}
#  724: {'name': '58, 36, 48', 'exp_sup': 368.08, 'utility': 145637}
#  725: {'name': '31, 68', 'exp_sup': 368.01, 'utility': 78607}
#  726: {'name': '52, 62, 7', 'exp_sup': 367.79, 'utility': 158817}
#  727: {'name': '52, 36, 56', 'exp_sup': 367.78, 'utility': 174448}
#  728: {'name': '21, 11', 'exp_sup': 367.61, 'utility': 48059}
#  729: {'name': '29, 7, 36', 'exp_sup': 367.53, 'utility': 129806}
#  730: {'name': '52, 7, 34', 'exp_sup': 367.47, 'utility': 237717}
#  731: {'name': '46, 23', 'exp_sup': 367.44, 'utility': 46944}
#  732: {'name': '38, 68', 'exp_sup': 367.24, 'utility': 61548}
#  733: {'name': '58, 36, 56', 'exp_sup': 366.87, 'utility': 95479}
#  734: {'name': '52, 60, 25', 'exp_sup': 366.74, 'utility': 167886}
#  735: {'name': '52, 7, 56', 'exp_sup': 366.73, 'utility': 206467}
#  736: {'name': '40, 60, 48', 'exp_sup': 366.71, 'utility': 351142}
#  737: {'name': '62, 14', 'exp_sup': 366.67, 'utility': 15913}
#  738: {'name': '40, 7, 36', 'exp_sup': 366.49, 'utility': 238719}
#  739: {'name': '58, 60, 5', 'exp_sup': 366.44, 'utility': 126130}
#  740: {'name': '74, 15', 'exp_sup': 366.38, 'utility': 32094}
#  741: {'name': '29, 40, 48', 'exp_sup': 366.24, 'utility': 351549}
#  742: {'name': '58, 62, 56', 'exp_sup': 366.22, 'utility': 95289}
#  743: {'name': '29, 58, 34', 'exp_sup': 366.14, 'utility': 180860}
#  744: {'name': '29, 40, 66', 'exp_sup': 366.11, 'utility': 306518}
#  745: {'name': '52, 58, 25', 'exp_sup': 366.04, 'utility': 122999}
#  746: {'name': '58, 40, 66', 'exp_sup': 366.0, 'utility': 258753}
#  747: {'name': '52, 7, 36', 'exp_sup': 365.86, 'utility': 161217}
#  748: {'name': '29, 7, 34', 'exp_sup': 365.85, 'utility': 206963}
#  749: {'name': '60, 2', 'exp_sup': 365.75, 'utility': 56277}
#  750: {'name': '36, 14', 'exp_sup': 365.75, 'utility': 15982}
#  751: {'name': '60, 62, 36', 'exp_sup': 365.62, 'utility': 94994}
#  752: {'name': '29, 60, 48', 'exp_sup': 365.55, 'utility': 241763}
#  753: {'name': '40, 36, 48', 'exp_sup': 365.26, 'utility': 302368}
#  754: {'name': '52, 36, 48', 'exp_sup': 365.23, 'utility': 225653}
#  755: {'name': '58, 62, 7', 'exp_sup': 365.09, 'utility': 80003}
#  756: {'name': '72, 11', 'exp_sup': 364.61, 'utility': 89738}
#  757: {'name': '58, 7, 66', 'exp_sup': 364.54, 'utility': 126907}
#  758: {'name': '58, 62, 66', 'exp_sup': 364.44, 'utility': 94488}
#  759: {'name': '29, 7, 56', 'exp_sup': 364.28, 'utility': 175354}
#  760: {'name': '11, 70', 'exp_sup': 364.17, 'utility': 54175}
#  761: {'name': '29, 40, 25', 'exp_sup': 364.14, 'utility': 243096}
#  762: {'name': '60, 62, 7', 'exp_sup': 364.12, 'utility': 125858}
#  763: {'name': '52, 56, 66', 'exp_sup': 364.06, 'utility': 216840}
#  764: {'name': '29, 62, 56', 'exp_sup': 364.01, 'utility': 142821}
#  765: {'name': '52, 58, 9', 'exp_sup': 364.0, 'utility': 139546}
#  766: {'name': '40, 60, 34', 'exp_sup': 363.98, 'utility': 336770}
#  767: {'name': '29, 60, 5', 'exp_sup': 363.89, 'utility': 173424}
#  768: {'name': '15, 19', 'exp_sup': 363.85, 'utility': 49272}
#  769: {'name': '29, 36, 48', 'exp_sup': 363.76, 'utility': 193128}
#  770: {'name': '38, 11', 'exp_sup': 363.76, 'utility': 49199}
#  771: {'name': '17, 23', 'exp_sup': 363.65, 'utility': 62346}
#  772: {'name': '29, 40, 5', 'exp_sup': 363.6, 'utility': 285020}
#  773: {'name': '29, 60, 34', 'exp_sup': 363.54, 'utility': 226730}
#  774: {'name': '29, 62, 66', 'exp_sup': 363.47, 'utility': 141539}
#  775: {'name': '60, 62, 66', 'exp_sup': 363.46, 'utility': 141605}
#  776: {'name': '29, 36, 56', 'exp_sup': 363.2, 'utility': 142893}
#  777: {'name': '40, 7, 34', 'exp_sup': 363.14, 'utility': 314141}
#  778: {'name': '58, 40, 34', 'exp_sup': 363.03, 'utility': 292168}
#  779: {'name': '60, 62, 56', 'exp_sup': 362.99, 'utility': 140878}
#  780: {'name': '40, 62, 56', 'exp_sup': 362.9, 'utility': 251027}
#  781: {'name': '48, 14', 'exp_sup': 362.88, 'utility': 62280}
#  782: {'name': '40, 62, 7', 'exp_sup': 362.78, 'utility': 236980}
#  783: {'name': '17, 1', 'exp_sup': 362.68, 'utility': 80787}
#  784: {'name': '5, 14', 'exp_sup': 362.6, 'utility': 30415}
#  785: {'name': '52, 62, 5', 'exp_sup': 362.48, 'utility': 153466}
#  786: {'name': '17, 50', 'exp_sup': 362.37, 'utility': 65467}
#  787: {'name': '58, 62, 48', 'exp_sup': 362.17, 'utility': 140500}
#  788: {'name': '72, 50', 'exp_sup': 362.03, 'utility': 86616}
#  789: {'name': '52, 62, 34', 'exp_sup': 361.99, 'utility': 204089}
#  790: {'name': '52, 7, 48', 'exp_sup': 361.8, 'utility': 250826}
#  791: {'name': '7, 2', 'exp_sup': 361.79, 'utility': 46782}
#  792: {'name': '58, 7, 48', 'exp_sup': 361.76, 'utility': 173196}
#  793: {'name': '40, 60, 56', 'exp_sup': 361.64, 'utility': 302242}
#  794: {'name': '58, 7, 56', 'exp_sup': 361.59, 'utility': 127456}
#  795: {'name': '60, 7, 66', 'exp_sup': 361.56, 'utility': 173726}
#  796: {'name': '52, 62, 48', 'exp_sup': 361.55, 'utility': 217175}
#  797: {'name': '29, 7, 66', 'exp_sup': 361.55, 'utility': 174493}
#  798: {'name': '52, 58, 3', 'exp_sup': 361.49, 'utility': 167984}
#  799: {'name': '60, 7, 36', 'exp_sup': 361.35, 'utility': 127137}
#  800: {'name': '21, 38', 'exp_sup': 361.18, 'utility': 16245}
#  801: {'name': '40, 36, 56', 'exp_sup': 360.84, 'utility': 249345}
#  802: {'name': '44, 13', 'exp_sup': 360.73, 'utility': 15132}
#  803: {'name': '29, 36, 34', 'exp_sup': 360.53, 'utility': 175497}
#  804: {'name': '52, 40, 25', 'exp_sup': 360.35, 'utility': 274053}
#  805: {'name': '74, 19', 'exp_sup': 360.34, 'utility': 32335}
#  806: {'name': '58, 60, 34', 'exp_sup': 360.31, 'utility': 178151}
#  807: {'name': '52, 29, 9', 'exp_sup': 360.19, 'utility': 185704}
#  808: {'name': '58, 7, 34', 'exp_sup': 360.11, 'utility': 158868}
#  809: {'name': '29, 60, 25', 'exp_sup': 359.93, 'utility': 137735}
#  810: {'name': '29, 62, 34', 'exp_sup': 359.84, 'utility': 173770}
#  811: {'name': '58, 40, 5', 'exp_sup': 359.72, 'utility': 237980}
#  812: {'name': '60, 7, 34', 'exp_sup': 359.68, 'utility': 203096}
#  813: {'name': '7, 14', 'exp_sup': 359.52, 'utility': 30953}
#  814: {'name': '52, 7, 5', 'exp_sup': 359.48, 'utility': 185259}
#  815: {'name': '52, 56, 48', 'exp_sup': 359.45, 'utility': 260814}
#  816: {'name': '38, 50', 'exp_sup': 359.37, 'utility': 47360}
#  817: {'name': '60, 62, 48', 'exp_sup': 358.89, 'utility': 185735}
#  818: {'name': '52, 62, 25', 'exp_sup': 358.73, 'utility': 117385}
#  819: {'name': '29, 62, 5', 'exp_sup': 358.73, 'utility': 123470}
#  820: {'name': '29, 7, 5', 'exp_sup': 358.56, 'utility': 155195}
#  821: {'name': '29, 7, 48', 'exp_sup': 358.48, 'utility': 220074}
#  822: {'name': '29, 58, 25', 'exp_sup': 358.38, 'utility': 92671}
#  823: {'name': '29, 62, 25', 'exp_sup': 358.23, 'utility': 88962}
#  824: {'name': '52, 60, 9', 'exp_sup': 358.21, 'utility': 183408}
#  825: {'name': '40, 7, 48', 'exp_sup': 358.06, 'utility': 325169}
#  826: {'name': '60, 48, 66', 'exp_sup': 357.78, 'utility': 234159}
#  827: {'name': '52, 66, 5', 'exp_sup': 357.76, 'utility': 198732}
#  828: {'name': '58, 7, 5', 'exp_sup': 357.68, 'utility': 108446}
#  829: {'name': '58, 62, 5', 'exp_sup': 357.66, 'utility': 76987}
#  830: {'name': '54, 70', 'exp_sup': 357.58, 'utility': 22569}
#  831: {'name': '60, 36, 66', 'exp_sup': 357.54, 'utility': 143034}
#  832: {'name': '40, 62, 66', 'exp_sup': 357.52, 'utility': 248474}
#  833: {'name': '60, 36, 48', 'exp_sup': 357.51, 'utility': 192378}
#  834: {'name': '52, 36, 34', 'exp_sup': 357.29, 'utility': 206576}
#  835: {'name': '52, 29, 3', 'exp_sup': 357.23, 'utility': 213986}
#  836: {'name': '40, 7, 56', 'exp_sup': 356.93, 'utility': 281534}
#  837: {'name': '60, 36, 34', 'exp_sup': 356.85, 'utility': 172658}
#  838: {'name': '52, 36, 5', 'exp_sup': 356.64, 'utility': 154502}
#  839: {'name': '58, 56, 66', 'exp_sup': 356.57, 'utility': 139847}
#  840: {'name': '29, 58, 9', 'exp_sup': 356.46, 'utility': 109094}
#  841: {'name': '29, 62, 48', 'exp_sup': 356.35, 'utility': 186444}
#  842: {'name': '40, 36, 34', 'exp_sup': 356.35, 'utility': 283053}
#  843: {'name': '40, 7, 66', 'exp_sup': 356.33, 'utility': 280872}
#  844: {'name': '52, 56, 5', 'exp_sup': 356.23, 'utility': 196758}
#  845: {'name': '29, 36, 5', 'exp_sup': 356.0, 'utility': 123980}
#  846: {'name': '52, 40, 3', 'exp_sup': 355.85, 'utility': 316103}
#  847: {'name': '52, 48, 66', 'exp_sup': 355.65, 'utility': 264760}
#  848: {'name': '58, 60, 25', 'exp_sup': 355.63, 'utility': 91993}
#  849: {'name': '60, 66, 5', 'exp_sup': 355.54, 'utility': 168937}
#  850: {'name': '64, 13', 'exp_sup': 355.47, 'utility': 37454}
#  851: {'name': '60, 36, 56', 'exp_sup': 355.42, 'utility': 140659}
#  852: {'name': '58, 36, 66', 'exp_sup': 355.39, 'utility': 95678}
#  853: {'name': '52, 56, 34', 'exp_sup': 355.37, 'utility': 249452}
#  854: {'name': '60, 62, 5', 'exp_sup': 355.31, 'utility': 121646}
#  855: {'name': '40, 62, 48', 'exp_sup': 355.22, 'utility': 292743}
#  856: {'name': '58, 56, 48', 'exp_sup': 355.18, 'utility': 184325}
#  857: {'name': '29, 66, 5', 'exp_sup': 355.16, 'utility': 168785}
#  858: {'name': '29, 58, 3', 'exp_sup': 355.08, 'utility': 138064}
#  859: {'name': '29, 36, 25', 'exp_sup': 354.9, 'utility': 90676}
#  860: {'name': '60, 7, 48', 'exp_sup': 354.88, 'utility': 217948}
#  861: {'name': '40, 60, 5', 'exp_sup': 354.86, 'utility': 281918}
#  862: {'name': '25, 14', 'exp_sup': 354.82, 'utility': 15109}
#  863: {'name': '11, 19', 'exp_sup': 354.82, 'utility': 64428}
#  864: {'name': '29, 36, 66', 'exp_sup': 354.77, 'utility': 143064}
#  865: {'name': '60, 36, 5', 'exp_sup': 354.71, 'utility': 122054}
#  866: {'name': '60, 62, 34', 'exp_sup': 354.69, 'utility': 171186}
#  867: {'name': '52, 40, 9', 'exp_sup': 354.51, 'utility': 291736}
#  868: {'name': '52, 48, 34', 'exp_sup': 354.37, 'utility': 292525}
#  869: {'name': '58, 36, 5', 'exp_sup': 354.32, 'utility': 77457}
#  870: {'name': '40, 60, 25', 'exp_sup': 354.31, 'utility': 242299}
#  871: {'name': '52, 36, 66', 'exp_sup': 354.25, 'utility': 174267}
#  872: {'name': '34, 14', 'exp_sup': 354.21, 'utility': 53629}
#  873: {'name': '42, 1', 'exp_sup': 354.15, 'utility': 62587}
#  874: {'name': '40, 62, 34', 'exp_sup': 354.09, 'utility': 281448}
#  875: {'name': '29, 7, 25', 'exp_sup': 353.9, 'utility': 119416}
#  876: {'name': '58, 36, 34', 'exp_sup': 353.89, 'utility': 127491}
#  877: {'name': '29, 56, 66', 'exp_sup': 353.69, 'utility': 186108}
#  878: {'name': '27, 15', 'exp_sup': 353.68, 'utility': 38551}
#  879: {'name': '52, 60, 3', 'exp_sup': 353.2, 'utility': 211774}
#  880: {'name': '58, 48, 66', 'exp_sup': 353.19, 'utility': 187656}
#  881: {'name': '40, 36, 66', 'exp_sup': 352.71, 'utility': 250117}
#  882: {'name': '72, 19', 'exp_sup': 352.71, 'utility': 71877}
#  883: {'name': '60, 56, 66', 'exp_sup': 352.63, 'utility': 185820}
#  884: {'name': '29, 48, 66', 'exp_sup': 352.32, 'utility': 233604}
#  885: {'name': '52, 66, 34', 'exp_sup': 352.22, 'utility': 250124}
#  886: {'name': '7, 36, 34', 'exp_sup': 352.18, 'utility': 153972}
#  887: {'name': '58, 60, 9', 'exp_sup': 352.1, 'utility': 107700}
#  888: {'name': '58, 40, 25', 'exp_sup': 352.0, 'utility': 197913}
#  889: {'name': '58, 40, 9', 'exp_sup': 351.7, 'utility': 215154}
#  890: {'name': '52, 48, 5', 'exp_sup': 351.57, 'utility': 240306}
#  891: {'name': '58, 66, 5', 'exp_sup': 351.52, 'utility': 122934}
#  892: {'name': '58, 40, 3', 'exp_sup': 351.51, 'utility': 240548}
#  893: {'name': '62, 7, 36', 'exp_sup': 351.35, 'utility': 77360}
#  894: {'name': '62, 7, 66', 'exp_sup': 351.13, 'utility': 121204}
#  895: {'name': '58, 62, 34', 'exp_sup': 350.86, 'utility': 126079}
#  896: {'name': '56, 2', 'exp_sup': 350.86, 'utility': 53163}
#  897: {'name': '60, 66, 34', 'exp_sup': 350.63, 'utility': 219294}
#  898: {'name': '52, 7, 25', 'exp_sup': 350.6, 'utility': 148188}
#  899: {'name': '29, 56, 34', 'exp_sup': 350.58, 'utility': 218538}
#  900: {'name': '52, 36, 25', 'exp_sup': 350.56, 'utility': 120346}

# %% [markdown]
# ## Hiện thực retail

# %%
# chạy với retail
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_retail.txt, ./data/retail_utility.txt", 0.0001, 100)
algorithm.print_stats("./out/TUHUFP/retail/output_retail_top_100.txt")

# %%
# chạy với retail
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_retail.txt, ./data/retail_utility.txt", 0.0001, 300)
algorithm.print_stats("./out/TUHUFP/retail/output_retail_top_300.txt")

# %%
# chạy với retail
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_retail.txt, ./data/retail_utility.txt", 0.0001, 500)
algorithm.print_stats("./out/TUHUFP/retail/output_retail_top_500.txt")

# %%
# chạy với retail
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_retail.txt, ./data/retail_utility.txt", 0.0001, 700)
algorithm.print_stats("./out/TUHUFP/retail/output_retail_top_700.txt")

# %%
# chạy với retail
algorithm = AlgorithmTUHUFP()
algorithm.run("./data/input_retail.txt, ./data/retail_utility.txt", 0.0001, 900)
algorithm.print_stats("./out/TUHUFP/retail/output_retail_top_900.txt")

# %% [markdown]
# # Thuật toán 2: TUHUFP-Growth

# %%
import time, os
import tracemalloc
from typing import Dict, List, Tuple
from collections import defaultdict

# %% [markdown]
# ## Cài đặt cấu trúc dữ liệu

# %%
class Node:
    """
    Lớp đại diện cho một nút trong cây UHUFP (Cây mẫu tần suất tiện ích cao không chắc chắn).

    Thuộc tính:
        item (str hoặc None): Mục được lưu trữ trong nút này. Mặc định là None.
        prob (float): Xác suất liên quan đến nút này. Mặc định là 0.0.
        count (int): Số lần (hỗ trợ) của nút này. Mặc định là 0.
        utility (int): Giá trị tiện ích của mục của nút này. Mặc định là 0.
        nu (int): Tiện ích của nút, là giá trị tiện ích ước tính cho nút này. Mặc định là 0.
        children (dict): Từ điển lưu trữ các nút con, trong đó khóa là mục và giá trị là nút con tương ứng.
        parent (Node hoặc None): Tham chiếu đến nút cha của nút này. Mặc định là None.
    """

    def __init__(self, item=None, prob=0.0, count=0, utility=0, nu=0):
        """
        Khởi tạo một nút mới trong cây UHUFP.
        """
        self.item = item
        self.prob = prob
        self.count = count
        self.utility = utility
        self.children = {}
        self.parent = None
        self.nu = nu

# %%
class UHUFP_tree:
    """
    Lớp đại diện cho cây UHUFP (Cây mẫu tần suất tiện ích cao không chắc chắn).

    Thuộc tính:
        root (Node): Gốc của cây, là một đối tượng Node.
        header_table (defaultdict): Bảng tiêu đề, lưu trữ các liên kết đến các nút với cùng một mục.
    """

    def __init__(self):
        """
        Khởi tạo cây UHUFP với gốc là một nút rỗng và bảng tiêu đề là một defaultdict.
        """
        self.root = Node()
        self.header_table = defaultdict(list)

    def insert_reorganized_transaction(self, transaction, utilities, sorted_items):
        """
        Chèn một giao dịch đã được tổ chức lại vào cây UHUFP.

        Tham số:
            transaction (dict): Giao dịch với các mục và xác suất tương ứng.
            utilities (dict): Bảng tiện ích của các mục trong giao dịch.
            sorted_items (list): Danh sách các mục được sắp xếp theo thứ tự TWU giảm dần.
        """
        current_node = self.root
        rtu = sum(utilities.values())  # Tổng tiện ích của giao dịch

        for i, item in enumerate(sorted_items):
            item_prob = transaction[item]
            item_utility = utilities[item]
            
            if (item, item_prob, item_utility) in current_node.children:
                child_node = current_node.children[(item, item_prob, item_utility)]
                child_node.count += 1
                items_after = sorted_items[i+1:]
                remaining_utility = sum(utilities.get(it, 0) for it in items_after)
                child_node.nu += rtu - remaining_utility
            else:
                child_node = Node(item=item, prob=item_prob, count=1, utility=item_utility)
                items_after = sorted_items[i+1:]
                remaining_utility = sum(utilities.get(it, 0) for it in items_after)
                child_node.nu = rtu - remaining_utility
                
                child_node.parent = current_node
                current_node.children[(item, item_prob, item_utility)] = child_node
                self.header_table[item].append(child_node)
            
            current_node = child_node

    def insert_reorganized_path(self, transaction, utilities, sorted_items, miu):
        """
        Chèn một đường dẫn đã được tổ chức lại vào cây UHUFP.

        Tham số:
            transaction (dict): Giao dịch với các mục và xác suất tương ứng.
            utilities (dict): Bảng tiện ích của các mục trong giao dịch.
            sorted_items (list): Danh sách các mục được sắp xếp theo thứ tự tiện ích đường dẫn của item trong CPB giảm dần.
            miu (dict): Bảng tiện ích mục nhỏ nhất cho mỗi mục trong đường dẫn.
        """
        current_node = self.root
        for i, item in enumerate(sorted_items):
            item_prob = transaction[item]
            item_utility = utilities[item]

            if (item, item_prob, item_utility) in current_node.children:
                child_node = current_node.children[(item, item_prob, item_utility)]
                child_node.count += 1
                utility_after = sum(miu.get(x, 0) * child_node.count for x in list(sorted_items.keys())[i + 1:])
                child_node.nu += sorted_items[item] - utility_after
            else:
                child_node = Node(item=item, prob=item_prob, count=1, utility=item_utility)
                utility_after = sum(miu.get(x, 0) * child_node.count for x in list(sorted_items.keys())[i + 1:])
                child_node.nu = sorted_items[item] - utility_after

                child_node.parent = current_node
                current_node.children[(item, item_prob, item_utility)] = child_node
                self.header_table[item].append(child_node)

            current_node = child_node

    def print_header_table(self):
        """
        In bảng tiêu đề (header table) của cây UHUFP.
        """
        print("\nHeader Table:")
        for item, nodes in self.header_table.items():
            for node in nodes:
                print(f"  -> Node: Item={node.item}, Support={node.prob}, Count={node.count}, Utility={node.utility}")
        print("End of Header Table\n")

    def print_tree(self):
        """
        In cấu trúc của cây UHUFP.
        """
        def print_node(node, level=0):
            indent = ' ' * (level * 4)
            print(f"{indent}Item: {node.item}, Support: {node.prob}, Count: {node.count}, Utility: {node.utility}, Nu: {node.nu}")
            for child in node.children.values():
                print_node(child, level + 1)

        print("UHUFP Tree:")
        print_node(self.root)
        print("End of UHUFP Tree")

    def prune_patterns(self, k, item_twu, minUtil):
        """
        Cắt bớt các mẫu không cần thiết dựa trên TWU và số lượng top-k.

        Tham số:
            k (int): Số lượng các mục top-k cần giữ lại.
            item_twu (dict): Bảng TWU của các mục.
            minUtil (int): Ngưỡng tiện ích
        """
        item_exp_sups = {}
        for item, nodes in self.header_table.items():
            exp_sup = sum(node.prob * node.count for node in nodes)
            item_exp_sups[item] = exp_sup
        # Sắp xếp theo expSup của item
        sorted_items_by_exp_sup = sorted(self.header_table.keys(), key=lambda item: item_exp_sups[item], reverse=True)
        self.header_table = {item: self.header_table[item] for item in sorted_items_by_exp_sup}

        filtered_header_table = defaultdict(list)
        for item, nodes in self.header_table.items():
            k -= 1
            twu = item_twu[item]
            if twu >= minUtil:
                filtered_header_table[item] = self.header_table[item]
            if k <= 0:
                break
        self.header_table = filtered_header_table

    def prune_tree(self, node):
        """
        Loại bỏ các nút khỏi cây nếu mục của chúng không có trong bảng tiêu đề.

        Tham số:
            node (Node): Nút hiện tại đang xử lý để cắt tỉa.
        """
        items_to_keep = set(self.header_table.keys())
        children_to_keep = {k: v for k, v in node.children.items() if v.item in items_to_keep}
            
        node.children = children_to_keep
            
        for child in node.children.values():
            self.prune_tree(child)

# %% [markdown]
# ## Cài đặt thuật toán

# %%
class TUHUFP_Growth:
    """Lớp này triển khai thuật toán khai thác top-k mẫu phổ biến tiện ích cao không chắc chắn
    """

    def __init__(self):
        self.start_timestamp = 0
        self.end_timestamp = 0
        self.database_size = 0
        self.peak_memory_usage = 0
        self.top_k_UHUFP = []
        self.minUtil = 0

    
    def calculate_expected_support(self, paths, prefix):
        """Tính độ hỗ trợ mong đợi của mẫu (prefix) cụ thể thông qua đường dẫn đã thu thập

        Args:
            paths (Tuple(Tuple(List[str,float,int,int], int))): đường dẫn của prefix
            prefix (List[str]): mẫu cần tính giá trị tiện ích
        Returns:
            int: giá trị độ hỗ trợ mong đợi của prefix
        """

        total_expected_support = 0.0
        # paths = self.collect_paths_prefix(prefix)

        for path, count in paths:
            # Tạo tập hợp các item trong path
            path_items = {node[0] for node in path}

            # Kiểm tra xem tất cả các item trong prefix có nằm trong path không
            if all(item in path_items for item in prefix):
                path_support = 1.0
                for item in prefix:
                    # Tìm item trong path
                    i = next((i for i in path if i[0] == item), None)
                    if i:
                        path_support = round((path_support*i[1]),2) 
                    else:
                        path_support = 0
                        break

                total_expected_support += path_support * count 

        return round(total_expected_support, 2)




    def calculate_utility(self, paths, prefix):
        """Tính giá trí tiện ích của mẫu (prefix) cụ thể thông qua đường dẫn đã thu thập

        Args:
            paths (Tuple(Tuple(List[str,float,int,int], int))): đường dẫn của prefix
            prefix (List[str]): mẫu cần tính giá trị tiện ích
        Returns:
            int: giá trị tiện ích của prefix
        """

        prefix_utility = 0
        # paths = self.collect_paths_prefix(prefix)

        for path, count in paths:
            # Tạo tập hợp các item trong path
            path_items = {node[0] for node in path}

            # Kiểm tra xem tất cả các item trong prefix có nằm trong path không
            if all(item in path_items for item in prefix):
                sum_utility = 0
                for item in prefix:
                    # Tìm item trong path
                    i = next((i for i in path if i[0] == item), None)
                    if i:
                        sum_utility += i[2] 
                    else:
                        sum_utility = 0
                        break

                prefix_utility += sum_utility * count 

        return prefix_utility

        
 
    def calculate_twu(self, paths, prefix):
        """Tính TWU của prefix 

        Args:
            paths (Tuple(Tuple(List[str,float,int,int], int))): đường dẫn của prefix
            prefix (List[str]): mẫu cần tính TWU
        Returns:
            int: giá trị TWU
        """
        prefix_twu = 0
        # paths = self.collect_paths_prefix(prefix)

        for path, count in paths:
            # Tạo tập hợp các item trong path
            path_items = {node[0] for node in path}

            # Kiểm tra xem tất cả các item trong prefix có nằm trong path không
            if all(item in path_items for item in prefix):
                sum_twu= 0
                # Tính expected support cho path bằng cách nhân các xác suất (prob) của các items trong prefix
                for item in prefix:
                    # Tìm item trong path
                    i = next((i for i in path if i[0] == item), None)
                    if i:
                        sum_twu = i[3]  # Nhân xác suất (prob) của item trong path

                prefix_twu += sum_twu * count  # Nhân với count của path

        return prefix_twu


    def mine_top_k_patterns(self, uhufp_tree, k, minSup, minUtil, expected_support, prefix=None, top_k=None):
        """ Phương thức chính khai thác các tập mẫu UHUFP

        Args:
            uhufp_tree (UHUFP_tree): cây UHUFP của mẫu 
            k (int): số lượng mẫu cần tìm
            minSup (float): ngưỡng phổ biến trong top-k
            minUtil (int): ngưỡng tiện ích
            expected_support (float): giá trị độ hỗ trợ mong đợi của prefix, ban đâu là 0
            prefix (List[str]): là tiền tố của mẫu. Mặc đinh ban đầu None.
            top_k (List[UHUFP], ): danh sách chứa k mẫu UHUFP. Mặc đinh ban đầu None.

        Returns:
            List[UHUFP]: danh sách chứa k mẫu UHUFP.
        """
        if top_k is None:
            top_k = []
        if prefix is None:
            prefix = []
        if len(top_k) == k and top_k is not None:
            minSup = top_k[-1][1]

        #Duyệt từng phần từ trong bảng header
        for item, nodes in uhufp_tree.header_table.items():
            # kiểm tra item khác prefix
            if item not in prefix:
                max_prob = max(node.prob for node in nodes if node.item == item)
                overestimate = max_prob*expected_support
                if overestimate < minSup:
                    return top_k
                # Tạo mẫu mới từ prefix và item
                new_prefix = [item] + prefix

                if any(existing_pattern[0] == tuple(sorted(new_prefix)) for existing_pattern in top_k):
                    continue
                # print(f"ITEM: {new_prefix}")
                # thu thập conditional pattern base của mẫu
                conditional_pattern_base, miu, path_util_item = self.build_conditional_pattern_base(uhufp_tree, new_prefix, minUtil)
                if path_util_item >= minUtil:
                    # Tính độ hỗ trợ mong đợi
                    expected_support = self.calculate_expected_support(conditional_pattern_base, new_prefix)
            
                    # Tính giá trị tiện ích
                    utility = self.calculate_utility(conditional_pattern_base, new_prefix)
                    # xây dựng cây UHUFP cho new_prefix
                    conditional_pattern_tree = self.build_conditional_tree(conditional_pattern_base, miu)
                    # conditional_pattern_tree.print_tree()
                    # conditional_pattern_tree.print_header_table()
                    
                    # print(f"{new_prefix} : {expected_support} : {utility}")
                    
                    # kiểm tra độ hỗ trợ mong đợi với ngưỡng phổ biến và ngưỡng tiện ích
                    if expected_support > minSup:
                        if utility >= minUtil:
                            # Add the pattern to top_k list if necessary
                            top_k.append((tuple(sorted(new_prefix)), expected_support, utility))
                            # Sort and maintain top-k
                            top_k.sort(key=lambda x: (x[1], x[2]), reverse=True)
                            if len(top_k) > k:
                                top_k.pop()
                            if len(top_k) == k:
                                minSup = top_k[-1][1]
                        # tiếp tục gọi hàm với cây vừa tạo ở trên để khai thác các mẫu tiếp theo
                        if self.calculate_twu(conditional_pattern_base, new_prefix) >= minUtil:
                            if conditional_pattern_tree.root.children:
                                self.mine_top_k_patterns(conditional_pattern_tree, k, minSup, minUtil, expected_support, new_prefix, top_k)
    
        return top_k



    def collect_paths(self, uhufp_tree, prefix: List[str]) -> List[Tuple[List[Tuple[str, float, float, float]], int]]:
        """Phương thức thu thập các đường dẫn của prefix

        Args:
            uhufp_tree (UHUFP_tree): cây UHUFP của prefix
            prefix (List[str]): mẫu cần thu thập đường dẫn

        Returns:
            List[Tuple[List[Tuple[str, float, float, float]], int]]: các đường dẫn và các thông tin của đường dẫn
        """
        paths = []
        
        # Lấy item cuối cùng của prefix
        last_item = prefix[-1] if prefix else None
        # print(f"LAST ITEM: {last_item}")
        if last_item and last_item in uhufp_tree.header_table:
            for node in uhufp_tree.header_table[last_item]:
                path = []
                current_node = node
                
                # duyệt từ node hiện tại về gốc của cây
                while current_node and current_node.item is not None:
                    path.append((current_node.item, current_node.prob, current_node.utility, current_node.nu))
                    if current_node.parent is None:
                        break
                    current_node = current_node.parent
                
                # Đảo ngược path để có thứ tự từ gốc đến node hiện tại
                path.reverse()
                
                # Kiểm tra xem path có chứa tất cả các item trong prefix không
                if all(item in [p[0] for p in path] for item in prefix):
                    paths.append((path, node.count))
        # for path, count in paths:
            # print(f"Path: {path}, Count: {count}")
        return paths



    def build_conditional_pattern_base(self, uhufp_tree, item: str, min_util: float) -> List[Tuple[Dict[str, float], Dict[str, float], int]]:
        """phương thức thu thập đường dần của item và tổ chức lại đường dẫn

        Args:
            uhufp_tree (UHUFP_tree): cây UHUFP của item
            item (str): mẫu cần thu thập đường dẫn
            min_util (float): ngưỡng tiện ích

        Returns:
            List[Tuple[Dict[str, float], Dict[str, float], int]]: _description_
        """
        paths = self.collect_paths(uhufp_tree, item)
        conditional_pattern_base = []

        # print(f"Paths for item {item}: {paths}")
        path_utilities_item = defaultdict(int)
        for path, count in paths:
            path_utility = path[-1][3]  # Total utility of the path

            # tính tiện ích đường dẫn của item trong đường dẫn
            for i in path:
                path_utilities_item[i[0]] += path_utility

            # print(f"Path: {path}")
            # print(f"Path utility: {path_utility}")
            # print(f"Path utilities item: {dict(path_utilities_item)}")
        path_util_item = 0
        # tính tiện ích đường dẫn của item trong CPB
        for i in item:
            path_util_item += path_utilities_item[i]
        unpromissing_item = []
        miu = {}
        # các giá trị tiện ích nhỏ nhất của các item trong path
        for path, count in paths:
            for i, s, u, _ in path:
                if i in miu:
                    miu[i] = min(miu[i], u)
                else:
                    miu[i] = u

        for path, count in paths:
            filtered_pu = 0
            for i, s, _, u in path:
                if path_utilities_item[i] <= min_util:
                    filtered_pu += miu[i] * count
                    # print(f"Item: {i}, Node Utility: {u}, Min Utility: {miu[i]}, Count: {count}")
                    # print(f"Filtered Utility for item {i}: {filtered_pu}")
                    unpromissing_item.append((i,s,u))  
            
            reorganized_path = []

            for i, s, u, _ in path:
                if (i,s,u) not in unpromissing_item:
                    reorganized_path.append((i, s, u, path[-1][3] - filtered_pu))
            # sắp xếp danh sách path theo giá trị tiện ích đường dẫn của item trong CPB
            sorted_reorganized_path = sorted(reorganized_path, key=lambda x: path_utilities_item[x[0]], reverse=False)
            # print(f"Reorganized Path: {reorganized_path}")
            # print(f"Sorted Reorganized Path: {sorted_reorganized_path}")
        
            if sorted_reorganized_path:
                conditional_pattern_base.append((sorted_reorganized_path, count))
                # print(f"Conditional Pattern Base Entry: {conditional_pattern_base}")
        
        return conditional_pattern_base, miu, path_util_item



    def build_conditional_tree(self, conditional_pattern_base: List[Tuple[Tuple[str,float,int], int]], miu) -> 'UHUFP_tree':
        """Xây dựng cây UHUFP cho item từ CPB của item

        Args:
            conditional_pattern_base (List[Tuple[Tuple[str,float,int], int]]): chứa các đường dẫn của item
            miu (Dict[str:int]): danh sách các giá trị tiện ích nhỏ nhất của các item trong đường dẫn

        Returns:
            UHUFP_tree: cây UHUFP
        """
        
        conditional_tree = UHUFP_tree()

        for path, count in conditional_pattern_base:
            filtered_path = {item: support for item, support,_, _ in path}
            filtered_utilities = {item: util for item, _, util, _ in path}
            filtered_path_utility = {item: pu for item, _, _, pu in path}
            if filtered_path:  # nếu tồn tại path
                # print(f"Inserting transaction into conditional tree: Path: {filtered_path}, Utilities: {filtered_utilities}")
                conditional_tree.insert_reorganized_path(filtered_path, filtered_utilities, filtered_path_utility, miu)

        return conditional_tree


    def load_transactions_and_utilities(self, transaction_file: str, utility_file: str):
        """Đọc các cơ sở dữ liệu 

        Args:
            transaction_file (str): _description_
            utility_file (str): _description_

        Returns:
            Tuple[List[Dict[str, float]], List[Dict[str, float]], List[str], Dict[str, int], int]: các giá trị giao dịch chứa xác xuất và giá trị tiện ích
        """
        
        transactions = []
        utilities = []
        items = []
        dbUtil = 0
        item_twu = defaultdict(int)

        with open(transaction_file, mode='r') as tfile, open(utility_file, mode='r') as ufile:
            tlines = tfile.readlines()
            ulines = ufile.readlines()

            # Đọc file chứ dữ liệu xác xuất
            header = tlines[0].strip().split()
            items = [item.strip() for item in header]

            for line1, line2 in zip(tlines[1:], ulines):
                row = line1.strip().split()
                transaction = {items[i]: float(row[i]) for i in range(len(items)) if float(row[i]) > 0}
                transactions.append(transaction)

                parts = line2.strip().split(':')
                item_list = parts[0].split()
                utility_values = list(map(int, parts[2].split()))
                utility = {item_list[i]: utility_values[i] for i in range(len(item_list)) if item_list[i] in transaction}
                utilities.append(utility)
                dbUtil += int(parts[1])
                # print(transaction_utility)
                self.database_size += 1

            for utility in utilities:
                for item, util in utility.items():
                    item_twu[item] += sum(utility.values())
        
        return transactions, utilities, item, item_twu, dbUtil

    def build_tree_and_mine_patterns(self, transaction_file: str, utility_file: str, k: int, percentage: float, minSup: float):
        """Chạy thuật toán TUHUFP_Growth

        Args:
            transaction_file (str): các giao chứa xác xuất
            utility_file (str): giao chứa tiện ích
            k (int): số lượng mẫu cần khai thác
            percentage (float): ngưỡng tiện ích (%)
            minSup (float): ngưỡng phổ biến
        """
        
        self.start_timestamp = time.time()
        self.candidates = 0
        self.database_size = 0
        transactions, utilities, items, item_twu, dbUtil = self.load_transactions_and_utilities(transaction_file, utility_file)
        promising_items = set()
        unpromising_items = set()
        reorganized_transaction = defaultdict(float)
        reorganized_utilities = defaultdict(int)
        
        uhufp_tree = UHUFP_tree()
        minUtil = int(dbUtil*percentage)
        # lấy danh sách các item hứa hẹn
        for item, twu in item_twu.items():
            if twu >= self.minUtil:
                promising_items.add(item)
            else:
                unpromising_items.add(item)

        # print(promising_items)

        for transaction, utility in zip(transactions, utilities):
            # print(transaction)
            reorganized_transaction = {item: prob for item, prob in transaction.items() if item in promising_items}
            reorganized_utilities = {item: util for item, util in utility.items() if item in reorganized_transaction}
            sorted_items = sorted(reorganized_transaction.keys(), key=lambda item: item_twu[item], reverse=True)
            # print(sorted_items)
            # xây dựng cây UHUFP
            uhufp_tree.insert_reorganized_transaction(reorganized_transaction, reorganized_utilities, sorted_items)

        # uhufp_tree.print_header_table()
        # uhufp_tree.prune_patterns(k, item_twu, minUtil)
        # uhufp_tree.prune_tree(uhufp_tree.root)
        
        # print({'database util: ': dbUtil})
        print({'min util: ': minUtil})

        # Bắt đầu theo dõi bộ nhớ
        tracemalloc.start()
        self.top_k_UHUFP = self.mine_top_k_patterns(uhufp_tree, k, minSup, minUtil, 1.0)
        self.minUtil = minUtil
        self.top_k_UHUFP.sort(key=lambda x: x[2], reverse=True)
        # Kết thúc theo dõi bộ nhớ và lấy thông tin
        _, self.peak_memory_usage = tracemalloc.get_traced_memory()
        tracemalloc.stop()
        self.peak_memory_usage /= 10**6  # Chuyển đổi sang MB

        self.end_timestamp = time.time()
        # print("\nTop-K High Utility Frequent Patterns:")
        for i, (pattern, expSup, utility) in enumerate(self.top_k_UHUFP, 1):
            print(f"{i}. Pattern: {pattern}, ExpSup: {expSup}, Utility: {utility}")

    def print_stats(self, path):
        """Thống kê thông tin kết quả chạy thuật toán

        Args:
            path (str): đường dẫn lưu thông tin
        """
        total_utility = 0
        directory = os.path.dirname(path)
        if directory and not os.path.exists(directory):
            os.makedirs(directory)

        with open(path, 'w') as output_file:
            output_file.write(f"minUtil: {self.minUtil}\n")
            self.top_k_UHUFP.sort(key=lambda x: x[2], reverse=True)
            for i, (pattern, expSup, utility) in enumerate(self.top_k_UHUFP, 1):
                total_utility += utility
                output_file.write(f"{i}. Pattern: {pattern}, ExpSup: {expSup}, Utility: {utility}\n")
            output_file.write("=============  TOP-K UFPs v1.20 - STATS =============\n")
            output_file.write(f" Transactions count from database : {self.database_size}\n")
            output_file.write(f" Candidates count : {self.candidates}\n")
            output_file.write(f" Total utility : {total_utility}\n")
            output_file.write(f" Algorithm run time : {self.end_timestamp - self.start_timestamp:.0f} seconds\n")
            output_file.write(f" Peak memory usage : {self.peak_memory_usage:.2f} MB\n")  # Ghi lại peak memory usage

# %% [markdown]
# ## Thực nghiệm

# %%
transaction_file = './data/example.txt'
utility_file = './data/example_utility.txt'
k = 6
percentage = 0.3
minSup = 0.0
tuhufp_growth = TUHUFP_Growth()
tuhufp_growth.build_tree_and_mine_patterns(transaction_file, utility_file, k, percentage, minSup)
tuhufp_growth.print_stats("./out/TUHUFP_Growth/output_example.txt")

# %% [markdown]
# ## Hiện thực foodmart

# %%
transaction_file = './data/input_foodmart.txt'
utility_file = './data/foodmart_utility.txt'
k = 100
percentage = 0.0004
minSup = 0.0
tuhufp_growth = TUHUFP_Growth()
tuhufp_growth.build_tree_and_mine_patterns(transaction_file, utility_file, k, percentage, minSup)
tuhufp_growth.print_stats("./out/TUHUFP_Growth/foodmart/output_foodmart_top_100.txt")

# %% [markdown]
# ## Hiện thực Chess

# %%
transaction_file = './data/input_chess.txt'
utility_file = './data/chess_utility.txt'
k = 100
percentage = 0.001
minSup = 0.0
tuhufp_growth = TUHUFP_Growth()
tuhufp_growth.build_tree_and_mine_patterns(transaction_file, utility_file, k, percentage, minSup)
tuhufp_growth.print_stats("./out/TUHUFP_Growth/chess/output_chess_top_100.txt")

# %% [markdown]
# ## Hiện thực retail

# %%
transaction_file = '../../data/input_retail.txt'
utility_file = '../../data/retail_utility.txt'
k = 100
percentage = 0.0001
minSup = 0.0
tuhufp_growth = TUHUFP_Growth()
tuhufp_growth.build_tree_and_mine_patterns(transaction_file, utility_file, k, percentage, minSup)
tuhufp_growth.print_stats("../../out/TUHUFP_Growth/retail/output_retail_top_100.txt")

# %% [markdown]
# # Thuật toán 3: UHUOPM

# %% [markdown]
# ## Thư viện

# %%
import sys, os
import time
import tracemalloc
import random
random.seed(42)

# %% [markdown]
# ## Cài đặt cấu trúc dữ liệu

# %% [markdown]
# ### PUO-lists

# %%
class PUO:
    """
    Là một đối tượng lưu trữ các thông tin i của mỗi giao dịch (TID, xác xuất, tỷ lệ tiện ích, tỷ lệ tiện ích còn lại)
    """
    def __init__(self, TID, prob, utility, r_utility, twu, uo, ruo):
        """
        Khởi tạo PUO

        Args:
            TID (int): mã giao dịch
            prob (float): xác xuất tồn tại
            uo (float): giá trị tiện ích
            ruo (float): tiện ích giao dịch
        """
        self.TID = TID
        self.prob = prob
        self.utility = utility
        self.r_utility = r_utility
        self.twu = twu
        self.uo = round(uo, 4)
        self.ruo = round(ruo, 4)
        self.zrutils = self.utility if self.r_utility == 0 else 0

    def __repr__(self):
        return f"PUO(TID={self.TID}, prob={self.prob:.4f}, utility={self.utility}, r_utility={self.r_utility}, twu={self.twu}, uo={self.uo:.4f}, ruo={self.ruo:.4f})\n"

# %%
class PUOList:
    """
    Là một đối tượng lưu trữ danh sách giao dịch của i (PUO)
    """
    def __init__(self, name=None):
        """
        Khởi tạo PUOList

        Args:
            name (str): tên của i
            PUO (PUO): PUO
        """
        self.name = name
        self.puo_list = []

    def add_puo(self, PUO):
        self.puo_list.append(PUO)

    def __repr__(self):
        return f"PUOList(Name={self.name}, PUO={self.puo_list})\n"

# %%
class PFUTable:
    """
    PFUTable là đối tượng chứa các thông tin của một i bao gồm: tên, tần suất, tỷ lệ tiện ích, tỷ lệ tiện ích còn lại 
    """
    def __init__(self, name=None, puo_list=None):
        """
        khởi tạo PFUTable

        Args:
            name (str): tên của cup (tức tên của i)
            puo_list (PUOList): danh sách PUOList của i
        """
        self.name = name
        self.sup = len(puo_list.puo_list) if puo_list.puo_list else 0
        self.utility = round(sum(suo_list.utility for suo_list in puo_list.puo_list) if puo_list.puo_list else 0, 2)
        self.r_utility = round(sum(suo_list.r_utility for suo_list in puo_list.puo_list) if puo_list.puo_list else 0, 2)
        self.twu = sum(suo_list.twu for suo_list in puo_list.puo_list) if puo_list.puo_list else 0
        self.pro = sum(suo_list.prob for suo_list in puo_list.puo_list) if puo_list.puo_list else 0
        self.uo = round((sum(suo_list.uo for suo_list in puo_list.puo_list) / self.sup if puo_list.puo_list else 0) , 4)
        self.ruo = round((sum(suo_list.ruo for suo_list in puo_list.puo_list) / self.sup if puo_list.puo_list else 0), 4)
        self.zrutils = round(sum(suo_list.utility for suo_list in puo_list.puo_list if suo_list.r_utility == 0) if puo_list.puo_list else 0, 2)

    def __repr__(self):
        return f"PFUTable(name={self.name}, sup={self.sup}, pro={self.pro:.4f}, utility={self.utility}, r_utility={self.r_utility}, twu={self.twu}, uo={self.uo:.4f}, ruo={self.ruo:.4f})\n"

# %%
class MMU:
    def __init__(self, name, MMU):
        self.name = name
        self.MMU = MMU

# %%
# a b c d e
# 0.6 0 0.8 0.5 0
# 0 0.7 0.4 0 0
# 0.6 0.6 0.9 0.8 0
# 0 0.5 0 0.8 0
# 0.9 0.7 0.9 0.6 0.8
# 0 0 0.9 0 0.8
# 0 0 0.4 0.9 0
# 0.6 0.8 0 0.8 0.5
# 0.6 0 0.5 0.3 0
# 0 0 0.6 0 0.7

# a d c:65:14 7 44
# b c:37:4 33
# a b d c:38:21 4 2 11
# b d:11:8 3
# e a b d c:49:9 7 6 5 22 
# e c:58:36 22
# d c:23:1 22
# e a b d:61:36 21 2 2
# a d c:59:14 1 44
# e c:42:9 33

# %% [markdown]
# ## Cài đặt thuật toán

# %%
class UHUOPM:
    def __init__(self):
        self.start_timestamp = 0
        self.end_timestamp = 0
        self.database_size = 0
        self.mmu_dict = {}
        self.puo_list_dict = {}
        self.pfu_table_dict = {}
        self.utility_max = {}
        self.item_name = []
        self.min_sup = 0
        self.min_utility = 0
        self.PHUOPs = set()
        self.peak_memory_usage = 0

    def read_data(self, file_path):
        file_paths = file_path.split(", ")
        try:
            with open(file_paths[0], 'r') as file1, open(file_paths[1], 'r') as file2:
                print("Reading data . . .")
                tlines = file1.readlines()
                ulines = file2.readlines()   
                self.database_size = len(tlines)
                return tlines, ulines   
        except FileNotFoundError as e:
            print(f"File not found: {e}")
            print("STOP ALGORITHM !!!")
            sys.exit(0)
        except Exception as e:
            print(f"An error occurred: {e}")
            sys.exit(0)
    
    def process_data(self, file_path, GLMU):
        tlines, ulines = self.read_data(file_path)

        self.is_name = tlines[0].strip().split(" ")

        for i in self.is_name:
            self.puo_list_dict[i] = PUOList(i)

        for idx_line, line in enumerate(tlines[1:]):
            probabilities = list(map(float, line.strip().split())) 

            utility = ulines[idx_line]
            parts = utility.split(":")
            keys = parts[0].split()  
            total_sum = int(parts[1]) 
            values = list(map(int, parts[2].split()))  

            result = {key: value for key, value in zip(keys, values)}
            result["sum"] = total_sum
            
            for idx, prob in enumerate(probabilities):
                if prob > 0:
                    i = self.is_name[idx]
                    if i in result.keys():
                        positions = keys.index(i)
                        utility = result[i]
                        r_utility = sum(values[positions+1:])
                        uo = result[i] / result['sum']
                        ruo = sum(values[positions+1:]) / result['sum']

                        self.puo_list_dict[i].add_puo(PUO(idx_line + 1, prob, utility, r_utility, total_sum, uo, ruo))

        for idx, i in enumerate(self.is_name):
            self.mmu_dict[i] = max((GLMU / 100) * random.randint(1, 200), GLMU)
            self.pfu_table_dict[i] = PFUTable(i, self.puo_list_dict.get(i))

    def run_UHUOPM(self, file_path, k):
        

        # sorted_by_utility = sorted(self.pfu_table_dict.values(), key=lambda x: x.utility)
        # # a = [i.name for i in pfu_sort]
        # for i in sorted_by_utility:
        #     if i not in pfu_sort and i.utility > self.min_utility:
        #         pfu_sort.append(i)
        #         pfu_sort.remove(min(pfu_sort, key=lambda x: x.utility))
        #         self.min_utility = min(pfu_sort, key=lambda x: x.utility).utility
        # # self.min_sup = min(pfu_sort, key=lambda x: x.pro).pro
        # # b = [i.name for i in pfu_sort]

        # primary = [i.name for i in pfu_sort]

        # secondary = [
        #     i.name for i in self.pfu_table_dict.values()
        #     if i.r_utility > self.min_utility
        # ]

        # primary = sorted(primary, key=lambda x: self.pfu_table_dict.get(x).pro, reverse=True)
        # secondary = sorted(secondary, key=lambda x: self.pfu_table_dict.get(x).pro, reverse=True)

        # for i in primary:
        #     self.judge(i, k)
        
        # print(primary)
        # print(secondary)


        # secondary = [i.name for i in pfu_sort]

        
        # pfu_sort = sorted(self.pfu_table_dict.values(), key=lambda x: x.pro, reverse=True)
        
        # top_k_is = pfu_sort[:k]

        # self.min_utility = min(
        #     top_k_is,  
        #     key=lambda x: x.utility
        # ).utility

        # self.is_name = [i.name for i in top_k_is]

        # self.is_name = [i.name for i in pfu_sort]
        
        # self.item_name = sorted(self.item_name, key=lambda x: self.pfu_table_dict.get(x).utility, reverse=True)
        
        # self.min_sup = min(a, key=lambda x: x.pro).pro
        # self.is_name.extend(
        #     i.name
        #     for i in pfu_sort
        #     if i.name not in self.is_name and (i.utility + i.r_utility) > self.min_utility
        # )

        # print(len(self.is_name) ,(self.is_name))

        # print(self.puo_list_dict.keys())
        # print(self.pfu_table_dict)

        self.start_timestamp = time.time()

        D = self.database_size

        if 'foodmart' in file_path:
            GLMU = (k / 100) * 1000
        elif 'chess' in file_path or 'retail' in file_path:
            GLMU = (k / 100) * 100000
        else:
            GLMU = (k / 100)

        self.process_data(file_path, GLMU)

        
        # self.min_utility = min(pfu_sort, key=lambda x: x.utility).utility

        # is_with_high_twu = [i for i in self.pfu_table_dict.values() if i.twu >= self.min_utility and self.calculate_lu('', i.name) >= self.calculate_emu('', i.name)]
        # self.item_name = [i.name for i in is_with_high_twu]

        pfu_sort1 = sorted(self.pfu_table_dict.values(), key=lambda x: x.utility, reverse=True)[:k]
        pfu_sort = sorted(self.pfu_table_dict.values(), key=lambda x: x.pro, reverse=True)[:k]
        # self.item_name = sorted(self.item_name, key=lambda x: self.pfu_table_dict.get(x).utility, reverse=True)[:k]
        
        self.min_utility = min(pfu_sort1, key=lambda x: x.utility).utility
        # self.min_sup = min(pfu_sort, key=lambda x: x.pro).pro
        self.item_name = [i.name for i in pfu_sort1 if i.pro > self.min_sup]
        self.item_name = sorted(self.item_name, key=lambda x: self.pfu_table_dict.get(x).pro, reverse=True)[:k]
        # print(self.min_sup, self.min_utility)
        for x_a in self.item_name:
            pfu_x_a = self.pfu_table_dict.get(x_a)
            if pfu_x_a.pro < self.min_sup:
                break
            
            if pfu_x_a.utility >= self.min_utility and pfu_x_a.utility > self.calculate_miu(x_a):
                if pfu_x_a.pro > self.min_sup: 
                    self.judge(x_a, k)

        tracemalloc.start()
        self.PHUOP_Search("", self.item_name, k)
        # self.PHUOP_Search("", primary, secondary, k)
        self.PHUOPs = sorted(self.PHUOPs, key=lambda x: float(x[2].split(': ')[1]), reverse=True)[:k]

        i = 1
        for pfu in self.PHUOPs:
            print(f" {i}: {pfu}")
            i +=1

        _, self.peak_memory_usage = tracemalloc.get_traced_memory()
        tracemalloc.stop()
        self.peak_memory_usage /= 10**6
        self.end_timestamp = time.time()
    
    # def PHUOP_Search(self, X, primary, secondary, k):
    #     D = self.database_size
    #     for x_a in primary:
    #         pfu_x_a = self.pfu_table_dict.get(x_a)
    #         if pfu_x_a.pro < self.min_sup:
    #             return
    #         # print(x_a, pfu_x_a.utility >= self.min_utility, pfu_x_a.pro > self.min_sup)
    #         if pfu_x_a.utility > self.min_utility:
    #             if pfu_x_a.pro > self.min_sup: 
    #                 self.judge(x_a, k)

    #         if pfu_x_a.utility + pfu_x_a.r_utility >= self.min_utility:
    #             if pfu_x_a.pro > self.min_sup:
    #                 primary_extend = []
    #                 secondary_extend = []
                    
    #                 for x_b in secondary:
    #                     # print(x_b)
    #                     if self.pfu_table_dict.get(x_b).pro > self.min_sup and x_b != x_a:
    #                         puo_list = self.puo_list_dict.get(x_b)
    #                         max_prob = max(puo.prob for puo in puo_list.puo_list)
    #                         if pfu_x_a.pro * max_prob > self.min_sup:
    #                             x_ab = self.construct(X, x_a, x_b)
    #                             if x_ab != None:
    #                                 pfu_x_ab = self.pfu_table_dict.get(x_ab)
    #                                 # print(x_ab, pfu_x_ab.utility, pfu_x_ab.r_utility, self.min_sup, pfu_x_ab.pro > self.min_sup, self.calculate_lu(x_a, x_b) > self.min_utility)
    #                                 if pfu_x_ab.utility + pfu_x_ab.r_utility >= self.min_utility and pfu_x_ab.pro > self.min_sup:
    #                                     primary_extend.append(x_ab)
    #                                 if self.calculate_lu(x_a, x_b) >= self.min_utility:
    #                                     secondary_extend.append(x_ab)
    #                 # print(x_a, primary_extend, secondary_extend)
    #                 self.PHUOP_Search(x_a, primary_extend, secondary_extend, k)
    def calculate_lu(self, x_a, x_b):
        # if x_a > x_b:
        #     x_a, x_b = x_b, x_a
        if x_a == '':
            s = 0
            for i in self.puo_list_dict.get(x_b).puo_list:
                s += i.utility
            return s

        combined_utility = 0
        i_a = self.puo_list_dict.get(x_a).puo_list
        i_b = self.puo_list_dict.get(x_b).puo_list
        for Ea in i_a:
            for Eb in i_b:
                if Ea.TID == Eb.TID:
                    combined_utility += (Ea.utility + Ea.r_utility)
        
        return combined_utility
    
    def calculate_miu(self, x):
        selected_values = [self.mmu_dict[key] for key in x if key in self.mmu_dict]
        return min(selected_values) if selected_values else 0

    def calculate_smu(self, x):
        last_index = -1
        for char in x:
            if char in self.item_name:
                last_index = self.item_name.index(char)
        result = self.item_name[last_index + 1:]

        return min(self.calculate_miu(x), self.calculate_miu(result))

    def calculate_emu(self, x, e_x):
        last_index = -1
        for char in e_x:
            if char in self.item_name:
                last_index = self.item_name.index(char)
        result = self.item_name[last_index + 1:]

        if x == '':
            return min(self.calculate_miu(e_x), self.calculate_miu(result))

        return min(self.calculate_miu(x), self.calculate_miu(e_x), self.calculate_miu(result))
    
    def PHUOP_Search(self, X, exten_of_x, k):
        D = self.database_size    
        # print(X, exten_of_x)
        for idx, x_a in enumerate(exten_of_x):
            pfu_x_a = self.pfu_table_dict.get(x_a)
            
            if pfu_x_a.pro < self.min_sup:
                # print(X, x_a)
                return
                
            if pfu_x_a.utility >= self.min_utility and pfu_x_a.utility > self.calculate_miu(x_a):
                if pfu_x_a.pro > self.min_sup: 
                    self.judge(x_a, k)

            x_u_ru = pfu_x_a.utility + pfu_x_a.r_utility
            if x_u_ru - pfu_x_a.zrutils >= self.min_utility and x_u_ru > self.calculate_smu(x_a):
                if pfu_x_a.pro > self.min_sup:
                    exten = []
                    for x_b in exten_of_x[idx + 1:]:
                        if self.pfu_table_dict.get(x_b).pro > self.min_sup and self.calculate_lu(x_a, x_b) > self.calculate_emu(x_a, x_b):
                            puo_list = self.puo_list_dict.get(x_b)
                            max_prob = max(puo.prob for puo in puo_list.puo_list)
                            # print(pfu_x_a.pro * max_prob, pfu_x_a.pro, max_prob ,self.min_sup)
                            if pfu_x_a.pro * max_prob > self.min_sup:
                                x_ab = self.construct(X, x_a, x_b)
                                # print(x_a, x_b, x_ab)
                                if x_ab != None:
                                    pfu_x_ab = self.pfu_table_dict.get(x_ab)
                                    if pfu_x_ab.pro > self.min_sup and pfu_x_ab.utility + pfu_x_ab.r_utility > self.calculate_smu(x_ab) and pfu_x_ab.twu > self.min_utility:
                                        exten.append(x_ab)
                            else:
                                break
                        else:
                            break
                    # exten = sorted(exten, key=lambda x: self.pfu_table_dict.get(x).pro, reverse=True)
                    self.PHUOP_Search(x_a, exten, k)

    def judge(self, x, k):
        pfu_x = self.pfu_table_dict.get(x)
        if len(self.PHUOPs) >= k:
            self.min_sup = float(min(
                self.PHUOPs,  
                key=lambda x: float(x[1].split(': ')[1])
            )[1].split(': ')[1])

            self.min_utility = int(min(
                self.PHUOPs,  
                key=lambda x: float(x[2].split(': ')[1])
            )[2].split(': ')[1])

            min_utility_item = min(
                self.PHUOPs, 
                key=lambda x: float(x[2].split(': ')[1])
            )

            self.PHUOPs.remove(min_utility_item)
        
        self.PHUOPs.add((
            f"Name: {x}",
            f"prob: {pfu_x.pro:.2f}",
            f"utility: {pfu_x.utility}"
        ))        
        

    def construct(self, x, xa, xb):
        xa_list = xa.split(", ")
        xb_list = xb.split(", ")
        unique_numbers = set(xa_list + xb_list)
        x_ab = ", ".join(sorted(unique_numbers))
        self.puo_list_dict[x_ab] = PUOList(x_ab)
        self.pfu_table_dict[x_ab] = PFUTable(x_ab, PUOList(x_ab))
        TUTIL = self.pfu_table_dict[xa].utility + self.pfu_table_dict[xa].r_utility
        flag = False

        for Ea in self.puo_list_dict[xa].puo_list:
            for Eb in self.puo_list_dict[xb].puo_list:
                if Ea.TID == Eb.TID:
                    flag = True
                    if(self.puo_list_dict.get(x)):
                        for E in self.puo_list_dict.get(x).puo_list:
                            if E.TID == Ea.TID:
                                E_ab = PUO(Ea.TID, (Ea.prob * Eb.prob) / E.prob, Ea.utility + Eb.utility - E.utility, Eb.r_utility, Ea.twu, Ea.uo + Eb.uo - E.uo, Eb.ruo)

                                self.pfu_table_dict[x_ab].pro += E_ab.prob
                                self.pfu_table_dict[x_ab].uo += E_ab.uo
                                self.pfu_table_dict[x_ab].ruo += E_ab.ruo
                                self.pfu_table_dict[x_ab].utility += E_ab.utility
                                self.pfu_table_dict[x_ab].r_utility += E_ab.r_utility
                                self.pfu_table_dict[x_ab].twu += E_ab.twu
                                break
                    else:
                        E_ab = PUO(Ea.TID, (Ea.prob * Eb.prob), Ea.utility + Eb.utility, Eb.r_utility, Ea.twu, Ea.uo + Eb.uo, Eb.ruo)

                        self.pfu_table_dict[x_ab].pro += E_ab.prob
                        self.pfu_table_dict[x_ab].uo += E_ab.uo
                        self.pfu_table_dict[x_ab].ruo += E_ab.ruo
                        self.pfu_table_dict[x_ab].utility += E_ab.utility
                        self.pfu_table_dict[x_ab].r_utility += E_ab.r_utility
                        self.pfu_table_dict[x_ab].twu += E_ab.twu
                    
                    self.pfu_table_dict[x_ab].sup += 1
                    self.puo_list_dict[x_ab].add_puo(E_ab)
            if flag == False:
                TUTIL = TUTIL - Ea.utility - Ea.r_utility
                if TUTIL < self.calculate_smu(xa):
                    return None
            flag = False
            
        return x_ab


    def print_stats(self, path):
        """
        Thống kê thông tin kết quả chạy thuật toán

        Args:
            path (str): đường dẫn lưu thông tin
        """        
        total_utility = 0
        directory = os.path.dirname(path)
        if directory and not os.path.exists(directory):
            os.makedirs(directory)

        with open(path, 'w') as output_file:
            output_file.write(f"minUtil: {self.min_utility}\n")
            for t in self.PHUOPs:
                total_utility += int(t[2].split(": ")[1])
                output_file.write(f"{t[0]}: {t[1]}: {t[2]}\n")
            output_file.write("=============  TOP-K UHOUPM - STATS =============\n")
            output_file.write(f" Transactions count from database : {self.database_size}\n")
            output_file.write(f" Sum utility : {total_utility}\n")
            output_file.write(f" Algorithm run time : {self.end_timestamp - self.start_timestamp:.0f} seconds\n")
            output_file.write(f" Peak memory usage : {self.peak_memory_usage:.2f} MB\n")

# %%
algorithm = UHUOPM()
algorithm.run_UHUOPM("./data/example.txt, ./data/example_utility.txt", 6)
algorithm.print_stats("./out/UHUOPM/output_example.txt")
# Out:
# Reading data . . .
#  1: ('Name: a, c, d', 'prob: 0.97', 'utility: 42')
#  2: ('Name: b, c, d', 'prob: 0.87', 'utility: 40')
#  3: ('Name: c, d', 'prob: 1.95', 'utility: 38')
#  4: ('Name: a, d', 'prob: 1.20', 'utility: 35')
#  5: ('Name: d', 'prob: 3.30', 'utility: 30')
#  6: ('Name: a, b', 'prob: 1.64', 'utility: 23')

# %%
# chạy với foodmart
algorithm = UHUOPM()
algorithm.run_UHUOPM("./data/input_foodmart.txt, ./data/foodmart_utility.txt", 300)
algorithm.print_stats("./out/UHUOPM/foodmart/output_foodmart_top_25.txt")
# Out:
# Reading data . . .
#  1: ('Name: 1373', 'prob: 13.55', 'utility: 25560')
#  2: ('Name: 1292', 'prob: 12.60', 'utility: 24642')
#  3: ('Name: 988', 'prob: 9.30', 'utility: 24187')
#  4: ('Name: 225', 'prob: 8.04', 'utility: 22951')
#  5: ('Name: 222', 'prob: 9.33', 'utility: 22910')
#  6: ('Name: 272', 'prob: 13.54', 'utility: 22678')
#  7: ('Name: 1426', 'prob: 9.96', 'utility: 21692')
#  8: ('Name: 1161', 'prob: 10.54', 'utility: 21540')
#  9: ('Name: 1045', 'prob: 9.48', 'utility: 21090')
#  10: ('Name: 446', 'prob: 6.93', 'utility: 20625')
#  11: ('Name: 83', 'prob: 6.68', 'utility: 20563')
#  12: ('Name: 1518', 'prob: 7.94', 'utility: 20416')
#  13: ('Name: 1180', 'prob: 8.06', 'utility: 19890')
#  14: ('Name: 1012', 'prob: 11.65', 'utility: 19861')
#  15: ('Name: 175', 'prob: 9.14', 'utility: 19635')
#  16: ('Name: 1380', 'prob: 7.99', 'utility: 19548')
#  17: ('Name: 1368', 'prob: 7.57', 'utility: 19525')
#  18: ('Name: 1497', 'prob: 7.19', 'utility: 19406')
#  19: ('Name: 937', 'prob: 7.24', 'utility: 19133')
#  20: ('Name: 1508', 'prob: 10.16', 'utility: 19116')
#  21: ('Name: 1310', 'prob: 8.53', 'utility: 19102')
#  22: ('Name: 409', 'prob: 6.42', 'utility: 18768')
#  23: ('Name: 941', 'prob: 8.96', 'utility: 18565')
#  24: ('Name: 276', 'prob: 10.37', 'utility: 18528')
#  25: ('Name: 614', 'prob: 6.10', 'utility: 18522')
#  26: ('Name: 278', 'prob: 9.33', 'utility: 18480')
#  27: ('Name: 918', 'prob: 11.38', 'utility: 18414')
#  28: ('Name: 470', 'prob: 8.96', 'utility: 18259')
#  29: ('Name: 1282', 'prob: 10.05', 'utility: 18232')
#  30: ('Name: 702', 'prob: 6.33', 'utility: 18048')
#  31: ('Name: 1110', 'prob: 10.10', 'utility: 17920')
#  32: ('Name: 179', 'prob: 7.50', 'utility: 17875')
#  33: ('Name: 447', 'prob: 10.23', 'utility: 17856')
#  34: ('Name: 1121', 'prob: 5.14', 'utility: 17802')
#  35: ('Name: 246', 'prob: 9.63', 'utility: 17655')
#  36: ('Name: 422', 'prob: 8.73', 'utility: 17616')
#  37: ('Name: 365', 'prob: 7.45', 'utility: 17424')
#  38: ('Name: 1094', 'prob: 7.26', 'utility: 17342')
#  39: ('Name: 49', 'prob: 7.66', 'utility: 17238')
#  40: ('Name: 907', 'prob: 8.01', 'utility: 17100')
#  41: ('Name: 80', 'prob: 6.92', 'utility: 17060')
#  42: ('Name: 508', 'prob: 8.23', 'utility: 17055')
#  43: ('Name: 111', 'prob: 8.85', 'utility: 17052')
#  44: ('Name: 712', 'prob: 5.84', 'utility: 17028')
#  45: ('Name: 137', 'prob: 6.61', 'utility: 17020')
#  46: ('Name: 1398', 'prob: 6.86', 'utility: 17002')
#  47: ('Name: 320', 'prob: 5.47', 'utility: 16947')
#  48: ('Name: 1345', 'prob: 6.17', 'utility: 16927')
#  49: ('Name: 502', 'prob: 8.39', 'utility: 16801')
#  50: ('Name: 362', 'prob: 5.45', 'utility: 16674')
#  51: ('Name: 1493', 'prob: 7.55', 'utility: 16632')
#  52: ('Name: 11', 'prob: 7.21', 'utility: 16497')
#  53: ('Name: 274', 'prob: 6.55', 'utility: 16456')
#  54: ('Name: 69', 'prob: 10.07', 'utility: 16430')
#  55: ('Name: 776', 'prob: 5.25', 'utility: 16338')
#  56: ('Name: 313', 'prob: 7.94', 'utility: 16245')
#  57: ('Name: 474', 'prob: 6.15', 'utility: 16192')
#  58: ('Name: 530', 'prob: 6.11', 'utility: 16168')
#  59: ('Name: 27', 'prob: 9.44', 'utility: 16165')
#  60: ('Name: 1202', 'prob: 5.02', 'utility: 16154')
#  61: ('Name: 1423', 'prob: 11.75', 'utility: 16116')
#  62: ('Name: 449', 'prob: 9.12', 'utility: 15867')
#  63: ('Name: 532', 'prob: 6.09', 'utility: 15867')
#  64: ('Name: 1516', 'prob: 9.22', 'utility: 15792')
#  65: ('Name: 379', 'prob: 8.34', 'utility: 15785')
#  66: ('Name: 55', 'prob: 8.72', 'utility: 15750')
#  67: ('Name: 1150', 'prob: 6.02', 'utility: 15631')
#  68: ('Name: 1088', 'prob: 7.34', 'utility: 15604')
#  69: ('Name: 832', 'prob: 7.45', 'utility: 15552')
#  70: ('Name: 1159', 'prob: 6.42', 'utility: 15498')
#  71: ('Name: 506', 'prob: 5.25', 'utility: 15456')
#  72: ('Name: 1077', 'prob: 8.05', 'utility: 15455')
#  73: ('Name: 823', 'prob: 8.05', 'utility: 15435')
#  74: ('Name: 1081', 'prob: 7.03', 'utility: 15423')
#  75: ('Name: 639', 'prob: 7.03', 'utility: 15415')
#  76: ('Name: 323', 'prob: 6.38', 'utility: 15400')
#  77: ('Name: 868', 'prob: 5.20', 'utility: 15392')
#  78: ('Name: 1049', 'prob: 6.91', 'utility: 15327')
#  79: ('Name: 235', 'prob: 6.38', 'utility: 15265')
#  80: ('Name: 1389', 'prob: 8.17', 'utility: 15254')
#  81: ('Name: 1093', 'prob: 6.04', 'utility: 15174')
#  82: ('Name: 104', 'prob: 6.89', 'utility: 15171')
#  83: ('Name: 916', 'prob: 11.68', 'utility: 15163')
#  84: ('Name: 1136', 'prob: 6.71', 'utility: 15162')
#  85: ('Name: 419', 'prob: 9.29', 'utility: 14994')
#  86: ('Name: 123', 'prob: 6.40', 'utility: 14976')
#  87: ('Name: 190', 'prob: 5.69', 'utility: 14960')
#  88: ('Name: 464', 'prob: 8.01', 'utility: 14952')
#  89: ('Name: 668', 'prob: 3.34', 'utility: 14933')
#  90: ('Name: 1453', 'prob: 5.21', 'utility: 14928')
#  91: ('Name: 1336', 'prob: 6.20', 'utility: 14916')
#  92: ('Name: 445', 'prob: 6.11', 'utility: 14878')
#  93: ('Name: 520', 'prob: 10.36', 'utility: 14840')
#  94: ('Name: 189', 'prob: 7.29', 'utility: 14835')
#  95: ('Name: 53', 'prob: 6.48', 'utility: 14801')
#  96: ('Name: 1464', 'prob: 9.44', 'utility: 14800')
#  97: ('Name: 491', 'prob: 7.17', 'utility: 14742')
#  98: ('Name: 330', 'prob: 6.08', 'utility: 14726')
#  99: ('Name: 300', 'prob: 7.12', 'utility: 14700')
#  100: ('Name: 812', 'prob: 9.41', 'utility: 14696')
#  101: ('Name: 1254', 'prob: 7.73', 'utility: 14680')
#  102: ('Name: 1387', 'prob: 5.62', 'utility: 14658')
#  103: ('Name: 306', 'prob: 5.37', 'utility: 14652')
#  104: ('Name: 903', 'prob: 11.62', 'utility: 14616')
#  105: ('Name: 1076', 'prob: 6.15', 'utility: 14580')
#  106: ('Name: 231', 'prob: 8.75', 'utility: 14575')
#  107: ('Name: 844', 'prob: 8.48', 'utility: 14564')
#  108: ('Name: 1117', 'prob: 6.93', 'utility: 14560')
#  109: ('Name: 1296', 'prob: 8.60', 'utility: 14548')
#  110: ('Name: 418', 'prob: 7.58', 'utility: 14536')
#  111: ('Name: 283', 'prob: 7.09', 'utility: 14469')
#  112: ('Name: 744', 'prob: 5.96', 'utility: 14467')
#  113: ('Name: 281', 'prob: 8.97', 'utility: 14465')
#  114: ('Name: 218', 'prob: 6.27', 'utility: 14448')
#  115: ('Name: 435', 'prob: 9.24', 'utility: 14433')
#  116: ('Name: 695', 'prob: 6.12', 'utility: 14432')
#  117: ('Name: 1540', 'prob: 7.59', 'utility: 14432')
#  118: ('Name: 1211', 'prob: 4.51', 'utility: 14402')
#  119: ('Name: 1278', 'prob: 6.11', 'utility: 14382')
#  120: ('Name: 1348', 'prob: 8.83', 'utility: 14326')
#  121: ('Name: 1251', 'prob: 8.15', 'utility: 14320')
#  122: ('Name: 835', 'prob: 6.26', 'utility: 14309')
#  123: ('Name: 1063', 'prob: 7.43', 'utility: 14303')
#  124: ('Name: 383', 'prob: 8.89', 'utility: 14300')
#  125: ('Name: 975', 'prob: 3.05', 'utility: 14288')
#  126: ('Name: 811', 'prob: 7.48', 'utility: 14256')
#  127: ('Name: 305', 'prob: 5.24', 'utility: 14238')
#  128: ('Name: 50', 'prob: 4.49', 'utility: 14220')
#  129: ('Name: 20', 'prob: 8.20', 'utility: 14178')
#  130: ('Name: 1555', 'prob: 5.92', 'utility: 14160')
#  131: ('Name: 521', 'prob: 8.02', 'utility: 14155')
#  132: ('Name: 153', 'prob: 7.83', 'utility: 14144')
#  133: ('Name: 554', 'prob: 6.66', 'utility: 14130')
#  134: ('Name: 170', 'prob: 8.45', 'utility: 14080')
#  135: ('Name: 28', 'prob: 6.61', 'utility: 14076')
#  136: ('Name: 924', 'prob: 7.69', 'utility: 14040')
#  137: ('Name: 223', 'prob: 6.97', 'utility: 14036')
#  138: ('Name: 863', 'prob: 8.74', 'utility: 14006')
#  139: ('Name: 609', 'prob: 6.61', 'utility: 13986')
#  140: ('Name: 559', 'prob: 6.48', 'utility: 13983')
#  141: ('Name: 556', 'prob: 7.30', 'utility: 13975')
#  142: ('Name: 946', 'prob: 8.55', 'utility: 13965')
#  143: ('Name: 1104', 'prob: 8.96', 'utility: 13965')
#  144: ('Name: 703', 'prob: 7.98', 'utility: 13959')
#  145: ('Name: 416', 'prob: 5.22', 'utility: 13944')
#  146: ('Name: 1099', 'prob: 6.02', 'utility: 13932')
#  147: ('Name: 136', 'prob: 6.66', 'utility: 13932')
#  148: ('Name: 1269', 'prob: 5.60', 'utility: 13895')
#  149: ('Name: 713', 'prob: 4.86', 'utility: 13840')
#  150: ('Name: 847', 'prob: 4.76', 'utility: 13824')
#  151: ('Name: 16', 'prob: 6.67', 'utility: 13788')
#  152: ('Name: 575', 'prob: 7.44', 'utility: 13769')
#  153: ('Name: 1237', 'prob: 7.68', 'utility: 13750')
#  154: ('Name: 602', 'prob: 10.00', 'utility: 13696')
#  155: ('Name: 1070', 'prob: 7.32', 'utility: 13689')
#  156: ('Name: 986', 'prob: 5.92', 'utility: 13650')
#  157: ('Name: 991', 'prob: 7.01', 'utility: 13650')
#  158: ('Name: 304', 'prob: 14.23', 'utility: 13607')
#  159: ('Name: 1281', 'prob: 9.10', 'utility: 13573')
#  160: ('Name: 950', 'prob: 5.88', 'utility: 13533')
#  161: ('Name: 1160', 'prob: 8.19', 'utility: 13517')
#  162: ('Name: 1197', 'prob: 5.12', 'utility: 13502')
#  163: ('Name: 656', 'prob: 6.41', 'utility: 13475')
#  164: ('Name: 1473', 'prob: 9.40', 'utility: 13452')
#  165: ('Name: 1430', 'prob: 5.64', 'utility: 13440')
#  166: ('Name: 1529', 'prob: 5.82', 'utility: 13407')
#  167: ('Name: 756', 'prob: 7.50', 'utility: 13393')
#  168: ('Name: 141', 'prob: 5.57', 'utility: 13362')
#  169: ('Name: 1417', 'prob: 7.03', 'utility: 13357')
#  170: ('Name: 803', 'prob: 6.49', 'utility: 13338')
#  171: ('Name: 155', 'prob: 5.90', 'utility: 13335')
#  172: ('Name: 717', 'prob: 4.88', 'utility: 13328')
#  173: ('Name: 1119', 'prob: 8.86', 'utility: 13314')
#  174: ('Name: 724', 'prob: 4.73', 'utility: 13230')
#  175: ('Name: 640', 'prob: 9.36', 'utility: 13209')
#  176: ('Name: 1118', 'prob: 9.50', 'utility: 13178')
#  177: ('Name: 1007', 'prob: 7.37', 'utility: 13166')
#  178: ('Name: 896', 'prob: 6.88', 'utility: 13127')
#  179: ('Name: 358', 'prob: 5.76', 'utility: 13125')
#  180: ('Name: 842', 'prob: 3.48', 'utility: 13120')
#  181: ('Name: 322', 'prob: 7.14', 'utility: 13112')
#  182: ('Name: 1340', 'prob: 8.25', 'utility: 13107')
#  183: ('Name: 326', 'prob: 9.77', 'utility: 13091')
#  184: ('Name: 883', 'prob: 8.63', 'utility: 13041')
#  185: ('Name: 105', 'prob: 6.66', 'utility: 13020')
#  186: ('Name: 387', 'prob: 7.12', 'utility: 13014')
#  187: ('Name: 1374', 'prob: 5.84', 'utility: 13005')
#  188: ('Name: 1168', 'prob: 5.47', 'utility: 12988')
#  189: ('Name: 1525', 'prob: 5.16', 'utility: 12969')
#  190: ('Name: 555', 'prob: 7.59', 'utility: 12960')
#  191: ('Name: 922', 'prob: 7.53', 'utility: 12950')
#  192: ('Name: 54', 'prob: 9.51', 'utility: 12889')
#  193: ('Name: 1001', 'prob: 7.11', 'utility: 12852')
#  194: ('Name: 891', 'prob: 6.99', 'utility: 12844')
#  195: ('Name: 261', 'prob: 7.52', 'utility: 12844')
#  196: ('Name: 933', 'prob: 6.11', 'utility: 12844')
#  197: ('Name: 676', 'prob: 6.04', 'utility: 12824')
#  198: ('Name: 853', 'prob: 7.52', 'utility: 12804')
#  199: ('Name: 890', 'prob: 9.18', 'utility: 12789')
#  200: ('Name: 1416', 'prob: 7.62', 'utility: 12788')
#  201: ('Name: 1073', 'prob: 5.46', 'utility: 12765')
#  202: ('Name: 1472', 'prob: 8.86', 'utility: 12760')
#  203: ('Name: 606', 'prob: 8.66', 'utility: 12720')
#  204: ('Name: 8', 'prob: 6.47', 'utility: 12691')
#  205: ('Name: 1165', 'prob: 8.01', 'utility: 12690')
#  206: ('Name: 234', 'prob: 7.22', 'utility: 12690')
#  207: ('Name: 789', 'prob: 7.51', 'utility: 12670')
#  208: ('Name: 568', 'prob: 6.31', 'utility: 12654')
#  209: ('Name: 1248', 'prob: 6.25', 'utility: 12653')
#  210: ('Name: 1308', 'prob: 9.18', 'utility: 12642')
#  211: ('Name: 1291', 'prob: 9.65', 'utility: 12642')
#  212: ('Name: 1547', 'prob: 9.00', 'utility: 12614')
#  213: ('Name: 519', 'prob: 6.46', 'utility: 12606')
#  214: ('Name: 1384', 'prob: 8.61', 'utility: 12593')
#  215: ('Name: 1324', 'prob: 7.25', 'utility: 12578')
#  216: ('Name: 678', 'prob: 5.56', 'utility: 12546')
#  217: ('Name: 580', 'prob: 8.45', 'utility: 12532')
#  218: ('Name: 394', 'prob: 6.77', 'utility: 12520')
#  219: ('Name: 659', 'prob: 5.56', 'utility: 12519')
#  220: ('Name: 599', 'prob: 10.79', 'utility: 12519')
#  221: ('Name: 1241', 'prob: 7.62', 'utility: 12516')
#  222: ('Name: 708', 'prob: 4.47', 'utility: 12512')
#  223: ('Name: 193', 'prob: 5.91', 'utility: 12510')
#  224: ('Name: 884', 'prob: 5.81', 'utility: 12480')
#  225: ('Name: 825', 'prob: 8.29', 'utility: 12452')
#  226: ('Name: 1467', 'prob: 5.23', 'utility: 12416')
#  227: ('Name: 1390', 'prob: 11.26', 'utility: 12415')
#  228: ('Name: 493', 'prob: 8.31', 'utility: 12408')
#  229: ('Name: 63', 'prob: 6.74', 'utility: 12390')
#  230: ('Name: 484', 'prob: 5.42', 'utility: 12376')
#  231: ('Name: 742', 'prob: 7.80', 'utility: 12350')
#  232: ('Name: 915', 'prob: 7.67', 'utility: 12341')
#  233: ('Name: 1146', 'prob: 6.20', 'utility: 12336')
#  234: ('Name: 1213', 'prob: 6.35', 'utility: 12301')
#  235: ('Name: 44', 'prob: 8.34', 'utility: 12298')
#  236: ('Name: 489', 'prob: 6.90', 'utility: 12291')
#  237: ('Name: 321', 'prob: 8.28', 'utility: 12291')
#  238: ('Name: 882', 'prob: 7.54', 'utility: 12201')
#  239: ('Name: 407', 'prob: 4.64', 'utility: 12198')
#  240: ('Name: 467', 'prob: 5.82', 'utility: 12192')
#  241: ('Name: 200', 'prob: 9.80', 'utility: 12190')
#  242: ('Name: 414', 'prob: 8.49', 'utility: 12188')
#  243: ('Name: 584', 'prob: 8.80', 'utility: 12173')
#  244: ('Name: 1313', 'prob: 5.99', 'utility: 12152')
#  245: ('Name: 1272', 'prob: 7.02', 'utility: 12152')
#  246: ('Name: 82', 'prob: 7.45', 'utility: 12150')
#  247: ('Name: 68', 'prob: 6.55', 'utility: 12104')
#  248: ('Name: 512', 'prob: 5.63', 'utility: 12056')
#  249: ('Name: 191', 'prob: 7.54', 'utility: 12054')
#  250: ('Name: 774', 'prob: 7.90', 'utility: 12005')
#  251: ('Name: 1206', 'prob: 4.22', 'utility: 12004')
#  252: ('Name: 963', 'prob: 7.30', 'utility: 12000')
#  253: ('Name: 1264', 'prob: 9.35', 'utility: 11985')
#  254: ('Name: 1019', 'prob: 7.56', 'utility: 11968')
#  255: ('Name: 1428', 'prob: 4.59', 'utility: 11966')
#  256: ('Name: 149', 'prob: 7.13', 'utility: 11952')
#  257: ('Name: 1047', 'prob: 6.06', 'utility: 11951')
#  258: ('Name: 1342', 'prob: 5.38', 'utility: 11936')
#  259: ('Name: 952', 'prob: 6.61', 'utility: 11931')
#  260: ('Name: 1184', 'prob: 6.96', 'utility: 11928')
#  261: ('Name: 121', 'prob: 6.16', 'utility: 11920')
#  262: ('Name: 1074', 'prob: 5.45', 'utility: 11894')
#  263: ('Name: 1538', 'prob: 7.26', 'utility: 11893')
#  264: ('Name: 634', 'prob: 11.88', 'utility: 11881')
#  265: ('Name: 726', 'prob: 5.19', 'utility: 11877')
#  266: ('Name: 219', 'prob: 9.27', 'utility: 11844')
#  267: ('Name: 1279', 'prob: 7.18', 'utility: 11840')
#  268: ('Name: 1495', 'prob: 5.24', 'utility: 11832')
#  269: ('Name: 886', 'prob: 4.74', 'utility: 11818')
#  270: ('Name: 1142', 'prob: 7.54', 'utility: 11800')
#  271: ('Name: 673', 'prob: 8.20', 'utility: 11782')
#  272: ('Name: 1343', 'prob: 6.10', 'utility: 11767')
#  273: ('Name: 749', 'prob: 10.03', 'utility: 11748')
#  274: ('Name: 800', 'prob: 7.39', 'utility: 11729')
#  275: ('Name: 1048', 'prob: 9.43', 'utility: 11713')
#  276: ('Name: 221', 'prob: 5.29', 'utility: 11712')
#  277: ('Name: 526', 'prob: 4.86', 'utility: 11700')
#  278: ('Name: 1220', 'prob: 10.18', 'utility: 11700')
#  279: ('Name: 569', 'prob: 5.47', 'utility: 11692')
#  280: ('Name: 691', 'prob: 7.26', 'utility: 11685')
#  281: ('Name: 1357', 'prob: 9.10', 'utility: 11653')
#  282: ('Name: 415', 'prob: 7.88', 'utility: 11640')
#  283: ('Name: 819', 'prob: 8.06', 'utility: 11634')
#  284: ('Name: 751', 'prob: 6.76', 'utility: 11607')
#  285: ('Name: 260', 'prob: 8.51', 'utility: 11592')
#  286: ('Name: 610', 'prob: 6.23', 'utility: 11577')
#  287: ('Name: 308', 'prob: 10.94', 'utility: 11554')
#  288: ('Name: 728', 'prob: 9.17', 'utility: 11528')
#  289: ('Name: 1502', 'prob: 6.14', 'utility: 11521')
#  290: ('Name: 357', 'prob: 11.97', 'utility: 11520')
#  291: ('Name: 534', 'prob: 7.46', 'utility: 11491')
#  292: ('Name: 1208', 'prob: 4.57', 'utility: 11480')
#  293: ('Name: 1465', 'prob: 6.69', 'utility: 11430')
#  294: ('Name: 270', 'prob: 6.02', 'utility: 11424')
#  295: ('Name: 417', 'prob: 4.68', 'utility: 11424')
#  296: ('Name: 1367', 'prob: 5.47', 'utility: 11424')
#  297: ('Name: 452', 'prob: 5.00', 'utility: 11408')
#  298: ('Name: 1252', 'prob: 7.48', 'utility: 11391')
#  299: ('Name: 1116', 'prob: 7.73', 'utility: 11377')

# %%
# chạy với chess
algorithm = UHUOPM()
algorithm.run_UHUOPM("./data/input_chess.txt, ./data/chess_utility.txt", 25)
algorithm.print_stats("./out/UHUOPM/chess/output_chess_top_25.txt")

# %%
# chạy với chess
algorithm = UHUOPM()
algorithm.run_UHUOPM("./data/input_chess.txt, ./data/chess_utility.txt", 50)
algorithm.print_stats("./out/UHUOPM/chess/output_chess_top_50.txt")

# %%
# chạy với chess
algorithm = UHUOPM()
algorithm.run_UHUOPM("./data/input_chess.txt, ./data/chess_utility.txt", 75)
algorithm.print_stats("./out/UHUOPM/output_chess_top_75.txt")

# %%
# chạy với chess
algorithm = UHUOPM()
algorithm.run_UHUOPM("./data/input_chess.txt, ./data/chess_utility.txt", 100)
algorithm.print_stats("./out/UHUOPM/output_chess_top_100.txt")
# Out:
# Reading data . . .
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_2884\34182722.py", line 3, in <module>
#     algorithm.run_UHUOPM("./data/input_chess.txt, ./data/chess_utility.txt", 100)
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_2884\705314200.py", line 167, in run_UHUOPM
#     self.PHUOP_Search("", self.item_name, k)
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_2884\705314200.py", line 276, in PHUOP_Search
#     if self.pfu_table_dict.get(x_b).pro > self.min_sup and self.calculate_lu(x_a, x_b) > self.calculate_emu(x_a, x_b):
#                                                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_2884\705314200.py", line -1, in calculate_lu
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\executing\executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
# chạy với chess
algorithm = UHUOPM()
algorithm.run_UHUOPM("./data/input_chess.txt, ./data/chess_utility.txt", 125)
algorithm.print_stats("./out/UHUOPM/output_chess_top_125.txt")

# %%
# chạy với chess
algorithm = UHUOPM()
algorithm.run_UHUOPM("./data/input_chess.txt, ./data/chess_utility.txt", 150)
algorithm.print_stats("./out/UHUOPM/output_chess_top_150.txt")

# %%
algorithm = UHUOPM()
algorithm.run_UHUOPM("./data/input_retail.txt, ./data/retail_utility.txt", 100)
algorithm.print_stats("./out/UHUOPM/output_retail_top_100.txt")

# %%
algorithm = UHUOPM()
algorithm.run_UHUOPM("./data/input_pumsb2.txt, ./data/pumsb_utility.txt", 0.0005, 0.005, 0.0005, 300)
